# %% [markdown]
# # Combination of topic modelling, word embeddings and synomyms from an external ontology, for the identification of statistical datasets
#
# ## Adjusted (June 2022), to take into account related terms from ConceptNet (using two methods).
# * Carry-out topic modelling with a large enough corpus (Statistics Explained articles and Statistics Explained Glossary articles) and a large number of topics (1000) and extract **significant** (lemmatized) keywords. The objectives are two:
#     * to cover the whole corpus and thus the "correlated" datasets at a high granularity,
#     * avoid using common ("dominating") words in the matches with the user's query.
#
# * Enhance these keywords with their closest terms from the word embeddings created exclusively from Eurostat's content.
#
# *    The total large number of keywords can then differentiate the datasets.
#
# *    Enrich the user's query with close words from the word vectors and related words from ConceptNet (using two methods).
#
# * Put **first priority** to the matches with words in the enhanced topic modelling dictionary and **second** to the matches with any other words, to avoid "dominating" terms.
#
# ### Installation instructions
# This is a Google Colab notebook. You must have a Google account with a Google Drive to store the model and allow re-runs without re-creating the model. Please allow the code to access your Google Drive.
#
# *    You should have uploaded the externalAPI.ipynb notebook in your Google drive. A copy is included in [/Use Case C Topic modelling and Word embeddings/](https://github.com/eurostat/NLP4Stat/tree/testing/Use%20case%20C/Use%20Case%20C%20Topic%20modelling%20and%20Word%20embeddings).
# *    The notebook also expects to read from your Google Drive a copy of the word vectors produced by the codes in [Use Case C Word embeddings](https://github.com/eurostat/NLP4Stat/tree/testing/Use%20case%20C/Use%20Case%20C%20Word%20embeddings), in file SE_GL_wordvectors.txt - see chunk with title "Import the saved word vectors". This is available in the [Use Case C Word embeddings](https://github.com/eurostat/NLP4Stat/tree/testing/Use%20case%20C/Use%20Case%20C%20Word%20embeddings) folder.
# *   Launch the notebook and put your own credentials in the pyodbc.connect() call in the chunk with title "Connect to the Virtuoso database".
#
# ### The run time can be reduced by loading (rather than re-creating) the topic modelling LDA model and by de-activating the coherence calculations

# %% [markdown]
# ###Connect Google Drive

# %%
## To store the LDA model (allowing re-runs starting from re-loading the model)
## and also read the saved word vectors

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import the externalAPI notebook from the location you have uploaded it.

# %%
# %cd "/content/drive/MyDrive/ExternalAPI"
# Out:
# /content/drive/MyDrive/ExternalAPI

# %%
# !pip install import-ipynb 
import import_ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (7.9.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.6.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.1 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.11.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (2.16.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.12.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.18.1

# %%
import externalAPI
from externalAPI import conceptNet
from externalAPI import simpleCN_list
# Out:
# importing Jupyter notebook from externalAPI.ipynb
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nltk==3.4
#   Downloading nltk-3.4.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.4) (1.15.0)
# Collecting singledispatch
#   Downloading singledispatch-3.7.0-py2.py3-none-any.whl (9.2 kB)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4-py3-none-any.whl size=1436399 sha256=d37178650403534162d3a00c235b0b1a5f7eba08495224c578ba1196ce5ff398
#   Stored in directory: /root/.cache/pip/wheels/13/b8/81/2349be11dd144dc7b68ab983b58cd2fae353cdc50bbdeb09d0
# Successfully built nltk
# Installing collected packages: singledispatch, nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed nltk-3.4 singledispatch-3.7.0
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Installations

# %%
# !pip install pyodbc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyodbc
#   Downloading pyodbc-4.0.34-cp37-cp37m-manylinux_2_24_x86_64.whl (472 kB)
#      |████████████████████████████████| 472 kB 5.0 MB/s
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.34

# %%
# !pip install eurostat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting eurostat
#   Downloading eurostat-0.2.3-py3-none-any.whl (11 kB)
# Collecting pandasdmx<=0.9
#   Downloading pandaSDMX-0.9-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from eurostat) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from eurostat) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandasdmx<=0.9->eurostat) (4.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pandasdmx<=0.9->eurostat) (57.4.0)
# Collecting jsonpath-rw
#   Downloading jsonpath-rw-1.4.0.tar.gz (13 kB)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.6 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from jsonpath-rw->pandasdmx<=0.9->eurostat) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from jsonpath-rw->pandasdmx<=0.9->eurostat) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->eurostat) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->eurostat) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->eurostat) (2.8.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (2022.6.15)
# Building wheels for collected packages: jsonpath-rw
#   Building wheel for jsonpath-rw (setup.py) ... done
#   Created wheel for jsonpath-rw: filename=jsonpath_rw-1.4.0-py3-none-any.whl size=15147 sha256=6a98caa3fc9ee15d65f21f10ae10b8f5016d5bbe848c8aa7c97a6f316601eb23
#   Stored in directory: /root/.cache/pip/wheels/58/88/2a/8d619cf38d7cf939e54b6ccdece05d31b64b3eb419c11d1ed3
# Successfully built jsonpath-rw
# Installing collected packages: ply, jsonpath-rw, pandasdmx, eurostat
# Successfully installed eurostat-0.2.3 jsonpath-rw-1.4.0 pandasdmx-0.9 ply-3.11

# %%
## !pip install nltk==3.4 ## needs latest version

# %%
# !apt-get install virtuoso-opensource
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libvirtodbc0 virtuoso-opensource-6.1 virtuoso-opensource-6.1-bin
#   virtuoso-opensource-6.1-common virtuoso-server virtuoso-vad-conductor
#   virtuoso-vsp-startpage
# Suggested packages:
#   virtuoso-vad-doc virtuoso-vad-demo virtuoso-vad-tutorial
#   virtuoso-vad-rdfmappers virtuoso-vad-sparqldemo virtuoso-vad-syncml
#   virtuoso-vad-bpel virtuoso-vad-isparql virtuoso-vad-ods virtuoso-vad-dbpedia
#   virtuoso-vad-facetedbrowser
# The following NEW packages will be installed:
#   libvirtodbc0 virtuoso-opensource virtuoso-opensource-6.1
#   virtuoso-opensource-6.1-bin virtuoso-opensource-6.1-common virtuoso-server
#   virtuoso-vad-conductor virtuoso-vsp-startpage
# 0 upgraded, 8 newly installed, 0 to remove and 20 not upgraded.
# Need to get 4,835 kB of archives.
# After this operation, 27.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1-common amd64 6.1.6+repack-0ubuntu9 [45.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1-bin amd64 6.1.6+repack-0ubuntu9 [2,831 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvirtodbc0 amd64 6.1.6+repack-0ubuntu9 [259 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1 amd64 6.1.6+repack-0ubuntu9 [163 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource all 6.1.6+repack-0ubuntu9 [33.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-vad-conductor all 6.1.6+repack-0ubuntu9 [1,044 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-vsp-startpage all 6.1.6+repack-0ubuntu9 [428 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-server all 6.1.6+repack-0ubuntu9 [31.0 kB]
# Fetched 4,835 kB in 1s (4,393 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package virtuoso-opensource-6.1-common.
# (Reading database ... 155676 files and directories currently installed.)
# Preparing to unpack .../0-virtuoso-opensource-6.1-common_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1-common (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource-6.1-bin.
# Preparing to unpack .../1-virtuoso-opensource-6.1-bin_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1-bin (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package libvirtodbc0.
# Preparing to unpack .../2-libvirtodbc0_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking libvirtodbc0 (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource-6.1.
# Preparing to unpack .../3-virtuoso-opensource-6.1_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1 (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource.
# Preparing to unpack .../4-virtuoso-opensource_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-opensource (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-vad-conductor.
# Preparing to unpack .../5-virtuoso-vad-conductor_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-vad-conductor (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-vsp-startpage.
# Preparing to unpack .../6-virtuoso-vsp-startpage_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-vsp-startpage (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-server.
# Preparing to unpack .../7-virtuoso-server_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-server (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1-bin (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1-common (6.1.6+repack-0ubuntu9) ...
# Setting up libvirtodbc0 (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1 (6.1.6+repack-0ubuntu9) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up virtuoso-opensource (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-server (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-vad-conductor (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-vsp-startpage (6.1.6+repack-0ubuntu9) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for systemd (237-3ubuntu10.53) ...

# %% [markdown]
# ### Imports

# %%
import gensim
import pandas as pd
import numpy as np

import re

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

import pyodbc

# %% [markdown]
# ###Connect to the Virtuoso database

# %%
c = pyodbc.connect('DRIVER=/usr/lib/odbc/virtodbc.so;HOST=lod.csd.auth.gr:1111;UID=xxxxx;PWD=xxxxx;DATABASE=ESTAT')

# %%
#set encoding
c.setdecoding(pyodbc.SQL_CHAR, encoding='latin-1')
c.setencoding(encoding="latin-1")

# %%
cursor = c.cursor()

# %%
def load_table(cursor,query):
  cursor.execute(query)
  t1 = cursor.fetchall()
  df = pd.DataFrame.from_records(t1, columns=[x[0] for x in cursor.description])
  return df

# %% [markdown]
# ### Statistics Explained Glossary articles
#
# * Definitions from dat_glossary.
# * Titles from dat_link_info (with resource_information_id=1, i.e. Eurostat, see ESTAT.V1.mod_resource_information).
# * Match above on id.

# %%
query =      """SELECT T1.id, T1.definition, T2.title 
                FROM ESTAT.V1.dat_glossary as T1 
                INNER JOIN ESTAT.V1.dat_link_info as T2  
                  ON T1.id=T2.id 
                WHERE T2.resource_information_id=1 """

GL_df = load_table(cursor,query)
GL_df = GL_df[['id', 'title', 'definition']]

GL_df
# Out:
#          id                                              title  \
# 0         1                             Accident at work
# 1         5                          Fatal accident at work
# 2         6                      Non-fatal accident at work
# 3         8                             Aggregate demand
# 4         9                      Goods and services account
# ...     ...                                                ...
# 1309   2319          Actual individual consumption (AIC)
# 1310   2321                                Activity rate
# 1311   2322                          Activation policies
# 1312   2324                   Active enterprises - FRIBS
# 1313  10554                                           Glossary
#
#                                              definition
# 0       An     accident at work    in the framework ...
# 1       A     fatal accident at work    refers to an...
# 2       A     non-fatal      accident at work     is...
# 3        Aggregate demand    is the total amount of ...
# 4       The     goods and services account    shows ...
# ...                                                 ...
# 1309     Actual individual consumption    , abbrevia...
# 1310     Activity rate    is the percentage of     a...
# 1311    The     activation policies    are policies ...
# 1312    <Brief user-oriented definition, one or a fe...
# 1313  The Glossary contains short definitions of all...
#
# [1314 rows x 3 columns]

# %% [markdown]
# ### Delete records with empty definitions and carry out data cleansing

# %%
GL_df = GL_df.dropna(axis=0,how='any')
print(GL_df.isnull().sum())
GL_df.reset_index(drop=True, inplace=True)

import unicodedata as ud

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) 
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) 

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    ## x = re.sub(r'a.{2}',"'",x) ### !!! NEW: single quotes are read as: aXX
    
    x = x.encode('latin1').decode('utf-8') ## a\x80\x99
    x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x


GL_df['title'] = GL_df['title'].apply(clean)
GL_df['title'] = GL_df['title'].apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes
GL_df['definition'] = GL_df['definition'].apply(clean)

GL_df
# Out:
# id            0
# title         0
# definition    0
# dtype: int64
#          id                                title  \
# 0         1                     Accident at work
# 1         5               Fatal accident at work
# 2         6           Non-fatal accident at work
# 3         8                     Aggregate demand
# 4         9           Goods and services account
# ...     ...                                  ...
# 1309   2319  Actual individual consumption (AIC)
# 1310   2321                        Activity rate
# 1311   2322                  Activation policies
# 1312   2324           Active enterprises - FRIBS
# 1313  10554                             Glossary
#
#                                              definition
# 0     An accident at work in the framework of the ad...
# 1     A fatal accident at work refers to an accident...
# 2     A non-fatal accident at work is an accident wh...
# 3     Aggregate demand is the total amount of goods ...
# 4     The goods and services account shows the balan...
# ...                                                 ...
# 1309  Actual individual consumption, abbreviated as ...
# 1310  Activity rate is the percentage of active pers...
# 1311  The activation policies are policies designed ...
# 1312  <Brief user-oriented definition, one or a few ...
# 1313  The Glossary contains short definitions of all...
#
# [1314 rows x 3 columns]

# %% [markdown]
# ### Delete "special" records
#
# * i.e. redirections.

# %%
## Drop The records with definitions "The revision ..." and "Redirect to ..." 

idx = GL_df[GL_df['definition'].str.startswith('The revision #')].index
print(idx)
GL_df.drop(idx , inplace=True)
idx = GL_df[GL_df['definition'].str.startswith('Redirect to')].index
print(idx)
GL_df.drop(idx , inplace=True)
GL_df.reset_index(drop=True, inplace=True)
GL_df
# Out:
# Int64Index([ 230,  292,  384,  386,  433,  436,  438,  439,  504,  519,  530,
#              557,  588,  729,  742,  775,  826,  889,  891,  912,  960,  961,
#              969, 1003, 1007, 1133, 1144, 1182, 1231],
#            dtype='int64')
# Int64Index([], dtype='int64')
#          id                                title  \
# 0         1                     Accident at work
# 1         5               Fatal accident at work
# 2         6           Non-fatal accident at work
# 3         8                     Aggregate demand
# 4         9           Goods and services account
# ...     ...                                  ...
# 1280   2319  Actual individual consumption (AIC)
# 1281   2321                        Activity rate
# 1282   2322                  Activation policies
# 1283   2324           Active enterprises - FRIBS
# 1284  10554                             Glossary
#
#                                              definition
# 0     An accident at work in the framework of the ad...
# 1     A fatal accident at work refers to an accident...
# 2     A non-fatal accident at work is an accident wh...
# 3     Aggregate demand is the total amount of goods ...
# 4     The goods and services account shows the balan...
# ...                                                 ...
# 1280  Actual individual consumption, abbreviated as ...
# 1281  Activity rate is the percentage of active pers...
# 1282  The activation policies are policies designed ...
# 1283  <Brief user-oriented definition, one or a few ...
# 1284  The Glossary contains short definitions of all...
#
# [1285 rows x 3 columns]

# %% [markdown]
# ### Create column "raw content" with the titles and the definitions

# %%
GL_df['raw content'] = GL_df['title'] +'. '+GL_df['definition']
#GL_df['source'] = 'GL'
#GL_df = GL_df[['id','title','raw content','source']]
GL_df = GL_df[['id','title','raw content']]
GL_df
# Out:
#          id                                title  \
# 0         1                     Accident at work
# 1         5               Fatal accident at work
# 2         6           Non-fatal accident at work
# 3         8                     Aggregate demand
# 4         9           Goods and services account
# ...     ...                                  ...
# 1280   2319  Actual individual consumption (AIC)
# 1281   2321                        Activity rate
# 1282   2322                  Activation policies
# 1283   2324           Active enterprises - FRIBS
# 1284  10554                             Glossary
#
#                                             raw content
# 0     Accident at work. An accident at work in the f...
# 1     Fatal accident at work. A fatal accident at wo...
# 2     Non-fatal accident at work. A non-fatal accide...
# 3     Aggregate demand. Aggregate demand is the tota...
# 4     Goods and services account. The goods and serv...
# ...                                                 ...
# 1280  Actual individual consumption (AIC). Actual in...
# 1281  Activity rate. Activity rate is the percentage...
# 1282  Activation policies. The activation policies a...
# 1283  Active enterprises - FRIBS. <Brief user-orient...
# 1284  Glossary. The Glossary contains short definiti...
#
# [1285 rows x 3 columns]

# %% [markdown]
# ### Statistics Explained articles
#
# * IDs, titles from dat_link_info, with resource_information_id=1, i.e. Eurostat (see ESTAT.V1.mod_resource_information) and matching IDs from dat_article.
# * Carry out data cleansing on titles.

# %%
query =      """SELECT id, title 
                FROM ESTAT.V1.dat_link_info 
                WHERE resource_information_id=1 AND id IN (SELECT id FROM ESTAT.V1.dat_article) """

SE_df = load_table(cursor,query)

SE_df['title'] = SE_df['title'].apply(clean)
SE_df
# Out:
#         id                                              title
# 0        7                       Accidents at work statistics
# 1       13                          National accounts and GDP
# 2       16                Railway safety statistics in the EU
# 3       17               Railway freight transport statistics
# 4       18  Railway passenger transport statistics - quart...
# ..     ...                                                ...
# 887  10506  Methods for compiling PEEIs in short-term busi...
# 888  10531  Building the System of National Accounts - adm...
# 889  10539                       Asylum statistics introduced
# 890  10555                                Statistical article
# 891  10556                                 Background article
#
# [892 rows x 2 columns]

# %% [markdown]
# ### Add paragraphs titles and contents
#
# * From dat_article_paragraph with abstract=0 (i.e. "no").
# * Match article_id from dat_article_paragraph with id from dat_article.
# * Carry out data cleansing on titles and paragraph contents.

# %%
query =      """SELECT T1.id,T1.article_id, T1.title, T1.content
                FROM ESTAT.V1.dat_article_paragraph as T1
                INNER JOIN ESTAT.V1.dat_article as T2
                ON T1.article_id = T2.id
                WHERE T1.abstract=0 """

add_content = load_table(cursor,query)
add_content['title'] = add_content['title'].apply(clean)
add_content['content'] = add_content['content'].apply(clean)
add_content
# Out:
#         id  article_id                                              title  \
# 0        1        2905  Absences from work sharply increase in first h...
# 1        2        2905  Absences: 9.5 % of employment in Q4 2019 and 1...
# 2        3        2905  Higher share of absences from work among women...
# 3        4        2905  Absences from work due to own illness or disab...
# 4        5        2905                 Absences from work due to holidays
# ...    ...         ...                                                ...
# 3854  4744       10539                General presentation and definition
# 3855  4745       10539        Methodological aspects in asylum statistics
# 3856  4746       10539        Methodological aspects in Dublin statistics
# 3857  4747       10539  What questions can or cannot be answered with ...
# 3858  4748       10539                                     Policy context
#
#                                                 content
# 0     Absences from work recorded unprecedented high...
# 1     The article's next figure (Figure 4) compares ...
# 2     Considering all four quarters of 2020, the sha...
# 3     From Q4 2019 to Q4 2020, the number of people ...
# 4     Expressed as a share of employed people, absen...
# ...                                                 ...
# 3854  Scope of asylum statistics and Dublin statisti...
# 3855  Annual aggregate of the number of asylum appli...
# 3856  Asymmetries For most of the collected Dublin s...
# 3857  How many asylum seekers are entering EU Member...
# 3858  The collected asylum statistics and Dublin sta...
#
# [3859 rows x 4 columns]

# %% [markdown]
# ### Aggregate above paragraph titles and contents  from SE articles paragraphs by article id
#
# * Create a column _raw content_ which gathers all paragraph titles and contents in one text per article.

# %%
add_content_grouped = add_content.groupby(['article_id'])[['title','content']].aggregate(lambda x: list(x))
add_content_grouped.reset_index(drop=False, inplace=True)
for i in range(len(add_content_grouped)):
    add_content_grouped.loc[i,'raw content'] = ''
    for (a,b) in zip(add_content_grouped.loc[i,'title'],add_content_grouped.loc[i,'content']):
        add_content_grouped.loc[i,'raw content'] += ' '+a + ' ' + b
add_content_grouped = add_content_grouped[['article_id','raw content']]    

add_content_grouped
# Out:
#      article_id                                        raw content
# 0             7   Number of accidents In 2018, there were 3.1 m...
# 1            13   Developments for GDP in the EU-27: growth sin...
# 2            16   Fall in the number of railway accidents 9 % f...
# 3            17   Downturn for EU transport performance in 2019...
# 4            18   Rail passenger transport performance continue...
# ..          ...                                                ...
# 860       10456   Problem After successfully identifying and jo...
# 861       10470   Problem In France, there was significant room...
# 862       10506   General overview Nine PEEIs concern short-ter...
# 863       10531   What are administrative sources? The term adm...
# 864       10539   Main points Asylum statistics and Dublin stat...
#
# [865 rows x 2 columns]

# %% [markdown]
# ### Merge raw content of SE articles with main file
#
# * Add the title to column "raw content".

# %%
SE_df = pd.merge(SE_df,add_content_grouped,left_on='id',right_on='article_id',how='inner')
SE_df.drop(['article_id'],axis=1,inplace=True)

SE_df['raw content'] = SE_df['title'] +'. ' + SE_df['raw content']
#SE_df['source'] = 'SE'
#SE_df = SE_df[['id','title','raw content','source']]
SE_df = SE_df[['id','title','raw content']]

SE_df
# Out:
#         id                                              title  \
# 0        7                       Accidents at work statistics
# 1       13                          National accounts and GDP
# 2       16                Railway safety statistics in the EU
# 3       17               Railway freight transport statistics
# 4       18  Railway passenger transport statistics - quart...
# ..     ...                                                ...
# 860  10456  Merging statistics and geospatial information,...
# 861  10470  Merging statistics and geospatial information,...
# 862  10506  Methods for compiling PEEIs in short-term busi...
# 863  10531  Building the System of National Accounts - adm...
# 864  10539                       Asylum statistics introduced
#
#                                            raw content
# 0    Accidents at work statistics.  Number of accid...
# 1    National accounts and GDP.  Developments for G...
# 2    Railway safety statistics in the EU.  Fall in ...
# 3    Railway freight transport statistics.  Downtur...
# 4    Railway passenger transport statistics - quart...
# ..                                                 ...
# 860  Merging statistics and geospatial information,...
# 861  Merging statistics and geospatial information,...
# 862  Methods for compiling PEEIs in short-term busi...
# 863  Building the System of National Accounts - adm...
# 864  Asylum statistics introduced.  Main points Asy...
#
# [865 rows x 3 columns]

# %% [markdown]
# ### Concatenate the two dataframes

# %%
all_df = pd.concat([GL_df[['id','title','raw content']],SE_df[['id','title','raw content']]],ignore_index=True)
all_df
# Out:
#          id                                              title  \
# 0         1                                   Accident at work
# 1         5                             Fatal accident at work
# 2         6                         Non-fatal accident at work
# 3         8                                   Aggregate demand
# 4         9                         Goods and services account
# ...     ...                                                ...
# 2145  10456  Merging statistics and geospatial information,...
# 2146  10470  Merging statistics and geospatial information,...
# 2147  10506  Methods for compiling PEEIs in short-term busi...
# 2148  10531  Building the System of National Accounts - adm...
# 2149  10539                       Asylum statistics introduced
#
#                                             raw content
# 0     Accident at work. An accident at work in the f...
# 1     Fatal accident at work. A fatal accident at wo...
# 2     Non-fatal accident at work. A non-fatal accide...
# 3     Aggregate demand. Aggregate demand is the tota...
# 4     Goods and services account. The goods and serv...
# ...                                                 ...
# 2145  Merging statistics and geospatial information,...
# 2146  Merging statistics and geospatial information,...
# 2147  Methods for compiling PEEIs in short-term busi...
# 2148  Building the System of National Accounts - adm...
# 2149  Asylum statistics introduced.  Main points Asy...
#
# [2150 rows x 3 columns]

# %%
del SE_df, GL_df

# %% [markdown]
# ### Pre-processing input data (cont)
#
# Next we define a function _lemmatize_text()_ which accepts a string and:
# * Tokenizes the string and keeps only non-stop alphanumeric tokens (but not numbers only).
# * Keeps tokens with minimum length 5.
# * Lemmatizes the tokens.
#
# We call this function with the articles definitions in column "raw content" of dataframe _all_df_. The result, _texts_ is a nested list with 2150 outer elements corresponding to the SE Glossary and the SE articles. The inner lists contain the tokens for each text.

# %%
import nltk

nltk.download('wordnet')
nltk.download('stopwords')

from nltk.corpus import stopwords

w_tokenizer = nltk.tokenize.WordPunctTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

stop = stopwords.words('english')

def lemmatize_text(text): ## only alphanumeric characters and drop stop-words
    return [lemmatizer.lemmatize(w).lower() for w in w_tokenizer.tokenize(text) if w.isalnum() and not w.lower() in stop
           and not re.match(r'^[0-9]+$',w) and len(w) >=5]

all_df['raw content']=all_df['raw content'].apply(lambda x: lemmatize_text(x))

texts = all_df['raw content'].to_list()

print('\nFirst text: \n',texts[:1])
print('\nTotal texts: ',len(texts),'\n')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# First text:
#  [['accident', 'accident', 'framework', 'administrative', 'collection', 'european', 'statistics', 'accidents', 'discrete', 'occurrence', 'course', 'lead', 'physical', 'mental', 'phrase', 'course', 'mean', 'whilst', 'engaged', 'occupational', 'activity', 'spent', 'includes', 'case', 'traffic', 'accident', 'course', 'excludes', 'accident', 'journey', 'workplace', 'definition', 'accident', 'module', 'accidents', 'related', 'health', 'problem', 'labour', 'force', 'survey', 'principle', 'exception', 'accident', 'mental', 'excluded', 'difficult', 'distinguish', 'relevant', 'related', 'health', 'problem', 'following', 'type', 'accident', 'covered', 'respectively', 'definition', 'cases', 'included', 'cases', 'acute', 'poisoning', 'wilful', 'person', 'accidents', 'occurred', 'premise', 'employer', 'employ', 'victim', 'might', 'include', 'accident', 'attendance', 'meeting', 'course', 'providing', 'service', 'premise', 'another', 'employer', 'visited', 'purpose', 'course', 'victim', 'accidents', 'occur', 'meeting', 'visit', 'location', 'outside', 'premise', 'employer', 'employee', 'normally', 'based', 'accident', 'regular', 'break', 'including', 'lunch', 'place', 'organised', 'employer', 'accident', 'delivery', 'good', 'customer', 'premise', 'company', 'public', 'administration', 'private', 'individual', 'carrying', 'service', 'repair', 'maintenance', 'errand', 'client', 'premise', 'permanent', 'secondment', 'another', 'employer', 'activity', 'course', 'accident', 'caused', 'activity', 'related', 'victim', 'activity', 'accident', 'public', 'place', 'public', 'mean', 'transport', 'journey', 'course', 'traffic', 'accident', 'course', 'public', 'road', 'park', 'private', 'road', 'within', 'premise', 'enterprise', 'accident', 'involve', 'person', 'whose', 'occupational', 'activity', 'exerted', 'mainly', 'public', 'road', 'lorry', 'coach', 'driver', 'occupational', 'activity', 'frequently', 'occasionally', 'imply', 'journey', 'public', 'road', 'occupational', 'activity', 'include', 'repair', 'commercial', 'activity', 'service', 'activity', 'carried', 'premise', 'customer', 'category', 'includes', 'accident', 'involving', 'employee', 'occasionally', 'drive', 'office', 'external', 'meeting', 'course', 'place', 'employer', 'organised', 'activity', 'regular', 'break', 'including', 'lunch', 'accidents', 'board', 'mean', 'transport', 'course', 'underground', 'railway', 'train', 'aircraft', 'accident', 'slip', 'fall', 'assault', 'public', 'place', 'pavement', 'staircase', 'arrival', 'departure', 'area', 'station', 'airport', 'transport', 'journey', 'course', 'cases', 'excluded', 'commuting', 'accident', 'accident', 'occur', 'normal', 'journey', 'place', 'accident', 'occur', 'journey', 'worker', 'principal', 'secondary', 'residence', 'workplace', 'picking', 'child', 'school', 'accident', 'location', 'attended', 'related', 'training', 'workplace', 'restaurant', 'employee', 'habitually', 'lunch', 'excluded', 'unless', 'restaurant', 'company', 'premise', 'deliberate', 'inflicted', 'injury', 'accidents', 'strictly', 'natural', 'cause', 'accident', 'caused', 'solely', 'medical', 'condition', 'cardiac', 'cerebral', 'incident', 'sudden', 'onset', 'medical', 'condition', 'occurred', 'without', 'obvious', 'occupational', 'activity', 'victim', 'nevertheless', 'case', 'excluded', 'related', 'causal', 'element', 'ruled', 'example', 'bricklayer', 'faint', 'medical', 'cause', 'scaffolding', 'related', 'causal', 'element', 'accidental', 'injury', 'included', 'methodology', 'though', 'might', 'occurred', 'faint', 'injury', 'incurred', 'aggravated', 'scaffolding', 'ground', 'level', 'course', 'normal', 'accidents', 'purely', 'private', 'accident', 'victim', 'workplace', 'carrying', 'activity', 'related', 'example', 'visiting', 'station', 'hospital', 'office', 'airport', 'accidents', 'member', 'public', 'accident', 'activity', 'within', 'company', 'includes', 'family', 'member', 'employee', 'employer', 'premise', 'company', 'become', 'victim', 'accident', 'child', 'ex ...
#
# Total texts:  2150

# %%
del(all_df)

# %% [markdown]
# ### Fitting the selected LDA model
#
# * The next code shows the fitting of the LDA model with the selected parameters found (1000 topics). The parameters in the call of the function _ldamodel.LdaModel()_ and the number of topics were selected by grid search runs. We run several such runs with different combinations and values for the hyper-parameters.
#
# * For the final model, we first create a vocabulary from _texts_ with name _id2word_. This is a dictionary with the numeric ids of the terms as keys and the terms themselves as values. The terms are initially sorted alphabetically.
#
# * Before calling _ldamodel.LdaModel()_ we create a mapping with name _corpus_ of texts to terms in the bag-of-words (BOW) format. Each text is mapped into a list with 2-tuples: (word id, word count in each text). The terms in the vocabulary are then re-ordered according to their order of appearance in the texts. We set the bounds on the appearance of terms in the texts with the function _filter_extremes()_ on the _id2word_ vocabulary.
#
# * The coherence value of 0.45 is considered quite good. We store the fitted model in an object _lda_model_.
#
# * The model is also **stored to disk**, in a file _lda_model.pl_ in the same folder with the notebook.
#
# * There are 5087 unique tokens.
#
# ### Change the line _re_create = True_ to _re_create = False_ to import the stored model from file _lda_model.pl_

# %%
from gensim.models import CoherenceModel
import os
import pickle
file_name = '/content/drive/MyDrive/lda_model.pl'


lower_bound = 5 ## absolute number
upper_bound = 0.1 ## fraction -> 215 docs -> changed from 0.05 to 0.1


from gensim import corpora

#Create Dictionary
id2word = corpora.Dictionary(texts) #Gensim creates a unique id for each word in the document. 
id2word.filter_extremes(no_below=lower_bound, no_above=upper_bound)

print(id2word,'\n')

corpus = [id2word.doc2bow(text) for text in texts] 

print('Firsτ 2 texts in BOW format:\n')
print(corpus[:2],'\n')
print('First 2 texts in BOW format together with terms:\n')
for i in range(2):
    print([(id2word[term_id],term_id,freq) for (term_id,freq) in corpus[i]])

print('\nTotal texts: ',len(corpus))

num_topics = 1000
passes = 6 
alpha= 'auto'
iterations = 100 
decay = 0.7 ## changed from 0.3

re_create = True
if not re_create and not os.path.isfile('/content/drive/MyDrive/lda_model.pl'):
    re_create=True
    print('File lda_model.pl not found - re-creating the model')

if re_create:
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                               id2word=id2word,
                                               num_topics=num_topics, 
                                               random_state=100,
                                               update_every=0,
                                               passes=passes,
                                               alpha=alpha,
                                               iterations=iterations,
                                               decay = decay,
                                               per_word_topics=True,
                                               eval_every=1)
    
    #lda_model.save('lda_model')
    
    pickle.dump(lda_model, open(file_name, 'wb'))
    coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    print('\nCoherence Score: ', coherence_lda)  

else:    
    #lda_model = gensim.models.ldamodel.LdaModel.load('lda_model')
    lda_model = pickle.load(open(file_name, 'rb'))

#coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
#coherence_lda = coherence_model_lda.get_coherence()
#print('\nCoherence Score: ', coherence_lda)
# Out:
# Dictionary(5087 unique tokens: ['accident', 'accidental', 'accidents', 'acute', 'administration']...)
#
# Firsτ 2 texts in BOW format:
#
# [[(0, 26), (1, 1), (2, 8), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1), (8, 2), (9, 1), (10, 1), (11, 1), (12, 1), (13, 1), (14, 1), (15, 2), (16, 1), (17, 2), (18, 2), (19, 2), (20, 2), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 5), (27, 1), (28, 12), (29, 2), (30, 1), (31, 1), (32, 1), (33, 1), (34, 1), (35, 1), (36, 2), (37, 1), (38, 4), (39, 8), (40, 1), (41, 1), (42, 4), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 2), (53, 1), (54, 3), (55, 1), (56, 1), (57, 1), (58, 6), (59, 1), (60, 2), (61, 1), (62, 1), (63, 3), (64, 3), (65, 2), (66, 1), (67, 2), (68, 1), (69, 1), (70, 1), (71, 2), (72, 2), (73, 1), (74, 1), (75, 2), (76, 5), (77, 3), (78, 3), (79, 1), (80, 2), (81, 1), (82, 2), (83, 1), (84, 1), (85, 1), (86, 1), (87, 9), (88, 1), (89, 1), (90, 3), (91, 2), (92, 1), (93, 1), (94, 2), (95, 1), (96, 2), (97, 1), (98, 1), (99, 2), (100, 4), (101, 1), (102, 1), (103, 1), (104, 1), (105, 2), (106, 1), (107, 1), (108, 1), (109, 1), (110, 2), (111, 1), (112, 1), (113, 1), (114, 1), (115, 6), (116, 1), (117, 1), (118, 1), (119, 1), (120, 1), (121, 1), (122, 4), (123, 2)], [(0, 4), (59, 1), (115, 1), (124, 1), (125, 2)]]
#
# First 2 texts in BOW format together with terms:
#
# [('accident', 0, 26), ('accidental', 1, 1), ('accidents', 2, 8), ('acute', 3, 1), ('administration', 4, 1), ('administrative', 5, 1), ('aggravated', 6, 1), ('aircraft', 7, 1), ('airport', 8, 2), ('arrival', 9, 1), ('assault', 10, 1), ('attendance', 11, 1), ('attended', 12, 1), ('become', 13, 1), ('board', 14, 1), ('break', 15, 2), ('carried', 16, 1), ('carrying', 17, 2), ('cause', 18, 2), ('caused', 19, 2), ('child', 20, 2), ('client', 21, 1), ('coach', 22, 1), ('collection', 23, 1), ('commercial', 24, 1), ('commuting', 25, 1), ('company', 26, 5), ('counted', 27, 1), ('course', 28, 12), ('customer', 29, 2), ('delivery', 30, 1), ('departure', 31, 1), ('difficult', 32, 1), ('distinguish', 33, 1), ('drive', 34, 1), ('driver', 35, 1), ('element', 36, 2), ('employ', 37, 1), ('employee', 38, 4), ('employer', 39, 8), ('engaged', 40, 1), ('ensure', 41, 1), ('excluded', 42, 4), ('excludes', 43, 1), ('external', 44, 1), ('fall', 45, 1), ('family', 46, 1), ('framework', 47, 1), ('frequently', 48, 1), ('ground', 49, 1), ('hospital', 50, 1), ('imply', 51, 1), ('incident', 52, 2), ('incurred', 53, 1), ('injury', 54, 3), ('insurance', 55, 1), ('involve', 56, 1), ('involving', 57, 1), ('journey', 58, 6), ('lead', 59, 1), ('location', 60, 2), ('lorry', 61, 1), ('maintenance', 62, 1), ('medical', 63, 3), ('meeting', 64, 3), ('mental', 65, 2), ('methodology', 66, 1), ('might', 67, 2), ('module', 68, 1), ('natural', 69, 1), ('nevertheless', 70, 1), ('normal', 71, 2), ('normally', 72, 2), ('nursery', 73, 1), ('obvious', 74, 1), ('occasionally', 75, 2), ('occupational', 76, 5), ('occur', 77, 3), ('occurred', 78, 3), ('occurrence', 79, 1), ('office', 80, 2), ('onset', 81, 1), ('organised', 82, 2), ('park', 83, 1), ('permanent', 84, 1), ('physical', 85, 1), ('poisoning', 86, 1), ('premise', 87, 9), ('principal', 88, 1), ('principle', 89, 1), ('private', 90, 3), ('problem', 91, 2), ('providing', 92, 1), ('railway', 93, 1), ('regular', 94, 2), ('relevant', 95, 1), ('repair', 96, 2), ('residence', 97, 1), ('responsible', 98, 1), ('restaurant', 99, 2), ('road', 100, 4), ('school', 101, 1), ('secondary', 102, 1), ('solely', 103, 1), ('spent', 104, 1), ('station', 105, 2), ('statistics', 106, 1), ('strictly', 107, 1), ('sudden', 108, 1), ('though', 109, 1), ('traffic', 110, 2), ('train', 111, 1), ('training', 112, 1), ('underground', 113, 1), ('unless', 114, 1), ('victim', 115, 6), ('visit', 116, 1), ('visited', 117, 1), ('visiting', 118, 1), ('whilst', 119, 1), ('whose', 120, 1), ('worker', 121, 1), ('workplace', 122, 4), ('would', 123, 2)]
# [('accident', 0, 4), ('lead', 59, 1), ('victim', 115, 1), ('death', 124, 1), ('fatal', 125, 2)]
#
# Total texts:  2150
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# Coherence Score:  0.45215583971116996

# %%
del(texts)

# %% [markdown]
# ### The topics coherences
#
# ### De-activate this chunk (un-comment the first line) to save time

# %%
# %%script false --no-raise-error ## COMMENT THIS TO SAVE TIME
#
# topic_names = ['Topic '+str(i) for i in range(num_topics)]
# try:
#     coh_topics = coherence_model_lda.get_coherence_per_topic(segmented_topics=None,with_std=False, with_support=False)
#
#     #for (i,tn) in enumerate(topic_names):
#     #    print('Topic {0:2d}. Coherence: {1:6f}  {2:s}.  '.format(i+1,coh_topics[i],tn))
#
#     fig, ax = plt.subplots(figsize=(20,6), dpi= 100, facecolor='w', edgecolor='k')
#     x=np.arange(num_topics)+1
#     plt.bar(x=x,height=coh_topics)
#     plt.xlabel("Topic")
#     plt.ylabel("Coherence")
#     plt.title("Coherence by topic")
#     plt.show()
# except NameError:
#     print('Coherence data not found')

# %% [markdown]
# ## Read the Eurostat's database table of contents
#
# * From the parsed table_of_contents.xml file, stored in the database.
# * Keep only records - leaves, corresponding to datasets.
# *    Column 'Normalized file description': from column 'File description' with the same pre-processing as the texts, i.e. tokenizing, keeping only non-stop alphanumeric tokens (but not numbers only), keeping tokens with minimum length 5 and finally lemmatization.
# *    Column 'Normalized full path': as above from column 'Names'.
# *    Create also 'Normalized file description - stems' and 'Normalized full path - stems' with the stems of the lemmas in the previous columns.

# %%
import ast

query      = """SELECT id, number, codes, names, file_descr, file_code, level 
                FROM ESTAT.V1.dat_all_datasets """

crumbs_df = load_table(cursor,query)

crumbs_df['codes'] = crumbs_df['codes'].apply(lambda x: ast.literal_eval(x))
crumbs_df['names'] = crumbs_df['names'].apply(lambda x: ast.literal_eval(x))
crumbs_df.rename(columns={'number':'Number','codes':'Codes','names':'Names','file_descr':'File description','level':'Level','file_code':'File code'},inplace=True)
crumbs_df = crumbs_df[['Number','Names','File description','File code']].copy()

## Keep only records - leaves, corresponding to datasets.
idx = crumbs_df[crumbs_df['File code']==''].index
crumbs_df.drop(index=idx, inplace=True) 
crumbs_df.reset_index(drop=True,inplace=True)

crumbs_df['Names']=crumbs_df['Names'].apply(lambda x: x[1:]) ## do not include top level

from nltk.stem import PorterStemmer
ps = PorterStemmer()

def list_to_words(sentence_list):
    tokens_list = []
    for sentence in sentence_list:
        tokens = lemmatize_text(sentence)
        tokens_list.extend(tokens)
    return tokens_list

crumbs_df['Normalized file description'] = crumbs_df['File description'].apply(lambda x: x.lower())
crumbs_df['Normalized file description'] = crumbs_df['Normalized file description'].apply(lambda x: lemmatize_text(x))
crumbs_df['Normalized file description - stems'] = crumbs_df['Normalized file description'].apply(lambda x: [ps.stem(w) for w in x])

crumbs_df['Normalized full path'] = crumbs_df['Names'].apply(lambda x: [y.lower() for y in x])
crumbs_df['Normalized full path'] = crumbs_df['Normalized full path'].apply(lambda x: list_to_words(x))
crumbs_df['Normalized full path - stems'] = crumbs_df['Normalized full path'].apply(lambda x: [ps.stem(w) for w in x])

#crumbs_df['source'] = 'dataset'

#crumbs_df.to_excel(outfile,index=False)
crumbs_df.insert(0, 'id', range(len(crumbs_df)))

crumbs_df
# Out:
#         id       Number                                              Names  \
# 0        0  1.1.1.1.1.1  [General and regional statistics, European and...
# 1        1  1.1.1.1.1.2  [General and regional statistics, European and...
# 2        2  1.1.1.1.2.1  [General and regional statistics, European and...
# 3        3  1.1.1.1.2.2  [General and regional statistics, European and...
# 4        4  1.1.1.1.2.3  [General and regional statistics, European and...
# ...    ...          ...                                                ...
# 8740  8740  4.8.6.3.3.8  [Skills-related statistics, Skills development...
# 8741  8741    4.8.6.4.1  [Skills-related statistics, Skills development...
# 8742  8742    4.8.6.5.1  [Skills-related statistics, Skills development...
# 8743  8743    4.8.6.5.2  [Skills-related statistics, Skills development...
# 8744  8744    4.8.6.5.3  [Skills-related statistics, Skills development...
#
#                                        File description        File code  \
# 0                              Consumers - monthly data        ei_bsco_m
# 1                            Consumers - quarterly data        ei_bsco_q
# 2                               Industry - monthly data     ei_bsin_m_r2
# 3                             Industry - quarterly data     ei_bsin_q_r2
# 4                           Construction - monthly data     ei_bsbu_m_r2
# ...                                                 ...              ...
# 8740  Students in tertiary education - as % of 20-24...  educ_uoe_enrt08
# 8741  Enterprises that provided training to develop/...   isoc_ske_ittn2
# 8742  Enterprises providing training by type of trai...     trng_cvt_01s
# 8743  Participants in CVT courses by sex and size cl...     trng_cvt_12s
# 8744  Main skills targeted by CVT courses by type of...    trng_cvt_29n2
#
#                             Normalized file description  \
# 0                                   [consumer, monthly]
# 1                                 [consumer, quarterly]
# 2                                   [industry, monthly]
# 3                                 [industry, quarterly]
# 4                               [construction, monthly]
# ...                                                 ...
# 8740   [student, tertiary, education, year, population]
# 8741  [enterprise, provided, training, develop, upgr...
# 8742  [enterprise, providing, training, training, cl...
# 8743  [participant, course, class, person, employed,...
# 8744  [skill, targeted, course, skill, activity, ent...
#
#                     Normalized file description - stems  \
# 0                                     [consum, monthli]
# 1                                   [consum, quarterli]
# 2                                   [industri, monthli]
# 3                                 [industri, quarterli]
# 4                                  [construct, monthli]
# ...                                                 ...
# 8740             [student, tertiari, educ, year, popul]
# 8741  [enterpris, provid, train, develop, upgrad, sk...
# 8742  [enterpris, provid, train, train, class, enter...
# 8743  [particip, cours, class, person, employ, enter...
# 8744  [skill, target, cours, skill, activ, enterpris...
#
#                                    Normalized full path  \
# 0     [general, regional, statistic, european, natio...
# 1     [general, regional, statistic, european, natio...
# 2     [general, regional, statistic, european, natio...
# 3     [general, regional, statistic, european, natio...
# 4     [general, regional, statistic, european, natio...
# ...                                                 ...
# 8740  [skill, related, statistic, skill, development...
# 8741  [skill, related, statistic, skill, development...
# 8742  [skill, related, statistic, skill, development...
# 8743  [skill, related, statistic, skill, development...
# 8744  [skill, related, statistic, skill, development...
#
#                            Normalized full path - stems
# 0     [gener, region, statist, european, nation, ind...
# 1     [gener, region, statist, european, nation, ind...
# 2     [gener, region, statist, european, nation, ind...
# 3     [gener, region, statist, european, nation, ind...
# 4     [gener, region, statist, european, nation, ind...
# ...                                                 ...
# 8740  [skill, relat, statist, skill, develop, partic...
# 8741  [skill, relat, statist, skill, develop, partic...
# 8742  [skill, relat, statist, skill, develop, partic...
# 8743  [skill, relat, statist, skill, develop, partic...
# 8744  [skill, relat, statist, skill, develop, partic...
#
# [8745 rows x 9 columns]

# %% [markdown]
# ### The topics as a mix of keywords.
#
# The above LDA model is built with 1000 different topics where each topic is a combination of keywords and each keyword contributes with a certain weight to the topic.  This mix of keywords (limited to the top 10 keywords) is shown below, for the first 10 topics.

# %%
for i in range(10):
    print(i,[(id2word[term_id],prob) for (term_id,prob) in lda_model.get_topic_terms(i,topn=10)],'\n')
# Out:
# 0 [('import', 0.08064415), ('export', 0.071413204), ('china', 0.036581054), ('south', 0.033979658), ('billion', 0.028709134), ('russia', 0.02742682), ('korea', 0.025781346), ('turkey', 0.024090637), ('japan', 0.021615552), ('canada', 0.021169253)]
#
# 1 [('young', 0.19249038), ('unemployment', 0.027186848), ('woman', 0.01936997), ('training', 0.016305106), ('death', 0.011217792), ('child', 0.010352589), ('neither', 0.008921548), ('limitation', 0.008116532), ('problem', 0.0076200706), ('unemployed', 0.007581449)]
#
# 2 [('skill', 0.075797714), ('naturalisation', 0.04428445), ('tool', 0.032326028), ('required', 0.030608656), ('capability', 0.025223237), ('foreigner', 0.024359977), ('energy', 0.024165643), ('effective', 0.017489573), ('apply', 0.016827174), ('supporting', 0.016815409)]
#
# 3 [('online', 0.08127214), ('purchase', 0.06538629), ('prior', 0.043921098), ('internet', 0.04192555), ('user', 0.0388362), ('accessory', 0.026881723), ('delivery', 0.018843535), ('problem', 0.017371906), ('clothing', 0.017330714), ('sport', 0.017120883)]
#
# 4 [('unemployment', 0.05567424), ('youth', 0.03133554), ('older', 0.023384208), ('southern', 0.020996159), ('young', 0.019210069), ('childcare', 0.016770462), ('responsibility', 0.014593968), ('regional', 0.01329224), ('female', 0.012766173), ('gender', 0.011561474)]
#
# 5 [('candidate', 0.20161323), ('potential', 0.09292419), ('turkey', 0.07145699), ('montenegro', 0.059002455), ('serbia', 0.056901198), ('albania', 0.051504787), ('north', 0.05001526), ('macedonia', 0.04928318), ('kosovo', 0.047681175), ('bosnia', 0.04009354)]
#
# 6 [('absolute', 0.06771067), ('discrepancy', 0.0495087), ('inconsistency', 0.0488738), ('balance', 0.037249487), ('primary', 0.034665685), ('transaction', 0.03386676), ('component', 0.031765617), ('secondary', 0.031335086), ('showed', 0.022137964), ('asset', 0.020903962)]
#
# 7 [('affiliate', 0.07450926), ('foreign', 0.069965266), ('control', 0.059270486), ('compiling', 0.0427558), ('resident', 0.04171667), ('outward', 0.03508494), ('inward', 0.028861627), ('describe', 0.028461), ('institutional', 0.028368337), ('abroad', 0.023379782)]
#
# 8 [('characteristic', 0.109412014), ('applied', 0.052119553), ('livestock', 0.044369172), ('regulation', 0.038061082), ('march', 0.033567164), ('ending', 0.03306483), ('december', 0.02940872), ('october', 0.028035283), ('comparability', 0.018781848), ('earlier', 0.017931055)]
#
# 9 [('nitrogen', 0.059931684), ('billion', 0.037991423), ('telecommunication', 0.025947176), ('electronics', 0.025449798), ('pharmacy', 0.025441067), ('china', 0.016713344), ('weight', 0.016214203), ('output', 0.015628804), ('contributing', 0.015426024), ('aggregation', 0.01477158)]

# %% [markdown]
# ### Import the saved word vectors

# %%
from gensim.models.keyedvectors import KeyedVectors

w_vectors = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/MyDrive/SE_GL_wordvectors.txt', binary=False)

# %% [markdown]
# ### Keep the top 10 keywords per topic and extend them with the closest words based on the word vectors.
#
# * List *words*: the unique lemmas from the topic modelling enhanced with their closest terms from the word vectors.
# * List *used_words*: the subset of the above appearing in the full file descriptions.
# * List *words_stems*: the corresponding stems in list _words_.
# * List *used_words_stems*: the corresponding stems in list _used_words_.

# %%
words = set()


for topic_id in range(num_topics):
    top_words = [a for (a,b) in lda_model.show_topic(topic_id,topn=10)]
    add_wvs = [lemmatizer.lemmatize(w_vectors.most_similar(tok,topn=10)[0][0]) for tok in top_words if tok in w_vectors.index2word]
    words.update(top_words+add_wvs)


print('topic modelling words and similar:',len(words))
used_words = [word for word in words if any(crumbs_df['Normalized full path'].apply(lambda x: 1 if word in x else 0))]
print('of which appear in the full file descriptions: ',len(used_words))

words_stems = set([ps.stem(w) for w in words])
print('topic modelling words and similar - corresponding stems:',len(words_stems))
used_words_stems = [s for s in words_stems if any(crumbs_df['Normalized full path - stems'].apply(lambda x: 1 if s in x else 0))]

print('of which appear in the full file descriptions: ',len(used_words_stems))
# Out:
# topic modelling words and similar: 3046
# of which appear in the full file descriptions:  1350
# topic modelling words and similar - corresponding stems: 2348
# of which appear in the full file descriptions:  1267

# %%
import ipywidgets as widgets
from ipywidgets import Layout
layout = widgets.Layout(width='600px', height='60px')

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from IPython.display import HTML, display,clear_output

# %% [markdown]
# ## Run once the chunk below then just change inputs

# %% [markdown]
# * Enrich the initial query with close words from the word vectors and with related words from ConceptNet (two ways).
# * Find both types of matches:
#     * i) Using the lemmas (or stems) from the enriched query, which belong to the enhanced topic modelling vocabulary.
#     * ii) Using all lemmas (or stems) from the enriched query.
#     * Sort the results first by the number of matches in (i), then by the number of matches in (ii), so that the most significant matches have priority.
# * Using the stems of the lemmas is an option to circumvent weaknesses in the lemmatizer which in some cases leave different forms of the same word as separate lemmas.

# %%
import eurostat
#import qgrid

## below not used here
codes = {'hazard': 16, 'time': 1169, 'nace_r1': 888, 'geo': 4017, 
    'age691': None, 'rbd': 412, 'time1': None, 'nace_r2': 1298, 
    'worktime': 31, 'metroreg': 422, 'geo91': None, 'injury': 50, 'physact': 22, 'ceparema': 37, 
    'modinj': 11, 'train': 12, 'wrkenv': 15, 'frequenc': 61, 'tra_cov': 32, 'stk_flow': 190, 'par_mar': 302, 
    'currency': 193, 'cities': 13507, 'indic_env': 81, 'emp_cont': 17, 'loadstat': 3, 'size_emp': 31, 'airp_pr': 25160, 
    'unit': 668, 'nst07': 104, 'wat_proc': 56, 'comspec': 3, 'sex': 7, 'time91': None, 'age': 651, 
    'workproc': 9, 'age91': None, 'citizen': 4017, 'port_iww': 1032, 'source': 14, 'c_cabot': 4017, 
    'wrkstat': 5, 'c_birth': 4017, 'rep_airp': 1116, 'deviatn': 11, 'matagent': 23, 'diagnose': 28, 
    'rep_mar': 1842, 'partner': 4017, 'c_regis': 4017, 'geo1': None, 'seabasin': 12}
        

def relevant_datasets(Sentences,option,use_s_option,howmany,show_meta,show_meta_ind):
   
    print("\rPlease wait ...", end="")
    threshold = 0.8
    
    initial_tokens_list = lemmatize_text(Sentences)
    h = '<h3>Initial tokens:</h3>'
    h += '  '.join('[' + x + ']' for x in initial_tokens_list)

    h += '<h3>Similarity- and synomyms-enhanced tokens:</h3>'

    tokens_list=[] 
    ## list of entered lemmas together with lemmas of most similar words and lemmas of synonyms
    tokens_list += [lemmatizer.lemmatize(syn) for syn in simpleCN_list(initial_tokens_list,threshold)] ## one way to query ConceptNet
    tokens_list += [lemmatizer.lemmatize(w_vectors.most_similar(tok)[0][0]) for tok in initial_tokens_list if tok in w_vectors.index2word]
    ## second way of querying ConceptNet
    add_syns2 = [b for (a,b) in conceptNet(' '.join(initial_tokens_list))]
    add_syns2 = [a for elems in add_syns2 for (a,b,c) in elems]
    tokens_list += [lemmatizer.lemmatize(a) for a in add_syns2]
    tokens_list = list(set(tokens_list))

    print("\r", end="")
    ## corresponding stems
    tokens_list_stems = list(set([ps.stem(tok) for tok in tokens_list]))

    h += '  '.join('[' + x + ']' for x in tokens_list)+'<br/>'

    h += '<h3>Of these, tokens in the TM vocabulary which appear in the datasets full descriptions:</h3>'

    ## terms in tokens_list actually used in the full file descriptions 
    tokens_list_enhanced=[tok for tok in tokens_list if tok in used_words] 

    ## corresponding stems
    tokens_list_enhanced_stems = list(set([ps.stem(tok) for tok in tokens_list_enhanced]))

    h += '  '.join('[' + x + ']' for x in tokens_list_enhanced)+'<br/>'   
    
    #print('found in keywords used in datasets: ',used_words_stems2)
    h += '<h3>Datasets descriptions in descending order of tokens found - top '+str(howmany)+':</h3>'
    
    res2 = crumbs_df.copy()
    if option==1: ## use the Normalized file description
        if use_s_option == 1: ## with stemming
            res2['Words found s2'] = res2['Normalized file description - stems'].apply(lambda x: list(set([y for y in x if y in tokens_list_enhanced_stems])))
            res2['Number s2'] = res2['Normalized file description - stems'].apply(lambda x: len(set([y for y in x if y in tokens_list_enhanced_stems])))

            res2['Words found s1'] = res2['Normalized file description - stems'].apply(lambda x: list(set([y for y in x if y in tokens_list_stems])))
            res2['Number s1'] = res2['Normalized file description - stems'].apply(lambda x: len(set([y for y in x if y in tokens_list_stems])))
        else: ## no stemming
            res2['Words found s2'] = res2['Normalized file description'].apply(lambda x: list(set([y for y in x if y in tokens_list_enhanced])))
            res2['Number s2'] = res2['Normalized file description'].apply(lambda x: len(set([y for y in x if y in tokens_list_enhanced])))

            res2['Words found s1'] = res2['Normalized file description'].apply(lambda x: list(set([y for y in x if y in tokens_list])))
            res2['Number s1'] = res2['Normalized file description'].apply(lambda x: len(set([y for y in x if y in tokens_list])))
        
        res2.sort_values(by=['Number s2','Number s1'], axis=0, ascending=False, inplace=True)
        res2 = res2.loc[(res2['Number s2']>=1) | (res2['Number s1']>=1)]
        res2 = res2[['id','File description','File code','Words found s2','Number s2','Words found s1','Number s1']] ## corresponding records from crumbs_df
        
    else: ## use the Normalized full path   
        if use_s_option == 1: ## with stemming
            res2['Words found f2'] = res2['Normalized full path - stems'].apply(lambda x: list(set([y for y in x if y in tokens_list_enhanced_stems])))
            res2['Number f2'] = res2['Normalized full path - stems'].apply(lambda x: len(set([y for y in x if y in tokens_list_enhanced_stems])))

            res2['Words found f1'] = res2['Normalized full path - stems'].apply(lambda x: list(set([y for y in x if y in tokens_list_stems])))
            res2['Number f1'] = res2['Normalized full path - stems'].apply(lambda x: len(set([y for y in x if y in tokens_list_stems])))
        else: ## no stemming
            res2['Words found f2'] = res2['Normalized full path'].apply(lambda x: list(set([y for y in x if y in tokens_list_enhanced])))
            res2['Number f2'] = res2['Normalized full path'].apply(lambda x: len(set([y for y in x if y in tokens_list_enhanced])))

            res2['Words found f1'] = res2['Normalized full path'].apply(lambda x: list(set([y for y in x if y in tokens_list])))
            res2['Number f1'] = res2['Normalized full path'].apply(lambda x: len(set([y for y in x if y in tokens_list])))
    
        res2.sort_values(by=['Number f2','Number f1'], axis=0, ascending=False, inplace=True)
        res2 = res2.loc[(res2['Number f2']>=1) | (res2['Number f1']>=1)]
        res2 = res2[['id','File description','File code','Words found f2','Number f2','Words found f1','Number f1']] ## corresponding records from crumbs_df
    
    res2.reset_index(drop=True,inplace=True)
    res2.rename(columns={'index':'Dataset id'},inplace=True)
    
    if len(res2) == 0:
        h += 'No datasets found'+'<br/>'  
        display(HTML(h))
    else:
        display(HTML(h))
        #res2.to_excel('res2.xlsx')
        if len(res2) < howmany:
            howmany = len(res2)
        res2 = res2.iloc[:howmany]

        for i in range(len(res2)):
            url='https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=data%2F'+res2.loc[i,'File code']+'.tsv.gz'
            res2.loc[i,'Link'] = url
        
        display(HTML(res2.to_html()))
    
        if show_meta and len(res2)>0:

            dst = pd.read_csv(res2.loc[show_meta_ind,'Link'],sep='\t',low_memory=False)
            dcode=res2.loc[show_meta_ind,'File code']
            dms = eurostat.get_sdmx_dims(dcode)
            h1 = '<h3>'+str(show_meta_ind)+': File code: '+dcode+'</h3>'
            h1 += '<h3>'+res2.loc[show_meta_ind,'File description']+'</h3>'
            h1 += '<h3>Dimensions:</h3>'
            h1 += '  '.join('[' + x + ']' for x in dms)

            h2=''
            dims=dst.columns[0].split(',')
            dims = dims[:-1]+dims[-1].split('\\')
        
            tmp=dst.iloc[:,0].str.split(',',expand=True)
            for j in range(len(dims)-2): ## first the dimensions separated by comma
                if dims[j] not in codes.keys() or codes[dims[j]] != None:
                    h2+='<h4>'+dims[j]+':</h4>'
                    arr = pd.unique(tmp.iloc[:,j])
                    for i in range(len(arr)):
                        h2+= '[ '+arr[i]+': '+eurostat.get_dic(dims[j])[arr[i]] +' ]'
            display(HTML(h1))
            display(HTML(h2))            
            display(HTML(dst.head().to_html()))

# %% [markdown]
# ## Run once the chunk below then just change inputs

# %%
def relevant_datasets_to_text(): 
    
    first_text = 'In 2021 unemployment among young people in Greece increased. This was the result of recession over the last 10 years.'  
    style = {'description_width': 'initial'}
    
    textW = widgets.Textarea(
        value=first_text, 
        placeholder='Type something',
        description='',
        disabled=False,
        layout=Layout(width='90%', height='100px')
    )

    button = widgets.Button(description="Search")
    
    option = widgets.RadioButtons(
    options=['Simple description of datasets', 'Full-path description of datasets'],
    value='Full-path description of datasets', 
    layout={'width': 'max-content'}, 
    disabled=False
    )    
    
    howmany = widgets.IntSlider(
        description='Display:',
        #tooltip='maximum:',
        value=20,
        min=1, 
        max = 30,
        style=style )
    howmany.style.handle_color = 'lightblue'
    
    show_more = widgets.Checkbox(
        value=True,
        description='Show metadata for row:',
        disabled=False,
        indent=True
     )
    
    use_stems = widgets.Checkbox(
        value=True,
        description='Use stems',
        disabled=False,
        indent=True
    )
    
    select_ind = widgets.BoundedIntText(
        value=0,
        min=0,
        max=howmany.value-1,
        step=1,
        description='Row:',
        disabled=False,
        style={'description_width': 'initial'},
        layout = widgets.Layout(width='100px')
    )

    

    ui1=widgets.HBox([textW])
    ui2=widgets.HBox([option,button,howmany])
    ui3=widgets.HBox([show_more,select_ind,use_stems])
    ui4=widgets.VBox([ui1,ui2,ui3])
    display(ui4, layout=Layout(align_items='center'))

    def on_button_clicked(b):
        clear_output()
        display(ui4, layout=Layout(align_items='center'))
        if option.value == 'Simple description of datasets':
            opt_val = 1
        else:
            opt_val = 2
        if use_stems.value == True:
            use_s_opt  = 1
        else:
            use_s_opt  = 2
        relevant_datasets(textW.value,option=opt_val,use_s_option=use_s_opt,howmany=howmany.value,show_meta=show_more.value,show_meta_ind=select_ind.value)
       
    button.on_click(on_button_clicked)
    
    
relevant_datasets_to_text()
# Out:
# VBox(children=(HBox(children=(Textarea(value='In 2021 unemployment among young people in Greece increased. Thi…
# <h3>Initial tokens:</h3>[unemployment]  [among]  [young]  [people]  [greece]  [increased]  [result]  [recession]  [year]<h3>Similarity- and synomyms-enhanced tokens:</h3>[amongst]  [crowd]  [unemployed]  [naupactus]  [greek]  [recessional]  [chaeronea]  [great]  [tavros]  [malta]  [exaggerated]  [republic]  [balkan]  [parga]  [youth]  [boy]  [effect]  [graeco]  [saronic]  [population]  [birthday]  [outcome]  [hellenic]  [joblessness]  [older]  [war]  [employ]  [recorded]  [economic]  [decreased]  [brown]  [youngish]  [mantinea]  [nafplio]  [woman]  [consecutive]  [chick]  [athens]  [employment]  [trikala]  [kozani]  [navarino]  [party]  [glyfada]  [mantineia]  [receding]  [igoumenitsa]  [pharsalus]  [recessionary]  [augmented]  [brigham]  [twelvemonth]  [hair]  [timing]  [answer]  [month]  [gulf]  [stagira]  [antiparos]  [recovering]  [child]  [downturn]  [time]  [jobless]  [volvi]  [resulted]  [metsovo]  [amphitheatre]  [preveza]<br/><h3>Of these, tokens in the TM vocabulary which appear in the datasets full descriptions:</h3>[unemployed]  [republic]  [youth]  [effect]  [outcome]  [older]  [employ]  [recorded]  [woman]  [child]  [resulted]<br/><h3>Datasets descriptions in descending order of tokens found - top 20:</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>File description</th>
#       <th>File code</th>
#       <th>Words found f2</th>
#       <th>Number f2</th>
#       <th>Words found f1</th>
#       <th>Number f1</th>
#       <th>Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3168</td>
#       <td>Number of persons between 15 and 64 years old regularly taking care of other children up to 14 or people older than 15 in need of care</td>
#       <td>lfso_05regcp</td>
#       <td>[child, unemploy, older, employ]</td>
#       <td>4</td>
#       <td>[child, unemploy, older, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfso_05regcp.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2594</td>
#       <td>Employment by sex, age and economic activity (from 2008 onwards, NACE Rev. 2) - 1 000</td>
#       <td>lfsq_egan2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_egan2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2595</td>
#       <td>Employment by sex, age and economic activity (1998-2008, NACE Rev. 1.1) - 1 000</td>
#       <td>lfsq_egana</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_egana.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2596</td>
#       <td>Employment by sex, age and detailed economic activity (from 2008 onwards, NACE Rev. 2 two digit level) - 1 000</td>
#       <td>lfsq_egan22d</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_egan22d.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2597</td>
#       <td>Employment by sex, age and detailed economic activity (1998-2008, NACE Rev. 1.1 two digit level) - 1 000</td>
#       <td>lfsq_egana2d</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_egana2d.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2598</td>
#       <td>Employment by sex, age, time since job started and economic activity (from 2008 onwards, NACE Rev. 2) - 1 000</td>
#       <td>lfsq_egdn2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_egdn2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2599</td>
#       <td>Employment by sex, age, occupation and economic activity (from 2008 onwards, NACE Rev. 2) (1 000)</td>
#       <td>lfsq_eisn2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_eisn2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2608</td>
#       <td>Self-employment by sex, age and economic activity (from 2008 onwards, NACE Rev. 2) - 1 000</td>
#       <td>lfsq_esgan2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_esgan2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2609</td>
#       <td>Self-employment by sex, age and economic activity (1998-2008, NACE Rev. 1.1) - 1 000</td>
#       <td>lfsq_esgana</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_esgana.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2612</td>
#       <td>Employees by sex, age and economic activity (from 2008 onwards, NACE Rev. 2) - 1 000</td>
#       <td>lfsq_eegan2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_eegan2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2613</td>
#       <td>Employees by sex, age and economic activity (1998-2008, NACE Rev. 1.1) - 1 000</td>
#       <td>lfsq_eegana</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_eegana.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2616</td>
#       <td>Temporary employees by sex, age and economic activity (from 2008 onwards, NACE Rev. 2) - 1 000</td>
#       <td>lfsq_etgan2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_etgan2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2617</td>
#       <td>Temporary employees by sex, age and economic activity (1998-2008, NACE Rev. 1.1) - 1 000</td>
#       <td>lfsq_etgana</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_etgana.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2622</td>
#       <td>Full-time and part-time employment by sex and economic activity (from 2008 onwards, NACE Rev. 2) - 1 000</td>
#       <td>lfsq_epgan2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_epgan2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2623</td>
#       <td>Full-time and part-time employment by sex and economic activity (1998-2008, NACE Rev. 1.1) - 1 000</td>
#       <td>lfsq_epgana</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_epgana.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2629</td>
#       <td>Average number of usual weekly hours of work in main job, by sex, professional status, full-time/part-time and economic activity (from 2008 onwards, NACE Rev. 2) - hours</td>
#       <td>lfsq_ewhun2</td>
#       <td>[unemploy, result, employ]</td>
#       <td>3</td>
#       <td>[econom, result, unemploy, employ, popul]</td>
#       <td>5</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsq_ewhun2.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2630</td>
#       <td>Average number of usual weekly hours of work in main job, by sex, professional status, full-time/part-time and economic activity (1998-20
# <h3>0: File code: lfso_05regcp</h3><h3>Number of persons between 15 and 64 years old regularly taking care of other children up to 14 or people older than 15 in need of care</h3><h3>Dimensions:</h3>[AGE]  [FREQ]  [GEO]  [INDICATORS]  [OBS_FLAG]  [SEX]  [TIME]  [WSTATUS]  [YNLFS]
# <h4>sex:</h4>[ F: Females ][ M: Males ][ T: Total ]<h4>age:</h4>[ Y15-24: From 15 to 24 years ][ Y15-64: From 15 to 64 years ][ Y20-49: From 20 to 49 years ][ Y25-49: From 25 to 49 years ][ Y50-64: From 50 to 64 years ]<h4>wstatus:</h4>[ ACT: Persons in the labour force (former name: active persons) ][ EMP: Employed persons ][ INAC: Persons outside the labour force (former name: inactive persons) ][ POP: Population ][ UNE: Unemployed persons ]<h4>ynlfs:</h4>[ NO: No ][ NRP: No answer ][ RCARE1: The person regularly takes care of other children up to 14 ][ RCARE2: The person regularly takes care of relatives/friends aged 15 or more in need of care ][ RCARE3: The person regularly takes care of other children up to 14 and of relatives/friends aged 15 or more in need of care ][ TOTAL: Total ]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex,age,wstatus,ynlfs,time\geo</th>
#       <th>EU27_2007</th>
#       <th>EU15</th>
#       <th>EA18</th>
#       <th>EA17</th>
#       <th>EA13</th>
#       <th>BE</th>
#       <th>BG</th>
#       <th>CZ</th>
#       <th>DK</th>
#       <th>DE</th>
#       <th>EE</th>
#       <th>IE</th>
#       <th>EL</th>
#       <th>ES</th>
#       <th>FR</th>
#       <th>IT</th>
#       <th>CY</th>
#       <th>LV</th>
#       <th>LT</th>
#       <th>LU</th>
#       <th>HU</th>
#       <th>MT</th>
#       <th>NL</th>
#       <th>AT</th>
#       <th>PL</th>
#       <th>PT</th>
#       <th>RO</th>
#       <th>SI</th>
#       <th>SK</th>
#       <th>FI</th>
#       <th>SE</th>
#       <th>IS</th>
#       <th>NO</th>
#       <th>CH</th>
#       <th>UK</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>F,Y15-24,ACT,NO,2005</td>
#       <td>9720.2</td>
#       <td>7802.1</td>
#       <td>6087.0</td>
#       <td>6030.5</td>
#       <td>5838.5</td>
#       <td>180.8</td>
#       <td>107.9</td>
#       <td>157.9</td>
#       <td>155.6</td>
#       <td>1737.2</td>
#       <td>27.8</td>
#       <td>143.3</td>
#       <td>167.7</td>
#       <td>910.1</td>
#       <td>1085.0</td>
#       <td>763.0</td>
#       <td>16.2</td>
#       <td>56.4</td>
#       <td>50.4</td>
#       <td>6.4</td>
#       <td>129.8</td>
#       <td>16.4</td>
#       <td>201.9</td>
#       <td>237.0</td>
#       <td>779.1</td>
#       <td>228.3</td>
#       <td>406.6</td>
#       <td>38.0</td>
#       <td>131.6</td>
#       <td>139.7</td>
#       <td>254.6</td>
#       <td>13.1</td>
#       <td>26.1</td>
#       <td>229.9</td>
#       <td>1591.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F,Y15-24,ACT,NRP,2005</td>
#       <td>1209.2</td>
#       <td>1177.6</td>
#       <td>881.4</td>
#       <td>880.9</td>
#       <td>880.5</td>
#       <td>: u</td>
#       <td>8.8 u</td>
#       <td>4.6</td>
#       <td>6.3 u</td>
#       <td>420.8</td>
#       <td>:</td>
#       <td>1.1 u</td>
#       <td>11.3</td>
#       <td>30.3</td>
#       <td>:</td>
#       <td>:</td>
#       <td>:</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>:</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>414.5</td>
#       <td>:</td>
#       <td>16.0 u</td>
#       <td>:</td>
#       <td>:</td>
#       <td>:</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>:</td>
#       <td>135.2</td>
#       <td>: u</td>
#       <td>290.8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>F,Y15-24,ACT,RCARE1,2005</td>
#       <td>665.0</td>
#       <td>540.0</td>
#       <td>357.6</td>
#       <td>355.3</td>
#       <td>350.9</td>
#       <td>9.4 u</td>
#       <td>: u</td>
#       <td>12.0</td>
#       <td>20.2</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>2.9</td>
#       <td>4.5 u</td>
#       <td>96.1</td>
#       <td>114.3</td>
#       <td>46.4</td>
#       <td>1.6</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>10.9</td>
#       <td>:</td>
#       <td>13.6</td>
#       <td>14.1</td>
#       <td>65.3</td>
#       <td>11.1</td>
#       <td>25.8</td>
#       <td>1.0 u</td>
#       <td>: u</td>
#       <td>12.6</td>
#       <td>16.4</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>39.0</td>
#       <td>153.6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>F,Y15-24,ACT,RCARE2,2005</td>
#       <td>283.2</td>
#       <td>214.0</td>
#       <td>162.4</td>
#       <td>161.1</td>
#       <td>156.3</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>6.3</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>2.2</td>
#       <td>4.4 u</td>
#       <td>46.7</td>
#       <td>: u</td>
#       <td>21.0</td>
#       <td>0.7 u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>3.1 u</td>
#       <td>:</td>
#       <td>4.7 u</td>
#       <td>8.5</td>
#       <td>38.1</td>
#       <td>: u</td>
#       <td>8.2 u</td>
#       <td>1.9 u</td>
#       <td>2.7 u</td>
#       <td>6.7</td>
#       <td>4.2 u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>5.5 u</td>
#       <td>53.1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F,Y15-24,ACT,RCARE3,2005</td>
#       <td>92.9 u</td>
#       <td>75.2 u</td>
#       <td>56.7 u</td>
#       <td>56.7 u</td>
#       <td>55.9 u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>2.1 u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>19.8</td>
#       <td>: u</td>
#       <td>4.6 u</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>: u</td>
#       <td>:</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>7.5 u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>: u</td>
#       <td>3.6 u</td>
#       <td>12.7 u</td>
#     </tr>
#   </tbody>
# </table>
