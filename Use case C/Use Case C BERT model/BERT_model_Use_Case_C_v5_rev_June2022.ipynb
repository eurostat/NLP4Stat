# %% [markdown]
# ###Use Case C - BERT model notebook
#
# * Revised (February 2022) to read datasets information from the database.
# * Adjusted (June 2022) to read all inputs with SPARQL queries from the Knowledge Database. Also added the terms and definitions from [Eurostat's Concepts and Definitions Database](https://ec.europa.eu/eurostat/ramon/nomenclatures/index.cfm?TargetUrl=LST_NOM_DTL_GLOSSARY&StrNom=CODED2&StrLanguageCode=EN) in the fine-tuning stage.
# * This is a Google Colab notebook. You must have a Google account with a Google Drive to store/ load the model. Upload it from its location in GitHub and allow the code to access your Google Drive

# %% [markdown]
# ###Connect Google Drive

# %%
## To store the model (allowing re-runs starting from re-loading the model)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Installations

# %%
## !pip install pyodbc
# !pip install SPARQLWrapper
# !pip install sparql_dataframe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 51.6 MB/s
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 751 kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (4.11.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (4.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib>=6.1.1->SPARQLWrapper) (1.15.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 rdflib-6.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sparql_dataframe
#   Downloading sparql_dataframe-0.4-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from sparql_dataframe) (1.3.5)
# Requirement already satisfied: SPARQLWrapper>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from sparql_dataframe) (2.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.22.0->sparql_dataframe) (1.15.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper>=1.8.1->sparql_dataframe) (6.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (57.4.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (4.11.4)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (0.6.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (3.8.0)
# Installing collected packages: sparql-dataframe
# Successfully installed sparql-dataframe-0.4

# %%
# !apt-get install virtuoso-opensource
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libvirtodbc0 virtuoso-opensource-6.1 virtuoso-opensource-6.1-bin
#   virtuoso-opensource-6.1-common virtuoso-server virtuoso-vad-conductor
#   virtuoso-vsp-startpage
# Suggested packages:
#   virtuoso-vad-doc virtuoso-vad-demo virtuoso-vad-tutorial
#   virtuoso-vad-rdfmappers virtuoso-vad-sparqldemo virtuoso-vad-syncml
#   virtuoso-vad-bpel virtuoso-vad-isparql virtuoso-vad-ods virtuoso-vad-dbpedia
#   virtuoso-vad-facetedbrowser
# The following NEW packages will be installed:
#   libvirtodbc0 virtuoso-opensource virtuoso-opensource-6.1
#   virtuoso-opensource-6.1-bin virtuoso-opensource-6.1-common virtuoso-server
#   virtuoso-vad-conductor virtuoso-vsp-startpage
# 0 upgraded, 8 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,835 kB of archives.
# After this operation, 27.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1-common amd64 6.1.6+repack-0ubuntu9 [45.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1-bin amd64 6.1.6+repack-0ubuntu9 [2,831 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvirtodbc0 amd64 6.1.6+repack-0ubuntu9 [259 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1 amd64 6.1.6+repack-0ubuntu9 [163 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource all 6.1.6+repack-0ubuntu9 [33.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-vad-conductor all 6.1.6+repack-0ubuntu9 [1,044 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-vsp-startpage all 6.1.6+repack-0ubuntu9 [428 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-server all 6.1.6+repack-0ubuntu9 [31.0 kB]
# Fetched 4,835 kB in 2s (2,318 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package virtuoso-opensource-6.1-common.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../0-virtuoso-opensource-6.1-common_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1-common (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource-6.1-bin.
# Preparing to unpack .../1-virtuoso-opensource-6.1-bin_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1-bin (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package libvirtodbc0.
# Preparing to unpack .../2-libvirtodbc0_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking libvirtodbc0 (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource-6.1.
# Preparing to unpack .../3-virtuoso-opensource-6.1_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1 (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource.
# Preparing to unpack .../4-virtuoso-opensource_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-opensource (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-vad-conductor.
# Preparing to unpack .../5-virtuoso-vad-conductor_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-vad-conductor (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-vsp-startpage.
# Preparing to unpack .../6-virtuoso-vsp-startpage_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-vsp-startpage (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-server.
# Preparing to unpack .../7-virtuoso-server_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-server (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1-bin (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1-common (6.1.6+repack-0ubuntu9) ...
# Setting up libvirtodbc0 (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1 (6.1.6+repack-0ubuntu9) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up virtuoso-opensource (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-server (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-vad-conductor (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-vsp-startpage (6.1.6+repack-0ubuntu9) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for systemd (237-3ubuntu10.53) ...

# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 6.3 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.20.0-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 55.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 56.0 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 70.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 69.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.11.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=fcba13f18fa65eda970d35523525cb3c817ff4e9efeeb95c56c0600f8cf7edfa
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.20.0

# %%
# !pip install eurostat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting eurostat
#   Downloading eurostat-0.2.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from eurostat) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from eurostat) (1.3.5)
# Collecting pandasdmx<=0.9
#   Downloading pandaSDMX-0.9-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.2 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pandasdmx<=0.9->eurostat) (57.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandasdmx<=0.9->eurostat) (4.2.6)
# Collecting jsonpath-rw
#   Downloading jsonpath-rw-1.4.0.tar.gz (13 kB)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.3 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from jsonpath-rw->pandasdmx<=0.9->eurostat) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from jsonpath-rw->pandasdmx<=0.9->eurostat) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->eurostat) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->eurostat) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->eurostat) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->eurostat) (1.24.3)
# Building wheels for collected packages: jsonpath-rw
#   Building wheel for jsonpath-rw (setup.py) ... done
#   Created wheel for jsonpath-rw: filename=jsonpath_rw-1.4.0-py3-none-any.whl size=15147 sha256=ee1b476a6aebb78ea4bcbf76d0ce709e568c61011064229820ed419acd938fa9
#   Stored in directory: /root/.cache/pip/wheels/58/88/2a/8d619cf38d7cf939e54b6ccdece05d31b64b3eb419c11d1ed3
# Successfully built jsonpath-rw
# Installing collected packages: ply, jsonpath-rw, pandasdmx, eurostat
# Successfully installed eurostat-0.2.3 jsonpath-rw-1.4.0 pandasdmx-0.9 ply-3.11

# %% [markdown]
# ### Imports and settings

# %%
import gensim
import pandas as pd
import numpy as np
import re
#import nltk, os

import sklearn

import ipywidgets as widgets
import json
from sentence_transformers import SentenceTransformer, CrossEncoder, util
#import gzip
import torch
import random

#import pyodbc

#from collections import defaultdict
from sentence_transformers import SentenceTransformer, SentencesDataset
#from sentence_transformers.losses import TripletLoss, CosineSimilarityLoss, MultipleNegativesRankingLoss
from sentence_transformers.losses import MultipleNegativesRankingLoss
from sentence_transformers.readers import LabelSentenceReader, InputExample
from torch.utils.data import DataLoader

from pathlib import Path
from google.colab import data_table, drive
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances, euclidean_distances

from SPARQLWrapper import SPARQLWrapper, POST, DIGEST, GET
#from SPARQLWrapper import JSON, INSERT, DELETE
from SPARQLWrapper import JSON
import sparql_dataframe

# %% [markdown]
# ### Connect to the Virtuoso database

# %%
user = 'xxxxx'
passw = 'xxxxx'

# %%
def connect_virtuoso(DSN, UID, PWD):

    sparql = SPARQLWrapper(DSN)
    sparql.setHTTPAuth(DIGEST)
    sparql.setCredentials(UID, PWD)
    sparql.setMethod(GET)

    return sparql

# Connection to the KDB 
endpoint = "http://lod.csd.auth.gr:8890/sparql/"
sparql = connect_virtuoso(endpoint,user,passw)

# %% [markdown]
# ###The data cleansing function

# %%
def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) 
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) 

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    x = re.sub(r'â.{2}',"'",x) ### !!! NEW: single quotes are read as: âXX
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    #x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x

def lemmatize_text(text): ## only alphanumeric characters and drop stop-words
    return [lemmatizer.lemmatize(w).lower() for w in w_tokenizer.tokenize(text) if w.isalnum() and not w.lower() in stop
           and not re.match(r'^[0-9]+$',w) and len(w) >=5]


def lemmatize_list(x):
    str = ' '.join(x)
    return ' '.join(lemmatize_text(str))

# %% [markdown]
# ###Select Bi-encoder model

# %%
# Load pre-trained model that we will use as a base for fine tuning
# By Default it loads the first in options
# Warning: loading 2nd or 3rd model for finetuning requires large amounts of memory

bi_encoder_model_dropdown = widgets.Dropdown(options=["multi-qa-MiniLM-L6-cos-v1", "multi-qa-distilbert-cos-v1", "multi-qa-mpnet-base-cos-v1"])
display(widgets.HBox([widgets.Label(value="Bi-encoder model:"), bi_encoder_model_dropdown]))
# Out:
# HBox(children=(Label(value='Bi-encoder model:'), Dropdown(options=('multi-qa-MiniLM-L6-cos-v1', 'multi-qa-dist…

# %%
#We use the Bi-Encoder to encode all passages, so that we can use it with semantic search
bi_encoder = SentenceTransformer(bi_encoder_model_dropdown.value)
# Out:
# Downloading:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.22k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/25.5k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/383 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.8k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %% [markdown]
# ### SE Glossary articles
#
# * Titles, URLs and definitions.
# * Exclude some redirections.
# * Exclude one invalid URL from a remnant empty page.

# %% [markdown]
# ### The SPARQL query

# %%
RelationsStatements = """
DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
select ?a ?title ?content where {
    # ?a a estat:GlossaryArticle .
    # ?a estat:title ?title .
    # ?a estat:hasURL ?url.
    # ?a estat:content ?content .
    filter(!regex(?content, "^(The revision|Redirect to)")) 
    filter( regex(?url, "Glossary:")) 
} 
"""
## estat:GlossaryArticle OR StatisticsExplainedArticle
  
sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
GL_df = sparql.query().convert()['results']['bindings']
GL_df = pd.json_normalize(GL_df)
print(GL_df.columns)
# Out:
# Index(['a.type', 'a.value', 'title.type', 'title.value', 'content.type',
#        'content.value'],
#       dtype='object')

# %% [markdown]
# ### Processing and cleansing

# %%
GL_df.rename(columns={'title.value':'title','content.value':'content'},inplace=True)
GL_df['article_id'] = range(len(GL_df))
GL_df = GL_df[['article_id','title','content']]

GL_df= GL_df.replace('', np.nan) ## Check for anything empty
print(GL_df.isnull().sum())

GL_df['title'] = GL_df['title'].apply(clean).apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes
GL_df['content'] = GL_df['content'].apply(clean)
GL_df
# Out:
# article_id    0
# title         0
# content       0
# dtype: int64
#       article_id                       title  \
# 0              0            Accident at work
# 1              1  Gross domestic product GDP
# 2              2                    Toxicity
# 3              3             Structural fund
# 4              4                     PRODCOM
# ...          ...                         ...
# 1276        1276        Gross operating rate
# 1277        1277     Gross operating surplus
# 1278        1278             Personnel costs
# 1279        1279                     Stratum
# 1280        1280                   Subsidies
#
#                                                 content
# 0     An accident at work in the framework of the ad...
# 1     Gross domestic product abbreviated as GDP is a...
# 2     Toxicity measures the degree to which a substa...
# 3     The Structural funds are funding instruments t...
# 4     PRODCOM is an annual survey for the collection...
# ...                                                 ...
# 1276  The gross operating rate in structural busines...
# 1277  Gross operating surplus or profits is defined ...
# 1278  Within the context of structural business stat...
# 1279  In statistics a stratum plural strata refers t...
# 1280  Subsidies are current payments by the general ...
#
# [1281 rows x 3 columns]

# %% [markdown]
# ### Add paragraphs titles and contents from the SE articles
#
# * Excluding abstracts.

# %% [markdown]
# ### The SPARQL query

# %%
RelationsStatements = """
DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
select ?x ?t1 ?c where {
    # ?x a estat:StatisticsExplainedArticle .
    # ?x estat:hasParagraph  ?h .
    # ?h estat:title ?t1 .
    FILTER(?t1!="Abstract") .
    # ?h estat:content ?c .
} 
"""
  
sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
add_content = sparql.query().convert()['results']['bindings']
add_content = pd.json_normalize(add_content)
print(add_content.columns)
# Out:
# Index(['x.type', 'x.value', 't1.type', 't1.value', 'c.type', 'c.value'], dtype='object')

# %% [markdown]
# ### Processing and cleansing
#
# * Also delete duplicate titles.

# %%
add_content.rename(columns={'t1.value':'title','c.value':'content'},inplace=True)

## add_content = add_content[['title','content']].copy()

add_content['title'] = add_content['title'].apply(clean).apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes
add_content['content'] = add_content['content'].apply(clean)

add_content= add_content.replace('', np.nan) ## Check for anything empty
print(add_content.isnull().sum())

### DELETE NOT EXPRESSIVE TITLES!
### For safety: delete all duplicates
add_content.drop_duplicates(subset=['title'],keep=False,inplace=True)
add_content.reset_index(drop=True, inplace=True)
add_content['article_id'] = range(len(add_content))
add_content = add_content[['article_id','title','content']]
add_content
# Out:
# x.type     0
# x.value    0
# t1.type    0
# title      0
# c.type     0
# content    0
# dtype: int64
#       article_id                                              title  \
# 0              0  Why is coordination important to support stati...
# 1              1  Who are the key technical and financial partne...
# 2              2  The technical and financial partners support t...
# 3              3            Eurostat s statistical cooperation unit
# 4              4                  Official statistics in a nutshell
# ...          ...                                                ...
# 2775        2775                      Monthly and quarterly indices
# 2776        2776                              Annual overlap method
# 2777        2777                         One quarter overlap method
# 2778        2778                               Over the year method
# 2779        2779  Recommendations of the Eurostat Task Force Cha...
#
#                                                 content
# 0     More and better aid requires coordination and ...
# 1     A wide range of international organisations an...
# 2     The PARIS21 consortium plays an important role...
# 3     Eurostat s statistical cooperation unit provid...
# 4     Definition International principles Statistics...
# ...                                                 ...
# 2775  Short term business statistics provide data e ...
# 2776  In the annual overlap method the indices for a...
# 2777  In the one quarter overlap method the indices ...
# 2778  In the over the year method the indices for a ...
# 2779  Between 2010 and 2012 a task force of experts ...
#
# [2780 rows x 3 columns]

# %% [markdown]
# ### Read OECD's terms, contexts and definitions

# %% [markdown]
# ### The SPARQL query

# %%
RelationsStatements = """
DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
select ?a ?title ?context ?definition where{
    # ?a a estat:OECDTerm .
    # ?a estat:term ?title .
    optional { ?a estat:context ?context }
    # ?a estat:definition ?definition .
}
"""
  
sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
OECD_df = sparql.query().convert()['results']['bindings']
OECD_df = pd.json_normalize(OECD_df)
print(OECD_df.columns)
# Out:
# Index(['a.type', 'a.value', 'title.type', 'title.value', 'context.type',
#        'context.value', 'definition.type', 'definition.value'],
#       dtype='object')

# %% [markdown]
# ### Processing and cleansing

# %%
OECD_df.rename(columns={'title.value':'title','definition.value':'definition','context.value':'context'},inplace=True)

OECD_df.replace('',np.nan,inplace=True)
print(OECD_df.isnull().sum()) ## check for missing values

OECD_df['title'] = OECD_df['title'].apply(clean).apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes
OECD_df['definition'] = OECD_df['definition'].apply(clean)
OECD_df['context'] = OECD_df['context'].apply(clean)

OECD_df['article_id'] = range(len(OECD_df))
OECD_df = OECD_df[['article_id','title','definition','context']]
OECD_df
# Out:
# a.type                0
# a.value               0
# title.type            0
# title                 0
# context.type       5535
# context            5535
# definition.type       0
# definition            0
# dtype: int64
#       article_id                                              title  \
# 0              0                                     Abatement cost
# 1              1                              Abnormal obsolescence
# 2              2                         Abuse of dominant position
# 3              3  Accessibility as a statistical data quality di...
# 4              4                Accountability in management theory
# ...          ...                                                ...
# 6927        6927                                      Zero sum game
# 6928        6928                                       Zero tillage
# 6929        6929                                              Zones
# 6930        6930                                             Zoning
# 6931        6931                                                ZPG
#
#                                              definition  \
# 0     Abatement costs refer to expenditures which re...
# 1     Abnormal obsolescence is the loss in value of ...
# 2     The term abuse of dominant position refers to ...
# 3     The ease and the conditions with which statist...
# 4     A key concept in modern management theory and ...
# ...                                                 ...
# 6927  A game played by a number of persons in which ...
# 6928                                   Refer No tillage
# 6929  See Main Economic Indicator main country group...
# 6930  Zoning is the process in physical planning or ...
# 6931                         See Zero population growth
#
#                                                 context
# 0     The calculation of imputed abatement costs doe...
# 1     Abnormal obsolescence may occur because of a n...
# 2     These business practices by the firm not witho...
# 3     Accessibility refers to the availability of st...
# 4     The person or body to which the manager must r...
# ...                                                 ...
# 6927                                                NaN
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN
# 6931                                                NaN
#
# [6932 rows x 4 columns]

# %% [markdown]
# ### Split into two (title,content) collections

# %%
# using title-definition pairs
OECD_df1 = OECD_df[['article_id','title','definition']]
OECD_df1 = OECD_df1.rename(columns={'definition':'content'})

# using title-context pairs
OECD_df2 = OECD_df[['article_id','title','context']]
OECD_df2 = OECD_df2.rename(columns={'context':'content'})

OECD_df1 = OECD_df1[['article_id','title','content']]
OECD_df2 = OECD_df2[['article_id','title','content']]

# deleting empty
OECD_df1['content'] = OECD_df1['content'].replace('', np.nan)
OECD_df1 = OECD_df1.dropna(axis=0,subset=['content'])
OECD_df1['title'] = OECD_df1['title'].replace('', np.nan)
OECD_df1 = OECD_df1.dropna(axis=0,subset=['title'])

OECD_df2['content'] = OECD_df2['content'].replace('', np.nan)
OECD_df2 = OECD_df2.dropna(axis=0,subset=['content'])
OECD_df2['title'] = OECD_df2['title'].replace('', np.nan)
OECD_df2 = OECD_df2.dropna(axis=0,subset=['title'])

# %%
OECD_df1
# Out:
#       article_id                                              title  \
# 0              0                                     Abatement cost
# 1              1                              Abnormal obsolescence
# 2              2                         Abuse of dominant position
# 3              3  Accessibility as a statistical data quality di...
# 4              4                Accountability in management theory
# ...          ...                                                ...
# 6927        6927                                      Zero sum game
# 6928        6928                                       Zero tillage
# 6929        6929                                              Zones
# 6930        6930                                             Zoning
# 6931        6931                                                ZPG
#
#                                                 content
# 0     Abatement costs refer to expenditures which re...
# 1     Abnormal obsolescence is the loss in value of ...
# 2     The term abuse of dominant position refers to ...
# 3     The ease and the conditions with which statist...
# 4     A key concept in modern management theory and ...
# ...                                                 ...
# 6927  A game played by a number of persons in which ...
# 6928                                   Refer No tillage
# 6929  See Main Economic Indicator main country group...
# 6930  Zoning is the process in physical planning or ...
# 6931                         See Zero population growth
#
# [6932 rows x 3 columns]

# %%
OECD_df2
# Out:
#       article_id                                              title  \
# 0              0                                     Abatement cost
# 1              1                              Abnormal obsolescence
# 2              2                         Abuse of dominant position
# 3              3  Accessibility as a statistical data quality di...
# 4              4                Accountability in management theory
# ...          ...                                                ...
# 6590        6590                                 World Wide Web WWW
# 6591        6591                               Year on year changes
# 6592        6592                      Year on year YoY growth rates
# 6593        6593                                  Zero coupon bonds
# 6594        6594                     Zero coupon deep discount bond
#
#                                                 content
# 0     The calculation of imputed abatement costs doe...
# 1     Abnormal obsolescence may occur because of a n...
# 2     These business practices by the firm not witho...
# 3     Accessibility refers to the availability of st...
# 4     The person or body to which the manager must r...
# ...                                                 ...
# 6590  Originally developed by the European Laborator...
# 6591  Also often referred to as Year over year chang...
# 6592  Also often referred to as Year over year growt...
# 6593  Zero coupon and deep discount bonds have four ...
# 6594  There are three main advantages of zero or dee...
#
# [1397 rows x 3 columns]

# %%
del (OECD_df)

# %% [markdown]
# ### Processing and cleansing

# %% [markdown]
# ###Abstracts and context sections from SE articles

# %% [markdown]
# ### The SPARQL query

# %%
RelationsStatements = """
DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
select ?x ?title ?url ?partitle ?context ?content where {
    # ?x a estat:StatisticsExplainedArticle .
    # ?x estat:title ?title .
    # ?x estat:hasURL ?url .
    optional{?x estat:context ?context} .
optional {
    # ?x estat:hasParagraph  ?h .
    # ?h estat:title ?partitle .
    filter(?partitle="Abstract") .
    # ?h estat:content ?content .
}
} 
"""

sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
SE_df = sparql.query().convert()['results']['bindings']
SE_df = pd.json_normalize(SE_df)
print(SE_df.columns)
# Out:
# Index(['x.type', 'x.value', 'title.type', 'title.value', 'url.type',
#        'url.datatype', 'url.value', 'partitle.type', 'partitle.value',
#        'context.type', 'context.value', 'content.type', 'content.value'],
#       dtype='object')

# %% [markdown]
# ### Processing and cleansing

# %%
SE_df.rename(columns={'title.value':'title','partitle.value':'has_abstract','url.value':'url','context.value':'context','content.value':'abstract'},inplace=True)

SE_df.replace('',np.nan,inplace=True)
SE_df.replace('NaN',np.nan,inplace=True)
SE_df.replace('nan',np.nan,inplace=True)
SE_df.replace('None',np.nan,inplace=True)

print(SE_df.isnull().sum()) ## check for missing values


SE_df['article_id'] = range(len(SE_df))
SE_df = SE_df[['article_id','title','url','has_abstract','abstract','context']].copy()

SE_df['title'] = SE_df['title'].apply(clean).apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes
SE_df['context'] = SE_df['context'].apply(clean)
SE_df['abstract'] = SE_df['abstract'].apply(clean)


SE_df
# Out:
# x.type             0
# x.value            0
# title.type         0
# title              0
# url.type           0
# url.datatype       0
# url                0
# partitle.type     11
# has_abstract      11
# context.type     279
# context          304
# content.type      11
# abstract          42
# dtype: int64
#      article_id                                              title  \
# 0             0    Chemicals production and consumption statistics
# 1             1  Globalisation patterns in EU trade and investment
# 2             2  Statistical cooperation European Neighbourhood...
# 3             3     Territorial typologies manual acknowledgements
# 4             4  Statistics in development cooperation budget s...
# ..          ...                                                ...
# 887         887  Short term business statistics seasonal adjust...
# 888         888  Short term business statistics and annual chai...
# 889         889  Early estimates of income inequalities during ...
# 890         890                       The EU in the world business
# 891         891       The EU in the world research and development
#
#                                                    url has_abstract  \
# 0    https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# 1    https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# 2    https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# 3    https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# 4    https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# ..                                                 ...          ...
# 887  https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# 888  https://ec.europa.eu/eurostat/statistics-expla...     Abstract
# 889  https://ec.europa.eu/eurostat/statistics-expla...          NaN
# 890  https://ec.europa.eu/eurostat/statistics-expla...          NaN
# 891  https://ec.europa.eu/eurostat/statistics-expla...          NaN
#
#                                               abstract  \
# 0    This article presents an analysis of indicator...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    This article is part of a set of background ar...
# ..                                                 ...
# 887  This article describes the seasonal adjustment...
# 888  This article is part of a set of background ar...
# 889                                                NaN
# 890                                                NaN
# 891                                                NaN
#
#                                                context
# 0    The General Union Environment Action Programme...
# 1                                                  NaN
# 2    The ENP was developed in 2004 with the objecti...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 887                                                NaN
# 888                                                NaN
# 889  In the current extraordinary context of the Co...
# 890  Industrial activities such as manufacturing ar...
# 891  Practical applications of science are integrat...
#
# [892 rows x 6 columns]

# %%
# using title-context pairs
SE_df1 = SE_df[['article_id','title','context']]
SE_df1 = SE_df1.rename(columns={'context':'content'})

# using title-abstract pairs
SE_df2 = SE_df[['article_id','title','abstract']]
SE_df2 = SE_df2.rename(columns={'abstract':'content'})

# deleting empty
SE_df1['content'] = SE_df1['content'].replace('', np.nan)
SE_df1 = SE_df1.dropna(axis=0,subset=['content'])
SE_df1.reset_index(drop=True,inplace=True)

SE_df2['content'] = SE_df2['content'].replace('', np.nan).replace('nan', np.nan)
SE_df2 = SE_df2.dropna(axis=0,subset=['content'])
SE_df2.reset_index(drop=True,inplace=True)

# %%
SE_df1
# Out:
#      article_id                                              title  \
# 0             0    Chemicals production and consumption statistics
# 1             2  Statistical cooperation European Neighbourhood...
# 2             5              Intra EU trade exchange of micro data
# 3             7  Differences between balance of payments and fo...
# 4             8          Causes of death statistics people over 65
# ..          ...                                                ...
# 583         856  Sample size and non response quarterly statistics
# 584         857  Review of national supply use and input output...
# 585         889  Early estimates of income inequalities during ...
# 586         890                       The EU in the world business
# 587         891       The EU in the world research and development
#
#                                                content
# 0    The General Union Environment Action Programme...
# 1    The ENP was developed in 2004 with the objecti...
# 2    International trade in goods statistics provid...
# 3    The EU is a major player in the global economy...
# 4    Statistics concerning causes of death among pe...
# ..                                                 ...
# 583  The COVID 19 health crisis hit Europe in Janua...
# 584  Eurostat has carried out a survey to update in...
# 585  In the current extraordinary context of the Co...
# 586  Industrial activities such as manufacturing ar...
# 587  Practical applications of science are integrat...
#
# [588 rows x 3 columns]

# %%
SE_df2
# Out:
#      article_id                                              title  \
# 0             0    Chemicals production and consumption statistics
# 1             4  Statistics in development cooperation budget s...
# 2             5              Intra EU trade exchange of micro data
# 3             6  EU Labour Force Survey new methodology from 20...
# 4             7  Differences between balance of payments and fo...
# ..          ...                                                ...
# 845         884   Short term business statistics observation units
# 846         885   Short term business statistics quality and scope
# 847         886           Short term business statistics revisions
# 848         887  Short term business statistics seasonal adjust...
# 849         888  Short term business statistics and annual chai...
#
#                                                content
# 0    This article presents an analysis of indicator...
# 1    This article is part of a set of background ar...
# 2    This article presents the innovative statistic...
# 3    This article describes the methodology of the ...
# 4    Author Robert Obrzut Balance of payments stati...
# ..                                                 ...
# 845  A common definition of observation units also ...
# 846  This article presents various quality aspects ...
# 847  Revisions are defined as any change in a value...
# 848  This article describes the seasonal adjustment...
# 849  This article is part of a set of background ar...
#
# [850 rows x 3 columns]

# %%
del(SE_df)

# %% [markdown]
# ###Eurostat's Concepts and Definitions Database

# %% [markdown]
# ### The SPARQL query

# %%
RelationsStatements = """
DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
select ?a ?term ?definition where {
    # ?a a estat:CODEDTerm  .
    # ?a estat:term ?term .
    # ?a estat:definition ?definition .
} 
"""
sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
CODED_df = sparql.query().convert()['results']['bindings']
CODED_df = pd.json_normalize(CODED_df)
print(CODED_df.columns)
# Out:
# Index(['a.type', 'a.value', 'term.type', 'term.value', 'definition.type',
#        'definition.value'],
#       dtype='object')

# %% [markdown]
# ### Processing and cleansing

# %%
CODED_df.rename(columns={'term.value':'title','definition.value':'content'},inplace=True)

CODED_df.replace('',np.nan,inplace=True)
print(CODED_df.isnull().sum()) ## check for missing values


CODED_df['article_id'] = range(len(CODED_df))
CODED_df = CODED_df[['article_id','title','content']].copy()

CODED_df['title'] = CODED_df['title'].apply(clean).apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes
CODED_df['content'] = CODED_df['content'].apply(clean)



CODED_df
# Out:
# a.type             0
# a.value            0
# term.type          0
# title              0
# definition.type    0
# content            0
# dtype: int64
#        article_id                                              title  \
# 0               0                                           n k rule
# 1               1                                           Abortion
# 2               2             Achieved sample size ratio for persons
# 3               3                                       Capital good
# 4               4                                Technical expertise
# ...           ...                                                ...
# 11215       11215                                            Taxiway
# 11216       11216                                           Taxonomy
# 11217       11217                                            Teacher
# 11218       11218  Technical action plan for agricultural statistics
# 11219       11219                       Technical cooperation grants
#
#                                                  content
# 0      A cell is regarded as confidential if the n la...
# 1      Induced expulsion of the foetus during the fir...
# 2      Ratio of the number of completed personal inte...
# 3      Capital goods are goods other than material in...
# 4      A firms knowledge of and ability to use techno...
# ...                                                  ...
# 11215  A defined path on an airport established for t...
# 11216  Classification of things according to a presum...
# 11217  A person employed in an official capacity for ...
# 11218  In order to improve the way in which Community...
# 11219  There are two basic types of technical coopera...
#
# [11220 rows x 3 columns]

# %% [markdown]
# ###Merging all available glossaries and articles

# %%
# merge OECD glossary with add_content, GL_df and SE_df
glossaries = [OECD_df1, OECD_df2, GL_df, add_content, SE_df1, SE_df2,CODED_df]
merged_glossary = pd.concat(glossaries, ignore_index=True)

del(OECD_df1, OECD_df2, GL_df, add_content, SE_df1, SE_df2, CODED_df, glossaries)

# %%
# setting all pairs of titles and content to have a label of 1
# this is because all pairs are considered a positive example
merged_glossary['is_pair']=1

# %% [markdown]
# ### Analyse distribution of number of tokens (column "content")

# %%
tokenizer = bi_encoder.tokenizer

# %%
# The warning message does not affect the model, because the texts are
# automatically truncated when exceeding the maximum sequence lenth

tokens_count = []
for i in range(len(merged_glossary['content'])):
  tokens_count.append(len(tokenizer.tokenize(merged_glossary['content'][i])))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (838 > 512). Running this sequence through the model will result in indexing errors

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(tokens_count, bins=500)
plt.ylabel('frequency')
plt.xlabel('tokens')
plt.show()

# %%
# "zooming in" to 0-2500 in x axis
plt.hist(tokens_count, bins=500, range=(-1, 2500))
plt.ylabel('frequency')
plt.xlabel('tokens')
plt.show()

# %%
tokens_count_df = pd.DataFrame(tokens_count)
tokens_count_df.describe()
# Out:
#                   0
# count  25048.000000
# mean     108.721335
# std      249.432087
# min        2.000000
# 25%       22.000000
# 50%       44.000000
# 75%       99.000000
# max    15382.000000

# %%
print(f"Number of articles that their number of words exceed the max_seq_length={bi_encoder.max_seq_length}\
 of the bi-encoder model: {len(tokens_count_df[tokens_count_df[0]>bi_encoder.max_seq_length])}/{len(tokens_count_df)}\
  ({len(tokens_count_df[tokens_count_df[0]>bi_encoder.max_seq_length])/len(tokens_count_df)*100}%)")
# Out:
# Number of articles that their number of words exceed the max_seq_length=512 of the bi-encoder model: 931/25048  (3.716863621846055%)

# %% [markdown]
# ### Keep 80% of data for training and 20% for evaluation of the model

# %%
from sklearn.model_selection import train_test_split
train_features, eval_features, train_labels, eval_labels = train_test_split(merged_glossary[['title','content']], 
                                                                            merged_glossary[['is_pair']], 
                                                                            train_size=0.8, 
                                                                            random_state=1,
                                                                            stratify=merged_glossary['is_pair'])

# %%
train_features = train_features.reset_index(drop=True)
eval_features = eval_features.reset_index(drop=True)

# %% [markdown]
# ###Fine tuning bi-encoder (CUDA required)

# %%
# convert training examples to the appropriate format
train_examples = []
for i in range(len(train_features)):
  train_examples.append(InputExample(texts=[train_features['title'].iloc[i], train_features['content'].iloc[i]]))

# %%
finetune_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)

# %%
# MultipleNegativesRankingLoss is a great loss function if you only have positive pairs 
loss = MultipleNegativesRankingLoss(model=bi_encoder)

# %%
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator, BinaryClassificationEvaluator, MSEEvaluator
from sentence_transformers import evaluation

sentences1 = list(eval_features['title'])
sentences2 = list(eval_features['content'])
scores_eval = list(eval_labels['is_pair'])

evaluator = evaluation.MSEEvaluator(sentences1, sentences2, teacher_model=bi_encoder)

# %%
#cleaning up any CUDA related left-overs
import gc
gc.collect()
# Out:
# 50

# %% [markdown]
# ### Set the path to save the model in the Google Drive

# %%
# Fine-tune the model (BE CAREFUL TO SET A PATH FOR THE FINE-TUNED MODEL)
num_epochs = 5
bi_encoder.fit(train_objectives=[(finetune_dataloader, loss)], evaluator=evaluator, epochs=num_epochs,output_path='/content/drive/MyDrive/Data for Use Case C/testing_fine_tuning')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1253 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1253 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1253 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1253 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1253 [00:00<?, ?it/s]

# %% [markdown]
# ###Loading the fine-tuned model

# %%
fine_tuned_bi_encoder = SentenceTransformer('/content/drive/MyDrive/Data for Use Case C/testing_fine_tuning')

# %%
bi_encoder = fine_tuned_bi_encoder

# %% [markdown]
# ## Get results

# %% [markdown]
# ### Loading the datasets information from the database
#
# * This is essentially the parsed content of table_of_contents.xml from the bulk download facility

# %% [markdown]
# ### The SPARQL query

# %%
RelationsStatements = """
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
select * where { 
	# ?dataset  estat:term ?code ;
    rdfs:label ?description;
    estat:databasePath ?path ;
    estat:fileLink ?link.
} 
"""
sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
crumbs_df = sparql.query().convert()['results']['bindings']
crumbs_df = pd.json_normalize(crumbs_df)
print(crumbs_df.columns)
# Out:
# Index(['dataset.type', 'dataset.value', 'code.type', 'code.datatype',
#        'code.value', 'description.type', 'description.datatype',
#        'description.value', 'path.type', 'path.datatype', 'path.value',
#        'link.type', 'link.datatype', 'link.value'],
#       dtype='object')

# %% [markdown]
# ### Processing and cleansing

# %%
crumbs_df.rename(columns={'description.value':'File description','code.value':'File code','path.value':'Names','link.value':'Link'},inplace=True)

crumbs_df.replace('',np.nan,inplace=True)
print(crumbs_df.isnull().sum()) ## check for missing values

crumbs_df.reindex(['File code','File description','Names','Link'], axis=1)

crumbs_df['Names'] = crumbs_df['Names'].apply(lambda x: x.split(';'))
crumbs_df['Full path'] = crumbs_df['Names'].apply(lambda x: [y for y in x[1:]]) ## exclude first part

# Drop duplicates with the same file code
crumbs_df = crumbs_df.drop_duplicates(subset='File code', keep="first").reset_index(drop=True)
crumbs_df
# Out:
# dataset.type            0
# dataset.value           0
# code.type               0
# code.datatype           0
# File code               0
# description.type        0
# description.datatype    0
# File description        0
# path.type               0
# path.datatype           0
# Names                   0
# link.type               0
# link.datatype           0
# Link                    0
# dtype: int64
#      dataset.type                                      dataset.value  \
# 0             uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 1             uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 2             uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 3             uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 4             uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# ...           ...                                                ...
# 6812          uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6813          uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6814          uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6815          uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6816          uri  https://ec.europa.eu/eurostat/NLP4StatRef/know...
#
#           code.type                            code.datatype       File code  \
# 0     typed-literal  http://www.w3.org/2001/XMLSchema#string      aact_ali01
# 1     typed-literal  http://www.w3.org/2001/XMLSchema#string      aact_ali02
# 2     typed-literal  http://www.w3.org/2001/XMLSchema#string      aact_eaa01
# 3     typed-literal  http://www.w3.org/2001/XMLSchema#string      aact_eaa02
# 4     typed-literal  http://www.w3.org/2001/XMLSchema#string      aact_eaa03
# ...             ...                                      ...             ...
# 6812  typed-literal  http://www.w3.org/2001/XMLSchema#string    yth_incl_120
# 6813  typed-literal  http://www.w3.org/2001/XMLSchema#string    yth_part_010
# 6814  typed-literal  http://www.w3.org/2001/XMLSchema#string    yth_part_020
# 6815  typed-literal  http://www.w3.org/2001/XMLSchema#string    yth_part_030
# 6816  typed-literal  http://www.w3.org/2001/XMLSchema#string  yth_volunt_010
#
#      description.type                     description.datatype  \
# 0       typed-literal  http://www.w3.org/2001/XMLSchema#string
# 1       typed-literal  http://www.w3.org/2001/XMLSchema#string
# 2       typed-literal  http://www.w3.org/2001/XMLSchema#string
# 3       typed-literal  http://www.w3.org/2001/XMLSchema#string
# 4       typed-literal  http://www.w3.org/2001/XMLSchema#string
# ...               ...                                      ...
# 6812    typed-literal  http://www.w3.org/2001/XMLSchema#string
# 6813    typed-literal  http://www.w3.org/2001/XMLSchema#string
# 6814    typed-literal  http://www.w3.org/2001/XMLSchema#string
# 6815    typed-literal  http://www.w3.org/2001/XMLSchema#string
# 6816    typed-literal  http://www.w3.org/2001/XMLSchema#string
#
#                                        File description      path.type  \
# 0     Agricultural labour input statistics absolute ...  typed-literal
# 1          Agricultural labour input statistics indices  typed-literal
# 2     Economic accounts for agriculture values at cu...  typed-literal
# 3     Economic accounts for agriculture values at n ...  typed-literal
# 4     Economic accounts for agriculture values at co...  typed-literal
# ...                                                 ...            ...
# 6812  Young people living in households with very lo...  typed-literal
# 6813  Frequency of getting together with relatives o...  typed-literal
# 6814  Frequency of contacts with relatives or friend...  typed-literal
# 6815  Participation of young people in activities of...  typed-literal
# 6816  Participation of young people in informal volu...  typed-literal
#
#                                 path.datatype  \
# 0     http://www.w3.org/2001/XMLSchema#string
# 1     http://www.w3.org/2001/XMLSchema#string
# 2     http://www.w3.org/2001/XMLSchema#string
# 3     http://www.w3.org/2001/XMLSchema#string
# 4     http://www.w3.org/2001/XMLSchema#string
# ...                                       ...
# 6812  http://www.w3.org/2001/XMLSchema#string
# 6813  http://www.w3.org/2001/XMLSchema#string
# 6814  http://www.w3.org/2001/XMLSchema#string
# 6815  http://www.w3.org/2001/XMLSchema#string
# 6816  http://www.w3.org/2001/XMLSchema#string
#
#                                                   Names      link.type  \
# 0     [Database by themes,  Agriculture,  forestry a...  typed-literal
# 1     [Database by themes,  Agriculture,  forestry a...  typed-literal
# 2     [Database by themes,  Agriculture,  forestry a...  typed-literal
# 3     [Database by themes,  Agriculture,  forestry a...  typed-literal
# 4     [Database by themes,  Agriculture,  forestry a...  typed-literal
# ...                                                 ...            ...
# 6812  [Database by themes,  Population and social co...  typed-literal
# 6813  [Database by themes,  Population and social co...  typed-literal
# 6814  [Database by themes,  Population and social co...  typed-literal
# 6815  [Database by themes,  Population and social co...  typed-literal
# 6816  [Database by themes,  Population and social co...  typed-literal
#
#                                 link.datatype  \
# 0     http://www.w3.org/2001/XMLSchema#anyURI
# 1     http://www.w3.org/2001/XMLSchema#anyURI
# 2     http://www.w3.org/2001/XMLSchema#anyURI
# 3     http://www.w3.org/2001/XMLSchema#anyURI
# 4     http://www.w3.org/2001/XMLSchema#anyURI
# ...                                       ...
# 6812  http://www.w3.org/2001/XMLSchema#anyURI
# 6813  http://www.w3.org/2001/XMLSchema#anyURI
# 6814  http://www.w3.org/2001/XMLSchema#anyURI
# 6815  http://www.w3.org/2001/XMLSchema#anyURI
# 6816  http://www.w3.org/2001/XMLSchema#anyURI
#
#                                                    Link  \
# 0     https://ec.europa.eu/eurostat/estat-navtree-po...
# 1     https://ec.europa.eu/eurostat/estat-navtree-po...
# 2     https://ec.europa.eu/eurostat/estat-navtree-po...
# 3     https://ec.europa.eu/eurostat/estat-navtree-po...
# 4     https://ec.europa.eu/eurostat/estat-navtree-po...
# ...                                                 ...
# 6812  https://ec.europa.eu/eurostat/estat-navtree-po...
# 6813  https://ec.europa.eu/eurostat/estat-navtree-po...
# 6814  https://ec.europa.eu/eurostat/estat-navtree-po...
# 6815  https://ec.europa.eu/eurostat/estat-navtree-po...
# 6816  https://ec.europa.eu/eurostat/estat-navtree-po...
#
#                                               Full path
# 0     [ Agriculture,  forestry and fisheries,  Agric...
# 1     [ Agriculture,  forestry and fisheries,  Agric...
# 2     [ Agriculture,  forestry and fisheries,  Agric...
# 3     [ Agriculture,  forestry and fisheries,  Agric...
# 4     [ Agriculture,  forestry and fisheries,  Agric...
# ...                                                 ...
# 6812  [ Population and social conditions,  Youth,  Y...
# 6813  [ Population and social conditions,  Youth,  Y...
# 6814  [ Population and social conditions,  Youth,  Y...
# 6815  [ Population and social conditions,  Youth,  Y...
# 6816  [ Population and social conditions,  Youth,  Y...
#
# [6817 rows x 15 columns]

# %% [markdown]
# ###Calculate corpus embeddings in advance

# %%
# We encode all corpus into our vector space, using "File description" column. 
corpus_embeddings_simple = bi_encoder.encode(crumbs_df['File description'], convert_to_tensor=True, show_progress_bar=True)

# We encode all corpus into our vector space, using "Full path" column. 
corpus_embeddings_full = bi_encoder.encode(crumbs_df['Full path'], convert_to_tensor=True, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/214 [00:00<?, ?it/s]
# Batches:   0%|          | 0/214 [00:00<?, ?it/s]

# %%
#pre-download cross-encoder for re-ranking!
cross_encoder = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')
# Out:
# Downloading:   0%|          | 0.00/794 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/86.7M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# ## Simple UI - Run once the chunk below then just change inputs

# %%
import eurostat

codes = {'hazard': 16, 'time': 1169, 'nace_r1': 888, 'geo': 4017, 
    'age691': None, 'rbd': 412, 'time1': None, 'nace_r2': 1298, 
    'worktime': 31, 'metroreg': 422, 'geo91': None, 'injury': 50, 'physact': 22, 'ceparema': 37, 
    'modinj': 11, 'train': 12, 'wrkenv': 15, 'frequenc': 61, 'tra_cov': 32, 'stk_flow': 190, 'par_mar': 302, 
    'currency': 193, 'cities': 13507, 'indic_env': 81, 'emp_cont': 17, 'loadstat': 3, 'size_emp': 31, 'airp_pr': 25160, 
    'unit': 668, 'nst07': 104, 'wat_proc': 56, 'comspec': 3, 'sex': 7, 'time91': None, 'age': 651, 
    'workproc': 9, 'age91': None, 'citizen': 4017, 'port_iww': 1032, 'source': 14, 'c_cabot': 4017, 
    'wrkstat': 5, 'c_birth': 4017, 'rep_airp': 1116, 'deviatn': 11, 'matagent': 23, 'diagnose': 28, 
    'rep_mar': 1842, 'partner': 4017, 'c_regis': 4017, 'geo1': None, 'seabasin': 12}

def relevant_datasets(query, corpus_embeddings,howmany,show_meta,show_meta_ind):

    # Encode query into our vector space 
    question_embedding = bi_encoder.encode(query, convert_to_tensor=True)
    top_k = 100  # Number of  datasets we want to retrieve with the bi-encoder
    hits = util.semantic_search(question_embedding, corpus_embeddings, top_k=top_k)
    hits = hits[0]  # Get the hits for the first query
    hits_df = pd.DataFrame(hits)

    crumbs_df['corpus_id'] = crumbs_df.index
    hits_df1 = hits_df.merge(crumbs_df, on='corpus_id',how='left')
    hits_df1 = hits_df1[['corpus_id', 'score','File description', 'File code', 'Link']]

    #Re-ranking
    #Loading a cross-encoder model, and re-ranking the results of the bi-encoder
    #Cross-Encoder achieve higher performance than Bi-Encoders, however, they do not
    #scale well for large datasets. Here, it can make sense to combine Cross- and
    #Bi-Encoders, for Semantic Search scenarios: 
    #First, you use an efficient Bi-Encoder to retrieve e.g. the top-100 most
    #similar sentences for a query. Then, you use a Cross-Encoder to re-rank
    #these 100 hits by computing the score for every (query, hit) combination.

    a = hits_df1['File description']
    # Now, score all retrieved passages with the cross_encoder
    cross_inp = [[query, a[hit]] for hit in range(len(hits_df1))]
    cross_scores = cross_encoder.predict(cross_inp)

    # sigmoid function 
    def sigmoid(x):
      return 1 / (1 + np.exp(-x))
    # define vectorized sigmoid
    sigmoid_v = np.vectorize(sigmoid)
    cross_scores = sigmoid_v(cross_scores)

    hits_df1['cross_scores'] = cross_scores
    hits_df1 = hits_df1.sort_values(['cross_scores'],ascending=False).reset_index(drop=True)
    
    results = hits_df1[['corpus_id', 'cross_scores','File description', 'File code', 'Link']].head(howmany)
    
    hd = '<h3>Datasets descriptions in descending order of score - top '+str(howmany)+':</h3>'
    display(HTML(hd))
    display(HTML(results.to_html()))
    
    if show_meta:

        dst = pd.read_csv(results.loc[show_meta_ind,'Link'],sep='\t',low_memory=False)
        dcode=results.loc[show_meta_ind,'File code']
        
        dms = eurostat.get_sdmx_dims(dcode)
        h1 = '<h3>'+str(show_meta_ind)+': File code: '+dcode+'</h3>'
        h1 += '<h3>'+results.loc[show_meta_ind,'File description']+'</h3>'
        h1 += '<h3>Dimensions:</h3>'
        h1 += '  '.join('[' + x + ']' for x in dms)

        h2=''
        dims=dst.columns[0].split(',')
        dims = dims[:-1]+dims[-1].split('\\')
        
        tmp=dst.iloc[:,0].str.split(',',expand=True)
        
        for j in range(len(dims)-2): ## first the dimensions separated by comma
            if dims[j] not in codes.keys() or codes[dims[j]] != None:
                h2+='<h4>'+dims[j]+':</h4>'
                arr = pd.unique(tmp.iloc[:,j])
                for i in range(len(arr)):
                    h2+= '[ '+arr[i]+': '+eurostat.get_dic(dims[j])[arr[i]] +' ]'
        
        display(HTML(h1))
        display(HTML(h2))            
        display(HTML(dst.head().to_html()))

# %%
import ipywidgets as widgets
from ipywidgets import Layout
from IPython.display import HTML, display,clear_output

layout = widgets.Layout(width='600px', height='60px')

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
def relevant_datasets_to_text(corpus_embeddings_full, corpus_embeddings_simple): 
    
    first_text = 'In 2021 unemployment among young people in Greece increased. This was the result of recession over the last 10 years.'  
    style = {'description_width': 'initial'}
    
    textW = widgets.Textarea(
        value=first_text, 
        placeholder='Type something',
        description='',
        disabled=False,
        layout=Layout(width='90%', height='100px')
    )

    button = widgets.Button(description="Search")

    option = widgets.RadioButtons(
    options=['Simple description of datasets', 'Full-path description of datasets'],
    value='Full-path description of datasets', 
    layout={'width': 'max-content'}, 
    disabled=False
    )
    
    howmany = widgets.IntSlider(
        description='Display:',
        #tooltip='maximum:',
        value=20,
        min=1, 
        max = 30,
        style=style )
    howmany.style.handle_color = 'lightblue'
    
    show_more = widgets.Checkbox(
        value=True,
        description='Show metadata for row:',
        disabled=False,
        indent=True
     )
    
    select_ind = widgets.BoundedIntText(
        value=0,
        min=0,
        max=howmany.value-1,
        step=1,
        description='Row:',
        disabled=False,
        style={'description_width': 'initial'},
        layout = widgets.Layout(width='100px')
    )

    ui1=widgets.HBox([textW])
    ui2=widgets.HBox([option,button,howmany])
    ui3=widgets.HBox([show_more,select_ind])
    ui4=widgets.VBox([ui1,ui2,ui3])
    display(ui4, layout=Layout(align_items='center'))

    def on_button_clicked(b):
        clear_output()
        display(ui4, layout=Layout(align_items='center'))
        if option.value == 'Simple description of datasets':
            corpus_embeddings = corpus_embeddings_simple
        else:
          corpus_embeddings = corpus_embeddings_full
        relevant_datasets(textW.value,corpus_embeddings=corpus_embeddings, howmany=howmany.value,show_meta=show_more.value,show_meta_ind=select_ind.value)
       
    button.on_click(on_button_clicked)
    
    
relevant_datasets_to_text(corpus_embeddings_full, corpus_embeddings_simple)
# Out:
# VBox(children=(HBox(children=(Textarea(value='Quality of life depends on a variety of factors', layout=Layout(…
# <h3>Datasets descriptions in descending order of score - top 20:</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>corpus_id</th>
#       <th>cross_scores</th>
#       <th>File description</th>
#       <th>File code</th>
#       <th>Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2242</td>
#       <td>0.000429</td>
#       <td>Healthy life expectancy based on self perceived health</td>
#       <td>hlth_silc_17</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fhlth_silc_17.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4142</td>
#       <td>0.000181</td>
#       <td>Quality of education</td>
#       <td>med_ps24</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fmed_ps24.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5059</td>
#       <td>0.000084</td>
#       <td>Healthy life years at birth by sex</td>
#       <td>sdg_03_11</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fsdg_03_11.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6258</td>
#       <td>0.000084</td>
#       <td>Healthy life years at birth by sex</td>
#       <td>tps00150</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftps00150.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>524</td>
#       <td>0.000083</td>
#       <td>Life expectancy by age and sex</td>
#       <td>demo_mlexpec</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fdemo_mlexpec.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2201</td>
#       <td>0.000075</td>
#       <td>Healthy life years 1995 2003</td>
#       <td>hlth_hlye_h</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fhlth_hlye_h.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>526</td>
#       <td>0.000047</td>
#       <td>Life table by age and sex</td>
#       <td>demo_mlifetable</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fdemo_mlifetable.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2200</td>
#       <td>0.000047</td>
#       <td>Healthy life years by sex from 2004 onwards</td>
#       <td>hlth_hlye</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fhlth_hlye.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>525</td>
#       <td>0.000040</td>
#       <td>Life expectancy by age sex and educational attainment level</td>
#       <td>demo_mlexpecedu</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fdemo_mlexpecedu.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1442</td>
#       <td>0.000037</td>
#       <td>Life expectancy at birth by sex</td>
#       <td>enps_demo_mlexpec</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fenps_demo_mlexpec.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>5058</td>
#       <td>0.000037</td>
#       <td>Life expectancy at birth by sex</td>
#       <td>sdg_03_10</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fsdg_03_10.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>6295</td>
#       <td>0.000037</td>
#       <td>Life expectancy at birth by sex</td>
#       <td>tps00205</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftps00205.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>6298</td>
#       <td>0.000037</td>
#       <td>Life expectancy at birth by sex</td>
#       <td>tps00208</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftps00208.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>5638</td>
#       <td>0.000035</td>
#       <td>Healthy life years at age 65 by sex</td>
#       <td>tepsr_sp320</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftepsr_sp320.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>5693</td>
#       <td>0.000034</td>
#       <td>Healthy life years at 65 females</td>
#       <td>tespm130</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftespm130.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>3508</td>
#       <td>0.000031</td>
#       <td>Duration of working life</td>
#       <td>lfsi_dwl_a</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Flfsi_dwl_a.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>5692</td>
#       <td>0.000025</td>
#       <td>Healthy life years at 65 males</td>
#       <td>tespm120</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftespm120.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>6812</td>
#       <td>0.000020</td>
#       <td>Young people living in households with very low work intensity by sex age and living not living with parents</td>
#       <td>yth_incl_120</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fyth_incl_120.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>6215</td>
#       <td>0.000019</td>
#       <td>Life expectancy at age 65 by sex</td>
#       <td>tps00026</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Ftps00026.tsv.gz</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>557</td>
#       <td>0.000017</td>
#       <td>Life expectancy by age sex and NUTS 2 region</td>
#       <td>demo_r_mlifexp</td>
#       <td>https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&amp;file=data%2Fdemo_r_mlifexp.tsv.gz</td>
#     </tr>
#   </tbody>
# </table>
# <h3>0: File code: hlth_silc_17</h3><h3>Healthy life expectancy based on self perceived health</h3><h3>Dimensions:</h3>[FREQ]  [GEO]  [INDICATORS]  [INDIC_HE]  [OBS_FLAG]  [SEX]  [TIME]  [UNIT]
# <h4>unit:</h4>[ YR: Year ]<h4>indic_he:</h4>[ HE_50: Health expectancy in absolute values at 50 ][ HE_65: Health expectancy in absolute values at 65 ][ HE_BIRTH: Health expectancy in absolute values at birth  ]<h4>sex:</h4>[ F: Females ][ M: Males ][ T: Total ]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unit,indic_he,sex,geo\time</th>
#       <th>2020</th>
#       <th>2019</th>
#       <th>2018</th>
#       <th>2017</th>
#       <th>2016</th>
#       <th>2015</th>
#       <th>2014</th>
#       <th>2013</th>
#       <th>2012</th>
#       <th>2011</th>
#       <th>2010</th>
#       <th>2009</th>
#       <th>2008</th>
#       <th>2007</th>
#       <th>2006</th>
#       <th>2005</th>
#       <th>2004</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>YR,HE_50,F,AT</td>
#       <td>29.8</td>
#       <td>29.8</td>
#       <td>29.7</td>
#       <td>29.3</td>
#       <td>29.6</td>
#       <td>28.9</td>
#       <td>28.7</td>
#       <td>28.4</td>
#       <td>28.6</td>
#       <td>28.1</td>
#       <td>27.7</td>
#       <td>28.3</td>
#       <td>28.4</td>
#       <td>27.8</td>
#       <td>27.8</td>
#       <td>27.0</td>
#       <td>27.1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>YR,HE_50,F,BE</td>
#       <td>29.5</td>
#       <td>30.0 b</td>
#       <td>29.4</td>
#       <td>29.6</td>
#       <td>29.1</td>
#       <td>28.3</td>
#       <td>29.2</td>
#       <td>28.7</td>
#       <td>28.6</td>
#       <td>28.2</td>
#       <td>28.4</td>
#       <td>28.6</td>
#       <td>28.6</td>
#       <td>28.5</td>
#       <td>28.2</td>
#       <td>27.9</td>
#       <td>27.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>YR,HE_50,F,BG</td>
#       <td>24.3</td>
#       <td>25.2</td>
#       <td>24.5</td>
#       <td>24.0</td>
#       <td>23.9 b</td>
#       <td>23.1</td>
#       <td>22.9</td>
#       <td>23.5</td>
#       <td>22.6</td>
#       <td>22.3</td>
#       <td>21.9</td>
#       <td>21.2</td>
#       <td>20.4</td>
#       <td>18.8</td>
#       <td>17.5</td>
#       <td>:</td>
#       <td>:</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>YR,HE_50,F,CH</td>
#       <td>34.3</td>
#       <td>34.7</td>
#       <td>34.4</td>
#       <td>34.2</td>
#       <td>34.4</td>
#       <td>33.6</td>
#       <td>33.7</td>
#       <td>33.6</td>
#       <td>33.9</td>
#       <td>34.0</td>
#       <td>33.8</td>
#       <td>33.6</td>
#       <td>33.9</td>
#       <td>32.8</td>
#       <td>:</td>
#       <td>:</td>
#       <td>:</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>YR,HE_50,F,CY</td>
#       <td>29.3</td>
#       <td>29.6</td>
#       <td>29.8</td>
#       <td>30.5</td>
#       <td>30.9</td>
#       <td>29.1</td>
#       <td>28.9</td>
#       <td>27.3</td>
#       <td>27.2</td>
#       <td>25.7</td>
#       <td>26.0</td>
#       <td>25.2</td>
#       <td>25.4</td>
#       <td>23.4</td>
#       <td>23.0</td>
#       <td>22.5</td>
#       <td>:</td>
#     </tr>
#   </tbody>
# </table>
