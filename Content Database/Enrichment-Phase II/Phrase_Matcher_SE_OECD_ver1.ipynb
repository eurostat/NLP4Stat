# %% [markdown]
# # Statistics Explained  articles and matches with OECD's Glossary
#
# ## Objective: to build a common vocabulary and construct "profiles" of the terms of this vocabulary
#
# ### Installation instructions
# *    Download the notebook as "raw" file and save it with extension .ipynb (cut the .txt extension which is added)
# *    Install the necessary libraries from your jupyter command prompt. These, together with the versions used, are:
#     *    pyodbc==4.0.32
#     *    spacy==3.2.1
#     *    pandas==1.3.5
#     *    nltk==3.6.5
# *   Launch the notebook and put your own credentials for access to the Virtuoso database in the call to pyodbc.connect() in the chunk with title "Connect to the database"

# %% [markdown]
# ### The first time download the Spacy's library. Comment-out in subsequent runs
#
# * Note that we are using Spacy's "large" library.

# %%
import re
import pandas as pd
import spacy
import sys
from collections import Counter

## Run to install the language library, then comment-out
# !{sys.executable} -m spacy download en_core_web_lg

nlp = spacy.load('en_core_web_lg')
nlp.max_length = 1500000
print('Finished loading.')
# Out:
# Collecting en-core-web-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.2.0/en_core_web_lg-3.2.0-py3-none-any.whl (777.4 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in d:\programdata\anaconda3\lib\site-packages (from en-core-web-lg==3.2.0) (3.2.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.20.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.26.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.9.0)
# Requirement already satisfied: packaging>=20.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (21.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (4.62.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (8.0.13)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.1)
# Requirement already satisfied: setuptools in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (58.0.4)
# Requirement already satisfied: jinja2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.6.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.7.5)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in d:\programdata\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (4.0.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.26.7)
# Requirement already satisfied: colorama in c:\users\kimon\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\programdata\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Finished loading.

# %%
from datetime import datetime

def file_name(pre,ext):
    current_time = datetime.now() 
    return pre + '_'+ str(current_time.month)+ '_' + str(current_time.day) + \
                 '_' + str(current_time.hour)+ '_' + str(current_time.minute)  +'.'+ext

# %% [markdown]
# ### Connect to the database

# %%
import pyodbc
c = pyodbc.connect('DSN=Virtuoso All;DBA=ESTAT;UID=xxxxx;PWD=xxxxx')
cursor = c.cursor()

# %%
import re
#import unicodedata as ud

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) 
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) 

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    x = re.sub(r'â.{2}',"'",x) ### !!! NEW: single quotes are read as: âXX
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    #x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x

# %% [markdown]
# ### Statistics explained articles
#
# * IDs, titles from dat_link_info, with resource_information_id=1, i.e. Eurostat (see ESTAT.V1.mod_resource_information) and matching IDs from dat_article.
# * Carry out data cleansing on titles.

# %%
SQLCommand = """SELECT id, title 
                FROM ESTAT.V1.dat_link_info 
                WHERE resource_information_id=1 AND id IN (SELECT id FROM ESTAT.V1.dat_article) """

SE_df = pd.read_sql(SQLCommand,c)

SE_df['title'] = SE_df['title'].apply(clean)
SE_df.head(5)
# Out:
#    id                                              title
# 0   7                       Accidents at work statistics
# 1  13                          National accounts and GDP
# 2  16                Railway safety statistics in the EU
# 3  17               Railway freight transport statistics
# 4  18  Railway passenger transport statistics - quart...

# %% [markdown]
# ### Add paragraphs titles and contents
#
# * From dat_article_paragraph with abstract=0 (i.e. "no").
# * Match article_id from dat_article_paragraph with id from dat_article.
# * Carry out data cleansing on titles and paragraph contents.

# %%
SQLCommand = """SELECT article_id, title, content 
                FROM ESTAT.V1.dat_article_paragraph
                WHERE abstract=0 AND article_id IN (SELECT id FROM ESTAT.V1.dat_article) """

add_content = pd.read_sql(SQLCommand,c)
add_content['title'] = add_content['title'].apply(clean)
add_content['content'] = add_content['content'].apply(clean)
add_content
# Out:
#       article_id                                              title  \
# 0           2905  Absences from work sharply increase in first h...
# 1           2905  Absences: 9.5 % of employment in Q4 2019 and 1...
# 2           2905  Higher share of absences from work among women...
# 3           2905  Absences from work due to own illness or disab...
# 4           2905                 Absences from work due to holidays
# ...          ...                                                ...
# 3854       10539                General presentation and definition
# 3855       10539        Methodological aspects in asylum statistics
# 3856       10539        Methodological aspects in Dublin statistics
# 3857       10539  What questions can or cannot be answered with ...
# 3858       10539                                     Policy context
#
#                                                 content
# 0     Absences from work recorded unprecedented high...
# 1     The article's next figure (Figure 4) compares ...
# 2     Considering all four quarters of 2020, the sha...
# 3     From Q4 2019 to Q4 2020, the number of people ...
# 4     Expressed as a share of employed people, absen...
# ...                                                 ...
# 3854  Scope of asylum statistics and Dublin statisti...
# 3855  Annual aggregate of the number of asylum appli...
# 3856  Asymmetries For most of the collected Dublin s...
# 3857  How many asylum seekers are entering EU Member...
# 3858  The collected asylum statistics and Dublin sta...
#
# [3859 rows x 3 columns]

# %% [markdown]
# ### Aggregate above paragraph titles and contents  from SE articles paragraphs by article id
#
# * Create a column _raw content_ which gathers all paragraph titles and contents in one text per article.

# %%
add_content_grouped = add_content.groupby(['article_id'])[['title','content']].aggregate(lambda x: list(x))
add_content_grouped.reset_index(drop=False, inplace=True)
for i in range(len(add_content_grouped)):
    add_content_grouped.loc[i,'raw content'] = ''
    for (a,b) in zip(add_content_grouped.loc[i,'title'],add_content_grouped.loc[i,'content']):
        add_content_grouped.loc[i,'raw content'] += ' '+a + ' ' + b
add_content_grouped = add_content_grouped[['article_id','raw content']]    

add_content_grouped
# Out:
#      article_id                                        raw content
# 0             7   Number of accidents In 2018, there were 3.1 m...
# 1            13   Developments for GDP in the EU-27: growth sin...
# 2            16   Fall in the number of railway accidents 9 % f...
# 3            17   Downturn for EU transport performance in 2019...
# 4            18   Rail passenger transport performance continue...
# ..          ...                                                ...
# 860       10456   Problem After successfully identifying and jo...
# 861       10470   Problem In France, there was significant room...
# 862       10506   General overview Nine PEEIs concern short-ter...
# 863       10531   What are administrative sources? The term 'ad...
# 864       10539   Main points Asylum statistics and 'Dublin' st...
#
# [865 rows x 2 columns]

# %% [markdown]
# ### Merge raw content of SE articles with main file
#
# * Also, add title to definition.

# %%
SE_df = pd.merge(SE_df,add_content_grouped,left_on='id',right_on='article_id',how='inner')
SE_df.drop(['article_id'],axis=1,inplace=True)

SE_df['raw content'] = SE_df['title'] +'. '+SE_df['raw content']

SE_df.head(5)
# Out:
#    id                                              title  \
# 0   7                       Accidents at work statistics
# 1  13                          National accounts and GDP
# 2  16                Railway safety statistics in the EU
# 3  17               Railway freight transport statistics
# 4  18  Railway passenger transport statistics - quart...
#
#                                          raw content
# 0  Accidents at work statistics.  Number of accid...
# 1  National accounts and GDP.  Developments for G...
# 2  Railway safety statistics in the EU.  Fall in ...
# 3  Railway freight transport statistics.  Downtur...
# 4  Railway passenger transport statistics - quart...

# %% [markdown]
# ### Lemmatize 'raw content'
#
# * NLTK seems to be better than Spacy in lemmatization. Convert to lower-case before.

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

SE_df['raw content'] = SE_df['raw content'].apply(lambda x: x.lower())
SE_df['raw content']= SE_df['raw content'].apply(lemmatize_text)
SE_df['raw content']= [' '.join(map(str, l)) for l in SE_df['raw content']]
SE_df['raw content'] = SE_df['raw content'].apply(lambda x: x.upper())
SE_df
# Out:
#         id                                              title  \
# 0        7                       Accidents at work statistics
# 1       13                          National accounts and GDP
# 2       16                Railway safety statistics in the EU
# 3       17               Railway freight transport statistics
# 4       18  Railway passenger transport statistics - quart...
# ..     ...                                                ...
# 860  10456  Merging statistics and geospatial information,...
# 861  10470  Merging statistics and geospatial information,...
# 862  10506  Methods for compiling PEEIs in short-term busi...
# 863  10531  Building the System of National Accounts - adm...
# 864  10539                       Asylum statistics introduced
#
#                                            raw content
# 0    ACCIDENT AT WORK STATISTICS. NUMBER OF ACCIDEN...
# 1    NATIONAL ACCOUNT AND GDP. DEVELOPMENT FOR GDP ...
# 2    RAILWAY SAFETY STATISTIC IN THE EU. FALL IN TH...
# 3    RAILWAY FREIGHT TRANSPORT STATISTICS. DOWNTURN...
# 4    RAILWAY PASSENGER TRANSPORT STATISTIC - QUARTE...
# ..                                                 ...
# 860  MERGING STATISTIC AND GEOSPATIAL INFORMATION, ...
# 861  MERGING STATISTIC AND GEOSPATIAL INFORMATION, ...
# 862  METHOD FOR COMPILING PEEIS IN SHORT-TERM BUSIN...
# 863  BUILDING THE SYSTEM OF NATIONAL ACCOUNT - ADMI...
# 864  ASYLUM STATISTIC INTRODUCED. MAIN POINT ASYLUM...
#
# [865 rows x 3 columns]

# %% [markdown]
# ### OECD - Glossary of Statistical Terms
# https://stats.oecd.org/glossary/alpha.asp
#
# * Scrape terms and lemmatize.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

url = "https://stats.oecd.org/glossary/alpha.asp"
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
text = soup.get_text()
    
rows = soup.find_all('tr')
str_cells = str(rows)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
#print(cleantext)

list_rows = []
for row in rows:
    cells = row.find_all('a')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
#print(clean2)
#type(clean2)

df = pd.DataFrame(list_rows)
df.head(10)
df[0]=df[0].apply(lambda x: re.sub(r'\[',' ',x))
df[0]=df[0].apply(lambda x: re.sub(r'\]',' ',x))
df1 = df[0].str.split(',', expand=True)
df_t = df1.T
df_t=df_t[[22]]
df_t = df_t.rename(columns={22: 'term'})
nan_value = float("NaN")

df_t.replace(" ", nan_value, inplace=True)

df_t.dropna(subset = ["term"], inplace=True)
df_t.replace(" ", nan_value, inplace=True)
df_t.insert(0, 'id', range(len(df_t)))
df_t.reset_index(inplace=True)
df_t.drop(columns=['index'],inplace=True)
df_t.head()

df_t['lemmatized_term']= df_t['term'].apply(lambda x: x.lower())
df_t['lemmatized_term']= df_t['lemmatized_term'].apply(lemmatize_text)
df_t['lemmatized_term']= [' '.join(map(str, l)) for l in df_t['lemmatized_term']]
df_t['lemmatized_term']= df_t['lemmatized_term'].apply(lambda x: x.upper())
df_t
# Out:
#         id                               term  \
# 0        0                 A posteriori audit
# 1        1                     A priori audit
# 2        2         A programme language (APL)
# 3        3                          Abatement
# 4        4                     Abatement cost
# ...    ...                                ...
# 7074  7074   Zero-coupon / deep discount bond
# 7075  7075                  Zero-coupon bonds
# 7076  7076                              Zones
# 7077  7077                             Zoning
# 7078  7078                               ZPG
#
#                        lemmatized_term
# 0                   A POSTERIORI AUDIT
# 1                       A PRIORI AUDIT
# 2           A PROGRAMME LANGUAGE (APL)
# 3                            ABATEMENT
# 4                       ABATEMENT COST
# ...                                ...
# 7074  ZERO-COUPON / DEEP DISCOUNT BOND
# 7075                  ZERO-COUPON BOND
# 7076                              ZONE
# 7077                            ZONING
# 7078                               ZPG
#
# [7079 rows x 3 columns]

# %% [markdown]
# ### Prepare Spacy's PhraseMatcher by building a custom vocabulary from OECD's Glossary (from column 'lemmatized_term')

# %%
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp.vocab)
terms = df_t['lemmatized_term'].values.tolist()
# Only run nlp.make_doc to speed things up
patterns = [nlp.make_doc(text) for text in terms]
matcher.add("TerminologyList", patterns)

# %% [markdown]
# ### Apply PhraseMatcher
#
# * Collect results per SE article ('doc_id') in a dataframe 'res'. Ignore matches with 2 words or less.
# * Depending on length of match: columns '3-Phrases', '4-Phrases', '5-and-above-Phrases'. These will contain dictionaries with the matched lemmatized terms and their counts, in descending order of counts.
# * Column 'Terms' has a dictionary with the corresponding **original terms** in OECD's Glossary and their counts in the matches.

# %%
res = pd.DataFrame(index=range(len(SE_df)))
res['3-Phrases']=[[] for i in range(len(SE_df))]
res['4-Phrases']=[[] for i in range(len(SE_df))]
res['5-and-above-Phrases']=[[] for i in range(len(SE_df))]
res['Terms']=[dict() for i in range(len(SE_df))]
docs=nlp.pipe(SE_df['raw content'])
for (i,doc) in enumerate(docs):
    print(i)
    for sent in doc.sents:
        matches = matcher(sent)
        for match_id, start, end in matches:
            span = doc[start:end]
            n_words = len(span.text.split(' '))
            if n_words >= 3:
                doc_id = SE_df.loc[i,'id']
                idx = df_t.index[df_t['lemmatized_term'].str.contains(span.text,regex=False)].tolist()
                print(i,SE_df.loc[i,'title'],len(sent.text),'>',n_words,span.text,idx)
                res.loc[i,'doc_id']=doc_id
                for elem in df_t.loc[idx,'term'].values.tolist():
                    if elem in res.loc[i,'Terms'].keys():
                        res.loc[i,'Terms'][elem] +=1
                    else:
                        res.loc[i,'Terms'][elem] =1
                #res.loc[i,'Terms'].append(concepts_df.loc[idx,'term'].values.tolist())
                if n_words == 3:
                    res.loc[i,'3-Phrases'].append(span.text)
                elif n_words == 4:
                    res.loc[i,'4-Phrases'].append(span.text)
                else:
                    res.loc[i,'5-and-above-Phrases'].append(span.text)
# Out:
# 0
# 0 Accidents at work statistics 324 > 4 HEALTH AND SOCIAL WORK [1988, 3114]
# 1
# 1 National accounts and GDP 190 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 142 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 254 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 206 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 143 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 231 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 206 > 3 ANNUAL GROWTH RATE [242, 248]
# 1 National accounts and GDP 206 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 314 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 173 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 162 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 162 > 3 PURCHASING POWER STANDARD [5219]
# 1 National accounts and GDP 175 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 115 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 1 National accounts and GDP 262 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 1 National accounts and GDP 181 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 1 National accounts and GDP 254 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 1 National accounts and GDP 254 > 4 HEALTH AND SOCIAL WORK [1988, 3114]
# 1 National accounts and GDP 103 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 1 National accounts and GDP 143 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 158 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 371 > 4 HEALTH AND SOCIAL WORK [1988, 3114]
# 1 National accounts and GDP 275 > 4 HEALTH AND SOCIAL WORK [1988, 3114]
# 1 National accounts and GDP 122 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 1 National accounts and GDP 266 > 3 GROSS CAPITAL FORMATION [2806]
# 1 National accounts and GDP 292 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 204 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 1 National accounts and GDP 322 > 3 GROSS CAPITAL FORMATION [2806]
# 1 National accounts and GDP 322 > 6 EXTERNAL BALANCE OF GOOD AND SERVICE [2292]
# 1 National accounts and GDP 154 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 1 National accounts and GDP 229 > 3 COMPENSATION OF EMPLOYEE [988]
# 1 National accounts and GDP 155 > 3 COMPENSATION OF EMPLOYEE [988]
# 1 National accounts and GDP 132 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 2
# 3
# 4
# 5
# 6
# 6 R & D expenditure 181 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 6 R & D expenditure 180 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 7
# 7 Africa-EU - key statistical indicators 156 > 3 MILLENNIUM DEVELOPMENT GOAL [3973, 3974]
# 7 Africa-EU - key statistical indicators 123 > 3 INFANT MORTALITY RATE [3182]
# 7 Africa-EU - key statistical indicators 172 > 3 INFANT MORTALITY RATE [3182]
# 7 Africa-EU - key statistical indicators 154 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 7 Africa-EU - key statistical indicators 184 > 4 GDP AT CURRENT PRICE [2631]
# 8
# 9
# 9 Causes of death statistics 26 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 172 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 139 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 273 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 127 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 93 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 249 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 249 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 201 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 188 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 258 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 258 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 258 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 193 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 229 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 9 Causes of death statistics 149 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 10
# 11
# 11 Adult education survey - methodology 143 > 3 SPECIAL NEED EDUCATION [6018]
# 11 Adult education survey - methodology 167 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 11 Adult education survey - methodology 113 > 6 INTERNATIONAL STANDARD CLASSIFICATION OF EDUCATION (ISCED). [3368]
# 11 Adult education survey - methodology 114 > 6 INTERNATIONAL STANDARD CLASSIFICATION OF OCCUPATION (ISCO) [3369]
# 12
# 12 Adult learning statistics - characteristics of education and training 231 > 3 PLACE OF WORK [2449, 4285, 4901]
# 12 Adult learning statistics - characteristics of education and training 195 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 13
# 13 SDG 4 - Quality education 175 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 13 SDG 4 - Quality education 195 > 6 PROGRAMME FOR INTERNATIONAL STUDENT ASSESSMENT (PISA) [5149]
# 14
# 15
# 16
# 16 Environment statistics introduced 721 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 16 Environment statistics introduced 721 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 16 Environment statistics introduced 198 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 17
# 17 Greenhouse gas emission statistics - air emissions accounts 205 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 17 Greenhouse gas emission statistics - air emissions accounts 132 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 17 Greenhouse gas emission statistics - air emissions accounts 219 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 17 Greenhouse gas emission statistics - air emissions accounts 95 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 18
# 19
# 19 Forests, forestry and logging 167 > 3 OTHER WOODED LAND [4616]
# 19 Forests, forestry and logging 110 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 19 Forests, forestry and logging 152 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 19 Forests, forestry and logging 231 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 19 Forests, forestry and logging 231 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 20
# 21
# 21 LUCAS - Land use and land cover survey 220 > 5 FOOD AND AGRICULTURE ORGANISATION (FAO) [2484]
# 21 LUCAS - Land use and land cover survey 456 > 4 COMMON AGRICULTURAL POLICY (CAP) [965, 966]
# 21 LUCAS - Land use and land cover survey 170 > 3 SOIL ORGANIC MATTER [5989]
# 22
# 23
# 23 Road freight transport statistics - cabotage 351 > 3 ROAD CABOTAGE TRANSPORT [5635]
# 24
# 25
# 26
# 26 Chapter 7 259 > 3 PLACE OF RESIDENCE [4896]
# 26 Chapter 7 261 > 3 PLACE OF RESIDENCE [4896]
# 27
# 27 Road freight transport statistics 87 > 3 INTERNATIONAL ROAD TRANSPORT [3364]
# 28
# 29
# 29 SDG 17 - Partnerships for the goals 298 > 4 OFFICIAL DEVELOPMENT ASSISTANCE (ODA) [4486, 4487]
# 29 SDG 17 - Partnerships for the goals 298 > 4 OTHER OFFICIAL FLOW (OOFS) [4607]
# 29 SDG 17 - Partnerships for the goals 298 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 29 SDG 17 - Partnerships for the goals 298 > 4 OFFICIALLY SUPPORTED EXPORT CREDIT [288, 4494]
# 29 SDG 17 - Partnerships for the goals 150 > 4 GROSS NATIONAL INCOME (GNI) [2825]
# 29 SDG 17 - Partnerships for the goals 334 > 4 LEAST DEVELOPED COUNTRY (LDCS) [3608]
# 30
# 30 Coal production and consumption statistics 176 > 3 COKE OVEN COKE [919]
# 30 Coal production and consumption statistics 176 > 3 COKE OVEN COKE [919]
# 30 Coal production and consumption statistics 220 > 3 COKE OVEN COKE [919]
# 31
# 32
# 32 Living conditions in Europe - income distribution and income inequality 294 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 32 Living conditions in Europe - income distribution and income inequality 294 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 32 Living conditions in Europe - income distribution and income inequality 200 > 3 SOCIAL SECURITY BENEFIT [4609, 5457, 5972, 5973]
# 32 Living conditions in Europe - income distribution and income inequality 327 > 3 TYPE OF HOUSEHOLD [6662]
# 32 Living conditions in Europe - income distribution and income inequality 314 > 3 TYPE OF HOUSEHOLD [6662]
# 32 Living conditions in Europe - income distribution and income inequality 161 > 3 TYPE OF HOUSEHOLD [6662]
# 32 Living conditions in Europe - income distribution and income inequality 131 > 3 TYPE OF HOUSEHOLD [6662]
# 33
# 33 International trade in goods 148 > 3 ANNUAL GROWTH RATE [242, 248]
# 33 International trade in goods 169 > 3 ANNUAL GROWTH RATE [242, 248]
# 34
# 34 Material flow accounts and resource productivity 128 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 34 Material flow accounts and resource productivity 128 > 4 DOMESTIC MATERIAL CONSUMPTION (DMC) [1713]
# 34 Material flow accounts and resource productivity 219 > 3 GROSS CAPITAL FORMATION [2806]
# 35
# 35 Digital economy and society statistics - enterprises 212 > 4 ELECTRONIC DATA INTERCHANGE (EDI) [1932]
# 36
# 37
# 37 Healthy life years statistics 133 > 3 QUALITY OF LIFE [5263]
# 38
# 39
# 40
# 40 Children at risk of poverty or social exclusion 785 > 3 TYPE OF HOUSEHOLD [6662]
# 40 Children at risk of poverty or social exclusion 785 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 785 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 785 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 327 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 185 > 3 TYPE OF HOUSEHOLD [6662]
# 40 Children at risk of poverty or social exclusion 223 > 3 TYPE OF HOUSEHOLD [6662]
# 40 Children at risk of poverty or social exclusion 36 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 426 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 426 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 426 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 119 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 119 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 250 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 40 Children at risk of poverty or social exclusion 416 > 3 TYPE OF HOUSEHOLD [6662]
# 40 Children at risk of poverty or social exclusion 191 > 3 TYPE OF HOUSEHOLD [6662]
# 40 Children at risk of poverty or social exclusion 278 > 3 TYPE OF HOUSEHOLD [6662]
# 41
# 41 Population and population change statistics 165 > 4 RATE OF NATURAL INCREASE [5343]
# 42
# 42 The EU in the world - population 171 > 3 CRUDE BIRTH RATE [1289]
# 42 The EU in the world - population 171 > 3 CRUDE BIRTH RATE [1289]
# 42 The EU in the world - population 143 > 3 CRUDE BIRTH RATE [1289]
# 42 The EU in the world - population 172 > 3 CRUDE DEATH RATE [1290]
# 42 The EU in the world - population 229 > 3 CRUDE DEATH RATE [1290]
# 43
# 43 Chapter 2 269 > 3 PLACE OF RESIDENCE [4896]
# 43 Chapter 2 241 > 3 PLACE OF RESIDENCE [4896]
# 44
# 45
# 45 Environmental accounts - establishing the links between the environment and the economy 265 > 4 SUPPLY AND USE TABLE [3005, 4860, 6254, 6255, 6256, 6257]
# 45 Environmental accounts - establishing the links between the environment and the economy 238 > 3 WORLD BANK GROUP [7039]
# 45 Environmental accounts - establishing the links between the environment and the economy 198 > 4 ECONOMY-WIDE MATERIAL FLOW ACCOUNT [1858]
# 45 Environmental accounts - establishing the links between the environment and the economy 82 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 45 Environmental accounts - establishing the links between the environment and the economy 108 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 45 Environmental accounts - establishing the links between the environment and the economy 108 > 5 ENVIRONMENTAL PROTECTION EXPENDITURE ACCOUNT (EPEA) [2079]
# 45 Environmental accounts - establishing the links between the environment and the economy 366 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 45 Environmental accounts - establishing the links between the environment and the economy 366 > 3 INTERNATIONAL INVESTMENT POSITION [3350, 4224]
# 46
# 46 Exchange rates and interest rates 164 > 3 SHORT-TERM INTEREST RATE [5902]
# 47
# 48
# 48 Geographical information system of the Commission (GISCO) 166 > 4 GEOGRAPHICAL INFORMATION SYSTEM (GIS) [2682]
# 49
# 49 GDP per capita, consumption per capita and price level indices 125 > 3 ACTUAL INDIVIDUAL CONSUMPTION [75]
# 49 GDP per capita, consumption per capita and price level indices 235 > 3 ACTUAL INDIVIDUAL CONSUMPTION [75]
# 49 GDP per capita, consumption per capita and price level indices 198 > 3 COEFFICIENT OF VARIATION [909]
# 50
# 50 Update of the SNA 1993 and revision of ESA95 192 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 50 Update of the SNA 1993 and revision of ESA95 192 > 4 BALANCE OF PAYMENT MANUAL [382]
# 50 Update of the SNA 1993 and revision of ESA95 291 > 4 INTERNATIONAL MONETARY FUND (IMF) [3354]
# 50 Update of the SNA 1993 and revision of ESA95 291 > 7 ORGANISATION FOR ECONOMIC CO-OPERATION AND DEVELOPMENT (OECD) [4562]
# 50 Update of the SNA 1993 and revision of ESA95 177 > 3 ACTUAL SOCIAL CONTRIBUTION [76, 1969]
# 50 Update of the SNA 1993 and revision of ESA95 453 > 3 IMPUTED SOCIAL CONTRIBUTION [1970, 1971, 3095]
# 50 Update of the SNA 1993 and revision of ESA95 291 > 3 COMPENSATION OF EMPLOYEE [988]
# 50 Update of the SNA 1993 and revision of ESA95 358 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 50 Update of the SNA 1993 and revision of ESA95 146 > 3 RETURN TO CAPITAL [5598]
# 50 Update of the SNA 1993 and revision of ESA95 216 > 3 RETURN TO CAPITAL [5598]
# 50 Update of the SNA 1993 and revision of ESA95 99 > 4 RESEARCH AND DEVELOPMENT EXPENDITURE [5542]
# 50 Update of the SNA 1993 and revision of ESA95 205 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 50 Update of the SNA 1993 and revision of ESA95 205 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 50 Update of the SNA 1993 and revision of ESA95 241 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 50 Update of the SNA 1993 and revision of ESA95 301 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 50 Update of the SNA 1993 and revision of ESA95 301 > 4 BALANCE OF PAYMENT MANUAL [382]
# 50 Update of the SNA 1993 and revision of ESA95 115 > 3 RECORDING OF TRANSACTION [5392]
# 50 Update of the SNA 1993 and revision of ESA95 197 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 50 Update of the SNA 1993 and revision of ESA95 155 > 3 EXCESSIVE DEFICIT PROCEDURE [2200]
# 50 Update of the SNA 1993 and revision of ESA95 208 > 4 SUPPLY AND USE TABLE [3005, 4860, 6254, 6255, 6256, 6257]
# 50 Update of the SNA 1993 and revision of ESA95 284 > 5 REST OF THE WORLD ACCOUNT [5578]
# 50 Update of the SNA 1993 and revision of ESA95 284 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 51
# 52
# 53
# 54
# 54 R & D personnel 190 > 3 TOTAL LABOUR FORCE [6506]
# 54 R & D personnel 226 > 3 TOTAL LABOUR FORCE [6506]
# 54 R & D personnel 187 > 3 TOTAL LABOUR FORCE [6506]
# 54 R & D personnel 236 > 3 TOTAL LABOUR FORCE [6506]
# 54 R & D personnel 276 > 3 TOTAL LABOUR FORCE [6506]
# 55
# 55 Government finance statistics 133 > 4 STABILITY AND GROWTH PACT [6049]
# 55 Government finance statistics 132 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 55 Government finance statistics 109 > 3 EXCESSIVE DEFICIT PROCEDURE [2200]
# 55 Government finance statistics 165 > 4 SOCIAL TRANSFER IN KIND [5958, 5980]
# 55 Government finance statistics 165 > 3 TRANSFER IN KIND [685, 5958, 5980, 6580]
# 55 Government finance statistics 110 > 3 COMPENSATION OF EMPLOYEE [988]
# 55 Government finance statistics 166 > 4 CURRENT TAX ON INCOME [1333]
# 55 Government finance statistics 166 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 55 Government finance statistics 128 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 55 Government finance statistics 128 > 4 CURRENT TAX ON INCOME [1333]
# 55 Government finance statistics 128 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 55 Government finance statistics 177 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 55 Government finance statistics 67 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 55 Government finance statistics 105 > 4 CURRENT TAX ON INCOME [1333]
# 55 Government finance statistics 105 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 55 Government finance statistics 129 > 4 CURRENT TAX ON INCOME [1333]
# 55 Government finance statistics 129 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 55 Government finance statistics 68 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 55 Government finance statistics 148 > 4 CURRENT TAX ON INCOME [1333]
# 55 Government finance statistics 148 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 56
# 56 Government finance statistics - quarterly data 99 > 3 NOT SEASONALLY ADJUSTED [4410]
# 56 Government finance statistics - quarterly data 146 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 56 Government finance statistics - quarterly data 160 > 3 EXCESSIVE DEFICIT PROCEDURE [2200]
# 57
# 57 Structure of government debt 222 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 366 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 214 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 160 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 354 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 233 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 304 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 178 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 245 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 223 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 175 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 177 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 57 Structure of government debt 179 > 3 GOVERNMENT GROSS DEBT [2646, 2651, 2771]
# 58
# 59
# 59 Healthcare resource statistics - beds 189 > 3 PSYCHIATRIC CARE BED [5185]
# 59 Healthcare resource statistics - beds 116 > 3 PSYCHIATRIC CARE BED [5185]
# 59 Healthcare resource statistics - beds 428 > 3 PSYCHIATRIC CARE BED [5185]
# 59 Healthcare resource statistics - beds 267 > 3 PSYCHIATRIC CARE BED [5185]
# 59 Healthcare resource statistics - beds 149 > 5 LONG-TERM CARE BED IN HOSPITAL [3734]
# 59 Healthcare resource statistics - beds 152 > 5 LONG-TERM CARE BED IN HOSPITAL [3734]
# 59 Healthcare resource statistics - beds 115 > 3 PSYCHIATRIC CARE BED [5185]
# 60
# 61
# 62
# 62 Fishery statistics 118 > 4 COMMON FISHERY POLICY (CFP) [968]
# 63
# 64
# 64 Balance of payments statistics 30 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 64 Balance of payments statistics 147 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 64 Balance of payments statistics 199 > 3 OFFSHORE FINANCIAL CENTRE [4497]
# 65
# 65 Health statistics at regional level 307 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 307 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 307 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 307 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 121 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 121 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 143 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 174 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 155 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 197 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 229 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 259 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 65 Health statistics at regional level 307 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 66
# 67
# 68
# 68 Nuclear energy statistics 146 > 5 TONNE OF OIL EQUIVALENT (TOE) [6476]
# 69
# 69 Self-perceived health statistics 185 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 70
# 70 Minimum wage statistics 159 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 70 Minimum wage statistics 177 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 70 Minimum wage statistics 83 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 70 Minimum wage statistics 166 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 70 Minimum wage statistics 273 > 3 PURCHASING POWER STANDARD [5219]
# 70 Minimum wage statistics 97 > 4 HOUSEHOLD FINAL CONSUMPTION EXPENDITURE [2982]
# 71
# 71 Being young in Europe today - digital world 245 > 3 TYPE OF HOUSEHOLD [6662]
# 72
# 72 Information and communication service statistics - NACE Rev. 2 246 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 403 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 349 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 349 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 299 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 302 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 227 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 72 Information and communication service statistics - NACE Rev. 2 104 > 4 INCREASING RETURN TO SCALE [3124]
# 72 Information and communication service statistics - NACE Rev. 2 104 > 3 RETURN TO SCALE [1111, 3124, 5601]
# 73
# 73 Performance of the agricultural sector 274 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 73 Performance of the agricultural sector 363 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 73 Performance of the agricultural sector 255 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 73 Performance of the agricultural sector 226 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 73 Performance of the agricultural sector 254 > 3 NET VALUE ADDED [4246]
# 73 Performance of the agricultural sector 254 > 5 VALUE ADDED AT FACTOR COST [2841, 6828]
# 73 Performance of the agricultural sector 254 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 73 Performance of the agricultural sector 254 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 73 Performance of the agricultural sector 175 > 3 NET VALUE ADDED [4246]
# 74
# 75
# 76
# 77
# 77 Personal remittances statistics 269 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 242 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 161 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 275 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 254 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 153 > 3 ANNUAL GROWTH RATE [242, 248]
# 77 Personal remittances statistics 143 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 95 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 121 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 203 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 261 > 3 COMPENSATION OF EMPLOYEE [988]
# 77 Personal remittances statistics 214 > 3 COMPENSATION OF EMPLOYEE [988]
# 78
# 78 the introduction 217 > 3 PLACE OF RESIDENCE [4896]
# 78 the introduction 123 > 5 EUROPEAN FREE TRADE ASSOCIATION (EFTA) [2170]
# 78 the introduction 128 > 4 PLACE OF USUAL RESIDENCE [4900]
# 78 the introduction 241 > 3 PLACE OF RESIDENCE [4896]
# 78 the introduction 272 > 3 PLACE OF RESIDENCE [4896]
# 78 the introduction 281 > 3 QUALITY OF LIFE [5263]
# 78 the introduction 130 > 3 QUALITY OF LIFE [5263]
# 78 the introduction 279 > 7 EUROPEAN AGRICULTURAL FUND FOR RURAL DEVELOPMENT (EAFRD) [2159]
# 79
# 79 Population statistics at regional level 138 > 3 CRUDE BIRTH RATE [1289]
# 79 Population statistics at regional level 124 > 3 CRUDE BIRTH RATE [1289]
# 79 Population statistics at regional level 346 > 3 CRUDE BIRTH RATE [1289]
# 79 Population statistics at regional level 124 > 3 CRUDE BIRTH RATE [1289]
# 79 Population statistics at regional level 129 > 3 CRUDE BIRTH RATE [1289]
# 79 Population statistics at regional level 210 > 3 CRUDE BIRTH RATE [1289]
# 80
# 80 Water statistics 208 > 3 NUCLEAR POWER PLANT [4421]
# 80 Water statistics 199 > 3 AGRICULTURAL WATER USE [172]
# 81
# 81 Labour market slack ' annual statistics on unmet needs for employment 291 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 81 Labour market slack ' annual statistics on unmet needs for employment 258 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 82
# 82 Living conditions in Europe - housing 85 > 3 POPULATION AT RISK [4929]
# 82 Living conditions in Europe - housing 85 > 3 POPULATION AT RISK [4929]
# 83
# 83 Maritime freight and vessels statistics 163 > 3 GROSS TONNAGE (GT) [2837]
# 84
# 84 Human resources in science and technology 195 > 3 ANNUAL GROWTH RATE [242, 248]
# 85
# 85 Environmental protection expenditure accounts 46 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 85 Environmental protection expenditure accounts 201 > 5 NATIONAL EXPENDITURE ON ENVIRONMENTAL PROTECTION [4143]
# 85 Environmental protection expenditure accounts 434 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 85 Environmental protection expenditure accounts 173 > 5 NATIONAL EXPENDITURE ON ENVIRONMENTAL PROTECTION [4143]
# 85 Environmental protection expenditure accounts 173 > 5 NATIONAL EXPENDITURE ON ENVIRONMENTAL PROTECTION [4143]
# 85 Environmental protection expenditure accounts 596 > 3 ENVIRONMENTAL PROTECTION SERVICE [2082]
# 85 Environmental protection expenditure accounts 596 > 3 ENVIRONMENTAL PROTECTION ACTIVITY [2074]
# 85 Environmental protection expenditure accounts 89 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 85 Environmental protection expenditure accounts 297 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 85 Environmental protection expenditure accounts 297 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [2078, 2079, 2411]
# 85 Environmental protection expenditure accounts 277 > 3 ENVIRONMENTAL PROTECTION SERVICE [2082]
# 85 Environmental protection expenditure accounts 460 > 3 ENVIRONMENTAL PROTECTION SERVICE [2082]
# 86
# 87
# 87 Waste statistics 250 > 3 HAZARDOUS WASTE TREATMENT [2884]
# 88
# 89
# 89 Employment - annual statistics 117 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 89 Employment - annual statistics 287 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 89 Employment - annual statistics 142 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 89 Employment - annual statistics 141 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 90
# 90 Structural business statistics overview 189 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 90 Structural business statistics overview 189 > 6 GROSS VALUE ADDED AT FACTOR COST [2841]
# 90 Structural business statistics overview 189 > 5 VALUE ADDED AT FACTOR COST [2841, 6828]
# 90 Structural business statistics overview 316 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 90 Structural business statistics overview 348 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 90 Structural business statistics overview 335 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 90 Structural business statistics overview 295 > 5 SMALL AND MEDIUM-SIZED ENTERPRISE (SMES) [5942]
# 90 Structural business statistics overview 304 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 91
# 92
# 92 Energy statistics - an overview 106 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 92 Energy statistics - an overview 149 > 3 PURCHASING POWER STANDARD [5219]
# 93
# 93 Freight transport statistics - modal split 129 > 3 INTERNATIONAL ROAD TRANSPORT [3364]
# 93 Freight transport statistics - modal split 96 > 3 INTERNATIONAL ROAD TRANSPORT [3364]
# 94
# 94 Accommodation and food service statistics - NACE Rev. 2 205 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 94 Accommodation and food service statistics - NACE Rev. 2 287 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 94 Accommodation and food service statistics - NACE Rev. 2 164 > 3 APPARENT LABOUR PRODUCTIVITY [267]
# 95
# 96
# 97
# 97 Youth unemployment 104 > 4 INTERNATIONAL LABOUR ORGANISATION (ILO) [3351]
# 98
# 98 Educational attainment statistics 76 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 98 Educational attainment statistics 149 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 98 Educational attainment statistics 232 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99
# 99 Statistics on young people neither in employment nor in education or training 167 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 238 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 279 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 279 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 279 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 76 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 257 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 160 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 176 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 241 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 241 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 255 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 256 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 256 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 256 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 99 Statistics on young people neither in employment nor in education or training 248 > 3 PLACE OF RESIDENCE [4896]
# 100
# 100 Research and innovation statistics at regional level 250 > 4 RESEARCH AND DEVELOPMENT EXPENDITURE [5542]
# 100 Research and innovation statistics at regional level 91 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 100 Research and innovation statistics at regional level 110 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 100 Research and innovation statistics at regional level 129 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 100 Research and innovation statistics at regional level 237 > 6 INTERNATIONAL STANDARD CLASSIFICATION OF OCCUPATION (ISCO) [3369]
# 100 Research and innovation statistics at regional level 110 > 3 ECONOMICALLY ACTIVE POPULATION [1851]
# 100 Research and innovation statistics at regional level 102 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 101
# 101 Comparative price levels of consumer goods and services 54 > 3 COMPARATIVE PRICE LEVEL [984, 4055]
# 101 Comparative price levels of consumer goods and services 221 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 101 Comparative price levels of consumer goods and services 99 > 4 HOUSEHOLD FINAL CONSUMPTION EXPENDITURE [2982]
# 101 Comparative price levels of consumer goods and services 251 > 3 COEFFICIENT OF VARIATION [909]
# 101 Comparative price levels of consumer goods and services 111 > 3 COEFFICIENT OF VARIATION [909]
# 101 Comparative price levels of consumer goods and services 116 > 3 COEFFICIENT OF VARIATION [909]
# 101 Comparative price levels of consumer goods and services 108 > 4 HOUSEHOLD FINAL CONSUMPTION EXPENDITURE [2982]
# 101 Comparative price levels of consumer goods and services 108 > 4 HOUSEHOLD FINAL CONSUMPTION EXPENDITURE [2982]
# 101 Comparative price levels of consumer goods and services 175 > 3 COEFFICIENT OF VARIATION [909]
# 101 Comparative price levels of consumer goods and services 175 > 4 HOUSEHOLD FINAL CONSUMPTION EXPENDITURE [2982]
# 101 Comparative price levels of consumer goods and services 81 > 3 COEFFICIENT OF VARIATION [909]
# 102
# 103
# 103 Tax revenue statistics 115 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 115 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 115 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 35 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 35 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 54 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 54 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 202 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 202 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 71 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 71 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 71 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 54 > 3 ACTUAL SOCIAL CONTRIBUTION [76, 1969]
# 103 Tax revenue statistics 116 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 116 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 116 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 131 > 3 ACTUAL SOCIAL CONTRIBUTION [76, 1969]
# 103 Tax revenue statistics 338 > 3 SOCIAL INSURANCE SCHEME [5968]
# 103 Tax revenue statistics 338 > 3 SOCIAL INSURANCE SCHEME [5968]
# 103 Tax revenue statistics 338 > 3 SOCIAL INSURANCE SCHEME [5968]
# 103 Tax revenue statistics 198 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 198 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 198 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 60 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 60 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 240 > 6 TAX ON INDIVIDUAL OR HOUSEHOLD INCOME [6370]
# 103 Tax revenue statistics 184 > 6 TAX ON INDIVIDUAL OR HOUSEHOLD INCOME [6370]
# 103 Tax revenue statistics 92 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 216 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 216 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 185 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 185 > 3 TAX ON PRODUCT [4614, 6375, 6376]
# 103 Tax revenue statistics 185 > 4 OTHER TAX ON PRODUCTION [4614]
# 103 Tax revenue statistics 171 > 3 TAX ON PRODUCT [4614, 6375, 6376]
# 103 Tax revenue statistics 171 > 5 TAX AND DUTY ON IMPORT [6364]
# 103 Tax revenue statistics 171 > 3 TAX ON PRODUCT [4614, 6375, 6376]
# 103 Tax revenue statistics 63 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 143 > 3 TAX ON PRODUCT [4614, 6375, 6376]
# 103 Tax revenue statistics 217 > 5 TAX ON PRODUCTION AND IMPORT [6375]
# 103 Tax revenue statistics 35 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 35 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 64 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 64 > 3 OTHER CURRENT TAX [4586, 4587]
# 103 Tax revenue statistics 138 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 138 > 6 TAX ON INDIVIDUAL OR HOUSEHOLD INCOME [6370]
# 103 Tax revenue statistics 67 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 67 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 130 > 6 TAX ON INDIVIDUAL OR HOUSEHOLD INCOME [6370]
# 103 Tax revenue statistics 159 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 159 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 152 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 170 > 4 CURRENT TAX ON INCOME [1333]
# 103 Tax revenue statistics 170 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 103 Tax revenue statistics 178 > 3 ACTUAL SOCIAL CONTRIBUTION [76, 1969]
# 103 Tax revenue statistics 200 > 3 ACTUAL SOCIAL CONTRIBUTION [76, 1969]
# 103 Tax revenue statistics 148 > 3 IMPUTED SOCIAL CONTRIBUTION [1970, 1971, 3095]
# 103 Tax revenue statistics 148 > 3 ACTUAL SOCIAL CONTRIBUTION [76, 1969]
# 104
# 104 Tourism statistics 396 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 105
# 105 Chapter 5 259 > 3 PLACE OF RESIDENCE [4896]
# 105 Chapter 5 261 > 3 PLACE OF RESIDENCE [4896]
# 106
# 106 Wages and labour costs 126 > 3 PURCHASING POWER STANDARD [5219]
# 107
# 107 Overweight and obesity - BMI statistics 193 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 107 Overweight and obesity - BMI statistics 305 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 108
# 109
# 110
# 110 Tourism industries - economic analysis 196 > 5 VALUE ADDED AT FACTOR COST [2841, 6828]
# 110 Tourism industries - economic analysis 187 > 5 VALUE ADDED AT FACTOR COST [2841, 6828]
# 110 Tourism industries - economic analysis 194 > 5 VALUE ADDED AT FACTOR COST [2841, 6828]
# 111
# 111 Healthcare expenditure statistics 187 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 111 Healthcare expenditure statistics 180 > 3 PURCHASING POWER STANDARD [5219]
# 111 Healthcare expenditure statistics 156 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 112
# 112 Earnings statistics 243 > 3 PURCHASING POWER STANDARD [5219]
# 112 Earnings statistics 407 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 112 Earnings statistics 407 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 112 Earnings statistics 185 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 113
# 113 Causes of death statistics - people over 65 42 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 305 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 305 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 305 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 27 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 287 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 287 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 190 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 222 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 176 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 176 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 521 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 159 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 255 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 421 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 156 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 113 Causes of death statistics - people over 65 183 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 206 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 113 Causes of death statistics - people over 65 136 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 114
# 115
# 116
# 117
# 118
# 119
# 119 Social protection statistics - background 301 > 5 NON-PROFIT INSTITUTION SERVING HOUSEHOLD (NPISHS) [1346, 4369]
# 120
# 120 Social protection statistics - social benefits 218 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 120 Social protection statistics - social benefits 302 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 120 Social protection statistics - social benefits 231 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 120 Social protection statistics - social benefits 121 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 121
# 122
# 122 Services trade by enterprise characteristics - STEC 112 > 4 INTERNATIONAL TRADE IN SERVICE [3380, 4016]
# 123
# 124
# 124 EU statistics on income and living conditions (EU-SILC) methodology - health and labour conditions 204 > 3 PERCEIVED HEALTH STATUS [4795]
# 125
# 125 Health statistics introduced 532 > 5 SMALL AND MEDIUM-SIZED ENTERPRISE (SMES) [5942]
# 125 Health statistics introduced 289 > 3 SUSTAINABLE DEVELOPMENT INDICATOR [6288]
# 125 Health statistics introduced 196 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 125 Health statistics introduced 510 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 125 Health statistics introduced 333 > 3 STATISTICAL DATA COLLECTION [6088]
# 125 Health statistics introduced 333 > 3 CAUSE OF DEATH [743, 784, 1165, 6693]
# 126
# 126 Services producer price index overview 38 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 126 Services producer price index overview 150 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 127
# 128
# 129
# 129 Remittances according to the BPM6 manual 279 > 3 COMPENSATION OF EMPLOYEE [988]
# 129 Remittances according to the BPM6 manual 279 > 3 COMPENSATION OF EMPLOYEE [988]
# 129 Remittances according to the BPM6 manual 188 > 3 COMPENSATION OF EMPLOYEE [988]
# 129 Remittances according to the BPM6 manual 166 > 3 COMPENSATION OF EMPLOYEE [988]
# 129 Remittances according to the BPM6 manual 276 > 4 CURRENT TAX ON INCOME [1333]
# 129 Remittances according to the BPM6 manual 276 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 129 Remittances according to the BPM6 manual 276 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 129 Remittances according to the BPM6 manual 95 > 4 CURRENT TAX ON INCOME [1333]
# 129 Remittances according to the BPM6 manual 95 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 129 Remittances according to the BPM6 manual 359 > 3 SOCIAL INSURANCE SCHEME [5968]
# 129 Remittances according to the BPM6 manual 54 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 129 Remittances according to the BPM6 manual 127 > 3 INTERNATIONAL INVESTMENT POSITION [3350, 4224]
# 129 Remittances according to the BPM6 manual 171 > 3 MISCELLANEOUS CURRENT TRANSFER [3991]
# 129 Remittances according to the BPM6 manual 171 > 3 OTHER CAPITAL TRANSFER [4581]
# 129 Remittances according to the BPM6 manual 231 > 4 CAPITAL TRANSFER IN CASH [684]
# 129 Remittances according to the BPM6 manual 231 > 3 COMPENSATION OF EMPLOYEE [988]
# 129 Remittances according to the BPM6 manual 277 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 129 Remittances according to the BPM6 manual 277 > 4 INTERNATIONAL TRADE IN SERVICE [3380, 4016]
# 129 Remittances according to the BPM6 manual 277 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 129 Remittances according to the BPM6 manual 272 > 3 COMPENSATION OF EMPLOYEE [988]
# 129 Remittances according to the BPM6 manual 99 > 5 INTERNATIONAL TRANSACTION REPORTING SYSTEM (ITRS) [3382]
# 129 Remittances according to the BPM6 manual 174 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 129 Remittances according to the BPM6 manual 171 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 130
# 131
# 131 Fertility statistics 223 > 3 CRUDE BIRTH RATE [1289]
# 131 Fertility statistics 87 > 3 CRUDE BIRTH RATE [1289]
# 132
# 132 Recycling ' secondary material price indicator 283 > 4 WORLD TRADE ORGANISATION (WTO) [7048]
# 133
# 133 Educational expenditure statistics 193 > 4 PUBLIC EXPENDITURE ON EDUCATION [5193]
# 133 Educational expenditure statistics 67 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 133 Educational expenditure statistics 210 > 4 PUBLIC EXPENDITURE ON EDUCATION [5193]
# 133 Educational expenditure statistics 256 > 4 PUBLIC EXPENDITURE ON EDUCATION [5193]
# 133 Educational expenditure statistics 256 > 4 GROSS NATIONAL INCOME (GNI) [2825]
# 133 Educational expenditure statistics 157 > 4 PUBLIC EXPENDITURE ON EDUCATION [5193]
# 133 Educational expenditure statistics 305 > 4 EXPENDITURE ON EDUCATIONAL INSTITUTION [1616, 2238]
# 133 Educational expenditure statistics 149 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 133 Educational expenditure statistics 220 > 4 FINANCIAL AID TO STUDENT [2380]
# 134
# 134 Construction production (volume) index overview 86 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 135
# 135 Industrial production (volume) index overview 184 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 135 Industrial production (volume) index overview 227 > 3 RATE OF CHANGE [247, 5346, 5937, 6640]
# 136
# 136 Industrial producer price index overview 41 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 136 Industrial producer price index overview 157 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 136 Industrial producer price index overview 157 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 136 Industrial producer price index overview 72 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 136 Industrial producer price index overview 105 > 3 CONSUMER PRICE INDEX [1124, 1125, 2873]
# 136 Industrial producer price index overview 77 > 3 SUBSIDY ON PRODUCT [4611, 4612, 6216, 6218, 6219]
# 136 Industrial producer price index overview 181 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 136 Industrial producer price index overview 181 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# ...
# 817 Merging statistics and geospatial information - introduction 292 > 3 QUALITY OF LIFE [5263]
# 818
# 819
# 819 MEETS programme - towards more efficient enterprise and trade statistics 75 > 3 SUBJECT MATTER STATISTICIAN [6201]
# 819 MEETS programme - towards more efficient enterprise and trade statistics 211 > 3 INTERNATIONAL ACCOUNTING STANDARD [3328]
# 820
# 820 MEETS programme - priorities and new sets of indicators 440 > 5 SMALL AND MEDIUM-SIZED ENTERPRISE (SMES) [5942]
# 821
# 821 MEETS programme - introducing results 230 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 822
# 822 Intra-EU trade - exchange of micro-data 217 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 823
# 823 EU labour force survey ' development and history 199 > 3 WORK AT HOME [7019]
# 823 EU labour force survey ' development and history 219 > 4 INTERNATIONAL LABOUR ORGANISATION (ILO) [3351]
# 824
# 825
# 825 Globalisation patterns in trade and investment - introduction 78 > 3 OFFSHORE FINANCIAL CENTRE [4497]
# 825 Globalisation patterns in trade and investment - introduction 329 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 825 Globalisation patterns in trade and investment - introduction 279 > 4 WORLD TRADE ORGANISATION (WTO) [7048]
# 825 Globalisation patterns in trade and investment - introduction 214 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 825 Globalisation patterns in trade and investment - introduction 196 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 825 Globalisation patterns in trade and investment - introduction 247 > 6 EUROPEAN SYSTEM OF CENTRAL BANK (ESCB) [2176]
# 825 Globalisation patterns in trade and investment - introduction 255 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 825 Globalisation patterns in trade and investment - introduction 957 > 4 SPECIAL PURPOSE ENTITY (SPES) [6019]
# 825 Globalisation patterns in trade and investment - introduction 332 > 3 EUROPEAN CENTRAL BANK [2162]
# 825 Globalisation patterns in trade and investment - introduction 332 > 4 INTERNATIONAL MONETARY FUND (IMF) [3354]
# 825 Globalisation patterns in trade and investment - introduction 355 > 4 INTERNATIONAL TRADE IN SERVICE [3380, 4016]
# 825 Globalisation patterns in trade and investment - introduction 355 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 825 Globalisation patterns in trade and investment - introduction 283 > 3 OFFSHORE FINANCIAL CENTRE [4497]
# 825 Globalisation patterns in trade and investment - introduction 283 > 3 OFFSHORE FINANCIAL CENTRE [4497]
# 825 Globalisation patterns in trade and investment - introduction 242 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 826
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 91 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 269 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 269 > 4 INTERNATIONAL MONETARY FUND (IMF) [3354]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 269 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 269 > 3 INTERNATIONAL INVESTMENT POSITION [3350, 4224]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 269 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 121 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 121 > 3 INTERNATIONAL INVESTMENT POSITION [3350, 4224]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 62 > 3 FIFTH EDITION (BPM5) [383]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 182 > 3 EUROPEAN CENTRAL BANK [2162]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 314 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 181 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 539 > 4 INTERNATIONAL TRADE IN SERVICE [3380, 4016]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 539 > 3 FOREIGN DIRECT INVESTMENT [2506, 2507]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 256 > 3 DIRECT INVESTMENT RELATIONSHIP [1627]
# 826 Implementing the new international standards for foreign direct investment (FDI) statistics 45 > 4 SPECIAL PURPOSE ENTITY (SPES) [6019]
# 827
# 828
# 828 Farm structure survey - measurement errors 209 > 3 FULL-TIME EQUIVALENT EMPLOYMENT [2584]
# 829
# 830
# 830 Farm structure survey - administrative sources 166 > 3 DATE OF BIRTH [1445]
# 830 Farm structure survey - administrative sources 145 > 3 DATE OF BIRTH [1445]
# 830 Farm structure survey - administrative sources 153 > 3 PLACE OF RESIDENCE [4896]
# 830 Farm structure survey - administrative sources 155 > 3 PLACE OF RESIDENCE [4896]
# 830 Farm structure survey - administrative sources 83 > 4 COMMON AGRICULTURAL POLICY (CAP) [965, 966]
# 830 Farm structure survey - administrative sources 174 > 3 SINGLE FARM PAYMENT [5927]
# 830 Farm structure survey - administrative sources 86 > 3 SINGLE FARM PAYMENT [5927]
# 830 Farm structure survey - administrative sources 347 > 3 DATE OF BIRTH [1445]
# 830 Farm structure survey - administrative sources 97 > 3 SINGLE FARM PAYMENT [5927]
# 831
# 831 EU statistics on income and living conditions (EU-SILC) methodology ' sampling 55 > 4 NATIONAL STATISTICAL INSTITUTE (NSI) [4160]
# 831 EU statistics on income and living conditions (EU-SILC) methodology ' sampling 48 > 3 SIMPLE RANDOM SAMPLING [5921]
# 831 EU statistics on income and living conditions (EU-SILC) methodology ' sampling 178 > 3 SIMPLE RANDOM SAMPLING [5921]
# 832
# 833
# 833 EU statistics on income and living conditions (EU-SILC) methodology ' data collection 142 > 3 TAX ON INCOME [1333, 1637, 4613, 6369]
# 834
# 835
# 836
# 836 EU statistics on income and living conditions (EU-SILC) methodology - self-reported health 108 > 3 PERCEIVED HEALTH STATUS [4795]
# 837
# 838
# 838 EU statistics on income and living conditions (EU-SILC) methodology - housing conditions 253 > 3 TYPE OF HOUSEHOLD [6662]
# 839
# 840
# 841
# 842
# 842 EU labour force survey - documentation 177 > 6 INTERNATIONAL STANDARD CLASSIFICATION OF OCCUPATION (ISCO) [3369]
# 843
# 844
# 844 EU statistics on income and living conditions (EU-SILC) methodology - 2013 personal well-being indicators 160 > 3 PLACE OF RESIDENCE [4896]
# 844 EU statistics on income and living conditions (EU-SILC) methodology - 2013 personal well-being indicators 159 > 3 PLACE OF RESIDENCE [4896]
# 845
# 846
# 847
# 847 EU statistics on income and living conditions (EU-SILC) methodology - 2011 intergenerational transmission of disadvantages 362 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 847 EU statistics on income and living conditions (EU-SILC) methodology - 2011 intergenerational transmission of disadvantages 362 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 847 EU statistics on income and living conditions (EU-SILC) methodology - 2011 intergenerational transmission of disadvantages 227 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 847 EU statistics on income and living conditions (EU-SILC) methodology - 2011 intergenerational transmission of disadvantages 227 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 848
# 849
# 849 Energy balance - old methodology 228 > 3 COKE OVEN COKE [919]
# 849 Energy balance - old methodology 129 > 3 STATISTICAL DATA COLLECTION [6088]
# 849 Energy balance - old methodology 263 > 3 STATISTICAL DATA COLLECTION [6088]
# 850
# 850 Energy balance - new methodology 882 > 3 COKE OVEN COKE [919]
# 850 Energy balance - new methodology 882 > 3 GAS WORK GAS [2620]
# 850 Energy balance - new methodology 882 > 3 COKE OVEN GAS [920]
# 850 Energy balance - new methodology 882 > 3 BLAST FURNACE GAS [550]
# 850 Energy balance - new methodology 1186 > 3 STATISTICAL DATA COLLECTION [6088]
# 851
# 852
# 852 Differences between balance of payments and foreign trade statistics 67 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 852 Differences between balance of payments and foreign trade statistics 117 > 4 CENTRE OF ECONOMIC INTEREST [777]
# 853
# 853 Disability statistics background - Labour force survey - proxy analysis 242 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 854
# 854 Disability statistics background - Labour force survey - non-response analysis 189 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 854 Disability statistics background - Labour force survey - non-response analysis 303 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 854 Disability statistics background - Labour force survey - non-response analysis 194 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 854 Disability statistics background - Labour force survey - non-response analysis 286 > 3 LEVEL OF EDUCATION [3628, 4261, 4262, 4956, 5409]
# 855
# 855 Continuing Vocational Training Survey (CVTS) methodology 178 > 4 HEALTH AND SOCIAL WORK [1988, 3114]
# 856
# 856 City statistics ' economic aspects 168 > 4 INTERNATIONAL LABOUR ORGANISATION (ILO) [3351]
# 856 City statistics ' economic aspects 296 > 3 ECONOMICALLY ACTIVE POPULATION [1851]
# 856 City statistics ' economic aspects 296 > 3 ECONOMICALLY INACTIVE POPULATION [1852]
# 856 City statistics ' economic aspects 156 > 3 REPAIR AND MAINTENANCE [1331, 5500]
# 856 City statistics ' economic aspects 192 > 3 REPAIR AND MAINTENANCE [1331, 5500]
# 856 City statistics ' economic aspects 163 > 3 PLACE OF RESIDENCE [4896]
# 857
# 858
# 858 City statistics ' introduction 180 > 3 QUALITY OF LIFE [5263]
# 858 City statistics ' introduction 130 > 3 QUALITY OF LIFE [5263]
# 859
# 859 Building the System of National Accounts - strategy 257 > 4 INTERNATIONAL MONETARY FUND (IMF) [3354]
# 859 Building the System of National Accounts - strategy 257 > 5 DATA QUALITY ASSESSMENT FRAMEWORK (DQAF) [1416]
# 859 Building the System of National Accounts - strategy 209 > 4 NATIONAL STATISTICAL SYSTEM (NSS) [4162]
# 859 Building the System of National Accounts - strategy 710 > 3 MILLENNIUM DEVELOPMENT GOAL [3973, 3974]
# 859 Building the System of National Accounts - strategy 710 > 4 NATIONAL STATISTICAL OFFICE (NSO) [4161]
# 859 Building the System of National Accounts - strategy 167 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 859 Building the System of National Accounts - strategy 213 > 4 GROSS DOMESTIC PRODUCT (GDP) [2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 4298, 4957]
# 859 Building the System of National Accounts - strategy 213 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 859 Building the System of National Accounts - strategy 406 > 5 FUNDAMENTAL PRINCIPLE OF OFFICIAL STATISTIC [2600]
# 859 Building the System of National Accounts - strategy 406 > 5 FUNDAMENTAL PRINCIPLE OF OFFICIAL STATISTIC [2600]
# 860
# 861
# 862
# 862 Methods for compiling PEEIs in short-term business statistics 40 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 862 Methods for compiling PEEIs in short-term business statistics 127 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 862 Methods for compiling PEEIs in short-term business statistics 125 > 3 PRODUCER PRICE INDEX [3240, 4633, 5104, 6830]
# 862 Methods for compiling PEEIs in short-term business statistics 429 > 3 CONSUMER PRICE INDEX [1124, 1125, 2873]
# 863
# 863 Building the System of National Accounts - administrative sources 401 > 4 VALUE ADDED TAX (VAT) [1505, 3448, 4322, 6831, 6832, 6833, 6835, 6837]
# 863 Building the System of National Accounts - administrative sources 54 > 3 INTERNATIONAL ACCOUNTING STANDARD [3328]
# 863 Building the System of National Accounts - administrative sources 175 > 5 INTERNATIONAL FINANCIAL REPORTING STANDARD (IFRS) [3345]
# 863 Building the System of National Accounts - administrative sources 863 > 3 COMPENSATION OF EMPLOYEE [988]
# 863 Building the System of National Accounts - administrative sources 146 > 6 FINANCIAL INTERMEDIATION SERVICE INDIRECTLY MEASURED (FISIM) [2394]
# 863 Building the System of National Accounts - administrative sources 226 > 6 REINVESTED EARNINGS ON DIRECT FOREIGN INVESTMENT [5461]
# 863 Building the System of National Accounts - administrative sources 138 > 3 TANGIBLE FIXED ASSET [3267, 4597, 6330]
# 863 Building the System of National Accounts - administrative sources 138 > 3 INTANGIBLE FIXED ASSET [3267, 4597]
# 863 Building the System of National Accounts - administrative sources 466 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 863 Building the System of National Accounts - administrative sources 63 > 3 SUBSIDY ON PRODUCT [4611, 4612, 6216, 6218, 6219]
# 863 Building the System of National Accounts - administrative sources 164 > 3 TAX ON PRODUCT [4614, 6375, 6376]
# 863 Building the System of National Accounts - administrative sources 164 > 3 SUBSIDY ON PRODUCT [4611, 4612, 6216, 6218, 6219]
# 863 Building the System of National Accounts - administrative sources 164 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 863 Building the System of National Accounts - administrative sources 170 > 6 FINANCIAL INTERMEDIATION SERVICE INDIRECTLY MEASURED (FISIM) [2394]
# 863 Building the System of National Accounts - administrative sources 294 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 863 Building the System of National Accounts - administrative sources 294 > 4 REFERENCE RATE OF INTEREST [5421]
# 863 Building the System of National Accounts - administrative sources 83 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 863 Building the System of National Accounts - administrative sources 256 > 3 INSURANCE TECHNICAL RESERVE [3265]
# 863 Building the System of National Accounts - administrative sources 229 > 3 GROSS VALUE ADDED [2839, 2840, 2841, 2842, 2843]
# 863 Building the System of National Accounts - administrative sources 230 > 4 CONSUMPTION OF FIXED CAPITAL [1133]
# 863 Building the System of National Accounts - administrative sources 197 > 7 CLASSIFICATION OF THE FUNCTION OF GOVERNMENT (COFOG) [856]
# 863 Building the System of National Accounts - administrative sources 165 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 863 Building the System of National Accounts - administrative sources 91 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 863 Building the System of National Accounts - administrative sources 91 > 3 INTERNATIONAL INVESTMENT POSITION [3350, 4224]
# 863 Building the System of National Accounts - administrative sources 117 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 863 Building the System of National Accounts - administrative sources 120 > 4 GOOD AND SERVICE ACCOUNT [2727]
# 863 Building the System of National Accounts - administrative sources 198 > 5 SECONDARY DISTRIBUTION OF INCOME ACCOUNT [5787]
# 863 Building the System of National Accounts - administrative sources 122 > 3 BALANCE OF PAYMENT [382, 384, 385, 386, 388, 390, 392, 394, 396, 398, 400, 402, 404, 406, 959, 1317, 6403, 6407]
# 863 Building the System of National Accounts - administrative sources 327 > 3 BASIC STATISTICAL DATA [457]
# 864

# %%
res['3-Phrases']= res['3-Phrases'].apply(lambda x: dict(Counter(x).most_common()))
res['4-Phrases']= res['4-Phrases'].apply(lambda x: dict(Counter(x).most_common()))
res['5-and-above-Phrases']= res['5-and-above-Phrases'].apply(lambda x: dict(Counter(x).most_common()))

# %%
res=pd.merge(SE_df[['id','title']],res,left_on='id',right_on='doc_id',how='left')
res.drop(columns=['doc_id'],inplace=True)
res
# Out:
#         id                                              title  \
# 0        7                       Accidents at work statistics
# 1       13                          National accounts and GDP
# 2       16                Railway safety statistics in the EU
# 3       17               Railway freight transport statistics
# 4       18  Railway passenger transport statistics - quart...
# ..     ...                                                ...
# 860  10456  Merging statistics and geospatial information,...
# 861  10470  Merging statistics and geospatial information,...
# 862  10506  Methods for compiling PEEIs in short-term busi...
# 863  10531  Building the System of National Accounts - adm...
# 864  10539                       Asylum statistics introduced
#
#                                              3-Phrases  \
# 0                                                   {}
# 1    {'RATE OF CHANGE': 15, 'GROSS VALUE ADDED': 6,...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                NaN
# 861                                                NaN
# 862  {'PRODUCER PRICE INDEX': 3, 'CONSUMER PRICE IN...
# 863  {'GROSS VALUE ADDED': 4, 'BALANCE OF PAYMENT':...
# 864                                                NaN
#
#                                              4-Phrases  \
# 0                        {'HEALTH AND SOCIAL WORK': 1}
# 1                        {'HEALTH AND SOCIAL WORK': 3}
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                NaN
# 861                                                NaN
# 862                                                 {}
# 863  {'CONSUMPTION OF FIXED CAPITAL': 2, 'VALUE ADD...
# 864                                                NaN
#
#                                    5-and-above-Phrases  \
# 0                                                   {}
# 1    {'TAX ON PRODUCTION AND IMPORT': 2, 'EXTERNAL ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                NaN
# 861                                                NaN
# 862                                                 {}
# 863  {'FINANCIAL INTERMEDIATION SERVICE INDIRECTLY ...
# 864                                                NaN
#
#                                                  Terms
# 0    {' health and social work': 1, ' Incomes of he...
# 1    {' Annualised growth rate (annualised rate of ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                NaN
# 861                                                NaN
# 862  {' Input producer price indices': 3, ' Output ...
# 863  {' Deductible value added tax (VAT)': 1, ' Inv...
# 864                                                NaN
#
# [865 rows x 6 columns]

# %%
outfile = file_name('Phrase_Matcher_SE_OECD','xlsx')
res.to_excel(outfile)
