# %% [markdown]
# # Testing the Named Entities Recognition engine of Spacy
#
# ### Step 1. Loading Spacy models
# ***
#
# We install Spacy's language library for the first run. Then we can comment-out the download command. Note that we are loading Spacy's "medium" model.

# %%
import re
import pandas as pd
import spacy
import sys
from collections import Counter
import re


## Run to install the language library, then comment-out
## !{sys.executable} -m spacy download en
# !{sys.executable} -m spacy download en_core_web_md

nlp = spacy.load('en_core_web_md')
print('Finished loading.')
# Out:
# Requirement already satisfied: en-core-web-md==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.0.0/en_core_web_md-3.0.0-py3-none-any.whl#egg=en_core_web_md==3.0.0 in d:\programdata\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in d:\programdata\anaconda3\lib\site-packages (from en-core-web-md==3.0.0) (3.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.7.4)
# Requirement already satisfied: jinja2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.11.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (4.50.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.3.2)
# Requirement already satisfied: setuptools in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.4.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.7.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (8.0.1)
# Requirement already satisfied: packaging>=20.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (20.4)
# Requirement already satisfied: numpy>=1.15.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.19.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.0.1)
# Requirement already satisfied: pathy in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.3.5)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (3.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in d:\programdata\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (7.1.2)
# Requirement already satisfied: six in d:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in d:\programdata\anaconda3\lib\site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.2.1)
# Requirement already satisfied: boto3 in d:\programdata\anaconda3\lib\site-packages (from smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.17.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in d:\programdata\anaconda3\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in d:\programdata\anaconda3\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (0.3.4)
# Requirement already satisfied: botocore<1.21.0,>=1.20.7 in d:\programdata\anaconda3\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (1.20.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\programdata\anaconda3\lib\site-packages (from botocore<1.21.0,>=1.20.7->boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-md==3.0.0) (2.8.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# Finished loading.

# %% [markdown]
# ### Step 2. Pre-processing
# ***
#
# * Read two files exported from the database which contain the SE Glossary articles definitions and their titles.
# * In later versions, the corresponding tables will be directly exported from the database.
# * Merge by id and discard records with duplicate titles and/or definitions.

# %%
dat1= pd.read_csv("ESTAT_dat_concepts_2021_04_08.csv",sep=";")
dat2= pd.read_csv("ESTAT_dat_link_info_2021_04_08.csv",sep=";")
Gloss_concepts = pd.merge(dat1,dat2,on=['id'])
del(dat1,dat2)

Gloss_concepts = Gloss_concepts[['id','title','definition']]

Gloss_concepts = Gloss_concepts.drop_duplicates(subset=["definition"])
Gloss_concepts = Gloss_concepts.dropna(axis=0,subset=["definition"])
Gloss_concepts = Gloss_concepts.drop_duplicates(subset=["title"])
Gloss_concepts = Gloss_concepts.dropna(axis=0,subset=["title"])

Gloss_concepts.reset_index(drop=True, inplace=True)
Gloss_concepts.head()
# Out:
#    id                                              title  \
# 0   1  Arrival of tourist at a tourist accommodation ...
# 1   3                                    Nights spent
# 2   4                  Supply side tourism statistics
# 3   5                                         Tourist
# 4   7                         Asia-Europe Meeting (ASEM)
#
#                                           definition
# 0     See      arrival disambiguation page     fo...
# 1    A     night spent    or     tourism night   ...
# 2    Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3    For     tourism    statistics, a     travell...
# 4    The     Asia-Europe Meeting    , abbreviated...

# %% [markdown]
# ### Step 3. Pre-processing (cont)
# ***
#
# Keep a backup of the original definition and do some data cleansing.

# %%
Gloss_concepts['definition_init'] = Gloss_concepts['definition']

Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub("[^a-z\\.,A-Z0-9]", " ",x)) ## replace anything except digits,letters,comma and dot by space 
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(r'[a-zA-Z]+\d+', '.', x))## letters+digits -> .
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(' +', ' ',x)) ## remove more than one spaces
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub('^ +| +$', '',x)) ## remove start and end spaces
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(' +', ' ',x)) ## remove more than one spaces
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(' , ',', ',x)) ## space-comma-space -> comma-space


Gloss_concepts.head()
#len(Gloss_concepts.definition.values.tolist())
# Out:
#    id                                              title  \
# 0   1  Arrival of tourist at a tourist accommodation ...
# 1   3                                    Nights spent
# 2   4                  Supply side tourism statistics
# 3   5                                         Tourist
# 4   7                         Asia-Europe Meeting (ASEM)
#
#                                           definition  \
# 0  See arrival disambiguation page for other mean...
# 1  A night spent or tourism night overnight stay ...
# 2  Regulation EU No 692 2011 of 6 July 2011 estab...
# 3  For tourism statistics, a traveller is someone...
# 4  The Asia Europe Meeting, abbreviated as ASEM, ...
#
#                                      definition_init
# 0     See      arrival disambiguation page     fo...
# 1    A     night spent    or     tourism night   ...
# 2    Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3    For     tourism    statistics, a     travell...
# 4    The     Asia-Europe Meeting    , abbreviated...

# %% [markdown]
# ### Step 4. Apply the NER engine
# ***
#
# Create columns ORG, GPE, NORP, LOCATION which will hold dictionaries with entities recognized as:
# * Organizations;
# * Countries, cities, states;
# * Nationalities or religious or political groups;
# * Non-GPE locations, mountain ranges, bodies of water, respectively.
#
# In each dictionary in a record, the key is the entity and the values are a list with the token span's *start* index position, the token span's *stop* index position and the count in the definition of the glossary article.

# %%
nlp.max_length = 1500000

Gloss_concepts['ORG'] = [dict() for i in range(len(Gloss_concepts))]
Gloss_concepts['GPE'] = [dict() for i in range(len(Gloss_concepts))]
Gloss_concepts['NORP'] = [dict() for i in range(len(Gloss_concepts))]
Gloss_concepts['LOCATION'] = [dict() for i in range(len(Gloss_concepts))]

for i in range(len(Gloss_concepts)):
    if i % 100 == 0: print('i = ',i,' of ',len(Gloss_concepts))
    tokens = nlp(Gloss_concepts.loc[i,'definition'])
    entities = tokens.ents
    for ent in entities:
        #print(ent.text, ent.label_)
        if ent.label_ == 'ORG':
            if ent.text.upper() in Gloss_concepts.loc[i,'ORG'].keys():
                Gloss_concepts.loc[i,'ORG'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'ORG'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'ORG'][ent.text.upper()] = [[(ent.start,ent.end)],1]
        
        elif ent.label_ == 'GPE':
            if ent.text.upper() in Gloss_concepts.loc[i,'GPE'].keys():
                Gloss_concepts.loc[i,'GPE'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'GPE'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'GPE'][ent.text.upper()] = [[(ent.start,ent.end)],1]
                
        elif ent.label_ == 'NORP':
            if ent.text.upper() in Gloss_concepts.loc[i,'NORP'].keys():
                Gloss_concepts.loc[i,'NORP'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'NORP'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'NORP'][ent.text.upper()] = [[(ent.start,ent.end)],1]
                
        elif ent.label_ == 'LOCATION':
            if ent.text.upper() in Gloss_concepts.loc[i,'LOCATION'].keys():
                Gloss_concepts.loc[i,'LOCATION'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'LOCATION'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'LOCATION'][ent.text.upper()] = [[(ent.start,ent.end)],1]         
    
Gloss_concepts

#PERSON People, including fictional
#NORP Nationalities or religious or political groups
#FACILITY Buildings, airports, highways, bridges, etc.
#ORGANIZATION Companies, agencies, institutions, etc.
#GPE Countries, cities, states
#LOCATION Non-GPE locations, mountain ranges, bodies of water
#PRODUCT Vehicles, weapons, foods, etc. (Not services)
#EVENT Named hurricanes, battles, wars, sports events, etc.
#WORK OF ART Titles of books, songs, etc.
#LAW Named documents made into laws 
#LANGUAGE Any named language
#The following values are also annotated in a style similar to names:
#DATE Absolute or relative dates or periods
#TIME Times smaller than a day
#PERCENT Percentage (including “%”)
#MONEY Monetary values, including unit
#QUANTITY Measurements, as of weight or distance
#ORDINAL “first”, “second”
#CARDINAL Numerals that do not fall under another typ

Gloss_concepts.loc[50,'ORG']
# Out:
# i =  0  of  1284
# i =  100  of  1284
# i =  200  of  1284
# i =  300  of  1284
# i =  400  of  1284
# i =  500  of  1284
# i =  600  of  1284
# i =  700  of  1284
# i =  800  of  1284
# i =  900  of  1284
# i =  1000  of  1284
# i =  1100  of  1284
# i =  1200  of  1284
#         id                                              title  \
# 0        1  Arrival of tourist at a tourist accommodation ...
# 1        3                                    Nights spent
# 2        4                  Supply side tourism statistics
# 3        5                                         Tourist
# 4        7                         Asia-Europe Meeting (ASEM)
# ...    ...                                                ...
# 1279  2879                              Statistical territory
# 1280  2881                              Statistical indicator
# 1281  2885                                 Tourism industries
# 1282  2891                                           Sawnwood
# 1283  2896                                       LeaMickatest
#
#                                              definition  \
# 0     See arrival disambiguation page for other mean...
# 1     A night spent or tourism night overnight stay ...
# 2     Regulation EU No 692 2011 of 6 July 2011 estab...
# 3     For tourism statistics, a traveller is someone...
# 4     The Asia Europe Meeting, abbreviated as ASEM, ...
# ...                                                 ...
# 1279  The statistical territory of the European Unio...
# 1280  A statistical indicator is the representation ...
# 1281  For the article Tourism industries economic an...
# 1282  Sawnwood is wood that has been produced either...
# 1283                                               test
#
#                                         definition_init  \
# 0        See      arrival disambiguation page     fo...
# 1       A     night spent    or     tourism night   ...
# 2       Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3       For     tourism    statistics, a     travell...
# 4       The     Asia-Europe Meeting    , abbreviated...
# ...                                                 ...
# 1279    The     statistical territory    of the     ...
# 1280    A     statistical indicator    is the repres...
# 1281    For the article     Tourism industries - eco...
# 1282     Sawnwood    is wood that has been produced ...
# 1283                                               test
#
#                                                     ORG  \
# 0     {'EUROPEAN UNION': [[(14, 16)], 1], 'EU': [[(1...
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'ASEM': [[(7, 8), (36, 37)], 2], 'EUROPEAN UN...
# ...                                                 ...
# 1279  {'EUROPEAN UNION': [[(5, 7)], 1], 'EU': [[(7, ...
# 1280  {'EUROPEAN UNION': [[(80, 82)], 1], 'EU': [[(8...
# 1281  {'UNWTO': [[(19, 20)], 1], 'STS': [[(128, 129)...
# 1282                        {'SAWNWOOD': [[(0, 1)], 1]}
# 1283                                                 {}
#
#                                                     GPE  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'OCEANIA': [[(27, 28)], 1], 'NORWAY': [[(49, ...
# ...                                                 ...
# 1279  {'GERMANY': [[(37, 38)], 1], 'HELIGOLAND': [[(...
# 1280                                                 {}
# 1281                                                 {}
# 1282                                                 {}
# 1283                                                 {}
#
#                                                    NORP LOCATION
# 0                                                    {}       {}
# 1                                                    {}       {}
# 2                         {'EUROPEAN': [[(22, 23)], 1]}       {}
# 3                                                    {}       {}
# 4                                                    {}       {}
# ...                                                 ...      ...
# 1279  {'FRENCH': [[(59, 60)], 1], 'MARTINIQUE': [[(6...       {}
# 1280                                                 {}       {}
# 1281                      {'EUROPEAN': [[(27, 28)], 1]}       {}
# 1282                                                 {}       {}
# 1283                                                 {}       {}
#
# [1284 rows x 8 columns]

# %% [markdown]
# ### Step 5. Gathering the most common entities: example with ORG entities
# ***
#
# We can see a few errors and repetitions. These require some further cleansing steps and fine-tuning of the NER engine (not yet carried out). There are in total 947 terms identified as named entities - organizations.

# %%
from itertools import chain
org_list=sorted(list(chain.from_iterable(Gloss_concepts['ORG'].apply(lambda x: x.keys()))))
org_all_freqs = sorted(Counter(org_list))
print('Total terms identified as ORG: ',len(org_all_freqs))

print('\n100 most common:\n')
org_common_freqs = Counter(org_list).most_common(100)
org_common = sorted([x[0] for x in org_common_freqs])
print(org_common_freqs)
# Out:
# Total terms identified as ORG:  947
#
# 100 most common:
#
# [('EU', 203), ('THE EUROPEAN UNION', 88), ('EUROPEAN UNION', 72), ('EUROSTAT', 51), ('NACE', 31), ('EC', 23), ('THE EUROPEAN COMMISSION', 20), ('ESA', 19), ('EFTA', 18), ('ICT', 17), ('REGULATION EC', 17), ('THE EUROPEAN COUNCIL', 11), ('THE EUROPEAN PARLIAMENT', 11), ('OECD', 10), ('FSS', 8), ('ICD', 8), ('STS', 8), ('EEC', 7), ('EMU', 7), ('HICP', 7), ('LFS', 7), ('REGULATION EU', 7), ('THE EUROPEAN COMMUNITY', 7), ('CO 2', 6), ('FDI', 6), ('NL', 6), ('THE EUROPEAN STATISTICAL SYSTEM', 6), ('THE UNITED NATIONS', 6), ('UAA', 6), ('BMI', 5), ('CFC', 5), ('COMMISSION', 5), ('COUNCIL', 5), ('GNI', 5), ('HRST', 5), ('PPS', 5), ('SAPM', 5), ('THE COUNCIL OF THE EUROPEAN UNION', 5), ('THE EUROPEAN CENTRAL BANK', 5), ('THE EUROPEAN PATENT OFFICE', 5), ('THE UNITED NATIONS UN', 5), ('TPP', 5), ('COUNCIL DIRECTIVE', 4), ('DIRECTIVES', 4), ('EDP', 4), ('EEA', 4), ('ESA 2010', 4), ('EU SILC', 4), ('EUROPEAN BUSINESS STATISTICS REGULATION', 4), ('EUROPEAN ENVIRONMENTAL ECONOMIC ACCOUNTS', 4), ('GFCF', 4), ('INTEGRATED FARM STATISTICS', 4), ('ISCED', 4), ('KAU', 4), ('LABOUR', 4), ('NA', 4), ('NPISH', 4), ('NUAA', 4), ('SBS', 4), ('SGM', 4), ('SNA', 4), ('STATISTICAL DATA', 4), ('THE EUROPEAN ECONOMIC AREA EEA', 4), ('THE INTERNATIONAL MONETARY FUND', 4), ('THE WORLD HEALTH ORGANIZATION', 4), ('URBAN', 4), ('AEI', 3), ('ASEAN', 3), ('CAP', 3), ('CIS', 3), ('COICOP', 3), ('COMMISSION DECISION', 3), ('COUNCIL REGULATION', 3), ('COUNCIL REGULATION EC', 3), ('CROPS', 3), ('DE', 3), ('DIGITAL', 3), ('EPEA', 3), ('EUROBASE', 3), ('EUROPEAN COUNCIL', 3), ('FADN', 3), ('FISHER', 3), ('IPC', 3), ('ISCO', 3), ('ISIC', 3), ('LASPEYRES', 3), ('LIVESTOCK', 3), ('LSU', 3), ('MFA', 3), ('NATIONAL STATISTICAL INSTITUTES', 3), ('PAASCHE', 3), ('PEFA', 3), ('REUSE', 3), ('SDR', 3), ('SES', 3), ('SITC', 3), ('SYSTEM', 3), ('THE COUNCIL OF EUROPE', 3), ('THE EUROPEAN COMMISSION S', 3), ('THE EUROPEAN HEALTH INTERVIEW SURVEY EHIS', 3)]

# %% [markdown]
# ### Step 6. Storing information on these most common entities per article: example with ORG entities
# ***
#
# This is one way of storing the information on both all entities and counts and on the most common ones in a Pandas dataframe.

# %%
Gloss_concepts['ORG_COMMON_100'] = Gloss_concepts['ORG'].apply(lambda x: {y:x[y] for y in x.keys() if y in org_common})
Gloss_concepts
# Out:
#         id                                              title  \
# 0        1  Arrival of tourist at a tourist accommodation ...
# 1        3                                    Nights spent
# 2        4                  Supply side tourism statistics
# 3        5                                         Tourist
# 4        7                         Asia-Europe Meeting (ASEM)
# ...    ...                                                ...
# 1279  2879                              Statistical territory
# 1280  2881                              Statistical indicator
# 1281  2885                                 Tourism industries
# 1282  2891                                           Sawnwood
# 1283  2896                                       LeaMickatest
#
#                                              definition  \
# 0     See arrival disambiguation page for other mean...
# 1     A night spent or tourism night overnight stay ...
# 2     Regulation EU No 692 2011 of 6 July 2011 estab...
# 3     For tourism statistics, a traveller is someone...
# 4     The Asia Europe Meeting, abbreviated as ASEM, ...
# ...                                                 ...
# 1279  The statistical territory of the European Unio...
# 1280  A statistical indicator is the representation ...
# 1281  For the article Tourism industries economic an...
# 1282  Sawnwood is wood that has been produced either...
# 1283                                               test
#
#                                         definition_init  \
# 0        See      arrival disambiguation page     fo...
# 1       A     night spent    or     tourism night   ...
# 2       Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3       For     tourism    statistics, a     travell...
# 4       The     Asia-Europe Meeting    , abbreviated...
# ...                                                 ...
# 1279    The     statistical territory    of the     ...
# 1280    A     statistical indicator    is the repres...
# 1281    For the article     Tourism industries - eco...
# 1282     Sawnwood    is wood that has been produced ...
# 1283                                               test
#
#                                                     ORG  \
# 0     {'EUROPEAN UNION': [[(14, 16)], 1], 'EU': [[(1...
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'ASEM': [[(7, 8), (36, 37)], 2], 'EUROPEAN UN...
# ...                                                 ...
# 1279  {'EUROPEAN UNION': [[(5, 7)], 1], 'EU': [[(7, ...
# 1280  {'EUROPEAN UNION': [[(80, 82)], 1], 'EU': [[(8...
# 1281  {'UNWTO': [[(19, 20)], 1], 'STS': [[(128, 129)...
# 1282                        {'SAWNWOOD': [[(0, 1)], 1]}
# 1283                                                 {}
#
#                                                     GPE  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'OCEANIA': [[(27, 28)], 1], 'NORWAY': [[(49, ...
# ...                                                 ...
# 1279  {'GERMANY': [[(37, 38)], 1], 'HELIGOLAND': [[(...
# 1280                                                 {}
# 1281                                                 {}
# 1282                                                 {}
# 1283                                                 {}
#
#                                                    NORP LOCATION  \
# 0                                                    {}       {}
# 1                                                    {}       {}
# 2                         {'EUROPEAN': [[(22, 23)], 1]}       {}
# 3                                                    {}       {}
# 4                                                    {}       {}
# ...                                                 ...      ...
# 1279  {'FRENCH': [[(59, 60)], 1], 'MARTINIQUE': [[(6...       {}
# 1280                                                 {}       {}
# 1281                      {'EUROPEAN': [[(27, 28)], 1]}       {}
# 1282                                                 {}       {}
# 1283                                                 {}       {}
#
#                                          ORG_COMMON_100
# 0     {'EUROPEAN UNION': [[(14, 16)], 1], 'EU': [[(1...
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'EUROPEAN UNION': [[(39, 41)], 1], 'EU': [[(4...
# ...                                                 ...
# 1279  {'EUROPEAN UNION': [[(5, 7)], 1], 'EU': [[(7, ...
# 1280  {'EUROPEAN UNION': [[(80, 82)], 1], 'EU': [[(8...
# 1281  {'STS': [[(128, 129), (218, 219)], 2], 'SBS': ...
# 1282                                                 {}
# 1283                                                 {}
#
# [1284 rows x 9 columns]

# %% [markdown]
# ### Step 7. Exporting the dataframe to Excel
# ***
# This is useful for the manual inspection and the design of rules for the fine-tuning of the NER engine. This output can then directly be imported in the database.

# %%
Gloss_concepts.to_excel('Gloss_concepts.xlsx')
