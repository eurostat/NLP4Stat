# %% [markdown]
# # Statistics Explained  articles and matches with Eurostat's Concepts and Definitions Database
#
# ## Objective: to build a common vocabulary and construct "profiles" of the SE articles

# %%
import re
import pandas as pd
import spacy
import sys
from collections import Counter

## Run to install the language library, then comment-out
#!{sys.executable} -m spacy download en_core_web_lg

nlp = spacy.load('en_core_web_lg')
nlp.max_length = 1500000
print('Finished loading.')
# Out:
# Finished loading.

# %%
from datetime import datetime

def file_name(pre,ext):
    current_time = datetime.now() 
    return pre + '_'+ str(current_time.month)+ '_' + str(current_time.day) + \
                 '_' + str(current_time.hour)+ '_' + str(current_time.minute)  +'.'+ext

# %%
import pyodbc
c = pyodbc.connect('DSN=Virtuoso All;DBA=ESTAT;UID=kimon;PWD=RkhvQYZ442e2JVXLHdtW')
cursor = c.cursor()

# %%
#import unicodedata as ud

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) 
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) 

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    x = re.sub(r'â.{2}',"'",x) ### !!! NEW: single quotes are read as: âXX
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    #x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x

# %% [markdown]
# ### Statistics explained articles
#
# * IDs, titles from dat_link_info, with resource_information_id=1, i.e. Eurostat (see ESTAT.V1.mod_resource_information) and matching IDs from dat_article.
# * Carry out data cleansing on titles.

# %%
SQLCommand = """SELECT id, title 
                FROM ESTAT.V1.dat_link_info 
                WHERE resource_information_id=1 AND id IN (SELECT id FROM ESTAT.V1.dat_article) """

SE_df = pd.read_sql(SQLCommand,c)

SE_df['title'] = SE_df['title'].apply(clean)
SE_df.head(5)
# Out:
#    id                                              title
# 0   7                       Accidents at work statistics
# 1  13                          National accounts and GDP
# 2  16                Railway safety statistics in the EU
# 3  17               Railway freight transport statistics
# 4  18  Railway passenger transport statistics - quart...

# %% [markdown]
# ### Add paragraphs titles and contents
#
# * From dat_article_paragraph with abstract=0 (i.e. "no").
# * Match article_id from dat_article_paragraph with id from dat_article.
# * Carry out data cleansing on titles and paragraph contents.

# %%
SQLCommand = """SELECT article_id, title, content 
                FROM ESTAT.V1.dat_article_paragraph
                WHERE abstract=0 AND article_id IN (SELECT id FROM ESTAT.V1.dat_article) """

add_content = pd.read_sql(SQLCommand,c)
add_content['title'] = add_content['title'].apply(clean)
add_content['content'] = add_content['content'].apply(clean)
add_content
# Out:
#       article_id                                              title  \
# 0           2905  Absences from work sharply increase in first h...
# 1           2905  Absences: 9.5 % of employment in Q4 2019 and 1...
# 2           2905  Higher share of absences from work among women...
# 3           2905  Absences from work due to own illness or disab...
# 4           2905                 Absences from work due to holidays
# ...          ...                                                ...
# 3854       10539                General presentation and definition
# 3855       10539        Methodological aspects in asylum statistics
# 3856       10539        Methodological aspects in Dublin statistics
# 3857       10539  What questions can or cannot be answered with ...
# 3858       10539                                     Policy context
#
#                                                 content
# 0     Absences from work recorded unprecedented high...
# 1     The article's next figure (Figure 4) compares ...
# 2     Considering all four quarters of 2020, the sha...
# 3     From Q4 2019 to Q4 2020, the number of people ...
# 4     Expressed as a share of employed people, absen...
# ...                                                 ...
# 3854  Scope of asylum statistics and Dublin statisti...
# 3855  Annual aggregate of the number of asylum appli...
# 3856  Asymmetries For most of the collected Dublin s...
# 3857  How many asylum seekers are entering EU Member...
# 3858  The collected asylum statistics and Dublin sta...
#
# [3859 rows x 3 columns]

# %% [markdown]
# ### Aggregate above paragraph titles and contents  from SE articles paragraphs by article id
#
# * Create a column _raw content_ which gathers all paragraph titles and contents in one text per article.

# %%
add_content_grouped = add_content.groupby(['article_id'])[['title','content']].aggregate(lambda x: list(x))
add_content_grouped.reset_index(drop=False, inplace=True)
for i in range(len(add_content_grouped)):
    add_content_grouped.loc[i,'raw content'] = ''
    for (a,b) in zip(add_content_grouped.loc[i,'title'],add_content_grouped.loc[i,'content']):
        add_content_grouped.loc[i,'raw content'] += ' '+a + ' ' + b
add_content_grouped = add_content_grouped[['article_id','raw content']]    

add_content_grouped
# Out:
#      article_id                                        raw content
# 0             7   Number of accidents In 2018, there were 3.1 m...
# 1            13   Developments for GDP in the EU-27: growth sin...
# 2            16   Fall in the number of railway accidents 9 % f...
# 3            17   Downturn for EU transport performance in 2019...
# 4            18   Rail passenger transport performance continue...
# ..          ...                                                ...
# 860       10456   Problem After successfully identifying and jo...
# 861       10470   Problem In France, there was significant room...
# 862       10506   General overview Nine PEEIs concern short-ter...
# 863       10531   What are administrative sources? The term 'ad...
# 864       10539   Main points Asylum statistics and 'Dublin' st...
#
# [865 rows x 2 columns]

# %% [markdown]
# ### Merge raw content of SE articles with main file
#
# * Also, add title to definition.

# %%
SE_df = pd.merge(SE_df,add_content_grouped,left_on='id',right_on='article_id',how='inner')
SE_df.drop(['article_id'],axis=1,inplace=True)

SE_df['raw content'] = SE_df['title'] +'. '+SE_df['raw content']

SE_df.head(5)
# Out:
#    id                                              title  \
# 0   7                       Accidents at work statistics
# 1  13                          National accounts and GDP
# 2  16                Railway safety statistics in the EU
# 3  17               Railway freight transport statistics
# 4  18  Railway passenger transport statistics - quart...
#
#                                          raw content
# 0  Accidents at work statistics.  Number of accid...
# 1  National accounts and GDP.  Developments for G...
# 2  Railway safety statistics in the EU.  Fall in ...
# 3  Railway freight transport statistics.  Downtur...
# 4  Railway passenger transport statistics - quart...

# %% [markdown]
# ### Lemmatize 'raw content'
#
# * NLTK seems to be better than Spacy in lemmatization. Convert to lower-case before.

# %%
import nltk

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

SE_df['raw content'] = SE_df['raw content'].apply(lambda x: x.lower())
SE_df['raw content']= SE_df['raw content'].apply(lemmatize_text)
SE_df['raw content']= [' '.join(map(str, l)) for l in SE_df['raw content']]
SE_df['raw content'] = SE_df['raw content'].apply(lambda x: x.upper())
SE_df
# Out:
#         id                                              title  \
# 0        7                       Accidents at work statistics
# 1       13                          National accounts and GDP
# 2       16                Railway safety statistics in the EU
# 3       17               Railway freight transport statistics
# 4       18  Railway passenger transport statistics - quart...
# ..     ...                                                ...
# 860  10456  Merging statistics and geospatial information,...
# 861  10470  Merging statistics and geospatial information,...
# 862  10506  Methods for compiling PEEIs in short-term busi...
# 863  10531  Building the System of National Accounts - adm...
# 864  10539                       Asylum statistics introduced
#
#                                            raw content
# 0    ACCIDENT AT WORK STATISTICS. NUMBER OF ACCIDEN...
# 1    NATIONAL ACCOUNT AND GDP. DEVELOPMENT FOR GDP ...
# 2    RAILWAY SAFETY STATISTIC IN THE EU. FALL IN TH...
# 3    RAILWAY FREIGHT TRANSPORT STATISTICS. DOWNTURN...
# 4    RAILWAY PASSENGER TRANSPORT STATISTIC - QUARTE...
# ..                                                 ...
# 860  MERGING STATISTIC AND GEOSPATIAL INFORMATION, ...
# 861  MERGING STATISTIC AND GEOSPATIAL INFORMATION, ...
# 862  METHOD FOR COMPILING PEEIS IN SHORT-TERM BUSIN...
# 863  BUILDING THE SYSTEM OF NATIONAL ACCOUNT - ADMI...
# 864  ASYLUM STATISTIC INTRODUCED. MAIN POINT ASYLUM...
#
# [865 rows x 3 columns]

# %% [markdown]
# ### Eurostat's Concepts and Definitions Database
#
# * Download from database.

# %%
SQLCommand = """SELECT id, code_id, term
                FROM ESTAT.V1.dat_estat_glossary 
             """


concepts_df = pd.read_sql(SQLCommand,c)
concepts_df

concepts_df
# Out:
#           id  code_id                                               term
# 0          1    12789                                         (n,k) rule
# 1          2    12799                                         (p,q) rule
# 2          3    19247                                           Âµ-ARGUS
# 3          4     5545                        Abandoned wine-growing area
# 4          5    20003                      Abduction by a legal guardian
# ...      ...      ...                                                ...
# 11215  11216     4277                   Value adjustments on investments
# 11216  11217     4284  Value of transactions between affiliated enter...
# 11217  11218     4285                Value re-adjustments on investments
# 11218  11219    19099                        Widened agricultural census
# 11219  11220     4344                                  Wind (code RA300)
#
# [11220 rows x 3 columns]

# %% [markdown]
# ### Lemmatize terms
#
# * Convert to lower-case first.

# %%
concepts_df['lemmatized_term'] = concepts_df['term'].apply(lambda x: x.lower())
concepts_df['lemmatized_term']= concepts_df['lemmatized_term'].apply(lemmatize_text)
concepts_df['lemmatized_term']= [' '.join(map(str, l)) for l in concepts_df['lemmatized_term']]
concepts_df['lemmatized_term'] = concepts_df['lemmatized_term'].apply(lambda x: x.upper())
concepts_df
# Out:
#           id  code_id                                               term  \
# 0          1    12789                                         (n,k) rule
# 1          2    12799                                         (p,q) rule
# 2          3    19247                                           Âµ-ARGUS
# 3          4     5545                        Abandoned wine-growing area
# 4          5    20003                      Abduction by a legal guardian
# ...      ...      ...                                                ...
# 11215  11216     4277                   Value adjustments on investments
# 11216  11217     4284  Value of transactions between affiliated enter...
# 11217  11218     4285                Value re-adjustments on investments
# 11218  11219    19099                        Widened agricultural census
# 11219  11220     4344                                  Wind (code RA300)
#
#                                          lemmatized_term
# 0                                             (N,K) RULE
# 1                                             (P,Q) RULE
# 2                                               ÂΜ-ARGUS
# 3                            ABANDONED WINE-GROWING AREA
# 4                          ABDUCTION BY A LEGAL GUARDIAN
# ...                                                  ...
# 11215                     VALUE ADJUSTMENT ON INVESTMENT
# 11216  VALUE OF TRANSACTION BETWEEN AFFILIATED ENTERP...
# 11217                 VALUE RE-ADJUSTMENTS ON INVESTMENT
# 11218                        WIDENED AGRICULTURAL CENSUS
# 11219                                  WIND (CODE RA300)
#
# [11220 rows x 4 columns]

# %% [markdown]
# ### Prepare Spacy's PhraseMatcher by building a custom vocabulary from Eurostat's database of concepts and definitions (column 'lemmatized_term')

# %%
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp.vocab)
terms = concepts_df['lemmatized_term'].values.tolist()

patterns = [nlp.make_doc(text) for text in terms]
matcher.add("TerminologyList", patterns)

# %% [markdown]
# ### Apply PhraseMatcher
#
# * Collect results per SE article ('doc_id') in a dataframe 'res'. Ignore matches with 2 words or less.
# * Depending on the length of a match: columns '3-Phrases', '4-Phrases', '5-and-above-Phrases'. These will contain dictionaries with the matched lemmatized terms and their counts, in descending order of counts.
# * Column 'Terms' has a dictionary with the corresponding **original terms** in Eurostat's database of concepts and definitions and their counts in the matches.

# %%
res = pd.DataFrame(index=range(len(SE_df)))
res['3-Phrases']=[[] for i in range(len(SE_df))]
res['4-Phrases']=[[] for i in range(len(SE_df))]
res['5-and-above-Phrases']=[[] for i in range(len(SE_df))]
res['Terms']=[dict() for i in range(len(SE_df))]
docs=nlp.pipe(SE_df['raw content'])
for (i,doc) in enumerate(docs):
    print(i)
    for sent in doc.sents:
        matches = matcher(sent)
        for match_id, start, end in matches:
            span = doc[start:end]
            n_words = len(span.text.split(' '))
            if n_words >= 3:
                doc_id = SE_df.loc[i,'id']
                idx = concepts_df.index[concepts_df['lemmatized_term'].str.contains(span.text,regex=False)].tolist()
                print(i,SE_df.loc[i,'title'],len(sent.text),'>',n_words,span.text,idx)
                res.loc[i,'doc_id']=doc_id
                for elem in concepts_df.loc[idx,'term'].values.tolist():
                    if elem in res.loc[i,'Terms'].keys():
                        res.loc[i,'Terms'][elem] +=1
                    else:
                        res.loc[i,'Terms'][elem] =1
                #res.loc[i,'Terms'].append(concepts_df.loc[idx,'term'].values.tolist())
                if n_words == 3:
                    res.loc[i,'3-Phrases'].append(span.text)
                elif n_words == 4:
                    res.loc[i,'4-Phrases'].append(span.text)
                else:
                    res.loc[i,'5-and-above-Phrases'].append(span.text)
# Out:
# 0
# 0 Accidents at work statistics 28 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 145 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 146 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 73 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 104 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 218 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 161 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 197 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 197 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 92 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 53 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 278 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 278 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 379 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 324 > 4 HEALTH AND SOCIAL WORK [4344]
# 0 Accidents at work statistics 145 > 3 TYPE OF INJURY [10482]
# 0 Accidents at work statistics 145 > 3 TYPE OF INJURY [10482]
# 0 Accidents at work statistics 203 > 3 TYPE OF INJURY [10482]
# 0 Accidents at work statistics 229 > 3 PERSON IN EMPLOYMENT [7376]
# 0 Accidents at work statistics 314 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 133 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 180 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 162 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 311 > 3 ACCIDENT AT WORK [35]
# 0 Accidents at work statistics 311 > 3 ACCIDENT AT WORK [35]
# 1
# 1 National accounts and GDP 190 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 142 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 254 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 206 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 143 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 231 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 206 > 3 ANNUAL GROWTH RATE [418, 428, 620, 621]
# 1 National accounts and GDP 206 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 314 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 173 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 162 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 162 > 3 PURCHASING POWER STANDARD [8030, 8031, 8032, 8033]
# 1 National accounts and GDP 162 > 4 PURCHASING POWER STANDARD (PPS) [8033]
# 1 National accounts and GDP 175 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 378 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 1 National accounts and GDP 378 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 1 National accounts and GDP 143 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 1 National accounts and GDP 69 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 1 National accounts and GDP 184 > 4 HEALTH AND SOCIAL WORK [4344]
# 1 National accounts and GDP 103 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 1 National accounts and GDP 143 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 158 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 371 > 4 HEALTH AND SOCIAL WORK [4344]
# 1 National accounts and GDP 275 > 4 HEALTH AND SOCIAL WORK [4344]
# 1 National accounts and GDP 122 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 1 National accounts and GDP 283 > 3 FINAL CONSUMPTION EXPENDITURE [3441, 3442, 3443, 3444, 3445, 3911, 4085, 4493, 6601]
# 1 National accounts and GDP 59 > 3 FINAL CONSUMPTION EXPENDITURE [3441, 3442, 3443, 3444, 3445, 3911, 4085, 4493, 6601]
# 1 National accounts and GDP 50 > 3 GROSS CAPITAL FORMATION [4138, 4139, 4140, 4141]
# 1 National accounts and GDP 246 > 4 NON-PROFIT INSTITUTION SERVING HOUSEHOLD [6519, 6524, 6525, 6526, 6527, 10249]
# 1 National accounts and GDP 292 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 126 > 4 GROSS FIXED CAPITAL FORMATION [4211, 4212, 4213, 4214, 4215, 4216, 4217, 10718, 11059]
# 1 National accounts and GDP 77 > 3 RATE OF CHANGE [427, 8213]
# 1 National accounts and GDP 139 > 4 GROSS FIXED CAPITAL FORMATION [4211, 4212, 4213, 4214, 4215, 4216, 4217, 10718, 11059]
# 1 National accounts and GDP 322 > 4 NON-PROFIT INSTITUTION SERVING HOUSEHOLD [6519, 6524, 6525, 6526, 6527, 10249]
# 1 National accounts and GDP 322 > 3 GROSS CAPITAL FORMATION [4138, 4139, 4140, 4141]
# 1 National accounts and GDP 322 > 6 EXTERNAL BALANCE OF GOOD AND SERVICE [3340]
# 1 National accounts and GDP 58 > 4 GROSS FIXED CAPITAL FORMATION [4211, 4212, 4213, 4214, 4215, 4216, 4217, 10718, 11059]
# 1 National accounts and GDP 127 > 3 GROSS OPERATING SURPLUS [4244, 4245]
# 1 National accounts and GDP 127 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 1 National accounts and GDP 127 > 5 TAX ON PRODUCTION AND IMPORT [9977, 9978]
# 1 National accounts and GDP 229 > 3 COMPENSATION OF EMPLOYEE [1458, 1459, 1460, 1461, 1462, 1463]
# 1 National accounts and GDP 155 > 3 COMPENSATION OF EMPLOYEE [1458, 1459, 1460, 1461, 1462, 1463]
# 1 National accounts and GDP 71 > 3 GROSS OPERATING SURPLUS [4244, 4245]
# 1 National accounts and GDP 50 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 1 National accounts and GDP 50 > 5 TAX ON PRODUCTION AND IMPORT [9977, 9978]
# 2
# 2 Railway safety statistics in the EU 253 > 3 LEVEL CROSSING ACCIDENT [5444]
# 2 Railway safety statistics in the EU 84 > 4 FIRE IN ROLLING STOCK [3548]
# 2 Railway safety statistics in the EU 224 > 9 ACCIDENT TO PERSON CAUSED BY ROLLING STOCK IN MOTION [47]
# 2 Railway safety statistics in the EU 138 > 9 ACCIDENT TO PERSON CAUSED BY ROLLING STOCK IN MOTION [47]
# 2 Railway safety statistics in the EU 106 > 3 LEVEL CROSSING ACCIDENT [5444]
# 2 Railway safety statistics in the EU 106 > 9 ACCIDENT TO PERSON CAUSED BY ROLLING STOCK IN MOTION [47]
# 2 Railway safety statistics in the EU 310 > 3 PERSON SERIOUSLY INJURED [7391]
# 2 Railway safety statistics in the EU 310 > 3 PERSON SERIOUSLY INJURED [7391]
# 2 Railway safety statistics in the EU 310 > 3 PERSON SERIOUSLY INJURED [7391]
# 2 Railway safety statistics in the EU 134 > 3 PERSON SERIOUSLY INJURED [7391]
# 2 Railway safety statistics in the EU 61 > 3 LEVEL CROSSING ACCIDENT [5444]
# 2 Railway safety statistics in the EU 97 > 3 PERSON SERIOUSLY INJURED [7391]
# 2 Railway safety statistics in the EU 179 > 3 PERSON SERIOUSLY INJURED [7391]
# 3
# 4
# 5
# 6
# 6 R & D expenditure 172 > 3 RATE OF CHANGE [427, 8213]
# 6 R & D expenditure 182 > 3 RATE OF CHANGE [427, 8213]
# 7
# 7 Africa-EU - key statistical indicators 104 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# 7 Africa-EU - key statistical indicators 55 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# 7 Africa-EU - key statistical indicators 123 > 3 INFANT MORTALITY RATE [4811, 4812]
# 7 Africa-EU - key statistical indicators 139 > 3 INFANT MORTALITY RATE [4811, 4812]
# 7 Africa-EU - key statistical indicators 133 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 7 Africa-EU - key statistical indicators 133 > 4 GROSS DOMESTIC PRODUCT (GDP) [4165, 4166, 4167, 4168, 4169, 4170]
# 7 Africa-EU - key statistical indicators 226 > 3 TOURIST ACCOMMODATION ESTABLISHMENT [1366, 10268]
# 8
# 9
# 9 Causes of death statistics 26 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 185 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 139 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 44 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 127 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 93 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 249 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 249 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 201 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 188 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 272 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 272 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 272 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 193 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 67 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 9 Causes of death statistics 170 > 3 CAUSE OF DEATH [636, 1089, 1090, 1136, 1745, 10532]
# 10
# 11
# 11 Adult education survey - methodology 98 > 3 SPECIAL NEED EDUCATION [9368]
# 11 Adult education survey - methodology 167 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 11 Adult education survey - methodology 113 > 6 INTERNATIONAL STANDARD CLASSIFICATION OF EDUCATION (ISCED) [5087, 5088]
# 11 Adult education survey - methodology 114 > 5 INTERNATIONAL STANDARD CLASSIFICATION OF OCCUPATION [5089]
# 11 Adult education survey - methodology 161 > 3 DEGREE OF URBANISATION [2376]
# 12
# 12 Adult learning statistics - characteristics of education and training 231 > 8 PLANNED PERIOD OF TRAINING, INSTRUCTION OR PRACTICAL EXPERIENCE [7479]
# 12 Adult learning statistics - characteristics of education and training 231 > 3 PLACE OF WORK [5583, 7470]
# 12 Adult learning statistics - characteristics of education and training 195 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 13
# 13 SDG 4 - Quality education 186 > 5 EARLY CHILDHOOD EDUCATION AND CARE [2737]
# 13 SDG 4 - Quality education 76 > 5 EARLY CHILDHOOD EDUCATION AND CARE [2737]
# 13 SDG 4 - Quality education 141 > 5 EARLY CHILDHOOD EDUCATION AND CARE [2737]
# 13 SDG 4 - Quality education 175 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 13 SDG 4 - Quality education 195 > 5 PROGRAMME FOR INTERNATIONAL STUDENT ASSESSMENT [7910]
# 14
# 14 Agriculture statistics at regional level 141 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 14 Agriculture statistics at regional level 138 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 14 Agriculture statistics at regional level 188 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 14 Agriculture statistics at regional level 152 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 14 Agriculture statistics at regional level 275 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 15
# 16
# 16 Environment statistics introduced 1121 > 3 AIR EMISSION ACCOUNT [327]
# 16 Environment statistics introduced 1121 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [3093, 3094]
# 16 Environment statistics introduced 1121 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [3093, 3094]
# 16 Environment statistics introduced 1121 > 4 ENVIRONMENTAL PROTECTION EXPENDITURE ACCOUNT [3094]
# 16 Environment statistics introduced 1121 > 5 ENVIRONMENTAL GOOD AND SERVICE SECTOR [3087, 3088]
# 16 Environment statistics introduced 245 > 3 INTERNATIONAL MONETARY FUND [5074, 5075]
# 16 Environment statistics introduced 198 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [3093, 3094]
# 16 Environment statistics introduced 198 > 5 ENVIRONMENTAL GOOD AND SERVICE SECTOR [3087, 3088]
# 16 Environment statistics introduced 190 > 3 DOMESTIC MATERIAL CONSUMPTION [2659]
# 17
# 17 Greenhouse gas emission statistics - air emissions accounts 56 > 3 AIR EMISSION ACCOUNT [327]
# 17 Greenhouse gas emission statistics - air emissions accounts 205 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 17 Greenhouse gas emission statistics - air emissions accounts 132 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 17 Greenhouse gas emission statistics - air emissions accounts 171 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 17 Greenhouse gas emission statistics - air emissions accounts 171 > 4 GROSS DOMESTIC PRODUCT (GDP) [4165, 4166, 4167, 4168, 4169, 4170]
# 17 Greenhouse gas emission statistics - air emissions accounts 95 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 18
# 19
# 19 Forests, forestry and logging 167 > 3 OTHER WOODED LAND [3711, 3712, 5714, 6036, 6239, 6240, 6256, 7020, 7021, 7022, 9065, 9394]
# 19 Forests, forestry and logging 110 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 19 Forests, forestry and logging 152 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 19 Forests, forestry and logging 231 > 3 APPARENT LABOUR PRODUCTIVITY [448]
# 19 Forests, forestry and logging 231 > 3 APPARENT LABOUR PRODUCTIVITY [448]
# 20
# 21
# 21 LUCAS - Land use and land cover survey 145 > 3 LOGISTIC REGRESSION MODEL [5599]
# 21 LUCAS - Land use and land cover survey 278 > 4 FARM STRUCTURE SURVEY (FSS) [3398]
# 21 LUCAS - Land use and land cover survey 239 > 3 AGRI-ENVIRONMENTAL INDICATOR (AEI) [320]
# 21 LUCAS - Land use and land cover survey 131 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 149 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 444 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 227 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 24 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 267 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 158 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 56 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 126 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 62 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 203 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 102 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 110 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 84 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 446 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 157 > 3 SHANNON EVENNESS INDEX [11165]
# 21 LUCAS - Land use and land cover survey 255 > 3 SHANNON EVENNESS INDEX [11165]
# 22
# 22 Survey on agricultural production methods 137 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 22 Survey on agricultural production methods 137 > 4 UTILISED AGRICULTURAL AREA (UAA) [10696]
# 22 Survey on agricultural production methods 192 > 3 TYPE OF HOUSING [10481]
# 23
# 23 Road freight transport statistics - cabotage 86 > 3 MOVEMENT OF GOOD [6126]
# 23 Road freight transport statistics - cabotage 351 > 3 ROAD CABOTAGE TRANSPORT [8694]
# 24
# 24 Tourism statistics - nights spent at tourist accommodation establishments 76 > 4 HOTEL AND SIMILAR ESTABLISHMENT [4473]
# 25
# 25 Tourism statistics - annual results for the accommodation sector 110 > 3 TOURIST ACCOMMODATION ESTABLISHMENT [1366, 10268]
# 25 Tourism statistics - annual results for the accommodation sector 75 > 3 COUNTRY OF ORIGIN [1860, 1861]
# 25 Tourism statistics - annual results for the accommodation sector 70 > 3 DEGREE OF URBANISATION [2376]
# 25 Tourism statistics - annual results for the accommodation sector 43 > 3 DEGREE OF URBANISATION [2376]
# 26
# 26 Chapter 7 147 > 4 POPULATION AND HOUSING CENSUS [7522]
# 26 Chapter 7 170 > 4 EUROPEAN STATISTICAL SYSTEM (ESS) [3230, 3231]
# 27
# 27 Road freight transport statistics 87 > 3 INTERNATIONAL ROAD TRANSPORT [5083]
# 28
# 28 Agri-environmental indicator - cropping patterns 218 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 28 Agri-environmental indicator - cropping patterns 218 > 4 UTILISED AGRICULTURAL AREA (UAA) [10696]
# 28 Agri-environmental indicator - cropping patterns 160 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 29
# 29 SDG 17 - Partnerships for the goals 298 > 3 OFFICIAL DEVELOPMENT ASSISTANCE [6711, 6712]
# 29 SDG 17 - Partnerships for the goals 298 > 3 OTHER OFFICIAL FLOW [6953]
# 29 SDG 17 - Partnerships for the goals 298 > 3 FOREIGN DIRECT INVESTMENT [3658, 3659, 3660, 3661, 3662, 3663, 3664, 3665, 3666]
# 29 SDG 17 - Partnerships for the goals 298 > 4 FOREIGN DIRECT INVESTMENT (FDI) [3660, 3661]
# 29 SDG 17 - Partnerships for the goals 298 > 4 OFFICIALLY SUPPORTED EXPORT CREDIT [502, 6718]
# 29 SDG 17 - Partnerships for the goals 32 > 3 OFFICIAL DEVELOPMENT ASSISTANCE [6711, 6712]
# 29 SDG 17 - Partnerships for the goals 155 > 3 GROSS NATIONAL INCOME [4238]
# 29 SDG 17 - Partnerships for the goals 98 > 3 OFFICIAL DEVELOPMENT ASSISTANCE [6711, 6712]
# 30
# 31
# 31 Natural gas supply statistics 330 > 3 COUNTRY OF ORIGIN [1860, 1861]
# 32
# 32 Living conditions in Europe - income distribution and income inequality 220 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 220 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 128 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 201 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 201 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 125 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 208 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 102 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 221 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 294 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 32 Living conditions in Europe - income distribution and income inequality 294 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 294 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 32 Living conditions in Europe - income distribution and income inequality 251 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 111 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 156 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 156 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 167 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 79 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 224 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 143 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 260 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 146 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 119 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 94 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 115 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 58 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 154 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 171 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 337 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 137 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 322 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 183 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 314 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 287 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 171 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 64 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 283 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 161 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 208 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 79 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 215 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 292 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 227 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 32 Living conditions in Europe - income distribution and income inequality 168 > 3 EQUIVALISED DISPOSABLE INCOME [3135]
# 33
# 33 International trade in goods 148 > 4 AVERAGE ANNUAL GROWTH RATE [620, 621]
# 33 International trade in goods 148 > 3 ANNUAL GROWTH RATE [418, 428, 620, 621]
# 33 International trade in goods 169 > 4 AVERAGE ANNUAL GROWTH RATE [620, 621]
# 33 International trade in goods 169 > 3 ANNUAL GROWTH RATE [418, 428, 620, 621]
# 34
# 34 Material flow accounts and resource productivity 128 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 34 Material flow accounts and resource productivity 128 > 4 GROSS DOMESTIC PRODUCT (GDP) [4165, 4166, 4167, 4168, 4169, 4170]
# 34 Material flow accounts and resource productivity 128 > 3 DOMESTIC MATERIAL CONSUMPTION [2659]
# 34 Material flow accounts and resource productivity 219 > 3 GROSS CAPITAL FORMATION [4138, 4139, 4140, 4141]
# 34 Material flow accounts and resource productivity 187 > 3 DOMESTIC MATERIAL CONSUMPTION [2659]
# 34 Material flow accounts and resource productivity 93 > 3 DOMESTIC MATERIAL CONSUMPTION [2659]
# 35
# 36
# 36 Digital economy and society statistics - households and individuals 235 > 3 DEGREE OF URBANISATION [2376]
# 37
# 37 Healthy life years statistics 29 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 67 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 67 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 78 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 134 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 131 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# 37 Healthy life years statistics 55 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 52 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 248 > 3 QUALITY OF LIFE [8110]
# 37 Healthy life years statistics 206 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 206 > 3 HEALTHY LIFE YEAR [4357]
# 37 Healthy life years statistics 206 > 3 HEALTHY LIFE YEAR [4357]
# 38
# 39
# 40
# 40 Children at risk of poverty or social exclusion 539 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 539 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 472 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 375 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 36 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 161 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 200 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 63 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 119 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 119 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 250 > 3 LEVEL OF EDUCATION [4404, 5446, 5451]
# 40 Children at risk of poverty or social exclusion 292 > 3 COUNTRY OF BIRTH [1853, 1854, 7525]
# 41
# 41 Population and population change statistics 124 > 4 POPULATION ON 1 JANUARY [7539]
# 41 Population and population change statistics 165 > 5 CRUDE RATE OF NATURAL INCREASE [1970]
# 41 Population and population change statistics 278 > 5 CRUDE RATE OF NET MIGRATION [1971, 1972]
# 42
# 42 The EU in the world - population 274 > 3 TOTAL FERTILITY RATE [10203]
# 42 The EU in the world - population 264 > 3 TOTAL FERTILITY RATE [10203]
# 42 The EU in the world - population 101 > 3 TOTAL FERTILITY RATE [10203]
# 42 The EU in the world - population 154 > 3 TOTAL FERTILITY RATE [10203]
# 42 The EU in the world - population 215 > 3 TOTAL FERTILITY RATE [10203]
# 42 The EU in the world - population 107 > 3 TOTAL FERTILITY RATE [10203]
# 42 The EU in the world - population 171 > 3 CRUDE BIRTH RATE [1954, 1955, 1956]
# 42 The EU in the world - population 171 > 3 CRUDE BIRTH RATE [1954, 1955, 1956]
# 42 The EU in the world - population 56 > 3 CRUDE BIRTH RATE [1954, 1955, 1956]
# 42 The EU in the world - population 172 > 3 CRUDE DEATH RATE [1957, 1958, 1959, 1960]
# 42 The EU in the world - population 241 > 3 CRUDE DEATH RATE [1957, 1958, 1959, 1960]
# 42 The EU in the world - population 114 > 3 APPLICATION FOR ASYLUM [450]
# 42 The EU in the world - population 169 > 3 COUNTRY OF ORIGIN [1860, 1861]
# 43
# 43 Chapter 2 299 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 126 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 335 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 85 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 43 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 165 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 43 Chapter 2 422 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 43 Chapter 2 89 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 586 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 586 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 100 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 120 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 44 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 320 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 260 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 43 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 178 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 221 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 110 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 219 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 219 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 233 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 201 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 228 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 61 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 75 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 102 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 196 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 256 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 192 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 137 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 205 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 197 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 119 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 103 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 278 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 278 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 140 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 140 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 141 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 114 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 76 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 147 > 4 POPULATION AND HOUSING CENSUS [7522]
# 43 Chapter 2 80 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 296 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 296 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 296 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 306 > 4 LABOUR FORCE SURVEY (LFS) [5307]
# 43 Chapter 2 90 > 3 DEGREE OF URBANISATION [2376]
# 43 Chapter 2 89 > 3 DEGREE OF URBANISATION [2376]
# 44
# 44 Business demography statistics 162 > 5 TOTAL NUMBER OF PERSON EMPLOYED [10230]
# 44 Business demography statistics 136 > 3 NUMBER OF EMPLOYEE [6618, 6619, 6620, 10226, 10227]
# 45
# 45 Environmental accounts - establishing the links between the environment and the economy 78 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 45 Environmental accounts - establishing the links between the environment and the economy 265 > 4 SUPPLY AND USE TABLE [9803, 9804, 9805]
# 45 Environmental accounts - establishing the links between the environment and the economy 238 > 3 INTERNATIONAL MONETARY FUND [5074, 5075]
# 45 Environmental accounts - establishing the links between the environment and the economy 238 > 3 WORLD BANK GROUP [10971]
# 45 Environmental accounts - establishing the links between the environment and the economy 62 > 3 AIR EMISSION ACCOUNT [327]
# 45 Environmental accounts - establishing the links between the environment and the economy 28 > 4 PHYSICAL ENERGY FLOW ACCOUNT [7446]
# 45 Environmental accounts - establishing the links between the environment and the economy 44 > 5 ENVIRONMENTAL GOOD AND SERVICE SECTOR [3087, 3088]
# 45 Environmental accounts - establishing the links between the environment and the economy 44 > 6 ENVIRONMENTAL GOOD AND SERVICE SECTOR (EGSS) [3088]
# 45 Environmental accounts - establishing the links between the environment and the economy 113 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 45 Environmental accounts - establishing the links between the environment and the economy 47 > 3 ENVIRONMENTAL PROTECTION EXPENDITURE [3093, 3094]
# 45 Environmental accounts - establishing the links between the environment and the economy 47 > 4 ENVIRONMENTAL PROTECTION EXPENDITURE ACCOUNT [3094]
# 45 Environmental accounts - establishing the links between the environment and the economy 221 > 4 GROSS FIXED CAPITAL FORMATION [4211, 4212, 4213, 4214, 4215, 4216, 4217, 10718, 11059]
# 45 Environmental accounts - establishing the links between the environment and the economy 216 > 5 ENVIRONMENTAL SUBSIDY AND SIMILAR TRANSFER [3100]
# 45 Environmental accounts - establishing the links between the environment and the economy 149 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 45 Environmental accounts - establishing the links between the environment and the economy 149 > 3 INTERNATIONAL INVESTMENT POSITION [5068, 5069, 5070, 5071, 6320]
# 46
# 47
# 47 Sector accounts 41 > 5 PROFIT SHARE OF NON-FINANCIAL CORPORATION [7903]
# 47 Sector accounts 48 > 5 PROFIT SHARE OF NON-FINANCIAL CORPORATION [7903]
# 47 Sector accounts 158 > 5 PROFIT SHARE OF NON-FINANCIAL CORPORATION [7903]
# 48
# 48 Geographical information system of the Commission (GISCO) 503 > 3 SPATIAL DATA INFRASTRUCTURE [9349]
# 48 Geographical information system of the Commission (GISCO) 217 > 3 DEGREE OF URBANISATION [2376]
# 49
# 49 GDP per capita, consumption per capita and price level indices 235 > 4 ACTUAL INDIVIDUAL CONSUMPTION (AIC) [165, 166, 167]
# 49 GDP per capita, consumption per capita and price level indices 127 > 3 PRICE LEVEL INDEX [7669, 7670]
# 49 GDP per capita, consumption per capita and price level indices 112 > 3 COEFFICIENT OF VARIATION [1325, 1326, 1327]
# 50
# 50 Update of the SNA 1993 and revision of ESA95 222 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 50 Update of the SNA 1993 and revision of ESA95 291 > 3 INTERNATIONAL MONETARY FUND [5074, 5075]
# 50 Update of the SNA 1993 and revision of ESA95 291 > 6 ORGANISATION FOR ECONOMIC CO-OPERATION AND DEVELOPMENT [6808]
# 50 Update of the SNA 1993 and revision of ESA95 177 > 3 ACTUAL SOCIAL CONTRIBUTION [170, 2974, 2975, 2976, 2977, 2988, 4514, 4515]
# 50 Update of the SNA 1993 and revision of ESA95 121 > 3 DEFINED CONTRIBUTION SCHEME [2353, 2354, 2355, 6594]
# 50 Update of the SNA 1993 and revision of ESA95 218 > 3 DEFINED BENEFIT SCHEME [2348, 2349, 2350]
# 50 Update of the SNA 1993 and revision of ESA95 302 > 3 UNFUNDED PENSION SCHEME [6422, 10555]
# 50 Update of the SNA 1993 and revision of ESA95 302 > 4 SOCIAL SECURITY PENSION SCHEME [9296]
# 50 Update of the SNA 1993 and revision of ESA95 194 > 3 EMPLOYERS' PENSION SCHEME [2983]
# 50 Update of the SNA 1993 and revision of ESA95 453 > 4 EMPLOYERS' IMPUTED SOCIAL CONTRIBUTION [2979, 2980, 2981]
# 50 Update of the SNA 1993 and revision of ESA95 453 > 3 IMPUTED SOCIAL CONTRIBUTION [2979, 2980, 2981, 4667, 4668]
# 50 Update of the SNA 1993 and revision of ESA95 114 > 3 COMPENSATION OF EMPLOYEE [1458, 1459, 1460, 1461, 1462, 1463]
# 50 Update of the SNA 1993 and revision of ESA95 358 > 4 CONSUMPTION OF FIXED CAPITAL [1684, 1685, 1686, 1687]
# 50 Update of the SNA 1993 and revision of ESA95 216 > 3 RATE OF RETURN [3261, 3325, 4247, 6339, 8211, 8212]
# 50 Update of the SNA 1993 and revision of ESA95 24 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 50 Update of the SNA 1993 and revision of ESA95 70 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 50 Update of the SNA 1993 and revision of ESA95 143 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 50 Update of the SNA 1993 and revision of ESA95 205 > 4 CONSUMPTION OF FIXED CAPITAL [1684, 1685, 1686, 1687]
# 50 Update of the SNA 1993 and revision of ESA95 205 > 4 CONSUMPTION OF FIXED CAPITAL [1684, 1685, 1686, 1687]
# 50 Update of the SNA 1993 and revision of ESA95 241 > 4 CONSUMPTION OF FIXED CAPITAL [1684, 1685, 1686, 1687]
# 50 Update of the SNA 1993 and revision of ESA95 301 > 3 GOOD FOR PROCESSING [4032]
# 50 Update of the SNA 1993 and revision of ESA95 301 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 50 Update of the SNA 1993 and revision of ESA95 161 > 3 GOOD FOR PROCESSING [4032]
# 50 Update of the SNA 1993 and revision of ESA95 115 > 3 RECORDING OF TRANSACTION [8279]
# 50 Update of the SNA 1993 and revision of ESA95 197 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 50 Update of the SNA 1993 and revision of ESA95 158 > 3 GOOD FOR PROCESSING [4032]
# 50 Update of the SNA 1993 and revision of ESA95 62 > 4 EXPENDITURE ACCORDING TO PURPOSE [3292]
# 50 Update of the SNA 1993 and revision of ESA95 290 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 50 Update of the SNA 1993 and revision of ESA95 306 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 50 Update of the SNA 1993 and revision of ESA95 299 > 4 SUPPLY AND USE TABLE [9803, 9804, 9805]
# 50 Update of the SNA 1993 and revision of ESA95 302 > 3 QUARTERLY ECONOMIC ACCOUNT [8131]
# 50 Update of the SNA 1993 and revision of ESA95 315 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 50 Update of the SNA 1993 and revision of ESA95 229 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 50 Update of the SNA 1993 and revision of ESA95 229 > 5 REST OF THE WORLD ACCOUNT [8621, 8622]
# 50 Update of the SNA 1993 and revision of ESA95 229 > 6 EXTERNAL ACCOUNT OF GOOD AND SERVICE [3337]
# 50 Update of the SNA 1993 and revision of ESA95 54 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 50 Update of the SNA 1993 and revision of ESA95 325 > 3 GENERAL GOVERNMENT SECTOR [3912]
# 50 Update of the SNA 1993 and revision of ESA95 54 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 51
# 51 Agri-environmental indicator - livestock patterns 111 > 3 LIVESTOCK DENSITY INDEX [4118, 5536]
# 51 Agri-environmental indicator - livestock patterns 125 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 51 Agri-environmental indicator - livestock patterns 125 > 4 UTILISED AGRICULTURAL AREA (UAA) [10696]
# 51 Agri-environmental indicator - livestock patterns 172 > 4 GRAZING LIVESTOCK DENSITY INDEX [4118]
# 51 Agri-environmental indicator - livestock patterns 172 > 3 LIVESTOCK DENSITY INDEX [4118, 5536]
# 52
# 52 Farms and farmland in the European Union - statistics 171 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 52 Farms and farmland in the European Union - statistics 171 > 4 UTILISED AGRICULTURAL AREA (UAA) [10696]
# 52 Farms and farmland in the European Union - statistics 383 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 52 Farms and farmland in the European Union - statistics 167 > 3 TIME SERIES ANALYSIS [10132]
# 52 Farms and farmland in the European Union - statistics 165 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 52 Farms and farmland in the European Union - statistics 303 > 3 UTILISED AGRICULTURAL AREA [10695, 10696, 10697, 10698, 10699]
# 53
# 54
# 54 R & D personnel 284 > 3 FULL-TIME EQUIVALENT (FTE) [3818, 3819]
# 54 R & D personnel 210 > 6 HUMAN RESOURCE IN SCIENCE AND TECHNOLOGY [4553]
# 54 R & D personnel 210 > 6 HUMAN RESOURCE IN SCIENCE AND TECHNOLOGY [4553]
# 54 R & D personnel 144 > 3 FIELD OF EDUCATION [3431]
# 54 R & D personnel 108 > 3 FIELD OF EDUCATION [3431]
# 54 R & D personnel 242 > 3 COUNTRY OF ORIGIN [1860, 1861]
# 54 R & D personnel 240 > 3 FIELD OF EDUCATION [3431]
# 54 R & D personnel 142 > 3 FIELD OF EDUCATION [3431]
# 54 R & D personnel 121 > 3 FIELD OF EDUCATION [3431]
# 54 R & D personnel 129 > 3 FIELD OF EDUCATION [3431]
# 55
# 55 Government finance statistics 132 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 55 Government finance statistics 132 > 4 GROSS DOMESTIC PRODUCT (GDP) [4165, 4166, 4167, 4168, 4169, 4170]
# 55 Government finance statistics 109 > 4 EXCESSIVE DEFICIT PROCEDURE (EDP) [3265]
# 55 Government finance statistics 221 > 3 GENERAL GOVERNMENT SECTOR [3912]
# 55 Government finance statistics 196 > 3 GENERAL GOVERNMENT SECTOR [3912]
# 55 Government finance statistics 121 > 3 NET SOCIAL CONTRIBUTION [6349, 6350]
# 55 Government finance statistics 188 > 3 NET SOCIAL CONTRIBUTION [6349, 6350]
# 55 Government finance statistics 126 > 5 OUTPUT FOR OWN FINAL USE [7044]
# 55 Government finance statistics 242 > 3 NET SOCIAL CONTRIBUTION [6349, 6350]
# 55 Government finance statistics 165 > 4 SOCIAL TRANSFER IN KIND [9257, 9303, 9304, 9305]
# 55 Government finance statistics 165 > 3 TRANSFER IN KIND [1017, 1018, 9257, 9303, 9304, 9305, 10339]
# 55 Government finance statistics 110 > 3 COMPENSATION OF EMPLOYEE [1458, 1459, 1460, 1461, 1462, 1463]
# 55 Government finance statistics 152 > 4 GROSS FIXED CAPITAL FORMATION [4211, 4212, 4213, 4214, 4215, 4216, 4217, 10718, 11059]
# 55 Government finance statistics 164 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 55 Government finance statistics 164 > 3 TAX ON INCOME [2051, 2052, 2053, 7001, 9951, 9968, 9969]
# 55 Government finance statistics 128 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 55 Government finance statistics 128 > 5 TAX ON PRODUCTION AND IMPORT [9977, 9978]
# 55 Government finance statistics 128 > 6 CURRENT TAX ON INCOME, WEALTH, ETC [2051, 2052, 2053]
# 55 Government finance statistics 128 > 6 CURRENT TAX ON INCOME, WEALTH, ETC. [2052, 2053]
# 55 Government finance statistics 128 > 3 TAX ON INCOME [2051, 2052, 2053, 7001, 9951, 9968, 9969]
# 55 Government finance statistics 45 > 3 NET SOCIAL CONTRIBUTION [6349, 6350]
# 55 Government finance statistics 113 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 55 Government finance statistics 113 > 5 TAX ON PRODUCTION AND IMPORT [9977, 9978]
# 55 Government finance statistics 67 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 55 Government finance statistics 67 > 5 TAX ON PRODUCTION AND IMPORT [9977, 9978]
# 55 Government finance statistics 105 > 3 TAX ON INCOME [2051, 2052, 2053, 7001, 9951, 9968, 9969]
# 55 Government finance statistics 53 > 3 NET SOCIAL CONTRIBUTION [6349, 6350]
# 55 Government finance statistics 219 > 3 NET SOCIAL CONTRIBUTION [6349, 6350]
# 55 Government finance statistics 129 > 3 TAX ON INCOME [2051, 2052, 2053, 7001, 9951, 9968, 9969]
# 55 Government finance statistics 68 > 3 TAX ON PRODUCTION [7002, 7003, 9976, 9977, 9978]
# 55 Government finance statistics 68 > 5 TAX ON PRODUCTION AND IMPORT [9977, 9978]
# 55 Government finance statistics 148 > 3 TAX ON INCOME [2051, 2052, 2053, 7001, 9951, 9968, 9969]
# 56
# 56 Government finance statistics - quarterly data 203 > 4 FINANCIAL ASSET AND LIABILITY [3493, 7014]
# 56 Government finance statistics - quarterly data 133 > 4 HOLDING GAIN AND LOSS [4434, 6370, 6371, 6408, 8232, 8233]
# 56 Government finance statistics - quarterly data 133 > 4 OTHER CHANGE IN VOLUME [6875, 11138]
# 56 Government finance statistics - quarterly data 175 > 4 FINANCIAL ASSET AND LIABILITY [3493, 7014]
# 56 Government finance statistics - quarterly data 227 > 3 INVESTMENT FUND SHARE [3117, 5166, 6494, 6929]
# 56 Government finance statistics - quarterly data 227 > 3 CURRENCY AND DEPOSIT [2012, 2013, 2014]
# 56 Government finance statistics - quarterly data 74 > 3 CURRENCY AND DEPOSIT [2012, 2013, 2014]
# 56 Government finance statistics - quarterly data 108 > 4 FINANCIAL ASSET AND LIABILITY [3493, 7014]
# 56 Government finance statistics - quarterly data 78 > 4 FINANCIAL ASSET AND LIABILITY [3493, 7014]
# 56 Government finance statistics - quarterly data 128 > 3 CURRENCY AND DEPOSIT [2012, 2013, 2014]
# 57
# 57 Structure of government debt 251 > 3 GENERAL GOVERNMENT SECTOR [3912]
# 57 Structure of government debt 251 > 3 SOCIAL SECURITY FUND [9293, 9294, 9295]
# 57 Structure of government debt 230 > 3 SOCIAL SECURITY FUND [9293, 9294, 9295]
# 57 Structure of government debt 168 > 3 CURRENCY AND DEPOSIT [2012, 2013, 2014]
# 57 Structure of government debt 96 > 3 CURRENCY AND DEPOSIT [2012, 2013, 2014]
# 57 Structure of government debt 233 > 3 CURRENCY AND DEPOSIT [2012, 2013, 2014]
# 57 Structure of government debt 304 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 57 Structure of government debt 148 > 3 FINANCIAL CORPORATION SECTOR [3505, 3506, 6459]
# 57 Structure of government debt 63 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 57 Structure of government debt 34 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 58
# 58 Hospital discharges and length of stay statistics 279 > 3 MENTAL HEALTH CARE [5897]
# 58 Hospital discharges and length of stay statistics 279 > 3 HEALTH CARE INSTITUTION [4346]
# 58 Hospital discharges and length of stay statistics 211 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 218 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 218 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 189 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 426 > 3 MENTAL HEALTH CARE [5897]
# 58 Hospital discharges and length of stay statistics 189 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 265 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 199 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 148 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 106 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 66 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 223 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 205 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 195 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 157 > 3 MENTAL HEALTH CARE [5897]
# 58 Hospital discharges and length of stay statistics 248 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 102 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 388 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 166 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 87 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 58 Hospital discharges and length of stay statistics 155 > 3 MENTAL HEALTH CARE [5897]
# 58 Hospital discharges and length of stay statistics 155 > 3 HEALTH CARE INSTITUTION [4346]
# 59
# 59 Healthcare resource statistics - beds 232 > 4 AVERAGE LENGTH OF STAY [626, 627]
# 60
# 61
# 61 International trade in goods by enterprise size 102 > 3 NUMBER OF ENTERPRISE [6621, 6622, 6623, 6624, 6625, 6626, 6627, 6628, 6629]
# 61 International trade in goods by enterprise size 144 > 3 NUMBER OF ENTERPRISE [6621, 6622, 6623, 6624, 6625, 6626, 6627, 6628, 6629]
# 61 International trade in goods by enterprise size 77 > 3 NUMBER OF ENTERPRISE [6621, 6622, 6623, 6624, 6625, 6626, 6627, 6628, 6629]
# 61 International trade in goods by enterprise size 178 > 3 NUMBER OF ENTERPRISE [6621, 6622, 6623, 6624, 6625, 6626, 6627, 6628, 6629]
# 61 International trade in goods by enterprise size 167 > 3 NUMBER OF ENTERPRISE [6621, 6622, 6623, 6624, 6625, 6626, 6627, 6628, 6629]
# 61 International trade in goods by enterprise size 85 > 3 NUMBER OF ENTERPRISE [6621, 6622, 6623, 6624, 6625, 6626, 6627, 6628, 6629]
# 62
# 62 Fishery statistics 73 > 3 FACTOR OF PRODUCTION [3367, 3371, 5228]
# 62 Fishery statistics 141 > 3 FACTOR OF PRODUCTION [3367, 3371, 5228]
# 62 Fishery statistics 334 > 8 INTERNATIONAL COUNCIL FOR THE EXPLORATION OF THE SEA [5052]
# 63
# 63 NACE background 58 > 3 CLASSIFICATION OF PRODUCT [1255, 1256, 9483]
# 64
# 64 Balance of payments statistics 30 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 64 Balance of payments statistics 147 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 64 Balance of payments statistics 147 > 4 GROSS DOMESTIC PRODUCT (GDP) [4165, 4166, 4167, 4168, 4169, 4170]
# 64 Balance of payments statistics 180 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 282 > 3 EXPORT OF SERVICE [3323]
# 64 Balance of payments statistics 155 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 137 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 171 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 171 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 164 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 107 > 3 EMPLOYEE STOCK OPTION [2958, 2959]
# 64 Balance of payments statistics 145 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 327 > 3 EMPLOYEE STOCK OPTION [2958, 2959]
# 64 Balance of payments statistics 268 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 64 Balance of payments statistics 155 > 3 EMPLOYEE STOCK OPTION [2958, 2959]
# 64 Balance of payments statistics 131 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 65
# 65 Health statistics at regional level 42 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# 65 Health statistics at regional level 187 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# 65 Health statistics at regional level 214 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# 65 Health statistics at regional level 174 > 4 LIFE EXPECTANCY AT BIRTH [5476]
# ...
# 855 Continuing Vocational Training Survey (CVTS) methodology 442 > 3 CONTINUING VOCATIONAL TRAINING [1721, 1722, 1723, 1724, 6908]
# 855 Continuing Vocational Training Survey (CVTS) methodology 442 > 3 UNPAID FAMILY WORKER [10618]
# 855 Continuing Vocational Training Survey (CVTS) methodology 110 > 4 APPRENTICESHIP OR TRAINING CONTRACT [458]
# 855 Continuing Vocational Training Survey (CVTS) methodology 25 > 4 PARTICIPANT IN CVT COURSE [7189]
# 855 Continuing Vocational Training Survey (CVTS) methodology 110 > 4 PARTICIPANT IN CVT COURSE [7189]
# 855 Continuing Vocational Training Survey (CVTS) methodology 242 > 4 APPRENTICESHIP OR TRAINING CONTRACT [458]
# 855 Continuing Vocational Training Survey (CVTS) methodology 242 > 3 STRUCTURAL BUSINESS STATISTIC [9686]
# 855 Continuing Vocational Training Survey (CVTS) methodology 90 > 4 APPRENTICESHIP OR TRAINING CONTRACT [458]
# 856
# 856 City statistics ' economic aspects 86 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 856 City statistics ' economic aspects 206 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 856 City statistics ' economic aspects 296 > 3 ECONOMICALLY ACTIVE POPULATION [2806, 2807, 2808]
# 856 City statistics ' economic aspects 131 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 856 City statistics ' economic aspects 214 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 857
# 858
# 858 City statistics ' introduction 180 > 3 QUALITY OF LIFE [8110]
# 858 City statistics ' introduction 343 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 858 City statistics ' introduction 94 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 858 City statistics ' introduction 96 > 3 DEGREE OF URBANISATION [2376]
# 858 City statistics ' introduction 130 > 3 QUALITY OF LIFE [8110]
# 858 City statistics ' introduction 121 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 858 City statistics ' introduction 139 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 858 City statistics ' introduction 116 > 3 FUNCTIONAL URBAN AREA [3831, 3832, 3833]
# 858 City statistics ' introduction 177 > 3 DEGREE OF URBANISATION [2376]
# 859
# 859 Building the System of National Accounts - strategy 158 > 3 NATIONAL STATISTICAL OFFICE [6223]
# 859 Building the System of National Accounts - strategy 257 > 3 INTERNATIONAL MONETARY FUND [5074, 5075]
# 859 Building the System of National Accounts - strategy 321 > 3 NATIONAL STATISTICAL SYSTEM [6224]
# 859 Building the System of National Accounts - strategy 209 > 3 NATIONAL STATISTICAL SYSTEM [6224]
# 859 Building the System of National Accounts - strategy 175 > 3 NATIONAL STATISTICAL SYSTEM [6224]
# 859 Building the System of National Accounts - strategy 130 > 3 NATIONAL STATISTICAL SYSTEM [6224]
# 859 Building the System of National Accounts - strategy 395 > 3 NATIONAL STATISTICAL OFFICE [6223]
# 859 Building the System of National Accounts - strategy 664 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 859 Building the System of National Accounts - strategy 202 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 859 Building the System of National Accounts - strategy 110 > 4 NON-PROFIT INSTITUTION SERVING HOUSEHOLD [6519, 6524, 6525, 6526, 6527, 10249]
# 859 Building the System of National Accounts - strategy 213 > 3 GROSS DOMESTIC PRODUCT [4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172]
# 859 Building the System of National Accounts - strategy 213 > 4 GROSS DOMESTIC PRODUCT (GDP) [4165, 4166, 4167, 4168, 4169, 4170]
# 859 Building the System of National Accounts - strategy 213 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 859 Building the System of National Accounts - strategy 153 > 3 NATIONAL STATISTICAL OFFICE [6223]
# 859 Building the System of National Accounts - strategy 115 > 3 NATIONAL STATISTICAL OFFICE [6223]
# 859 Building the System of National Accounts - strategy 55 > 3 STATISTICAL BUSINESS REGISTER [9476, 9477]
# 859 Building the System of National Accounts - strategy 289 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 859 Building the System of National Accounts - strategy 81 > 3 DATA COLLECTION METHOD [2122]
# 859 Building the System of National Accounts - strategy 248 > 3 INTERNATIONAL MONETARY FUND [5074, 5075]
# 860
# 860 Merging statistics and geospatial information, 2014 projects - Hungary 238 > 3 GEOGRAPHIC INFORMATION SYSTEM [3958, 3959, 3960, 3961]
# 860 Merging statistics and geospatial information, 2014 projects - Hungary 238 > 4 GEOGRAPHIC INFORMATION SYSTEM (GIS) [3960]
# 861
# 861 Merging statistics and geospatial information, 2014 projects - France 197 > 3 STATISTICAL BUSINESS REGISTER [9476, 9477]
# 861 Merging statistics and geospatial information, 2014 projects - France 84 > 3 STATISTICAL BUSINESS REGISTER [9476, 9477]
# 861 Merging statistics and geospatial information, 2014 projects - France 115 > 4 POPULATION AND HOUSING CENSUS [7522]
# 861 Merging statistics and geospatial information, 2014 projects - France 303 > 3 STATISTICAL BUSINESS REGISTER [9476, 9477]
# 861 Merging statistics and geospatial information, 2014 projects - France 185 > 3 PRODUCTION OF STATISTIC [7867]
# 862
# 862 Methods for compiling PEEIs in short-term business statistics 310 > 3 VOLUME OF SALE [10816]
# 862 Methods for compiling PEEIs in short-term business statistics 40 > 3 PRODUCER PRICE INDEX [4790, 7051, 7818, 7819, 7820, 7821, 7822, 7834]
# 862 Methods for compiling PEEIs in short-term business statistics 230 > 3 PRODUCER PRICE INDEX [4790, 7051, 7818, 7819, 7820, 7821, 7822, 7834]
# 862 Methods for compiling PEEIs in short-term business statistics 93 > 3 PRODUCER PRICE INDEX [4790, 7051, 7818, 7819, 7820, 7821, 7822, 7834]
# 862 Methods for compiling PEEIs in short-term business statistics 517 > 3 CONSUMER PRICE INDEX [1662, 1663, 1664, 1665, 1666]
# 862 Methods for compiling PEEIs in short-term business statistics 138 > 4 POSTAL AND COURIER SERVICE [7581]
# 862 Methods for compiling PEEIs in short-term business statistics 193 > 4 FREQUENCY OF DATA COLLECTION [3781]
# 863
# 863 Building the System of National Accounts - administrative sources 266 > 3 VALUE ADDED TAX [10736, 10737, 10738, 10739]
# 863 Building the System of National Accounts - administrative sources 266 > 4 VALUE ADDED TAX (VAT) [10738, 10739]
# 863 Building the System of National Accounts - administrative sources 266 > 5 VALUE ADDED TAX (VAT) DATA [10739]
# 863 Building the System of National Accounts - administrative sources 147 > 4 USE FOR STATISTICAL PURPOSE [10660]
# 863 Building the System of National Accounts - administrative sources 54 > 4 INTERNATIONAL ACCOUNTING STANDARD COMMITTEE [5041]
# 863 Building the System of National Accounts - administrative sources 59 > 5 INTERNATIONAL FINANCIAL REPORTING STANDARD (IFRS) [5058, 5059]
# 863 Building the System of National Accounts - administrative sources 284 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 863 Building the System of National Accounts - administrative sources 440 > 3 CHANGE IN STOCK [1151, 1152, 1153, 1154, 1155, 1156]
# 863 Building the System of National Accounts - administrative sources 440 > 3 CHANGE IN STOCK [1151, 1152, 1153, 1154, 1155, 1156]
# 863 Building the System of National Accounts - administrative sources 440 > 3 OTHER OPERATING INCOME [6958]
# 863 Building the System of National Accounts - administrative sources 422 > 3 MATERIAL AND SUPPLY [5152, 5830, 5831]
# 863 Building the System of National Accounts - administrative sources 422 > 3 CHANGE IN STOCK [1151, 1152, 1153, 1154, 1155, 1156]
# 863 Building the System of National Accounts - administrative sources 422 > 3 MATERIAL AND SUPPLY [5152, 5830, 5831]
# 863 Building the System of National Accounts - administrative sources 422 > 3 OTHER OPERATING COST [6957]
# 863 Building the System of National Accounts - administrative sources 422 > 3 COMPENSATION OF EMPLOYEE [1458, 1459, 1460, 1461, 1462, 1463]
# 863 Building the System of National Accounts - administrative sources 146 > 5 FINANCIAL INTERMEDIATION SERVICE INDIRECTLY MEASURED [3521, 3522]
# 863 Building the System of National Accounts - administrative sources 146 > 6 FINANCIAL INTERMEDIATION SERVICE INDIRECTLY MEASURED (FISIM) [3522]
# 863 Building the System of National Accounts - administrative sources 226 > 6 REINVESTED EARNINGS ON DIRECT FOREIGN INVESTMENT [8416, 8417]
# 863 Building the System of National Accounts - administrative sources 226 > 3 DIRECT FOREIGN INVESTMENT [2518, 2519, 8416, 8417]
# 863 Building the System of National Accounts - administrative sources 76 > 3 OTHER CURRENT TRANSFER [6882, 6883, 6884]
# 863 Building the System of National Accounts - administrative sources 43 > 4 GROSS FIXED CAPITAL FORMATION [4211, 4212, 4213, 4214, 4215, 4216, 4217, 10718, 11059]
# 863 Building the System of National Accounts - administrative sources 138 > 3 TANGIBLE FIXED ASSET [114, 125, 126, 4951, 4952, 4953, 6921, 6922, 9908, 9910, 9911, 9912]
# 863 Building the System of National Accounts - administrative sources 138 > 3 INTANGIBLE FIXED ASSET [114, 125, 4951, 4952, 4953, 6921, 6922, 9908]
# 863 Building the System of National Accounts - administrative sources 81 > 3 PERPETUAL INVENTORY METHOD [7369, 7370, 7371]
# 863 Building the System of National Accounts - administrative sources 349 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 863 Building the System of National Accounts - administrative sources 63 > 3 SUBSIDY ON PRODUCT [6993, 6994, 6995, 6996, 9741, 9742, 9743, 9744, 9745, 9746, 9747, 9956]
# 863 Building the System of National Accounts - administrative sources 164 > 3 TAX ON PRODUCT [7002, 7003, 9976, 9977, 9978, 9979, 9980, 9981, 9982]
# 863 Building the System of National Accounts - administrative sources 164 > 3 SUBSIDY ON PRODUCT [6993, 6994, 6995, 6996, 9741, 9742, 9743, 9744, 9745, 9746, 9747, 9956]
# 863 Building the System of National Accounts - administrative sources 66 > 3 RESEARCH AND DEVELOPMENT [6707, 8551, 8552, 8553, 8554, 8555]
# 863 Building the System of National Accounts - administrative sources 115 > 3 WITHDRAWAL FROM STOCK [10926]
# 863 Building the System of National Accounts - administrative sources 141 > 3 WITHDRAWAL FROM STOCK [10926]
# 863 Building the System of National Accounts - administrative sources 82 > 3 WITHDRAWAL FROM STOCK [10926]
# 863 Building the System of National Accounts - administrative sources 84 > 3 WITHDRAWAL FROM STOCK [10926]
# 863 Building the System of National Accounts - administrative sources 164 > 4 CONSUMPTION OF FIXED CAPITAL [1684, 1685, 1686, 1687]
# 863 Building the System of National Accounts - administrative sources 109 > 3 CERTIFICATE OF DEPOSIT [1130]
# 863 Building the System of National Accounts - administrative sources 170 > 5 FINANCIAL INTERMEDIATION SERVICE INDIRECTLY MEASURED [3521, 3522]
# 863 Building the System of National Accounts - administrative sources 170 > 6 FINANCIAL INTERMEDIATION SERVICE INDIRECTLY MEASURED (FISIM) [3522]
# 863 Building the System of National Accounts - administrative sources 318 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 863 Building the System of National Accounts - administrative sources 318 > 4 REFERENCE RATE OF INTEREST [8327]
# 863 Building the System of National Accounts - administrative sources 87 > 3 WAGE AND SALARY [4264, 10829, 10830, 10831, 10832, 10833, 10834, 10835, 10836, 10837, 10838]
# 863 Building the System of National Accounts - administrative sources 83 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 863 Building the System of National Accounts - administrative sources 214 > 3 INSURANCE TECHNICAL RESERVE [4945, 4946, 6475, 6476]
# 863 Building the System of National Accounts - administrative sources 130 > 3 GROSS VALUE ADDED [4257, 4258, 4259, 4260, 4261, 4262]
# 863 Building the System of National Accounts - administrative sources 153 > 3 GENERAL GOVERNMENT SECTOR [3912]
# 863 Building the System of National Accounts - administrative sources 230 > 4 CONSUMPTION OF FIXED CAPITAL [1684, 1685, 1686, 1687]
# 863 Building the System of National Accounts - administrative sources 197 > 7 CLASSIFICATION OF THE FUNCTION OF GOVERNMENT (COFOG) [1257, 1258]
# 863 Building the System of National Accounts - administrative sources 124 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 863 Building the System of National Accounts - administrative sources 40 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 863 Building the System of National Accounts - administrative sources 91 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 863 Building the System of National Accounts - administrative sources 91 > 3 INTERNATIONAL INVESTMENT POSITION [5068, 5069, 5070, 5071, 6320]
# 863 Building the System of National Accounts - administrative sources 117 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 863 Building the System of National Accounts - administrative sources 86 > 4 GOOD AND SERVICE ACCOUNT [4024, 11058]
# 863 Building the System of National Accounts - administrative sources 82 > 5 ALLOCATION OF PRIMARY INCOME ACCOUNT [367, 368]
# 863 Building the System of National Accounts - administrative sources 103 > 4 SECONDARY DISTRIBUTION OF INCOME [8980, 8981, 8982]
# 863 Building the System of National Accounts - administrative sources 103 > 5 SECONDARY DISTRIBUTION OF INCOME ACCOUNT [8981, 8982]
# 863 Building the System of National Accounts - administrative sources 109 > 3 BALANCE OF PAYMENT [212, 646, 647, 648, 649, 650, 651, 1401, 9565, 10006, 10015]
# 863 Building the System of National Accounts - administrative sources 210 > 3 NON-PRODUCED NON-FINANCIAL ASSET [183, 6516]
# 863 Building the System of National Accounts - administrative sources 210 > 3 PRODUCED NON-FINANCIAL ASSET [183, 6516, 7814]
# 863 Building the System of National Accounts - administrative sources 172 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 863 Building the System of National Accounts - administrative sources 172 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 863 Building the System of National Accounts - administrative sources 172 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 863 Building the System of National Accounts - administrative sources 285 > 3 BASIC STATISTICAL DATA [707]
# 864
# 864 Asylum statistics introduced 349 > 4 APPLICATION FOR INTERNATIONAL PROTECTION [451]
# 864 Asylum statistics introduced 189 > 3 APPLICATION FOR ASYLUM [450]
# 864 Asylum statistics introduced 62 > 4 APPLICATION FOR INTERNATIONAL PROTECTION [451]
# 864 Asylum statistics introduced 181 > 3 APPLICATION FOR ASYLUM [450]
# 864 Asylum statistics introduced 189 > 4 APPLICATION FOR INTERNATIONAL PROTECTION [451]
# 864 Asylum statistics introduced 169 > 3 COUNTRY OF ORIGIN [1860, 1861]
# 864 Asylum statistics introduced 101 > 3 FIRST INSTANCE DECISION [3552]
# 864 Asylum statistics introduced 101 > 3 FIRST INSTANCE DECISION [3552]
# 864 Asylum statistics introduced 101 > 3 FIRST INSTANCE DECISION [3552]
# 864 Asylum statistics introduced 101 > 3 FIRST INSTANCE DECISION [3552]
# 864 Asylum statistics introduced 63 > 3 THIRD COUNTRY NATIONAL [10091, 10092, 10093, 10094, 10095]
# 864 Asylum statistics introduced 63 > 6 THIRD COUNTRY NATIONAL ORDERED TO LEAVE [10093]
# 864 Asylum statistics introduced 83 > 3 THIRD COUNTRY NATIONAL [10091, 10092, 10093, 10094, 10095]
# 864 Asylum statistics introduced 83 > 9 THIRD COUNTRY NATIONAL RETURNED FOLLOWING AN ORDER TO LEAVE [10095]
# 864 Asylum statistics introduced 101 > 3 FIRST INSTANCE DECISION [3552]
# 864 Asylum statistics introduced 105 > 7 ASYLUM APPLICANT CONSIDERED TO BE UNACCOMPANIED MINOR [547]
# 864 Asylum statistics introduced 281 > 4 REST OF THE WORLD [8619, 8620, 8621, 8622, 8623, 8624]
# 864 Asylum statistics introduced 392 > 5 PERSON ELIGIBLE FOR SUBSIDIARY PROTECTION [7375]
# 864 Asylum statistics introduced 266 > 4 APPLICATION FOR INTERNATIONAL PROTECTION [451]
# 864 Asylum statistics introduced 185 > 3 APPLICATION FOR ASYLUM [450]
# 864 Asylum statistics introduced 138 > 5 PERSON ELIGIBLE FOR SUBSIDIARY PROTECTION [7375]
# 864 Asylum statistics introduced 241 > 4 APPLICATION FOR INTERNATIONAL PROTECTION [451]

# %%
res['3-Phrases']= res['3-Phrases'].apply(lambda x: dict(Counter(x).most_common()))
res['4-Phrases']= res['4-Phrases'].apply(lambda x: dict(Counter(x).most_common()))
res['5-and-above-Phrases']= res['5-and-above-Phrases'].apply(lambda x: dict(Counter(x).most_common()))

# %%
res=pd.merge(SE_df[['id','title']],res,left_on='id',right_on='doc_id',how='left')
res.drop(columns=['doc_id'],inplace=True)
res
# Out:
#         id                                              title  \
# 0        7                       Accidents at work statistics
# 1       13                          National accounts and GDP
# 2       16                Railway safety statistics in the EU
# 3       17               Railway freight transport statistics
# 4       18  Railway passenger transport statistics - quart...
# ..     ...                                                ...
# 860  10456  Merging statistics and geospatial information,...
# 861  10470  Merging statistics and geospatial information,...
# 862  10506  Methods for compiling PEEIs in short-term busi...
# 863  10531  Building the System of National Accounts - adm...
# 864  10539                       Asylum statistics introduced
#
#                                              3-Phrases  \
# 0    {'ACCIDENT AT WORK': 20, 'TYPE OF INJURY': 3, ...
# 1    {'RATE OF CHANGE': 15, 'GROSS VALUE ADDED': 6,...
# 2    {'PERSON SERIOUSLY INJURED': 6, 'LEVEL CROSSIN...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860               {'GEOGRAPHIC INFORMATION SYSTEM': 1}
# 861  {'STATISTICAL BUSINESS REGISTER': 3, 'PRODUCTI...
# 862  {'PRODUCER PRICE INDEX': 3, 'VOLUME OF SALE': ...
# 863  {'GROSS VALUE ADDED': 4, 'WITHDRAWAL FROM STOC...
# 864  {'FIRST INSTANCE DECISION': 5, 'APPLICATION FO...
#
#                                              4-Phrases  \
# 0                        {'HEALTH AND SOCIAL WORK': 1}
# 1    {'HEALTH AND SOCIAL WORK': 3, 'GROSS FIXED CAP...
# 2                         {'FIRE IN ROLLING STOCK': 1}
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860         {'GEOGRAPHIC INFORMATION SYSTEM (GIS)': 1}
# 861               {'POPULATION AND HOUSING CENSUS': 1}
# 862  {'POSTAL AND COURIER SERVICE': 1, 'FREQUENCY O...
# 863  {'REST OF THE WORLD': 5, 'CONSUMPTION OF FIXED...
# 864  {'APPLICATION FOR INTERNATIONAL PROTECTION': 5...
#
#                                    5-and-above-Phrases  \
# 0                                                   {}
# 1    {'TAX ON PRODUCTION AND IMPORT': 2, 'EXTERNAL ...
# 2    {'ACCIDENT TO PERSON CAUSED BY ROLLING STOCK I...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860                                                 {}
# 861                                                 {}
# 862                                                 {}
# 863  {'FINANCIAL INTERMEDIATION SERVICE INDIRECTLY ...
# 864  {'PERSON ELIGIBLE FOR SUBSIDIARY PROTECTION': ...
#
#                                                  Terms
# 0    {'Accident at work': 20, 'Health and social wo...
# 1    {'Annualised rate of change': 15, 'Rates of ch...
# 2    {'Level crossing accidents': 3, 'Fires in roll...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 860  {'Geographic information system': 1, 'Geograph...
# 861  {'Statistical business register': 3, 'Statisti...
# 862  {'Volume of sales': 1, 'Industrial producer pr...
# 863  {'Value added tax': 2, 'Value added tax (VAT)'...
# 864  {'Application for international protection': 5...
#
# [865 rows x 6 columns]

# %%
outfile = file_name('Phrase_Matcher_SE_Eurostat','xlsx')
res.to_excel(outfile)
