# %% [markdown]
# # Use Case A - Faceted search (in progress)
# ***

# %%
import pandas as pd
import numpy as np
#import ipywidgets
import ipywidgets as widgets
from ipywidgets import interact,Layout, IntSlider, interactive, widgets, interact_manual,HBox,fixed,VBox, Box, HTML
from ipywidgets import Button, FloatText, Textarea, Dropdown, Label
from ipywidgets import interact_manual
layout = widgets.Layout(width='400px', height='30px')
import ipydatetime
import datetime
#from __future__ import print_function
from ipywidgets import Text, HBox, VBox, Box
from IPython.display import display

# %% [markdown]
# ## A. Import Statistics Explained data from the database
# ***
#
# ### A1. id, context and last update

# %%
import pyodbc

c = pyodbc.connect('DSN=Virtuoso All;DBA=ESTAT;UID=user_name; PWD=password')
cursor = c.cursor()

dat1 = pd.read_sql("SELECT id,context,last_update FROM ESTAT.V1.dat_article",c)
dat1
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 638  4970  Trade is an important indicator of Europeâs ...
# 639  4972  Having a secure supply of energy is crucial fo...
# 640  4987  Economic and financial statistics have become ...
# 641  4989
# 642  4997  Lifelong learning can take place in a variety ...
#
#             last_update
# 0   2021-04-14 16:09:00
# 1   2020-09-16 14:36:00
# 2   2020-11-26 16:06:00
# 3   2020-12-07 17:31:00
# 4   2021-04-29 10:45:00
# ..                  ...
# 638 2021-03-31 13:04:00
# 639 2021-06-10 11:23:00
# 640 2021-06-22 11:47:00
# 641 2020-09-28 08:48:00
# 642 2021-06-17 16:23:00
#
# [643 rows x 3 columns]

# %% [markdown]
# ### A2. ids, titles and URLs

# %%
add_titles_urls = pd.read_sql("SELECT id,title,url FROM ESTAT.V1.dat_link_info",c)
add_titles_urls
# Out:
#         id                                              title  \
# 0        1          Absences from work - quarterly statist...
# 1        2   Figure 1: Absences from work in the EU, Q1 20...
# 2        3   Figure 4: Absences from work, Q4 2019 - Q4 20...
# 3        4                  All articles on the labour market
# 4        5                             EU labour force survey
# ...    ...                                                ...
# 7022  7023                                    Aggregate
# 7023  7024              OECD glossary of statistical terms
# 7024  7025               European statistics on tourism
# 7025  7026                     Regulation (EU) No 692/2011
# 7026  7027                    Regulation (EU) No 1051/2011
#
#                                                     url
# 0     https://ec.europa.eu/eurostat/statistics-expla...
# 1     https://ec.europa.eu/eurostat/databrowser/view...
# 2     https://ec.europa.eu/eurostat/databrowser/view...
# 3     /eurostat/statistics-explained/index.php?title...
# 4     /eurostat/statistics-explained/index.php?title...
# ...                                                 ...
# 7022  https://ec.europa.eu/eurostat/statistics-expla...
# 7023    http://stats.oecd.org/glossary/detail.asp?ID=68
# 7024  https://ec.europa.eu/eurostat/statistics-expla...
# 7025  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 7026  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
#
# [7027 rows x 3 columns]

# %% [markdown]
# ### Merge above
#
# Inner join on id.

# %%
dat2 = pd.merge(dat1,add_titles_urls,on='id',how='inner')
dat2
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 638  4970  Trade is an important indicator of Europeâs ...
# 639  4972  Having a secure supply of energy is crucial fo...
# 640  4987  Economic and financial statistics have become ...
# 641  4989
# 642  4997  Lifelong learning can take place in a variety ...
#
#             last_update                                              title  \
# 0   2021-04-14 16:09:00          Absences from work - quarterly statist...
# 1   2020-09-16 14:36:00            Accidents and injuries statistics
# 2   2020-11-26 16:06:00                 Accidents at work statistics
# 3   2020-12-07 17:31:00          Accidents at work - statistics by econ...
# 4   2021-04-29 10:45:00          Africa-EU - international trade in goo...
# ..                  ...                                                ...
# 638 2021-03-31 13:04:00          EU trade in COVID-19 related products ...
# 639 2021-06-10 11:23:00          EU imports of energy products - recent...
# 640 2021-06-22 11:47:00          European Neighbourhood Policy - South ...
# 641 2020-09-28 08:48:00          Ageing Europe - statistics on pensions...
# 642 2021-06-17 16:23:00                    Adult learning statistics
#
#                                                    url
# 0    https://ec.europa.eu/eurostat/statistics-expla...
# 1    https://ec.europa.eu/eurostat/statistics-expla...
# 2    https://ec.europa.eu/eurostat/statistics-expla...
# 3    https://ec.europa.eu/eurostat/statistics-expla...
# 4    https://ec.europa.eu/eurostat/statistics-expla...
# ..                                                 ...
# 638  https://ec.europa.eu/eurostat/statistics-expla...
# 639  https://ec.europa.eu/eurostat/statistics-expla...
# 640  https://ec.europa.eu/eurostat/statistics-expla...
# 641  https://ec.europa.eu/eurostat/statistics-expla...
# 642  https://ec.europa.eu/eurostat/statistics-expla...
#
# [643 rows x 5 columns]

# %% [markdown]
# ### A3. ids, titles and abstracts
#
# From the ESTAT.V1.dat_article_paragraph table with abstract=1.

# %%
add_abstracts = pd.read_sql("SELECT id,article_id,title,content,abstract FROM ESTAT.V1.dat_article_paragraph WHERE abstract=1",c)
add_abstracts
# Out:
#        id  article_id     title  \
# 0       7           1  Abstract
# 1      11          10  Abstract
# 2      18          39  Abstract
# 3      25          50  Abstract
# 4      31          56  Abstract
# ..    ...         ...       ...
# 638  3349        4970  Abstract
# 639  3355        4972  Abstract
# 640  3359        4987  Abstract
# 641  3365        4989  Abstract
# 642  3371        4997  Abstract
#
#                                                content  abstract
# 0     Absences from work can be classified into two...         1
# 1    This article presents an overview of European ...         1
# 2    This article presents a set of main statistica...         1
# 3     This article presents a set of main statistic...         1
# 4    This article provides a picture of internation...         1
# ..                                                 ...       ...
# 638   To help prevent the spread of the COVID-19 pa...         1
# 639  This article provides a picture of trade in en...         1
# 640  This article is part of an online publication ...         1
# 641  Ageing Europe â looking at the lives of olde...         1
# 642   This article provides an overview of adult le...         1
#
# [643 rows x 5 columns]

# %% [markdown]
# ### Merge above
#
# Inner join on id, article_id.

# %%
dat3 = pd.merge(dat2,add_abstracts[['article_id','content']],left_on='id',right_on='article_id',how='inner')
dat3.rename(columns={'content':'abstract'},inplace=True)
dat3 = dat3[['id','context','title','abstract','url','last_update']]

dat3
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 638  4970  Trade is an important indicator of Europeâs ...
# 639  4972  Having a secure supply of energy is crucial fo...
# 640  4987  Economic and financial statistics have become ...
# 641  4989
# 642  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 638          EU trade in COVID-19 related products ...
# 639          EU imports of energy products - recent...
# 640          European Neighbourhood Policy - South ...
# 641          Ageing Europe - statistics on pensions...
# 642                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 638   To help prevent the spread of the COVID-19 pa...
# 639  This article provides a picture of trade in en...
# 640  This article is part of an online publication ...
# 641  Ageing Europe â looking at the lives of olde...
# 642   This article provides an overview of adult le...
#
#                                                    url         last_update
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 638  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 639  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 640  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 641  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 642  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
# [643 rows x 6 columns]

# %% [markdown]
# ### A4. ids, titles and contents
#
# From the ESTAT.V1.dat_article_paragraph table with abstract=0.

# %%
add_content = pd.read_sql("SELECT id,article_id,title,content,abstract FROM ESTAT.V1.dat_article_paragraph WHERE abstract=0",c)
add_content
# Out:
#         id  article_id                                              title  \
# 0        1           1  Absences from work sharply increase in first h...
# 1        2           1  Absences: 9.5 % of employment in Q4 2019 and 1...
# 2        3           1  Higher share of absences from work among women...
# 3        4           1  Absences from work due to own illness or disab...
# 4        5           1                 Absences from work due to holidays
# ...    ...         ...                                                ...
# 2723  3366        4989                     Measuring expenditure patterns
# 2724  3367        4997  Participation rate of adults in learning in th...
# 2725  3368        4997  Participation rate of adults in learning in th...
# 2726  3369        4997  Providers of non-formal education and training...
# 2727  3370        4997      Participation in informal learning activities
#
#                                                 content  abstract
# 0      Absences from work recorded unprecedented hig...         0
# 1      The article's next figure (Figure 4) compares...         0
# 2      Considering all four quarters of 2020, the sh...         0
# 3      From Q4 2019 to Q4 2020, the number of people...         0
# 4      Expressed as a share of employed people, abse...         0
# ...                                                 ...       ...
# 2723  Household budget surveys (HBS) focus on collec...         0
# 2724   The strategic framework for European cooperat...         0
# 2725   In addition to the data from the labour force...         0
# 2726   Employers were the most common providers of n...         0
# 2727   Next to information on participation in forma...         0
#
# [2728 rows x 5 columns]

# %% [markdown]
# ### Aggregate above by article id
#
# Aggregate titles and contents in one string.

# %%
add_content_grouped = add_content.groupby(['article_id'])['title','content'].aggregate(lambda x: list(x))
add_content_grouped.reset_index(inplace=True)
for i in range(len(add_content_grouped)):
    add_content_grouped.loc[i,'raw content'] = ''
    for (a,b) in zip(add_content_grouped.loc[i,'title'],add_content_grouped.loc[i,'content']):
        add_content_grouped.loc[i,'raw content'] += ' '+a + ' ' + b
add_content_grouped = add_content_grouped[['article_id','raw content']]    

add_content_grouped
# Out:
# <ipython-input-8-4edcea5ac3ee>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   add_content_grouped = add_content.groupby(['article_id'])['title','content'].aggregate(lambda x: list(x))
#      article_id                                        raw content
# 0             1   Absences from work sharply increase in first ...
# 1            10   Deaths from accidents, injuries and assault  ...
# 2            39   Number of accidents  In 2018, there were 3.1 ...
# 3            50   Developments over time   Non-fatal accidents ...
# 4            56   Africaâs main trade in goods partner is the...
# ..          ...                                                ...
# 615        4970   Sharp increase in COVID-19 related imports in...
# 616        4972   Overview  The latest figures show the upward ...
# 617        4987   Current account  The current account of the  ...
# 618        4989   Pensions  The transition for individuals from...
# 619        4997   Participation rate of adults in learning in t...
#
# [620 rows x 2 columns]

# %% [markdown]
# ### Merge above
#
# * Inner join on id, article_id.

# %%
dat4 = pd.merge(dat3,add_content_grouped,left_on='id',right_on='article_id',how='inner')
dat4.drop(['article_id'],axis=1,inplace=True)

dat4
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 615  4970  Trade is an important indicator of Europeâs ...
# 616  4972  Having a secure supply of energy is crucial fo...
# 617  4987  Economic and financial statistics have become ...
# 618  4989
# 619  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 615          EU trade in COVID-19 related products ...
# 616          EU imports of energy products - recent...
# 617          European Neighbourhood Policy - South ...
# 618          Ageing Europe - statistics on pensions...
# 619                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 615   To help prevent the spread of the COVID-19 pa...
# 616  This article provides a picture of trade in en...
# 617  This article is part of an online publication ...
# 618  Ageing Europe â looking at the lives of olde...
# 619   This article provides an overview of adult le...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 615  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 616  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 617  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 618  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 619  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
#                                            raw content
# 0     Absences from work sharply increase in first ...
# 1     Deaths from accidents, injuries and assault  ...
# 2     Number of accidents  In 2018, there were 3.1 ...
# 3     Developments over time   Non-fatal accidents ...
# 4     Africaâs main trade in goods partner is the...
# ..                                                 ...
# 615   Sharp increase in COVID-19 related imports in...
# 616   Overview  The latest figures show the upward ...
# 617   Current account  The current account of the  ...
# 618   Pensions  The transition for individuals from...
# 619   Participation rate of adults in learning in t...
#
# [620 rows x 7 columns]

# %% [markdown]
# ## B. Data cleansing
# ***

# %%
import re

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) ## NEW
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) ## NEW

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    
    return x

# %%
dat4['title'].apply(clean)
dat4['abstract'].apply(clean)
dat4['raw content'].apply(clean)
dat4['url'].apply(clean,quotes=False)

dat4
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 615  4970  Trade is an important indicator of Europeâs ...
# 616  4972  Having a secure supply of energy is crucial fo...
# 617  4987  Economic and financial statistics have become ...
# 618  4989
# 619  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 615          EU trade in COVID-19 related products ...
# 616          EU imports of energy products - recent...
# 617          European Neighbourhood Policy - South ...
# 618          Ageing Europe - statistics on pensions...
# 619                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 615   To help prevent the spread of the COVID-19 pa...
# 616  This article provides a picture of trade in en...
# 617  This article is part of an online publication ...
# 618  Ageing Europe â looking at the lives of olde...
# 619   This article provides an overview of adult le...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 615  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 616  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 617  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 618  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 619  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
#                                            raw content
# 0     Absences from work sharply increase in first ...
# 1     Deaths from accidents, injuries and assault  ...
# 2     Number of accidents  In 2018, there were 3.1 ...
# 3     Developments over time   Non-fatal accidents ...
# 4     Africaâs main trade in goods partner is the...
# ..                                                 ...
# 615   Sharp increase in COVID-19 related imports in...
# 616   Overview  The latest figures show the upward ...
# 617   Current account  The current account of the  ...
# 618   Pensions  The transition for individuals from...
# 619   Participation rate of adults in learning in t...
#
# [620 rows x 7 columns]

# %% [markdown]
# ## C. Read categories from external file
# ***
#
# In a later version, this will be done through a connection with the knowledge database.

# %%
categories = pd.read_excel('articles_6_25_19_30.xlsx',index_col=None) ## use the default index
categories['url'].apply(clean,quotes=False)
categories['title'].apply(clean,quotes=False)
categories
# Out:
#      Unnamed: 0                                           abstract  \
# 0             0  This article presents an overview of  European...
# 1             1   Leaving the parental home is considered as a ...
# 2             2  This article presents an overview of statistic...
# 3             3  This article provides a picture of internation...
# 4             4   This article presents recent statistics on th...
# ..          ...                                                ...
# 620         620  Ageing Europe — looking at the lives of older ...
# 621         621  Ageing Europe — looking at the lives of older ...
# 622         622  Ageing Europe — looking at the lives of older ...
# 623         623  Ageing Europe — looking at the lives of older ...
# 624         624  Ageing Europe — looking at the lives of older ...
#
#                                                 alerts  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    [{'content': '', 'title': 'Table 4   is availa...
# ..                                                 ...
# 620  [{'content': 'Within the EU survey on income a...
# 621                                                NaN
# 622                                                NaN
# 623  [{'content': 'Material deprivation is the enfo...
# 624  [{'content': 'Health status and health service...
#
#                                             categories  \
# 0    ['Education and training', 'Participation in e...
# 1    ['Household composition and family situation',...
# 2    ['Services', 'Statistical article', 'Structura...
# 3    ['Non-EU countries', 'Trade in goods', 'Statis...
# 4    ['Asylum and migration', 'Population', 'Acquis...
# ..                                                 ...
# 620  ['Statistical article', 'Poverty and social ex...
# 621  ['Statistical article', 'Labour market', 'Acci...
# 622  ['Statistical article', 'Population', 'Populat...
# 623  ['Statistical article', 'Housing', 'Living con...
# 624  ['Statistical article', 'Health', 'Mortality a...
#
#                                                context  \
# 0    Adults with a low level of educational attainm...
# 1    In addition to the Labour Force Survey (LFS), ...
# 2    The freedom to provide services and the freedo...
# 3    Trade is an important indicator of Europe’s pr...
# 4    Within the European Commission, the Directorat...
# ..                                                 ...
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
# 624                                                NaN
#
#                                           data_sources  \
# 0    The  adult education survey (AES)  is the sour...
# 1    Source:  Statistics presented in this article ...
# 2    Coverage  Administrative and support services ...
# 3    EU data is taken from  Eurostat's   COMEXT  da...
# 4    Eurostat  produces statistics on a range of is...
# ..                                                 ...
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
# 624                                                NaN
#
#                                                  excel  \
# 0    [{'title': 'Adult learning statistics ET2018.x...
# 1    [{'title': 'Map, Tables and figures.xlsx',\n '...
# 2                                                  NaN
# 3    [{'title': 'Africa 2021.xlsx',\n 'url': '/euro...
# 4    [{'title': 'Acquisitions of citizenship 15 Mar...
# ..                                                 ...
# 620  [{'title': '06 Ageing Europe Social life and o...
# 621  [{'title': '04 Ageing Europe Working and movin...
# 622  [{'title': '01 Ageing Europe Population develo...
# 623  [{'title': '02 Ageing Europe Housing and livin...
# 624  [{'title': '03 Ageing Europe Health and disabi...
#
#                                           full_article  last_update  \
# 0    [{'content': '      About 44 % of adults aged ...          NaN
# 1    [{'content': '    Map 1 indicates that in 2019...          NaN
# 2    [{'content': '    In 2017 there were 1.4 milli...          NaN
# 3    [{'content': '    In 2020, the largest trade p...          NaN
# 4    [{'content': '    In 2019, 706 400 people obta...          NaN
# ..                                                 ...          ...
# 620  [{'content': '    People at work often exert t...          NaN
# 621  [{'content': '    In 2019, there were 200.0 mi...          NaN
# 622  [{'content': '     Population ageing will rapi...          NaN
# 623  [{'content': '    Recent decades have been cha...          NaN
# 624  [{'content': '     Women aged 65 years could e...          NaN
#
#                                                  title  \
# 0                   Adult learning statistics - cha...
# 1                   Age of young people leaving the...
# 2                   Administrative and support serv...
# 3                   Africa-EU - international trade...
# 4                   Acquisition of citizenship stat...
# ..                                                 ...
# 620                 Ageing Europe - statistics on s...
# 621                 Ageing Europe - statistics on w...
# 622                 Ageing Europe - statistics on p...
# 623                 Ageing Europe - statistics on h...
# 624                 Ageing Europe - statistics on h...
#
#                                                    url  \
# 0    https://ec.europa.eu/eurostat/statistics-expla...
# 1    https://ec.europa.eu/eurostat/statistics-expla...
# 2    https://ec.europa.eu/eurostat/statistics-expla...
# 3    https://ec.europa.eu/eurostat/statistics-expla...
# 4    https://ec.europa.eu/eurostat/statistics-expla...
# ..                                                 ...
# 620  https://ec.europa.eu/eurostat/statistics-expla...
# 621  https://ec.europa.eu/eurostat/statistics-expla...
# 622  https://ec.europa.eu/eurostat/statistics-expla...
# 623  https://ec.europa.eu/eurostat/statistics-expla...
# 624  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                                 Titles  \
# 0    Formal and non-formal adult education and trai...
# 1    Geographical differences. Gender differences. ...
# 2    Structural profile. Sectoral analysis. Country...
# 3    Africa’s main trade in goods partner is the EU...
# 4    EU-27 Member States granted citizenship to 706...
# ..                                                 ...
# 620  Physical activity of older people. Older peopl...
# 621  Employment patterns among older people. Focus ...
# 622  Older people — population overview. Older peop...
# 623  Household composition among older people. Olde...
# 624  Life expectancy and healthy life years among o...
#
#                                            Raw content
# 0    Formal and non-formal adult education and trai...
# 1    Geographical differences. Map 1 indicates that...
# 2    Structural profile. In 2017 there were 1.4 mil...
# 3    Africa’s main trade in goods partner is the EU...
# 4    EU-27 Member States granted citizenship to 706...
# ..                                                 ...
# 620  Physical activity of older people. People at w...
# 621  Employment patterns among older people. In 201...
# 622  Older people — population overview. Population...
# 623  Household composition among older people. Rece...
# 624  Life expectancy and healthy life years among o...
#
# [625 rows x 13 columns]

# %% [markdown]
# ### Merge with main file
#
# Merge on URL (inner join).

# %%
dat5 = pd.merge(dat4,categories[['categories','url']],on='url',how='inner')

import datetime

def file_name(pre,ext):
    current_time = datetime.datetime.now() 
    return pre + '_'+ str(current_time.month)+ '_' + str(current_time.day) + \
                 '_' + str(current_time.hour)+ '_' + str(current_time.minute)  +'.'+ext
    
dat5
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 614  4970  Trade is an important indicator of Europeâs ...
# 615  4972  Having a secure supply of energy is crucial fo...
# 616  4987  Economic and financial statistics have become ...
# 617  4989
# 618  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 614          EU trade in COVID-19 related products ...
# 615          EU imports of energy products - recent...
# 616          European Neighbourhood Policy - South ...
# 617          Ageing Europe - statistics on pensions...
# 618                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 614   To help prevent the spread of the COVID-19 pa...
# 615  This article provides a picture of trade in en...
# 616  This article is part of an online publication ...
# 617  Ageing Europe â looking at the lives of olde...
# 618   This article provides an overview of adult le...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 614  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 615  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 616  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 617  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 618  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
#                                            raw content  \
# 0     Absences from work sharply increase in first ...
# 1     Deaths from accidents, injuries and assault  ...
# 2     Number of accidents  In 2018, there were 3.1 ...
# 3     Developments over time   Non-fatal accidents ...
# 4     Africaâs main trade in goods partner is the...
# ..                                                 ...
# 614   Sharp increase in COVID-19 related imports in...
# 615   Overview  The latest figures show the upward ...
# 616   Current account  The current account of the  ...
# 617   Pensions  The transition for individuals from...
# 618   Participation rate of adults in learning in t...
#
#                                             categories
# 0    ['Employment', 'Labour market', 'Statistical a...
# 1    ['Health', 'Health status', 'Statistical artic...
# 2    ['Accidents at work', 'Health', 'Health and sa...
# 3    ['Accidents at work', 'Health', 'Health and sa...
# 4    ['Non-EU countries', 'Trade in goods', 'Statis...
# ..                                                 ...
# 614  ['International trade', 'Trade in goods', 'Tra...
# 615  ['Energy', 'Trade in goods', 'Trade in goods b...
# 616  ['Balance of payments', 'European Neighbourhoo...
# 617  ['Statistical article', 'Social protection', '...
# 618  ['Education and training', 'Lifelong learning'...
#
# [619 rows x 8 columns]

# %%
del(dat1,add_titles_urls)
del(dat2,add_abstracts)
del(add_content)
del(dat3,add_content_grouped)
del(dat4,categories)

# %% [markdown]
# ### Create date information

# %%
dat5['new_date'] = [d.date() for d in dat5['last_update']]  
dat5['year'] = dat5['last_update'].dt.year
dat5['year'] =dat5["year"].astype(str)
#pd.set_option('precision', 0)

dat5.replace('', np.nan, inplace=True)

dat5['year'].fillna(value="Not found", inplace=True)

print(dat5.isnull().sum(),'\n')

dat5.reset_index(drop=True,inplace=True)
dat5
# Out:
# id              0
# context        65
# title           0
# abstract        0
# url             0
# last_update     0
# raw content     0
# categories      0
# new_date        0
# year            0
# dtype: int64
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 614  4970  Trade is an important indicator of Europeâs ...
# 615  4972  Having a secure supply of energy is crucial fo...
# 616  4987  Economic and financial statistics have become ...
# 617  4989                                                NaN
# 618  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 614          EU trade in COVID-19 related products ...
# 615          EU imports of energy products - recent...
# 616          European Neighbourhood Policy - South ...
# 617          Ageing Europe - statistics on pensions...
# 618                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 614   To help prevent the spread of the COVID-19 pa...
# 615  This article provides a picture of trade in en...
# 616  This article is part of an online publication ...
# 617  Ageing Europe â looking at the lives of olde...
# 618   This article provides an overview of adult le...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 614  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 615  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 616  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 617  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 618  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
#                                            raw content  \
# 0     Absences from work sharply increase in first ...
# 1     Deaths from accidents, injuries and assault  ...
# 2     Number of accidents  In 2018, there were 3.1 ...
# 3     Developments over time   Non-fatal accidents ...
# 4     Africaâs main trade in goods partner is the...
# ..                                                 ...
# 614   Sharp increase in COVID-19 related imports in...
# 615   Overview  The latest figures show the upward ...
# 616   Current account  The current account of the  ...
# 617   Pensions  The transition for individuals from...
# 618   Participation rate of adults in learning in t...
#
#                                             categories    new_date  year
# 0    ['Employment', 'Labour market', 'Statistical a...  2021-04-14  2021
# 1    ['Health', 'Health status', 'Statistical artic...  2020-09-16  2020
# 2    ['Accidents at work', 'Health', 'Health and sa...  2020-11-26  2020
# 3    ['Accidents at work', 'Health', 'Health and sa...  2020-12-07  2020
# 4    ['Non-EU countries', 'Trade in goods', 'Statis...  2021-04-29  2021
# ..                                                 ...         ...   ...
# 614  ['International trade', 'Trade in goods', 'Tra...  2021-03-31  2021
# 615  ['Energy', 'Trade in goods', 'Trade in goods b...  2021-06-10  2021
# 616  ['Balance of payments', 'European Neighbourhoo...  2021-06-22  2021
# 617  ['Statistical article', 'Social protection', '...  2020-09-28  2020
# 618  ['Education and training', 'Lifelong learning'...  2021-06-17  2021
#
# [619 rows x 10 columns]

# %% [markdown]
# ## D. Add themes / sub-themes information in the articles
# ***
#
# * We create dictionary _themes_ manually.
# * Dictionary _dict_categories_ is used for debugging. The keys are the categories found in the SE articles and the values are the corresponding article ids.
# * Each article will have a list of themes and a list of corresponding sub-themes, potentially empty. If the article has a category which is a key of _themes_ the theme is added to the first list. If it has a category which is is one of the values of _themes_ i.e. it is a sub-theme, the corresponding key (theme) is added to the first list and the sub-theme is added to the second list.
# * There are relatively few articles without such information:
#     * No info in themes:  51
#     * No info in sub_themes:  90

# %%
import ast

themes = {'General and regional statistics/EU policies':
          ['Non-EU countries','Regions and cities','Sustainable development goals',
          'Policy indicators'],
          'Economy and finance': 
          ['Balance of payments','Comparative price levels (PPPs)','Consumer prices',
           'Exchange rates and interest rates','Government finance','National accounts (incl. GDP)'],
          'Population and social conditions':
          ['Asylum and migration','Crime','Culture','Education and training','Health',
           'Labour market','Living conditions','Population','Social protection','Sport','Youth'],
          'Industry and services': ['Short-term business statistics','Structural business statistics',
                                    'Business registers','Globalisation in businesses','Production statistics',
                                    'Tourism'],
          'Agriculture, forestry and fisheries':['Agriculture','Fisheries','Forestry'],
          'International trade':['Goods','Services'],
          'Transport':['Transport'],
          'Environment and energy':['Energy','Environment'],
          'Science, technology and digital society':['Digital economy and society','Science and technology']}

dict_categories=dict()

for i in range(len(dat5)):
    
    cats=dat5.loc[i,'categories']
    cats = [i.split('/')[-1].strip() for i in ast.literal_eval(cats)]
    cats = [cat.strip() for cat in cats]
        
    for cat in cats:
        if cat in dict_categories.keys():
            dict_categories[cat].append(dat5.loc[i,'id'])
        else:
            dict_categories[cat] = [dat5.loc[i,'id']]



dat5['themes'] = pd.Series([set() for i in range(len(dat5))])
dat5['sub_themes'] = pd.Series([set() for i in range(len(dat5))])
for i in range(len(dat5)):
    
    cats=dat5.loc[i,'categories']
    cats = [i.split('/')[-1].strip() for i in ast.literal_eval(cats)]
    cats = [cat.strip() for cat in cats]
    #dat5.loc[i,'themes'] = set()
    #dat5.loc[i,'sub_themes'] = set()

    for cat in cats:
        if cat in themes.keys():
            #print('found theme: ',cat)
            dat5.loc[i,'themes'].add(cat)
            #dat5.loc[i,'sub_themes'].add(cat)
        else:
            for theme in themes.keys():
                if cat in themes[theme]:
                    #print('i=',i,' cat = ',cat,' theme= ',theme)
                    dat5.loc[i,'themes'].add(theme)
                    dat5.loc[i,'sub_themes'].add(cat)
    
dat5['themes'] = dat5['themes'].apply(lambda x: ';'.join(x))    
dat5['sub_themes'] = dat5['sub_themes'].apply(lambda x: ';'.join(x))    

dat5
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 614  4970  Trade is an important indicator of Europeâs ...
# 615  4972  Having a secure supply of energy is crucial fo...
# 616  4987  Economic and financial statistics have become ...
# 617  4989                                                NaN
# 618  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 614          EU trade in COVID-19 related products ...
# 615          EU imports of energy products - recent...
# 616          European Neighbourhood Policy - South ...
# 617          Ageing Europe - statistics on pensions...
# 618                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 614   To help prevent the spread of the COVID-19 pa...
# 615  This article provides a picture of trade in en...
# 616  This article is part of an online publication ...
# 617  Ageing Europe â looking at the lives of olde...
# 618   This article provides an overview of adult le...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 614  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 615  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 616  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 617  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 618  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
#                                            raw content  \
# 0     Absences from work sharply increase in first ...
# 1     Deaths from accidents, injuries and assault  ...
# 2     Number of accidents  In 2018, there were 3.1 ...
# 3     Developments over time   Non-fatal accidents ...
# 4     Africaâs main trade in goods partner is the...
# ..                                                 ...
# 614   Sharp increase in COVID-19 related imports in...
# 615   Overview  The latest figures show the upward ...
# 616   Current account  The current account of the  ...
# 617   Pensions  The transition for individuals from...
# 618   Participation rate of adults in learning in t...
#
#                                             categories    new_date  year  \
# 0    ['Employment', 'Labour market', 'Statistical a...  2021-04-14  2021
# 1    ['Health', 'Health status', 'Statistical artic...  2020-09-16  2020
# 2    ['Accidents at work', 'Health', 'Health and sa...  2020-11-26  2020
# 3    ['Accidents at work', 'Health', 'Health and sa...  2020-12-07  2020
# 4    ['Non-EU countries', 'Trade in goods', 'Statis...  2021-04-29  2021
# ..                                                 ...         ...   ...
# 614  ['International trade', 'Trade in goods', 'Tra...  2021-03-31  2021
# 615  ['Energy', 'Trade in goods', 'Trade in goods b...  2021-06-10  2021
# 616  ['Balance of payments', 'European Neighbourhoo...  2021-06-22  2021
# 617  ['Statistical article', 'Social protection', '...  2020-09-28  2020
# 618  ['Education and training', 'Lifelong learning'...  2021-06-17  2021
#
#                                                 themes  \
# 0                     Population and social conditions
# 1                     Population and social conditions
# 2                     Population and social conditions
# 3                     Population and social conditions
# 4    General and regional statistics/EU policies;In...
# ..                                                 ...
# 614                                International trade
# 615                             Environment and energy
# 616  General and regional statistics/EU policies;Ec...
# 617                   Population and social conditions
# 618                   Population and social conditions
#
#                                sub_themes
# 0                           Labour market
# 1                                  Health
# 2                    Labour market;Health
# 3                    Labour market;Health
# 4                        Non-EU countries
# ..                                    ...
# 614
# 615                                Energy
# 616  Non-EU countries;Balance of payments
# 617                     Social protection
# 618                Education and training
#
# [619 rows x 12 columns]

# %% [markdown]
# ## E. Tokenize and stem the articles titles, contexts, abstracts and contents
# ***

# %%
#Stemming.

import gensim
from gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import stem_text
from gensim.parsing.porter import PorterStemmer

p = PorterStemmer()

def text_to_words(text):
    words = str(gensim.utils.simple_preprocess(text, deacc=True))
    words = remove_stopwords(words) 
    words = gensim.utils.tokenize(words)
        
    ## keep also original token!!! 
    words = [p.stem(token) for token in words]  
    #print(words)
    return ' '.join(words)        

for i in range(len(dat5)):
    dat5.loc[i,'title tokens']=text_to_words(dat5.loc[i,'title'])
    if not pd.isnull(dat5.loc[i,'context']):
        dat5.loc[i,'context tokens']=text_to_words(dat5.loc[i,'context'])
    else:
        dat5.loc[i,'context tokens']=''
    dat5.loc[i,'abstract tokens']=text_to_words(dat5.loc[i,'abstract'])
    dat5.loc[i,'raw content tokens']=text_to_words(dat5.loc[i,'raw content'])

dat5
# Out:
#        id                                            context  \
# 0       1  The COVID-19 pandemic hit Europe in January an...
# 1      10  The importance of action to prevent accidents ...
# 2      39  A safe, healthy working environment is a cruci...
# 3      50  A safe, healthy working environment is a cruci...
# 4      56  Trade is an important indicator of Europeâs ...
# ..    ...                                                ...
# 614  4970  Trade is an important indicator of Europeâs ...
# 615  4972  Having a secure supply of energy is crucial fo...
# 616  4987  Economic and financial statistics have become ...
# 617  4989                                                NaN
# 618  4997  Lifelong learning can take place in a variety ...
#
#                                                  title  \
# 0            Absences from work - quarterly statist...
# 1              Accidents and injuries statistics
# 2                   Accidents at work statistics
# 3            Accidents at work - statistics by econ...
# 4            Africa-EU - international trade in goo...
# ..                                                 ...
# 614          EU trade in COVID-19 related products ...
# 615          EU imports of energy products - recent...
# 616          European Neighbourhood Policy - South ...
# 617          Ageing Europe - statistics on pensions...
# 618                    Adult learning statistics
#
#                                               abstract  \
# 0     Absences from work can be classified into two...
# 1    This article presents an overview of European ...
# 2    This article presents a set of main statistica...
# 3     This article presents a set of main statistic...
# 4    This article provides a picture of internation...
# ..                                                 ...
# 614   To help prevent the spread of the COVID-19 pa...
# 615  This article provides a picture of trade in en...
# 616  This article is part of an online publication ...
# 617  Ageing Europe â looking at the lives of olde...
# 618   This article provides an overview of adult le...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-14 16:09:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2020-09-16 14:36:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-12-07 17:31:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-04-29 10:45:00
# ..                                                 ...                 ...
# 614  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 615  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-10 11:23:00
# 616  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-22 11:47:00
# 617  https://ec.europa.eu/eurostat/statistics-expla... 2020-09-28 08:48:00
# 618  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-17 16:23:00
#
#                                            raw content  \
# 0     Absences from work sharply increase in first ...
# 1     Deaths from accidents, injuries and assault  ...
# 2     Number of accidents  In 2018, there were 3.1 ...
# 3     Developments over time   Non-fatal accidents ...
# 4     Africaâs main trade in goods partner is the...
# ..                                                 ...
# 614   Sharp increase in COVID-19 related imports in...
# 615   Overview  The latest figures show the upward ...
# 616   Current account  The current account of the  ...
# 617   Pensions  The transition for individuals from...
# 618   Participation rate of adults in learning in t...
#
#                                             categories    new_date  year  \
# 0    ['Employment', 'Labour market', 'Statistical a...  2021-04-14  2021
# 1    ['Health', 'Health status', 'Statistical artic...  2020-09-16  2020
# 2    ['Accidents at work', 'Health', 'Health and sa...  2020-11-26  2020
# 3    ['Accidents at work', 'Health', 'Health and sa...  2020-12-07  2020
# 4    ['Non-EU countries', 'Trade in goods', 'Statis...  2021-04-29  2021
# ..                                                 ...         ...   ...
# 614  ['International trade', 'Trade in goods', 'Tra...  2021-03-31  2021
# 615  ['Energy', 'Trade in goods', 'Trade in goods b...  2021-06-10  2021
# 616  ['Balance of payments', 'European Neighbourhoo...  2021-06-22  2021
# 617  ['Statistical article', 'Social protection', '...  2020-09-28  2020
# 618  ['Education and training', 'Lifelong learning'...  2021-06-17  2021
#
#                                                 themes  \
# 0                     Population and social conditions
# 1                     Population and social conditions
# 2                     Population and social conditions
# 3                     Population and social conditions
# 4    General and regional statistics/EU policies;In...
# ..                                                 ...
# 614                                International trade
# 615                             Environment and energy
# 616  General and regional statistics/EU policies;Ec...
# 617                   Population and social conditions
# 618                   Population and social conditions
#
#                                sub_themes  \
# 0                           Labour market
# 1                                  Health
# 2                    Labour market;Health
# 3                    Labour market;Health
# 4                        Non-EU countries
# ..                                    ...
# 614
# 615                                Energy
# 616  Non-EU countries;Balance of payments
# 617                     Social protection
# 618                Education and training
#
#                                           title tokens  \
# 0                   absenc from work quarterli statist
# 1                             accid and injuri statist
# 2                                accid at work statist
# 3                accid at work statist by econom activ
# 4               africa eu intern trade in good statist
# ..                                                 ...
# 614                    eu trade in covid relat product
# 615         eu import of energi product recent develop
# 616  european neighbourhood polici south statist on...
# 617   ag europ statist on pension incom and expenditur
# 618                                adult learn statist
#
#                                         context tokens  \
# 0    the covid pandem hit europ in januari and febr...
# 1    the import of action to prevent accid and inju...
# 2    safe healthi work environ is crucial factor in...
# 3    safe healthi work environ is crucial factor in...
# 4    trade is an import indic of europea prosper an...
# ..                                                 ...
# 614  trade is an import indic of europea prosper an...
# 615  have secur suppli of energi is crucial for the...
# 616  econom and financi statist have becom on of th...
# 617
# 618  lifelong learn can take place in varieti of en...
#
#                                        abstract tokens  \
# 0    absenc from work can be classifi into two grou...
# 1    thi articl present an overview of european uni...
# 2    thi articl present set of main statist find in...
# 3    thi articl present set of main statist find in...
# 4    thi articl provid pictur of intern trade in go...
# ..                                                 ...
# 614  to help prevent the spread of the covid pandem...
# 615  thi articl provid pictur of trade in energi pr...
# 616  thi articl is part of an onlin public and prov...
# 617  ag europ look at the live of older peopl in th...
# 618  thi articl provid an overview of adult learn s...
#
#                                     raw content tokens
# 0    absenc from work sharpli increas in first half...
# 1    death from accid injuri and assault in there w...
# 2    number of accid in there were million non fata...
# 3    develop over time non fatal accid in there wer...
# 4    africaa main trade in good partner is the eu i...
# ..                                                 ...
# 614  sharp increas in covid relat import in april a...
# 615  overview the latest figur show the upward tren...
# 616  current account the current account of the eu ...
# 617  pension the transit for individu from work to ...
# 618  particip rate of adult in learn in the last fo...
#
# [619 rows x 16 columns]

# %%
print('No info in themes: ',sum(dat5['themes']==''))
print('No info in sub_themes: ',sum(dat5['sub_themes']==''))

outfile = file_name('dat5','xlsx')
dat5.to_excel(outfile)
# Out:
# No info in themes:  51
# No info in sub_themes:  90

# %% [markdown]
# ## F. Facets
# ***
# ### The function filtering the results.

# %%
def articles(Top_articles, Keywords, Categories, themes_dd, sub_themes_dd,year):

    Keywords = text_to_words(Keywords) 
    print(Keywords)
    if (Keywords == ''):
        print("")
        return
    
    idx = np.where(dat5['title tokens'].str.contains(Keywords) | dat5['raw content tokens'].str.contains(Keywords) |  
               dat5['context tokens'].str.contains(Keywords) | dat5['abstract tokens'].str.contains(Keywords))
    df1 = dat5.loc[idx]
    #df1 = dat5[(dat5['raw content tokens'].str.contains(Keywords) or 
    #           dat5['contex tokens'].str.contains(Keywords) or dat5['abstract tokens'].str.contains(Keywords)).any()]
    
    if year != "All years":    
        df1 = df1[df1['year'].str.contains(year)]    

    if Categories != "All categories":
        df1 = df1[df1['categories'].str.contains(Categories)]
        
        
    if themes_dd != "All themes":
        df1 = df1[df1['themes'].str.contains(themes_dd)]

    if sub_themes_dd:    
        df1 = df1[df1['sub_themes'].str.contains(sub_themes_dd)]
        
        
    if df1.title.count() == 0:
        print("Not matches found")
    else:
        print(df1.title.count()," articles found")
        h = '<br/>'.join(['<a href="' + l + '" target="_blank">'+ n for l,n in df1[["url","title"]][0:Top_articles].values])
        return display(HTML( h))

# %% [markdown]
# ### The widgets.

# %%
def query_build2(themes):
    style = {'description_width': 'initial'}

    Categories = widgets.Dropdown(
        description='Select Category:',
        options=['All categories'] + sorted(list(dict_categories.keys())),
        style=style
    )
    
    themes_dd = widgets.Dropdown(
        description='Select Theme:',
        options=['All themes']+sorted([k for k in themes.keys()]),
        style=style
    )    
    
    sub_themes_dd = widgets.Dropdown(
        description='Select Sub-theme:',
        options= [''],
        style=style
    )    
    

    def on_change(change):
        if change['type'] == 'change' and change['name'] == 'value':
            #print("changed to %s" % change['new'])
            if change['new'] == 'All themes':
                sub_themes_dd.options = []
            else:    
                sub_themes_dd.options = themes[themes_dd.value]
            

    themes_dd.observe(on_change)

 
    Top_articles = widgets.IntSlider(
        description='Display',
        tooltip='maximum:',
        value=5,
        min=1, 
        max = 30,
        style={'description_width': 'initial'}
    )


    Keywords = widgets.Text(
        value='hospit',
        placeholder='Type something',
        description='Keywords:',
        disabled=False
    )



    year = widgets.Dropdown(
        options=['All years','2021','2020','2019','2018','Not found'],
        value='All years',
        description='Year:',
        disabled=False)

    out = widgets.interactive_output(articles, {'Top_articles': Top_articles, 'Keywords': Keywords, 'Categories':Categories,
                                              'themes_dd':themes_dd,'sub_themes_dd':sub_themes_dd,'year':year})

    left_box = widgets.VBox([Keywords,Categories])
    right_box = widgets.VBox([themes_dd, sub_themes_dd])
    box = widgets.HBox([left_box, right_box])
    display(box)
    
    display(year, out, Top_articles)

query_build2(themes)
# Out:
# HBox(children=(VBox(children=(Text(value='hospit', description='Keywords:', placeholder='Type something'), Dro…
# Dropdown(description='Year:', options=('All years', '2021', '2020', '2019', '2018', 'Not found'), value='All y…
# Output()
# IntSlider(value=5, description='Display', max=30, min=1, style=SliderStyle(description_width='initial'))
