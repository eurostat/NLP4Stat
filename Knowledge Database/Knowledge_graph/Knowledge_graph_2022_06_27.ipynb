# %% [markdown]
# ## Visualization of knowledge graphs
#
# *    This is a Google Colab notebook. You must have a Google account with a Google Drive to store/ load the main file with the relationships, for inspection.
# *    Upload the notebook from its location in GitHub and allow the code to access your Google Drive.
# *    Please put your credentials in the cell "Connect to the Virtuoso database".
# *    Put your own keywords in the cell with tile "Enter keywords below". Note that the search is case-sensitive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Installations

# %%
# !pip install pyodbc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyodbc
#   Downloading pyodbc-4.0.32.tar.gz (280 kB)
#      |████████████████████████████████| 280 kB 7.5 MB/s
# Building wheels for collected packages: pyodbc
#   Building wheel for pyodbc (setup.py) ... done
#   Created wheel for pyodbc: filename=pyodbc-4.0.32-cp37-cp37m-linux_x86_64.whl size=287369 sha256=eddd56392fb3e2e1ea628f8ec33c2bd283827392bda7c5edbe94836afdc758c1
#   Stored in directory: /root/.cache/pip/wheels/2e/9c/da/8652fd42e0f662015554f00a9e96fe4f438dfd1ef59787879e
# Successfully built pyodbc
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.32

# %%
# !pip install pyvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvis
#   Downloading pyvis-0.2.1.tar.gz (21 kB)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.7/dist-packages (from pyvis) (2.11.3)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.7/dist-packages (from pyvis) (2.6.3)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from pyvis) (5.5.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (57.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9.6->pyvis) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonpickle>=1.4.1->pyvis) (4.11.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->pyvis) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonpickle>=1.4.1->pyvis) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonpickle>=1.4.1->pyvis) (3.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython>=5.3.0->pyvis) (0.7.0)
# Building wheels for collected packages: pyvis
#   Building wheel for pyvis (setup.py) ... done
#   Created wheel for pyvis: filename=pyvis-0.2.1-py3-none-any.whl size=23688 sha256=ad64296acfe73e66e4f1405fec4566d883a18ec1438f13d1bdcc861ccafb4eb0
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/04/6340d46afc74f59cc857a594ca1a2a14a1f4cbd4fd6c2e9306
# Successfully built pyvis
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-2.2.0 pyvis-0.2.1

# %%
# !pip install SPARQLWrapper
# !pip install sparql_dataframe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 11.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (57.4.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 496 kB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (4.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib>=6.1.1->SPARQLWrapper) (1.15.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.6.1 rdflib-6.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sparql_dataframe
#   Downloading sparql_dataframe-0.4-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: SPARQLWrapper>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from sparql_dataframe) (2.0.0)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from sparql_dataframe) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.22.0->sparql_dataframe) (1.15.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper>=1.8.1->sparql_dataframe) (6.1.1)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (0.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (4.11.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (4.1.1)
# Installing collected packages: sparql-dataframe
# Successfully installed sparql-dataframe-0.4

# %%
# !apt-get install virtuoso-opensource
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libvirtodbc0 virtuoso-opensource-6.1 virtuoso-opensource-6.1-bin
#   virtuoso-opensource-6.1-common virtuoso-server virtuoso-vad-conductor
#   virtuoso-vsp-startpage
# Suggested packages:
#   virtuoso-vad-doc virtuoso-vad-demo virtuoso-vad-tutorial
#   virtuoso-vad-rdfmappers virtuoso-vad-sparqldemo virtuoso-vad-syncml
#   virtuoso-vad-bpel virtuoso-vad-isparql virtuoso-vad-ods virtuoso-vad-dbpedia
#   virtuoso-vad-facetedbrowser
# The following NEW packages will be installed:
#   libvirtodbc0 virtuoso-opensource virtuoso-opensource-6.1
#   virtuoso-opensource-6.1-bin virtuoso-opensource-6.1-common virtuoso-server
#   virtuoso-vad-conductor virtuoso-vsp-startpage
# 0 upgraded, 8 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,835 kB of archives.
# After this operation, 27.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1-common amd64 6.1.6+repack-0ubuntu9 [45.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1-bin amd64 6.1.6+repack-0ubuntu9 [2,831 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvirtodbc0 amd64 6.1.6+repack-0ubuntu9 [259 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource-6.1 amd64 6.1.6+repack-0ubuntu9 [163 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-opensource all 6.1.6+repack-0ubuntu9 [33.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-vad-conductor all 6.1.6+repack-0ubuntu9 [1,044 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-vsp-startpage all 6.1.6+repack-0ubuntu9 [428 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 virtuoso-server all 6.1.6+repack-0ubuntu9 [31.0 kB]
# Fetched 4,835 kB in 2s (2,739 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package virtuoso-opensource-6.1-common.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../0-virtuoso-opensource-6.1-common_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1-common (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource-6.1-bin.
# Preparing to unpack .../1-virtuoso-opensource-6.1-bin_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1-bin (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package libvirtodbc0.
# Preparing to unpack .../2-libvirtodbc0_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking libvirtodbc0 (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource-6.1.
# Preparing to unpack .../3-virtuoso-opensource-6.1_6.1.6+repack-0ubuntu9_amd64.deb ...
# Unpacking virtuoso-opensource-6.1 (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-opensource.
# Preparing to unpack .../4-virtuoso-opensource_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-opensource (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-vad-conductor.
# Preparing to unpack .../5-virtuoso-vad-conductor_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-vad-conductor (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-vsp-startpage.
# Preparing to unpack .../6-virtuoso-vsp-startpage_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-vsp-startpage (6.1.6+repack-0ubuntu9) ...
# Selecting previously unselected package virtuoso-server.
# Preparing to unpack .../7-virtuoso-server_6.1.6+repack-0ubuntu9_all.deb ...
# Unpacking virtuoso-server (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1-bin (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1-common (6.1.6+repack-0ubuntu9) ...
# Setting up libvirtodbc0 (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-opensource-6.1 (6.1.6+repack-0ubuntu9) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up virtuoso-opensource (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-server (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-vad-conductor (6.1.6+repack-0ubuntu9) ...
# Setting up virtuoso-vsp-startpage (6.1.6+repack-0ubuntu9) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for systemd (237-3ubuntu10.53) ...

# %% [markdown]
# ## Imports

# %%
import os 
import re
import logging
import sys
import pyodbc
import hashlib
import pandas as pd
import numpy as np
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, POST, DIGEST, GET
from SPARQLWrapper import JSON, INSERT, DELETE
import sparql_dataframe

pd.set_option('display.max_rows', 500)

from IPython.display import Image

import random

import palettable
from palettable.colorbrewer.sequential import Blues_9
from palettable.colorbrewer.sequential import Greens_9
from palettable.colorbrewer.qualitative import Accent_8
from palettable.colorbrewer.qualitative import Paired_7

from pyvis import network as net
from IPython.core.display import display, HTML

# %% [markdown]
# ## Connect to the Virtuoso database

# %%
user = 'kimon'
passw='RkhvQYZ442e2JVXLHdtW'

# %%
def connect_db(DSN, DBA, UID, PWD):

    connection = pyodbc.connect('DRIVER=/usr/lib/odbc/virtodbc.so;HOST=lod.csd.auth.gr:1111;UID='+user+';PWD='+passw+';DATABASE=ESTAT')
    cursor = connection.cursor()

    return connection, cursor


def connect_virtuoso(DSN, UID, PWD):

    sparql = SPARQLWrapper(DSN)
    sparql.setHTTPAuth(DIGEST)
    sparql.setCredentials(UID, PWD)
    sparql.setMethod(GET)

    return sparql


# Connection to CDB 
connection, cursor = connect_db('Virtuoso All', 
                                'ESTAT', 
                                user, 
                                passw)

# Connection to the KDB 
endpoint = "http://lod.csd.auth.gr:8890/sparql/"
sparql = connect_virtuoso(endpoint, 
                          user, 
                          passw)

# %% [markdown]
# ## Extraction of relationships

# %%
def databaseTable(keywords):

  RelationsStatements = """
  DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
  PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
  PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
  PREFIX oecd: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/oecd/> 
  PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
  select ?article ?title ?articleURL ?r ?reftitle ?refURL where { 
      {?article rdf:type estat:Article .
      # ?article ?p ?t .}
      UNION
      {?article rdf:type estat:Article .
      # ?article estat:hasParagraph ?x.
      # ?x ?p ?t .}
      filter contains(str(?t),\" """ + str(keywords) + """\") 
      # ?article estat:title ?title .
      # ?article estat:hasURL ?articleURL.
      # ?article estat:hasReference ?r .
      {?r rdf:type estat:Table} 
      UNION
      {?r rdf:type estat:Database}
      # ?r estat:hasURL ?refURL .
      # ?r estat:title ?reftitle .
  } 
  """

  sparql.setQuery(RelationsStatements)
  sparql.method = "POST"
  sparql.setReturnFormat(JSON)
  results = sparql.query().convert()['results']['bindings']
  results = pd.json_normalize(results)
  
  return results

def articleTable(keywords):

  ##RelationsStatements = """
  ##DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
  ##PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
  ##PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
  ##PREFIX oecd: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/oecd/> 
  ##PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
  ##select ?article ?title ?articleURL ?euroArticle ?euroTitle ?euroURL where { 
  ##    {?article rdf:type estat:Article .
  ##    ?article ?p ?t .}
  ##    UNION
  ##    {?article rdf:type estat:Article .
  ##    ?article estat:hasParagraph ?x.
  ##    ?x ?p ?t .}
  ##    filter contains(str(?t),\" """ + str(keywords) + """\") 
  ##    ?article estat:title ?title .
  ##    ?article estat:hasURL ?articleURL.
  ##    ?article estat:hasReference ?r .
  ##    ?r estat:hasURI ?euroArticle.
  ##    ?euroArticle estat:title ?euroTitle .
  ##    ?euroArticle estat:hasURL ?euroURL.
  ##} 
  ### """
  RelationsStatements = """
  DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
  PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
  PREFIX estatdata: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
  PREFIX oecd: <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/oecd/> 
  select * where { 
      {?article rdf:type estat:Article .
      # ?article ?p ?t .}
      UNION
      {?article rdf:type estat:Article .
      # ?article estat:hasParagraph ?x.
      # ?x ?p ?t .}
      filter contains(str(?t),\" """ + str(keywords) + """\") 
      # ?article estat:title ?title .
      # ?article estat:hasURL ?articleURL.
      # ?article estat:hasReference ?r .
      { ?r estat:hasURI ?euroArticle.
      # ?euroArticle estat:title ?euroTitle .
        # ?euroArticle estat:hasURL ?euroURL.}
     UNION
     {?r estat:hasURL ?euroURL.
     # ?r estat:title ?euroTitle .
     BIND(?r as ?euroArticle)
    }   
  } 
  """
  
  sparql.setQuery(RelationsStatements)
  sparql.method = "POST"
  sparql.setReturnFormat(JSON)
  results = sparql.query().convert()['results']['bindings']
  results = pd.json_normalize(results)
  
  return results

# %% [markdown]
# ### Production of the dataframe with the relationships

# %%
def produce_df(keywords):

    results1 = databaseTable(keywords)
    print('results1')
    display(results1)
    print('results2')
    results2 = articleTable(keywords)
    display(results2)

    listData = []
    for name, row in results1.iterrows():
        listData.append((row[1], row[3], row[6], row[8], row[10], row[13]))

    listArticle = []
    for name, row in results2.iterrows():
        listArticle.append((row[1], row[3], row[6], row[8], row[10], row[13]))

    finalList = listData + listArticle

    hashHelper = {}
    articleURI, articleURL,articletitle, relatedURI, relatedURL, relatedtitle = [], [], [], [], [], []
    for relation in finalList:
        articleURI.append(relation[0])
        articleURL.append(relation[2])
        articletitle.append(relation[1])
        relatedURI.append(relation[3])
        relatedURL.append(relation[5])
        relatedtitle.append(relation[4])
        hashHelper['articleURI'] = articleURI
        hashHelper['articleURL'] = articleURL
        hashHelper['articletitle'] = articletitle
        hashHelper['relatedURI'] = relatedURI
        hashHelper['relatedURL'] = relatedURL
        hashHelper['relatedTitle'] = relatedtitle

    # Create DataFrame  
    df = pd.DataFrame(hashHelper)
    #print(df)
    print(len(finalList))
    return df

# %%
def produce_df2(keywords):

    results1 = databaseTable(keywords)
    
    results1.drop(columns=['article.type', 'title.type', 'articleURL.type', 'articleURL.datatype','r.type',
       'reftitle.type','refURL.type','refURL.datatype', ],inplace=True)
    results1.rename(columns={'article.value':'articleURI','title.value':'articleTitle','articleURL.value':'articleURL',
                             'r.value':'relatedURI','reftitle.value':'relatedTitle','refURL.value':'relatedURL'},inplace=True)

    results2 = articleTable(keywords)

    results2.drop(columns = ['article.type','p.type','p.value','t.type','t.value','title.type','articleURL.type','articleURL.datatype','r.value',      
                                 'euroURL.type', 'euroURL.datatype', 'x.type', 'x.value','r.type','euroArticle.type','euroTitle.type'],inplace=True)
    results2.rename(columns={'article.value':'articleURI','title.value':'articleTitle','articleURL.value':'articleURL',
                             'euroArticle.value':'relatedURI','euroTitle.value':'relatedTitle','euroURL.value':'relatedURL'},inplace=True)


    df = pd.concat([results1,results2])
    return df

# %% [markdown]
# ### Enter keywords below
# *    To re-run with different keywords change them below and re-run ("Runtime > Run after") from this cell.

# %%
keywords = 'electric vehicle'

# %% [markdown]
# ## Produce file for inspection

# %%
df = produce_df2(keywords)
df
df.to_excel('/content/drive/MyDrive/df.xlsx')
#display(df)

# %%
## add column relatedType indicating the type of the related resource

conditions = [
    (df['relatedURL'].str.contains('Glossary:')),              
    (df['relatedURL'].str.contains('statistics-explained/index.php')),
    ## (df['relatedURL'].str.contains('data/database')),
    ## (df['relatedURL'].str.contains('/news/')),    
    (df['relatedURL'].str.contains('eurostat/product')),    
    (df['relatedURL'].str.contains('eur-lex.europa.eu'))    
    ]
##values = ['GL article','SE article', 'Data', 'News','Publication','Legislation']
values = ['GL article','SE article', 'Publication','Legislation']
df['relatedType'] = np.select(conditions,values,default='Other') 
df = df[df['relatedType'] != 'Other'].copy()
df.reset_index(drop=False,inplace=True)
df.drop(columns='index',inplace=True)

display(df)
# Out:
#                                            articleURI  \
# 0   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 1   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 2   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 3   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 4   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 5   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 7   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 8   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 9   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 10  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 11  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 12  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 13  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 14  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 15  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 16  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 17  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 18  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 19  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 20  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 21  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 22  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 23  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 24  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 25  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 26  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 27  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 28  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 29  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 30  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 31  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 32  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 33  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 34  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 35  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 36  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 37  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 38  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 39  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 40  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 41  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 42  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 43  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 44  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 45  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 46  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 47  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 48  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 49  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 50  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 51  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 52  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 53  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 54  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 55  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 56  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 57  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 58  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 59  https://ec.europa.eu/eurostat/NLP4StatRef/know...
#
#                                          articleTitle  \
# 0   Waste statistics recycling of batteries and ac...
# 1   Waste statistics recycling of batteries and ac...
# 2   Waste statistics recycling of batteries and ac...
# 3   Waste statistics recycling of batteries and ac...
# 4   Waste statistics recycling of batteries and ac...
# 5   Waste statistics recycling of batteries and ac...
# 6   Waste statistics recycling of batteries and ac...
# 7   Waste statistics recycling of batteries and ac...
# 8   Waste statistics recycling of batteries and ac...
# 9   Waste statistics recycling of batteries and ac...
# 10  Waste statistics recycling of batteries and ac...
# 11  Waste statistics recycling of batteries and ac...
# 12  Waste statistics recycling of batteries and ac...
# 13  Waste statistics recycling of batteries and ac...
# 14  Waste statistics recycling of batteries and ac...
# 15  Waste statistics recycling of batteries and ac...
# 16  Waste statistics recycling of batteries and ac...
# 17  Waste statistics recycling of batteries and ac...
# 18  Waste statistics recycling of batteries and ac...
# 19  Waste statistics recycling of batteries and ac...
# 20  Waste statistics recycling of batteries and ac...
# 21  Waste statistics recycling of batteries and ac...
# 22             Transport statistics at regional level
# 23             Transport statistics at regional level
# 24             Transport statistics at regional level
# 25             Transport statistics at regional level
# 26             Transport statistics at regional level
# 27             Transport statistics at regional level
# 28             Transport statistics at regional level
# 29             Transport statistics at regional level
# 30             Transport statistics at regional level
# 31             Transport statistics at regional level
# 32             Transport statistics at regional level
# 33             Transport statistics at regional level
# 34             Transport statistics at regional level
# 35             Transport statistics at regional level
# 36             Transport statistics at regional level
# 37             Transport statistics at regional level
# 38             Transport statistics at regional level
# 39             Transport statistics at regional level
# 40             Transport statistics at regional level
# 41             Transport statistics at regional level
# 42             Transport statistics at regional level
# 43             Transport statistics at regional level
# 44             Transport statistics at regional level
# 45             Transport statistics at regional level
# 46             Transport statistics at regional level
# 47             Transport statistics at regional level
# 48      SDG 12 Responsible consumption and production
# 49      SDG 12 Responsible consumption and production
# 50      SDG 12 Responsible consumption and production
# 51      SDG 12 Responsible consumption and production
# 52      SDG 12 Responsible consumption and production
# 53      SDG 12 Responsible consumption and production
# 54       SDG 9 Industry innovation and infrastructure
# 55       SDG 9 Industry innovation and infrastructure
# 56       SDG 9 Industry innovation and infrastructure
# 57       SDG 9 Industry innovation and infrastructure
# 58       SDG 9 Industry innovation and infrastructure
# 59       SDG 9 Industry innovation and infrastructure
#
#                                            articleURL  \
# 0   https://ec.europa.eu/eurostat/statistics-expla...
# 1   https://ec.europa.eu/eurostat/statistics-expla...
# 2   https://ec.europa.eu/eurostat/statistics-expla...
# 3   https://ec.europa.eu/eurostat/statistics-expla...
# 4   https://ec.europa.eu/eurostat/statistics-expla...
# 5   https://ec.europa.eu/eurostat/statistics-expla...
# 6   https://ec.europa.eu/eurostat/statistics-expla...
# 7   https://ec.europa.eu/eurostat/statistics-expla...
# 8   https://ec.europa.eu/eurostat/statistics-expla...
# 9   https://ec.europa.eu/eurostat/statistics-expla...
# 10  https://ec.europa.eu/eurostat/statistics-expla...
# 11  https://ec.europa.eu/eurostat/statistics-expla...
# 12  https://ec.europa.eu/eurostat/statistics-expla...
# 13  https://ec.europa.eu/eurostat/statistics-expla...
# 14  https://ec.europa.eu/eurostat/statistics-expla...
# 15  https://ec.europa.eu/eurostat/statistics-expla...
# 16  https://ec.europa.eu/eurostat/statistics-expla...
# 17  https://ec.europa.eu/eurostat/statistics-expla...
# 18  https://ec.europa.eu/eurostat/statistics-expla...
# 19  https://ec.europa.eu/eurostat/statistics-expla...
# 20  https://ec.europa.eu/eurostat/statistics-expla...
# 21  https://ec.europa.eu/eurostat/statistics-expla...
# 22  https://ec.europa.eu/eurostat/statistics-expla...
# 23  https://ec.europa.eu/eurostat/statistics-expla...
# 24  https://ec.europa.eu/eurostat/statistics-expla...
# 25  https://ec.europa.eu/eurostat/statistics-expla...
# 26  https://ec.europa.eu/eurostat/statistics-expla...
# 27  https://ec.europa.eu/eurostat/statistics-expla...
# 28  https://ec.europa.eu/eurostat/statistics-expla...
# 29  https://ec.europa.eu/eurostat/statistics-expla...
# 30  https://ec.europa.eu/eurostat/statistics-expla...
# 31  https://ec.europa.eu/eurostat/statistics-expla...
# 32  https://ec.europa.eu/eurostat/statistics-expla...
# 33  https://ec.europa.eu/eurostat/statistics-expla...
# 34  https://ec.europa.eu/eurostat/statistics-expla...
# 35  https://ec.europa.eu/eurostat/statistics-expla...
# 36  https://ec.europa.eu/eurostat/statistics-expla...
# 37  https://ec.europa.eu/eurostat/statistics-expla...
# 38  https://ec.europa.eu/eurostat/statistics-expla...
# 39  https://ec.europa.eu/eurostat/statistics-expla...
# 40  https://ec.europa.eu/eurostat/statistics-expla...
# 41  https://ec.europa.eu/eurostat/statistics-expla...
# 42  https://ec.europa.eu/eurostat/statistics-expla...
# 43  https://ec.europa.eu/eurostat/statistics-expla...
# 44  https://ec.europa.eu/eurostat/statistics-expla...
# 45  https://ec.europa.eu/eurostat/statistics-expla...
# 46  https://ec.europa.eu/eurostat/statistics-expla...
# 47  https://ec.europa.eu/eurostat/statistics-expla...
# 48  https://ec.europa.eu/eurostat/statistics-expla...
# 49  https://ec.europa.eu/eurostat/statistics-expla...
# 50  https://ec.europa.eu/eurostat/statistics-expla...
# 51  https://ec.europa.eu/eurostat/statistics-expla...
# 52  https://ec.europa.eu/eurostat/statistics-expla...
# 53  https://ec.europa.eu/eurostat/statistics-expla...
# 54  https://ec.europa.eu/eurostat/statistics-expla...
# 55  https://ec.europa.eu/eurostat/statistics-expla...
# 56  https://ec.europa.eu/eurostat/statistics-expla...
# 57  https://ec.europa.eu/eurostat/statistics-expla...
# 58  https://ec.europa.eu/eurostat/statistics-expla...
# 59  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                            relatedURI  \
# 0   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 1   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 2   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 3   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 4   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 5   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 7   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 8   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 9   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 10  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 11  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 12  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 13  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 14  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 15  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 16  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 17  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 18  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 19  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 20  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 21  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 22  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 23  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 24  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 25  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 26  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 27  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 28  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 29  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 30  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 31  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 32  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 33  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 34  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 35  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 36  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 37  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 38  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 39  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 40  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 41  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 42  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 43  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 44  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 45  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 46  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 47  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 48  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 49  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 50  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 51  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 52  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 53  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 54  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 55  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 56  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 57  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 58  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 59  https://ec.europa.eu/eurostat/NLP4StatRef/know...
#
#                                          relatedTitle  \
# 0                   Environment statistics introduced
# 1                   Environment statistics introduced
# 2                          Municipal waste statistics
# 3                          Municipal waste statistics
# 4                          Packaging waste statistics
# 5                          Packaging waste statistics
# 6                           Waste shipment statistics
# 7                           Waste shipment statistics
# 8                                    Waste statistics
# 9                                    Waste statistics
# 10       Recycling secondary material price indicator
# 11       Recycling secondary material price indicator
# 12  Waste shipment statistics based on the Europea...
# 13  Waste shipment statistics based on the Europea...
# 14  Waste statistics electrical and electronic equ...
# 15  Waste statistics electrical and electronic equ...
# 16  Directive 2006 66 EC on portable batteries and...
# 17  Directive 2006 66 EC on portable batteries and...
# 18  Summaries of EU legislation Disposal of spent ...
# 19  Summaries of EU legislation Disposal of spent ...
# 20               Commission Regulation EU No 493 2012
# 21               Commission Regulation EU No 493 2012
# 22                           Air transport statistics
# 23                           Air transport statistics
# 24            Maritime freight and vessels statistics
# 25            Maritime freight and vessels statistics
# 26                     Passenger transport statistics
# 27                     Passenger transport statistics
# 28  Railway passenger transport statistics quarter...
# 29  Railway passenger transport statistics quarter...
# 30  Road safety statistics characteristics at nati...
# 31  Road safety statistics characteristics at nati...
# 32                Stock of vehicles at regional level
# 33                Stock of vehicles at regional level
# 34        Energy transport and environment indicators
# 35        Energy transport and environment indicators
# 36                         Eurostat regional yearbook
# 37                         Eurostat regional yearbook
# 38  Glossary for transport statistics 5th edition ...
# 39  Glossary for transport statistics 5th edition ...
# 40    Methodological manual on territorial typologies
# 41    Methodological manual on territorial typologies
# 42                               Directive 2009 42 EC
# 43                               Directive 2009 42 EC
# 44                          Regulation EU No 437 2003
# 45                          Regulation EU No 437 2003
# 46                          Regulation EU No 2018 643
# 47                          Regulation EU No 2018 643
# 48             Category Sustainable development goals
# 49             Category Sustainable development goals
# 50                                   SDG Introduction
# 51                                   SDG Introduction
# 52  Sustainable development in the European Union ...
# 53  Sustainable development in the European Union ...
# 54             Category Sustainable development goals
# 55             Category Sustainable development goals
# 56                                   SDG Introduction
# 57                                   SDG Introduction
# 58  Sustainable development in the European Union ...
# 59  Sustainable development in the European Union ...
#
#                                            relatedURL  relatedType
# 0   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 1   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 2   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 3   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 4   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 5   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 6   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 7   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 8   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 9   https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 10  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 11  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 12  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 13  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 14  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 15  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 16  http://eur-lex.europa.eu/legal-content/EN/ALL/...  Legislation
# 17  http://eur-lex.europa.eu/legal-content/EN/ALL/...  Legislation
# 18  https://eur-lex.europa.eu/legal-content/EN/LSU...  Legislation
# 19  https://eur-lex.europa.eu/legal-content/EN/LSU...  Legislation
# 20  http://eur-lex.europa.eu/legal-content/EN/TXT/...  Legislation
# 21  http://eur-lex.europa.eu/legal-content/EN/TXT/...  Legislation
# 22  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 23  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 24  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 25  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 26  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 27  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 28  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 29  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 30  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 31  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 32  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 33  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 34  http://ec.europa.eu/eurostat/product?code=KS-D...  Publication
# 35  http://ec.europa.eu/eurostat/product?code=KS-D...  Publication
# 36  http://ec.europa.eu/eurostat/product?code=KS-H...  Publication
# 37  http://ec.europa.eu/eurostat/product?code=KS-H...  Publication
# 38  http://ec.europa.eu/eurostat/product?code=KS-G...  Publication
# 39  http://ec.europa.eu/eurostat/product?code=KS-G...  Publication
# 40  http://ec.europa.eu/eurostat/product?code=KS-G...  Publication
# 41  http://ec.europa.eu/eurostat/product?code=KS-G...  Publication
# 42  http://eur-lex.europa.eu/LexUriServ/LexUriServ...  Legislation
# 43  http://eur-lex.europa.eu/LexUriServ/LexUriServ...  Legislation
# 44  http://eur-lex.europa.eu/LexUriServ/LexUriServ...  Legislation
# 45  http://eur-lex.europa.eu/LexUriServ/LexUriServ...  Legislation
# 46  http://eur-lex.europa.eu/LexUriServ/LexUriServ...  Legislation
# 47  http://eur-lex.europa.eu/LexUriServ/LexUriServ...  Legislation
# 48  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 49  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 50  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 51  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 52  http://ec.europa.eu/eurostat/product?code=KS-0...  Publication
# 53  http://ec.europa.eu/eurostat/product?code=KS-0...  Publication
# 54  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 55  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 56  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 57  https://ec.europa.eu/eurostat/statistics-expla...   SE article
# 58  http://ec.europa.eu/eurostat/product?code=KS-0...  Publication
# 59  http://ec.europa.eu/eurostat/product?code=KS-0...  Publication

# %%
## unique URIs in Articles and Related resources

valuesURI = df[['articleURI','relatedURI']].values
uniqueURI = np.unique(valuesURI)
print('uniqueURIs:')
uniqueURI

df2 = pd.DataFrame(uniqueURI,columns=['uniqueURI'])
df2['ID'] = range(len(df2))
df2
# Out:
# uniqueURIs:
#                                             uniqueURI  ID
# 0   https://ec.europa.eu/eurostat/NLP4StatRef/know...   0
# 1   https://ec.europa.eu/eurostat/NLP4StatRef/know...   1
# 2   https://ec.europa.eu/eurostat/NLP4StatRef/know...   2
# 3   https://ec.europa.eu/eurostat/NLP4StatRef/know...   3
# 4   https://ec.europa.eu/eurostat/NLP4StatRef/know...   4
# 5   https://ec.europa.eu/eurostat/NLP4StatRef/know...   5
# 6   https://ec.europa.eu/eurostat/NLP4StatRef/know...   6
# 7   https://ec.europa.eu/eurostat/NLP4StatRef/know...   7
# 8   https://ec.europa.eu/eurostat/NLP4StatRef/know...   8
# 9   https://ec.europa.eu/eurostat/NLP4StatRef/know...   9
# 10  https://ec.europa.eu/eurostat/NLP4StatRef/know...  10
# 11  https://ec.europa.eu/eurostat/NLP4StatRef/know...  11
# 12  https://ec.europa.eu/eurostat/NLP4StatRef/know...  12
# 13  https://ec.europa.eu/eurostat/NLP4StatRef/know...  13
# 14  https://ec.europa.eu/eurostat/NLP4StatRef/know...  14
# 15  https://ec.europa.eu/eurostat/NLP4StatRef/know...  15
# 16  https://ec.europa.eu/eurostat/NLP4StatRef/know...  16
# 17  https://ec.europa.eu/eurostat/NLP4StatRef/know...  17
# 18  https://ec.europa.eu/eurostat/NLP4StatRef/know...  18
# 19  https://ec.europa.eu/eurostat/NLP4StatRef/know...  19
# 20  https://ec.europa.eu/eurostat/NLP4StatRef/know...  20
# 21  https://ec.europa.eu/eurostat/NLP4StatRef/know...  21
# 22  https://ec.europa.eu/eurostat/NLP4StatRef/know...  22
# 23  https://ec.europa.eu/eurostat/NLP4StatRef/know...  23
# 24  https://ec.europa.eu/eurostat/NLP4StatRef/know...  24
# 25  https://ec.europa.eu/eurostat/NLP4StatRef/know...  25
# 26  https://ec.europa.eu/eurostat/NLP4StatRef/know...  26
# 27  https://ec.europa.eu/eurostat/NLP4StatRef/know...  27
# 28  https://ec.europa.eu/eurostat/NLP4StatRef/know...  28
# 29  https://ec.europa.eu/eurostat/NLP4StatRef/know...  29
# 30  https://ec.europa.eu/eurostat/NLP4StatRef/know...  30
# 31  https://ec.europa.eu/eurostat/NLP4StatRef/know...  31
# 32  https://ec.europa.eu/eurostat/NLP4StatRef/know...  32
# 33  https://ec.europa.eu/eurostat/NLP4StatRef/know...  33

# %%
## transfer the unique IDs to the main file

df3 = pd.merge(df,df2,how='inner', left_on='articleURI',right_on='uniqueURI')
df3.rename(columns={'ID':'articleID'},inplace=True)
df3 = pd.merge(df3,df2,how='inner', left_on='relatedURI',right_on='uniqueURI')
df3.rename(columns={'ID':'relatedID'},inplace=True)
df3 = df3[['articleID','relatedID','relatedType','articleURI','articleURL','articleTitle','relatedURI','relatedURL','relatedTitle']]
df3
# Out:
#     articleID  relatedID  relatedType  \
# 0           2          7   SE article
# 1           2          7   SE article
# 2           2          8   SE article
# 3           2          8   SE article
# 4           2          9   SE article
# 5           2          9   SE article
# 6           2         10   SE article
# 7           2         10   SE article
# 8           2         11   SE article
# 9           2         11   SE article
# 10          2         12   SE article
# 11          2         12   SE article
# 12          2         13   SE article
# 13          2         13   SE article
# 14          2         14   SE article
# 15          2         14   SE article
# 16          2         15  Legislation
# 17          2         15  Legislation
# 18          2         16  Legislation
# 19          2         16  Legislation
# 20          2         17  Legislation
# 21          2         17  Legislation
# 22          0         18   SE article
# 23          0         18   SE article
# 24          0         19   SE article
# 25          0         19   SE article
# 26          0         20   SE article
# 27          0         20   SE article
# 28          0         21   SE article
# 29          0         21   SE article
# 30          0         22   SE article
# 31          0         22   SE article
# 32          0         23   SE article
# 33          0         23   SE article
# 34          0         24  Publication
# 35          0         24  Publication
# 36          0         25  Publication
# 37          0         25  Publication
# 38          0         26  Publication
# 39          0         26  Publication
# 40          0         27  Publication
# 41          0         27  Publication
# 42          0         28  Legislation
# 43          0         28  Legislation
# 44          0         29  Legislation
# 45          0         29  Legislation
# 46          0         30  Legislation
# 47          0         30  Legislation
# 48          1         31   SE article
# 49          1         31   SE article
# 50          1         32   SE article
# 51          1         32   SE article
# 52          1         33  Publication
# 53          1         33  Publication
# 54          3          4   SE article
# 55          3          4   SE article
# 56          3          5   SE article
# 57          3          5   SE article
# 58          3          6  Publication
# 59          3          6  Publication
#
#                                            articleURI  \
# 0   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 1   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 2   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 3   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 4   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 5   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 7   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 8   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 9   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 10  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 11  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 12  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 13  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 14  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 15  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 16  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 17  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 18  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 19  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 20  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 21  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 22  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 23  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 24  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 25  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 26  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 27  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 28  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 29  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 30  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 31  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 32  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 33  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 34  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 35  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 36  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 37  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 38  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 39  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 40  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 41  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 42  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 43  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 44  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 45  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 46  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 47  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 48  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 49  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 50  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 51  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 52  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 53  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 54  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 55  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 56  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 57  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 58  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 59  https://ec.europa.eu/eurostat/NLP4StatRef/know...
#
#                                            articleURL  \
# 0   https://ec.europa.eu/eurostat/statistics-expla...
# 1   https://ec.europa.eu/eurostat/statistics-expla...
# 2   https://ec.europa.eu/eurostat/statistics-expla...
# 3   https://ec.europa.eu/eurostat/statistics-expla...
# 4   https://ec.europa.eu/eurostat/statistics-expla...
# 5   https://ec.europa.eu/eurostat/statistics-expla...
# 6   https://ec.europa.eu/eurostat/statistics-expla...
# 7   https://ec.europa.eu/eurostat/statistics-expla...
# 8   https://ec.europa.eu/eurostat/statistics-expla...
# 9   https://ec.europa.eu/eurostat/statistics-expla...
# 10  https://ec.europa.eu/eurostat/statistics-expla...
# 11  https://ec.europa.eu/eurostat/statistics-expla...
# 12  https://ec.europa.eu/eurostat/statistics-expla...
# 13  https://ec.europa.eu/eurostat/statistics-expla...
# 14  https://ec.europa.eu/eurostat/statistics-expla...
# 15  https://ec.europa.eu/eurostat/statistics-expla...
# 16  https://ec.europa.eu/eurostat/statistics-expla...
# 17  https://ec.europa.eu/eurostat/statistics-expla...
# 18  https://ec.europa.eu/eurostat/statistics-expla...
# 19  https://ec.europa.eu/eurostat/statistics-expla...
# 20  https://ec.europa.eu/eurostat/statistics-expla...
# 21  https://ec.europa.eu/eurostat/statistics-expla...
# 22  https://ec.europa.eu/eurostat/statistics-expla...
# 23  https://ec.europa.eu/eurostat/statistics-expla...
# 24  https://ec.europa.eu/eurostat/statistics-expla...
# 25  https://ec.europa.eu/eurostat/statistics-expla...
# 26  https://ec.europa.eu/eurostat/statistics-expla...
# 27  https://ec.europa.eu/eurostat/statistics-expla...
# 28  https://ec.europa.eu/eurostat/statistics-expla...
# 29  https://ec.europa.eu/eurostat/statistics-expla...
# 30  https://ec.europa.eu/eurostat/statistics-expla...
# 31  https://ec.europa.eu/eurostat/statistics-expla...
# 32  https://ec.europa.eu/eurostat/statistics-expla...
# 33  https://ec.europa.eu/eurostat/statistics-expla...
# 34  https://ec.europa.eu/eurostat/statistics-expla...
# 35  https://ec.europa.eu/eurostat/statistics-expla...
# 36  https://ec.europa.eu/eurostat/statistics-expla...
# 37  https://ec.europa.eu/eurostat/statistics-expla...
# 38  https://ec.europa.eu/eurostat/statistics-expla...
# 39  https://ec.europa.eu/eurostat/statistics-expla...
# 40  https://ec.europa.eu/eurostat/statistics-expla...
# 41  https://ec.europa.eu/eurostat/statistics-expla...
# 42  https://ec.europa.eu/eurostat/statistics-expla...
# 43  https://ec.europa.eu/eurostat/statistics-expla...
# 44  https://ec.europa.eu/eurostat/statistics-expla...
# 45  https://ec.europa.eu/eurostat/statistics-expla...
# 46  https://ec.europa.eu/eurostat/statistics-expla...
# 47  https://ec.europa.eu/eurostat/statistics-expla...
# 48  https://ec.europa.eu/eurostat/statistics-expla...
# 49  https://ec.europa.eu/eurostat/statistics-expla...
# 50  https://ec.europa.eu/eurostat/statistics-expla...
# 51  https://ec.europa.eu/eurostat/statistics-expla...
# 52  https://ec.europa.eu/eurostat/statistics-expla...
# 53  https://ec.europa.eu/eurostat/statistics-expla...
# 54  https://ec.europa.eu/eurostat/statistics-expla...
# 55  https://ec.europa.eu/eurostat/statistics-expla...
# 56  https://ec.europa.eu/eurostat/statistics-expla...
# 57  https://ec.europa.eu/eurostat/statistics-expla...
# 58  https://ec.europa.eu/eurostat/statistics-expla...
# 59  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                          articleTitle  \
# 0   Waste statistics recycling of batteries and ac...
# 1   Waste statistics recycling of batteries and ac...
# 2   Waste statistics recycling of batteries and ac...
# 3   Waste statistics recycling of batteries and ac...
# 4   Waste statistics recycling of batteries and ac...
# 5   Waste statistics recycling of batteries and ac...
# 6   Waste statistics recycling of batteries and ac...
# 7   Waste statistics recycling of batteries and ac...
# 8   Waste statistics recycling of batteries and ac...
# 9   Waste statistics recycling of batteries and ac...
# 10  Waste statistics recycling of batteries and ac...
# 11  Waste statistics recycling of batteries and ac...
# 12  Waste statistics recycling of batteries and ac...
# 13  Waste statistics recycling of batteries and ac...
# 14  Waste statistics recycling of batteries and ac...
# 15  Waste statistics recycling of batteries and ac...
# 16  Waste statistics recycling of batteries and ac...
# 17  Waste statistics recycling of batteries and ac...
# 18  Waste statistics recycling of batteries and ac...
# 19  Waste statistics recycling of batteries and ac...
# 20  Waste statistics recycling of batteries and ac...
# 21  Waste statistics recycling of batteries and ac...
# 22             Transport statistics at regional level
# 23             Transport statistics at regional level
# 24             Transport statistics at regional level
# 25             Transport statistics at regional level
# 26             Transport statistics at regional level
# 27             Transport statistics at regional level
# 28             Transport statistics at regional level
# 29             Transport statistics at regional level
# 30             Transport statistics at regional level
# 31             Transport statistics at regional level
# 32             Transport statistics at regional level
# 33             Transport statistics at regional level
# 34             Transport statistics at regional level
# 35             Transport statistics at regional level
# 36             Transport statistics at regional level
# 37             Transport statistics at regional level
# 38             Transport statistics at regional level
# 39             Transport statistics at regional level
# 40             Transport statistics at regional level
# 41             Transport statistics at regional level
# 42             Transport statistics at regional level
# 43             Transport statistics at regional level
# 44             Transport statistics at regional level
# 45             Transport statistics at regional level
# 46             Transport statistics at regional level
# 47             Transport statistics at regional level
# 48      SDG 12 Responsible consumption and production
# 49      SDG 12 Responsible consumption and production
# 50      SDG 12 Responsible consumption and production
# 51      SDG 12 Responsible consumption and production
# 52      SDG 12 Responsible consumption and production
# 53      SDG 12 Responsible consumption and production
# 54       SDG 9 Industry innovation and infrastructure
# 55       SDG 9 Industry innovation and infrastructure
# 56       SDG 9 Industry innovation and infrastructure
# 57       SDG 9 Industry innovation and infrastructure
# 58       SDG 9 Industry innovation and infrastructure
# 59       SDG 9 Industry innovation and infrastructure
#
#                                            relatedURI  \
# 0   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 1   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 2   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 3   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 4   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 5   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 6   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 7   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 8   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 9   https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 10  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 11  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 12  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 13  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 14  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 15  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 16  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 17  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 18  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 19  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 20  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 21  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 22  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 23  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 24  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 25  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 26  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 27  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 28  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 29  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 30  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 31  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 32  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 33  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 34  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 35  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 36  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 37  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 38  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 39  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 40  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 41  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 42  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 43  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 44  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 45  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 46  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 47  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 48  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 49  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 50  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 51  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 52  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 53  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 54  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 55  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 56  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 57  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 58  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 59  https://ec.europa.eu/eurostat/NLP4StatRef/know...
#
#                                            relatedURL  \
# 0   https://ec.europa.eu/eurostat/statistics-expla...
# 1   https://ec.europa.eu/eurostat/statistics-expla...
# 2   https://ec.europa.eu/eurostat/statistics-expla...
# 3   https://ec.europa.eu/eurostat/statistics-expla...
# 4   https://ec.europa.eu/eurostat/statistics-expla...
# 5   https://ec.europa.eu/eurostat/statistics-expla...
# 6   https://ec.europa.eu/eurostat/statistics-expla...
# 7   https://ec.europa.eu/eurostat/statistics-expla...
# 8   https://ec.europa.eu/eurostat/statistics-expla...
# 9   https://ec.europa.eu/eurostat/statistics-expla...
# 10  https://ec.europa.eu/eurostat/statistics-expla...
# 11  https://ec.europa.eu/eurostat/statistics-expla...
# 12  https://ec.europa.eu/eurostat/statistics-expla...
# 13  https://ec.europa.eu/eurostat/statistics-expla...
# 14  https://ec.europa.eu/eurostat/statistics-expla...
# 15  https://ec.europa.eu/eurostat/statistics-expla...
# 16  http://eur-lex.europa.eu/legal-content/EN/ALL/...
# 17  http://eur-lex.europa.eu/legal-content/EN/ALL/...
# 18  https://eur-lex.europa.eu/legal-content/EN/LSU...
# 19  https://eur-lex.europa.eu/legal-content/EN/LSU...
# 20  http://eur-lex.europa.eu/legal-content/EN/TXT/...
# 21  http://eur-lex.europa.eu/legal-content/EN/TXT/...
# 22  https://ec.europa.eu/eurostat/statistics-expla...
# 23  https://ec.europa.eu/eurostat/statistics-expla...
# 24  https://ec.europa.eu/eurostat/statistics-expla...
# 25  https://ec.europa.eu/eurostat/statistics-expla...
# 26  https://ec.europa.eu/eurostat/statistics-expla...
# 27  https://ec.europa.eu/eurostat/statistics-expla...
# 28  https://ec.europa.eu/eurostat/statistics-expla...
# 29  https://ec.europa.eu/eurostat/statistics-expla...
# 30  https://ec.europa.eu/eurostat/statistics-expla...
# 31  https://ec.europa.eu/eurostat/statistics-expla...
# 32  https://ec.europa.eu/eurostat/statistics-expla...
# 33  https://ec.europa.eu/eurostat/statistics-expla...
# 34  http://ec.europa.eu/eurostat/product?code=KS-D...
# 35  http://ec.europa.eu/eurostat/product?code=KS-D...
# 36  http://ec.europa.eu/eurostat/product?code=KS-H...
# 37  http://ec.europa.eu/eurostat/product?code=KS-H...
# 38  http://ec.europa.eu/eurostat/product?code=KS-G...
# 39  http://ec.europa.eu/eurostat/product?code=KS-G...
# 40  http://ec.europa.eu/eurostat/product?code=KS-G...
# 41  http://ec.europa.eu/eurostat/product?code=KS-G...
# 42  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 43  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 44  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 45  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 46  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 47  http://eur-lex.europa.eu/LexUriServ/LexUriServ...
# 48  https://ec.europa.eu/eurostat/statistics-expla...
# 49  https://ec.europa.eu/eurostat/statistics-expla...
# 50  https://ec.europa.eu/eurostat/statistics-expla...
# 51  https://ec.europa.eu/eurostat/statistics-expla...
# 52  http://ec.europa.eu/eurostat/product?code=KS-0...
# 53  http://ec.europa.eu/eurostat/product?code=KS-0...
# 54  https://ec.europa.eu/eurostat/statistics-expla...
# 55  https://ec.europa.eu/eurostat/statistics-expla...
# 56  https://ec.europa.eu/eurostat/statistics-expla...
# 57  https://ec.europa.eu/eurostat/statistics-expla...
# 58  http://ec.europa.eu/eurostat/product?code=KS-0...
# 59  http://ec.europa.eu/eurostat/product?code=KS-0...
#
#                                          relatedTitle
# 0                   Environment statistics introduced
# 1                   Environment statistics introduced
# 2                          Municipal waste statistics
# 3                          Municipal waste statistics
# 4                          Packaging waste statistics
# 5                          Packaging waste statistics
# 6                           Waste shipment statistics
# 7                           Waste shipment statistics
# 8                                    Waste statistics
# 9                                    Waste statistics
# 10       Recycling secondary material price indicator
# 11       Recycling secondary material price indicator
# 12  Waste shipment statistics based on the Europea...
# 13  Waste shipment statistics based on the Europea...
# 14  Waste statistics electrical and electronic equ...
# 15  Waste statistics electrical and electronic equ...
# 16  Directive 2006 66 EC on portable batteries and...
# 17  Directive 2006 66 EC on portable batteries and...
# 18  Summaries of EU legislation Disposal of spent ...
# 19  Summaries of EU legislation Disposal of spent ...
# 20               Commission Regulation EU No 493 2012
# 21               Commission Regulation EU No 493 2012
# 22                           Air transport statistics
# 23                           Air transport statistics
# 24            Maritime freight and vessels statistics
# 25            Maritime freight and vessels statistics
# 26                     Passenger transport statistics
# 27                     Passenger transport statistics
# 28  Railway passenger transport statistics quarter...
# 29  Railway passenger transport statistics quarter...
# 30  Road safety statistics characteristics at nati...
# 31  Road safety statistics characteristics at nati...
# 32                Stock of vehicles at regional level
# 33                Stock of vehicles at regional level
# 34        Energy transport and environment indicators
# 35        Energy transport and environment indicators
# 36                         Eurostat regional yearbook
# 37                         Eurostat regional yearbook
# 38  Glossary for transport statistics 5th edition ...
# 39  Glossary for transport statistics 5th edition ...
# 40    Methodological manual on territorial typologies
# 41    Methodological manual on territorial typologies
# 42                               Directive 2009 42 EC
# 43                               Directive 2009 42 EC
# 44                          Regulation EU No 437 2003
# 45                          Regulation EU No 437 2003
# 46                          Regulation EU No 2018 643
# 47                          Regulation EU No 2018 643
# 48             Category Sustainable development goals
# 49             Category Sustainable development goals
# 50                                   SDG Introduction
# 51                                   SDG Introduction
# 52  Sustainable development in the European Union ...
# 53  Sustainable development in the European Union ...
# 54             Category Sustainable development goals
# 55             Category Sustainable development goals
# 56                                   SDG Introduction
# 57                                   SDG Introduction
# 58  Sustainable development in the European Union ...
# 59  Sustainable development in the European Union ...

# %%
## related type groups and assignment to colors
type_groups = np.unique(df3['relatedType'])
print(type_groups)
node_colors = Paired_7.hex_colors[:len(type_groups)]
node_colors
# Out:
# ['Legislation' 'Publication' 'SE article']
# ['#A6CEE3', '#1F78B4', '#B2DF8A']

# %%
## Create graph

g=net.Network(height='600px', width='75%',heading='')
g.barnes_hut()
g.repulsion(node_distance=100, spring_length=200)

## First the unique articles - source nodes, by articleID 
uniqueArticles = df3.groupby(['articleID'])[['articleTitle']].agg(list).reset_index() ## aggregate into lists - titles are repeated
col_index = int(np.where(type_groups=='SE article')[0]) ## index of color to use for SE articles
for i in range(len(uniqueArticles)): ## for some reason, single elements must be put in a list, add_node() does not work
    g.add_nodes([uniqueArticles.loc[i,'articleID']], color=[node_colors[col_index]], label = [uniqueArticles.loc[i,'articleTitle'][0]])

## Then the related nodes, by type
relatedGroups = df3.groupby(['relatedType'])[['relatedID','relatedTitle']].agg(list).reset_index() ## again aggregate into lists
for i in range(len(relatedGroups)):
    how_many_nodes = len(relatedGroups.loc[i,'relatedID'])
    g.add_nodes(relatedGroups.loc[i,'relatedID'],label=relatedGroups.loc[i,'relatedTitle'], color=[node_colors[i]]*how_many_nodes)

## The edges
for i in range(len(df3)):        
    n1 = int(df3.loc[i,'articleID'])
    n2 = int(df3.loc[i,'relatedID'])
    type_ind = int(np.where(type_groups==df3.loc[i,'relatedType'])[0])
    col =  node_colors[type_ind]
    lbl = type_groups[type_ind]
    g.add_edge(n1,n2,color=col,label=lbl)
g.show('example.html')
display(HTML('example.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 75%;
#             height: 600px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": "#B2DF8A", "id": 0, "label": "Transport statistics at regional level", "shape": "dot"}, {"color": "#B2DF8A", "id": 1, "label": "SDG 12 Responsible consumption and production", "shape": "dot"}, {"color": "#B2DF8A", "id": 2, "label": "Waste statistics recycling of batteries and accumulators", "shape": "dot"}, {"color": "#B2DF8A", "id": 3, "label": "SDG 9 Industry innovation and infrastructure", "shape": "dot"}, {"color": "#A6CEE3", "id": 15, "label": "Directive 2006 66 EC on portable batteries and accumulators", "shape": "dot"}, {"color": "#A6CEE3", "id": 16, "label": "Summaries of EU legislation Disposal of spent batteries and accumulators", "shape": "dot"}, {"color": "#A6CEE3", "id": 17, "label": "Commission Regulation EU No 493 2012", "shape": "dot"}, {"color": "#A6CEE3", "id": 28, "label": "Directive 2009 42 EC", "shape": "dot"}, {"color": "#A6CEE3", "id": 29, "label": "Regulation EU No 437 2003", "shape": "dot"}, {"color": "#A6CEE3", "id": 30, "label": "Regulation EU No 2018 643", "shape": "dot"}, {"color": "#1F78B4", "id": 24, "label": "Energy transport and environment indicators", "shape": "dot"}, {"color": "#1F78B4", "id": 25, "label": "Eurostat regional yearbook", "shape": "dot"}, {"color": "#1F78B4", "id": 26, "label": "Glossary for transport statistics 5th edition 2019", "shape": "dot"}, {"color": "#1F78B4", "id": 27, "label": "Methodological manual on territorial typologies", "shape": "dot"}, {"color": "#1F78B4", "id": 33, "label": "Sustainable development in the European Union Monitoring report on progress towards the SDGS in an EU context 2021 edition", "shape": "dot"}, {"color": "#1F78B4", "id": 6, "label": "Sustainable development in the European Union Monitoring report on progress towards the SDGS in an EU context 2021 edition", "shape": "dot"}, {"color": "#B2DF8A", "id": 7, "label": "Environment statistics introduced", "shape": "dot"}, {"color": "#B2DF8A", "id": 8, "label": "Municipal waste statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 9, "label": "Packaging waste statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 10, "label": "Waste shipment statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 11, "label": "Waste statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 12, "label": "Recycling secondary material price indicator", "shape": "dot"}, {"color": "#B2DF8A", "id": 13, "label": "Waste shipment statistics based on the European list of waste codes", "shape": "dot"}, {"color": "#B2DF8A", "id": 14, "label": "Waste statistics electrical and electronic equipment", "shape": "dot"}, {"color": "#B2DF8A", "id": 18, "label": "Air transport statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 19, "label": "Maritime freight and vessels statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 20, "label": "Passenger transport statistics", "shape": "dot"}, {"color": "#B2DF8A", "id": 21, "label": "Railway passenger transport statistics quarterly and annual data", "shape": "dot"}, {"color": "#B2DF8A", "id": 22, "label": "Road safety statistics characteristics at national and regional level", "shape": "dot"}, {"color": "#B2DF8A", "id": 23, "label": "Stock of vehicles at regional level", "shape": "dot"}, {"color": "#B2DF8A", "id": 31, "label": "Category Sustainable development goals", "shape": "dot"}, {"color": "#B2DF8A", "id": 32, "label": "SDG Introduction", "shape": "dot"}, {"color": "#B2DF8A", "id": 4, "label": "Category Sustainable development goals", "shape": "dot"}, {"color": "#B2DF8A", "id": 5, "label": "SDG Introduction", "shape": "dot"}]);
#         edges = new vis.DataSet([{"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 7}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 8}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 9}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 10}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 11}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 12}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 13}, {"color": "#B2DF8A", "from": 2, "label": "SE article", "to": 14}, {"color": "#A6CEE3", "from": 2, "label": "Legislation", "to": 15}, {"color": "#A6CEE3", "from": 2, "label": "Legislation", "to": 16}, {"color": "#A6CEE3", "from": 2, "label": "Legislation", "to": 17}, {"color": "#B2DF8A", "from": 0, "label": "SE article", "to": 18}, {"color": "#B2DF8A", "from": 0, "label": "SE article", "to": 19}, {"color": "#B2DF8A", "from": 0, "label": "SE article", "to": 20}, {"color": "#B2DF8A", "from": 0, "label": "SE article", "to": 21}, {"color": "#B2DF8A", "from": 0, "label": "SE article", "to": 22}, {"color": "#B2DF8A", "from": 0, "label": "SE article", "to": 23}, {"color": "#1F78B4", "from": 0, "label": "Publication", "to": 24}, {"color": "#1F78B4", "from": 0, "label": "Publication", "to": 25}, {"color": "#1F78B4", "from": 0, "label": "Publication", "to": 26}, {"color": "#1F78B4", "from": 0, "label": "Publication", "to": 27}, {"color": "#A6CEE3", "from": 0, "label": "Legislation", "to": 28}, {"color": "#A6CEE3", "from": 0, "label": "Legislation", "to": 29}, {"color": "#A6CEE3", "from": 0, "label": "Legislation", "to": 30}, {"color": "#B2DF8A", "from": 1, "label": "SE article", "to": 31}, {"color": "#B2DF8A", "from": 1, "label": "SE article", "to": 32}, {"color": "#1F78B4", "from": 1, "label": "Publication", "to": 33}, {"color": "#B2DF8A", "from": 3, "label": "SE article", "to": 4}, {"color": "#B2DF8A", "from": 3, "label": "SE article", "to": 5}, {"color": "#1F78B4", "from": 3, "label": "Publication", "to": 6}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "barnesHut": {
#             "avoidOverlap": 0,
#             "centralGravity": 0.3,
#             "damping": 0.09,
#             "gravitationalConstant": -80000,
#             "springConstant": 0.001,
#             "springLength": 250
#         },
#         "enabled": true,
#         "repulsion": {
#             "centralGravity": 0.2,
#             "damping": 0.09,
#             "nodeDistance": 100,
#             "springConstant": 0.05,
#             "springLength": 200
#         },
#         "solver": "repulsion",
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
