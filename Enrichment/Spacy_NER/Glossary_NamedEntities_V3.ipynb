# %% [markdown]
# # Testing the Named Entities Recognition engine of Spacy
#
# Step 1. Loading Spacy models
#
# We install Spacy's language library for the first run. Then we can comment-out the download command.

# %%
import re
import pandas as pd
import spacy
import sys
from collections import Counter
import re

## Run to install the language library, then comment-out
# !{sys.executable} -m spacy download en

nlp = spacy.load('en_core_web_sm')
print('Finished loading.')
# Out:
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in d:\programdata\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in d:\programdata\anaconda3\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pathy in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: numpy>=1.15.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.2)
# Requirement already satisfied: packaging>=20.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: setuptools in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: jinja2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\programdata\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in d:\programdata\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in d:\programdata\anaconda3\lib\site-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: six in d:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: boto3 in d:\programdata\anaconda3\lib\site-packages (from smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.17.7)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in d:\programdata\anaconda3\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in d:\programdata\anaconda3\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.7 in d:\programdata\anaconda3\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.20.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\programdata\anaconda3\lib\site-packages (from botocore<1.21.0,>=1.20.7->boto3->smart-open<4.0.0,>=2.2.0->pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8.1)
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Pleaseuse the full
# pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Finished loading.

# %% [markdown]
# # Step 2. Pre-processing
#
#     Read two files exported from the database which contain the SE Glossary articles definitions and their titles.
#     In later versions, the corresponding tables will be directly exported from the database.
#     Merge byid and discard records with duplicate titles and/or definitions.

# %%
dat1= pd.read_csv("ESTAT_dat_concepts_2021_04_08.csv",sep=";")
dat2= pd.read_csv("ESTAT_dat_link_info_2021_04_08.csv",sep=";")
Gloss_concepts = pd.merge(dat1,dat2,on=['id'])
del(dat1,dat2)

Gloss_concepts = Gloss_concepts[['id','title','definition']]

Gloss_concepts = Gloss_concepts.drop_duplicates(subset=["definition"])
Gloss_concepts = Gloss_concepts.dropna(axis=0,subset=["definition"])
Gloss_concepts = Gloss_concepts.drop_duplicates(subset=["title"])
Gloss_concepts = Gloss_concepts.dropna(axis=0,subset=["title"])

Gloss_concepts.reset_index(drop=True, inplace=True)
Gloss_concepts.head()
# Out:
#    id                                              title  \
# 0   1  Arrival of tourist at a tourist accommodation ...
# 1   3                                    Nights spent
# 2   4                  Supply side tourism statistics
# 3   5                                         Tourist
# 4   7                         Asia-Europe Meeting (ASEM)
#
#                                           definition
# 0     See      arrival disambiguation page     fo...
# 1    A     night spent    or     tourism night   ...
# 2    Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3    For     tourism    statistics, a     travell...
# 4    The     Asia-Europe Meeting    , abbreviated...

# %% [markdown]
# # Step 3. Pre-processing (cont)
#
#     Keep a backup of the original definition.
#     Do some data cleansing.

# %%
Gloss_concepts['definition_init'] = Gloss_concepts['definition']


Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub('^ +| +$', '',x)) ## remove start and end spaces
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(' +', ' ',x)) ## remove more than one spaces
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(' , ',', ',x)) ## space-comma-space -> comma-space
Gloss_concepts['definition'] = Gloss_concepts['definition'].apply(lambda x: re.sub(r'\D\d{4}', '.', x))## replace a non-digit+4digits with a dot e.g. I5530Camping-> .Camping

Gloss_concepts.head()
#len(Gloss_concepts.definition.values.tolist())
# Out:
#    id                                              title  \
# 0   1  Arrival of tourist at a tourist accommodation ...
# 1   3                                    Nights spent
# 2   4                  Supply side tourism statistics
# 3   5                                         Tourist
# 4   7                         Asia-Europe Meeting (ASEM)
#
#                                           definition  \
# 0  See arrival disambiguation page for other mean...
# 1  A night spent or tourism night (overnight stay...
# 2  Regulation (EU) No 692. of 6 July. establishes...
# 3  For tourism statistics, a traveller is someone...
# 4  The Asia-Europe Meeting, abbreviated as ASEM, ...
#
#                                      definition_init
# 0     See      arrival disambiguation page     fo...
# 1    A     night spent    or     tourism night   ...
# 2    Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3    For     tourism    statistics, a     travell...
# 4    The     Asia-Europe Meeting    , abbreviated...

# %% [markdown]
# # Step 4. Apply the NER engine
#
#     Create columns ORG, GPE, NORP, LOCATION which will hold dictionaries with entities recognized as:
#         Organizations ;
#         Countries, cities, states ;
#         Nationalities or religious or political groups ;
#         Non-GPE locations, mountain ranges, bodies of water, respectively
#     In each dictionary in a record, the key is the entity and the values are a list with the token span's *start* index position, the token span's *stop* index position and the count in the definition of the glossary article.

# %%
nlp.max_length = 1500000

Gloss_concepts['ORG'] = [dict() for i in range(len(Gloss_concepts))]
Gloss_concepts['GPE'] = [dict() for i in range(len(Gloss_concepts))]
Gloss_concepts['NORP'] = [dict() for i in range(len(Gloss_concepts))]
Gloss_concepts['LOCATION'] = [dict() for i in range(len(Gloss_concepts))]

for i in range(len(Gloss_concepts)):
    if i % 100 == 0: print('i = ',i,' of ',len(Gloss_concepts))
    tokens = nlp(Gloss_concepts.loc[i,'definition'])
    entities = tokens.ents
    for ent in entities:
        #print(ent.text, ent.label_)
        if ent.label_ == 'ORG':
            if ent.text.upper() in Gloss_concepts.loc[i,'ORG'].keys():
                Gloss_concepts.loc[i,'ORG'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'ORG'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'ORG'][ent.text.upper()] = [[(ent.start,ent.end)],1]
        
        elif ent.label_ == 'GPE':
            if ent.text.upper() in Gloss_concepts.loc[i,'GPE'].keys():
                Gloss_concepts.loc[i,'GPE'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'GPE'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'GPE'][ent.text.upper()] = [[(ent.start,ent.end)],1]
                
        elif ent.label_ == 'NORP':
            if ent.text.upper() in Gloss_concepts.loc[i,'NORP'].keys():
                Gloss_concepts.loc[i,'NORP'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'NORP'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'NORP'][ent.text.upper()] = [[(ent.start,ent.end)],1]
                
        elif ent.label_ == 'LOCATION':
            if ent.text.upper() in Gloss_concepts.loc[i,'LOCATION'].keys():
                Gloss_concepts.loc[i,'LOCATION'][ent.text.upper()][0].append((ent.start,ent.end)) 
                Gloss_concepts.loc[i,'LOCATION'][ent.text.upper()][1] += 1 
            else:    
                Gloss_concepts.loc[i,'LOCATION'][ent.text.upper()] = [[(ent.start,ent.end)],1]         
    
Gloss_concepts

#PERSON People, including fictional
#NORP Nationalities or religious or political groups
#FACILITY Buildings, airports, highways, bridges, etc.
#ORGANIZATION Companies, agencies, institutions, etc.
#GPE Countries, cities, states
#LOCATION Non-GPE locations, mountain ranges, bodies of water
#PRODUCT Vehicles, weapons, foods, etc. (Not services)
#EVENT Named hurricanes, battles, wars, sports events, etc.
#WORK OF ART Titles of books, songs, etc.
#LAW Named documents made into laws 
#LANGUAGE Any named language
#The following values are also annotated in a style similar to names:
#DATE Absolute or relative dates or periods
#TIME Times smaller than a day
#PERCENT Percentage (including “%”)
#MONEY Monetary values, including unit
#QUANTITY Measurements, as of weight or distance
#ORDINAL “first”, “second”
#CARDINAL Numerals that do not fall under another typ
# Out:
# i =  0  of  1284
# i =  100  of  1284
# i =  200  of  1284
# i =  300  of  1284
# i =  400  of  1284
# i =  500  of  1284
# i =  600  of  1284
# i =  700  of  1284
# i =  800  of  1284
# i =  900  of  1284
# i =  1000  of  1284
# i =  1100  of  1284
# i =  1200  of  1284
#         id                                              title  \
# 0        1  Arrival of tourist at a tourist accommodation ...
# 1        3                                    Nights spent
# 2        4                  Supply side tourism statistics
# 3        5                                         Tourist
# 4        7                         Asia-Europe Meeting (ASEM)
# ...    ...                                                ...
# 1279  2879                              Statistical territory
# 1280  2881                              Statistical indicator
# 1281  2885                                 Tourism industries
# 1282  2891                                           Sawnwood
# 1283  2896                                       LeaMickatest
#
#                                              definition  \
# 0     See arrival disambiguation page for other mean...
# 1     A night spent or tourism night (overnight stay...
# 2     Regulation (EU) No 692. of 6 July. establishes...
# 3     For tourism statistics, a traveller is someone...
# 4     The Asia-Europe Meeting, abbreviated as ASEM, ...
# ...                                                 ...
# 1279  The statistical territory of the European Unio...
# 1280  A statistical indicator is the representation ...
# 1281  For the article Tourism industries - economic ...
# 1282  Sawnwood is wood that has been produced either...
# 1283                                               test
#
#                                         definition_init  \
# 0        See      arrival disambiguation page     fo...
# 1       A     night spent    or     tourism night   ...
# 2       Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3       For     tourism    statistics, a     travell...
# 4       The     Asia-Europe Meeting    , abbreviated...
# ...                                                 ...
# 1279    The     statistical territory    of the     ...
# 1280    A     statistical indicator    is the repres...
# 1281    For the article     Tourism industries - eco...
# 1282     Sawnwood    is wood that has been produced ...
# 1283                                               test
#
#                                                     ORG  \
# 0     {'EUROPEAN UNION': [[(14, 16)], 1], 'EU': [[(1...
# 1                                                    {}
# 2     {'EU': [[(2, 3)], 1], 'ACCOMMODATION': [[(47, ...
# 3                                                    {}
# 4     {'ASEM': [[(8, 9)], 1], 'THE EUROPEAN UNION': ...
# ...                                                 ...
# 1279  {'THE EUROPEAN UNION': [[(4, 7)], 1], 'EU': [[...
# 1280  {'EUROPEAN UNION': [[(82, 84)], 1], 'EU': [[(8...
# 1281  {'UNWTO': [[(21, 22)], 1], 'SBS': [[(134, 135)...
# 1282                        {'SAWNWOOD': [[(0, 1)], 1]}
# 1283                                                 {}
#
#                                                     GPE  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'OCEANIA': [[(29, 30)], 1], 'NORWAY': [[(57, ...
# ...                                                 ...
# 1279  {'STATES': [[(31, 32)], 1], 'GERMANY': [[(40, ...
# 1280                                                 {}
# 1281                                                 {}
# 1282                                                 {}
# 1283                                                 {}
#
#                                NORP LOCATION
# 0                                {}       {}
# 1                                {}       {}
# 2     {'EUROPEAN': [[(24, 25)], 1]}       {}
# 3                                {}       {}
# 4                                {}       {}
# ...                             ...      ...
# 1279    {'FRENCH': [[(62, 63)], 1]}       {}
# 1280                             {}       {}
# 1281  {'EUROPEAN': [[(29, 30)], 1]}       {}
# 1282                             {}       {}
# 1283                             {}       {}
#
# [1284 rows x 8 columns]

# %% [markdown]
# # Step 5. Gathering the most common entities: example with ORG entities
#
# We can see several errors and repetitions. These require some further cleansing steps and fine-tuning of the NER engine (not yet carried out).

# %%
from itertools import chain
org_list=sorted(list(chain.from_iterable(Gloss_concepts['ORG'].apply(lambda x: x.keys()))))
org_all_freqs = sorted(Counter(org_list))
print(org_all_freqs)
# Out:
# ["'EUROPEAN STATISTICS", '0.74 CYP', '93/24/EEC', '93/25/EEC', 'A EUROPEAN UNION', 'A RISK ASSESSMENT COMMITTEE', 'AAA', 'AAGR', 'ACCOMMODATION', 'ACID', 'ACL', 'ACP', 'ADSL', 'AE', 'AEA', 'AEI', 'AES', 'AF', 'AGE', 'AGENCY', 'AGRICULTURAL', 'AIC', 'ALL EUROPEAN UNION', 'AMOUNTS', 'AN EUROPEAN UNION', 'AN.2', 'ANALYSIS', 'ANIMAL', 'ANSER', 'APEC', 'ARA', 'ARAS', 'ARCHITECTURAL', 'AREAS', 'ARMA', 'AROPE', 'ASEAN', 'ASEM', 'ASIA-PACIFIC ECONOMIC COOPERATION', 'ASYLUM', 'ASYMMETRIC', 'AU', 'AUTOPSY', 'AVENA', 'AWU', 'BAM', 'BANK', 'BARBUDA AG REPUBLIC', 'BE)BELGIUM', 'BETWEEN EUROPEAN UNION', 'BGN', 'BIOMASS', 'BIS', 'BLANCO', 'BMI', 'BOARD OF APPEAL', 'BOD', 'BOTSWANA', 'BREEDING', 'BRICS', 'BROADCAST - BROADCASTING', 'BUSINESS INDUSTRIES', 'C.', 'CABOTAGE', 'CABOTAGE TOTAL', 'CAN', 'CAP', 'CAPITAL (K', 'CARCINOGENIC', 'CATTLE ( BOS', 'CC', 'CCP', 'CENTRAL', 'CEPA', "CERN CERN'S", 'CFP', 'CHARACTERISTICS', 'CHF', 'CHP', 'CIS', 'CLASSIFICATION', 'CLEMENTINES ( CITRUS', 'CLEMENVILLA / NOVA', 'CLV05_MEUR & CLV10_MEUR & CLV15_MEUR & CP_MPPS', 'CMR', 'CN', 'CN_X_HK', 'COASTAL', 'COFOG', 'COICOP', 'COKE', 'COMBINED', 'COMEXT', 'COMMISSION', 'COMMISSION COMMUNICATION', 'COMMISSION DELEGATED REGULATION', 'COMMISSION REGULATION', 'COMMISSIONERS', 'COMMON', 'COMMON FOREIGN AND SECURITY POLICY', 'COMMONWEALTH OF INDEPENDENT STATES COMMUNITY', 'COMMUNICATION', 'COMMUNITIES', 'COMMUNITY', 'COMPARING', 'CONSENSUAL', 'CONSOLIDATED', 'CONVENTION', 'COOPERATIVES', 'COPENHAGEN', 'COUNCIL', 'COUNCIL DIRECTIVE', 'COUNCIL DIRECTIVE 91/271/EEC', "COUNCIL DIRECTIVE./55/EC I.E. '", 'COUNCIL DIRECTIVES 93/23/EEC', 'COUNCIL OF EUROPE', 'COUNCIL REGULATION', 'COUNCIL REGULATION (EEC', 'CPA', 'CREDIT', 'CROATIA - KUNA', 'CROP STATISTICS', 'CROPS', 'CSA', 'CUBICLE', 'CURRENCIES', 'CVT', 'CZECHIA - KORUNA', 'CZK', 'D00', 'DAC', 'DDA', 'DE', 'DE) ESTONIA (EE', 'DE) ITALY', 'DELIBERATE', 'DELPHI', 'DEM', 'DEVELOPMENT (OEEC', 'DFLE', 'DIGITAL', 'DIRECTIVE(91/271', 'DIRECTIVE./1/EC', 'DIRECTIVE./95/EU', 'DIRECTIVES./65/EC,./110/', 'DIRECTORATE-GENERAL', 'DIVISION 01', 'DK', 'DKK', 'DMC', 'DMI', 'DROP', 'DSL', 'DZ', 'E.G. EUROPEAN ORGANIZATION FOR NUCLEAR RESEARCH', 'EA', 'EAA', 'EACH EUROPEAN UNION', 'EC', 'EC TREATY', 'ECB', 'ECHA', 'ECONOMETRIC', 'ECONOMIC', 'ECU', 'EDI', 'EDP', 'EEA', 'EEAICP', 'EEC', 'EEE', 'EEUROPE', 'EFDA', 'EFTA', 'EG', 'EGSS', 'EIB', 'EL', 'EL)', 'ELECTRONIC DATA INTERCHANGE', 'ELEVENTH INTERNATIONAL CONFERENCE OF LABOUR STATISTICIANS', 'EMAS', 'EMBL', 'EMCDDA', 'EMPLOYER', 'EMS', 'ENP', 'EP', 'EPC', 'EPEA', 'ERA', 'ERDF', 'ERTMS', 'ES', 'ESA', 'ESAW', 'ESI', 'ESMS', 'ESS', 'ESSPROS', 'ETC', 'ETEA', 'ETS', 'EU', 'EU DIRECTIVE./112/', 'EU ETS', 'EU KLEMS', 'EU REGULATIONS', 'EU STATISTICS', 'EU-15', 'EUEB', 'EUI', 'EURO', 'EUROBASE', 'EUROHIS', 'EUROPEAN ACTION SCHEME', 'EUROPEAN BUSINESS STATISTICS REGULATION', 'EUROPEAN COMMISSION', 'EUROPEAN COUNCIL', 'EUROPEAN COUNCIL FOR NUCLEAR RESEARCH', 'EUROPEAN ECONOMIC AREA', 'EUROPEAN ECONOMIC AREA EUROPEAN ENVIRONMENT AGENCY', 'EUROPEAN ENVIRONMENT AGENCY', 'EUROPEAN ENVIRONMENTAL ECONOMIC ACCOUNTS', 'EUROPEAN FREE TRADE ASSOCIATION', 'EUROPEAN HEALTH INTERVIEW SURVEY', 'EUROPEAN MOLECULAR BIOLOGY LABORATORY', 'EUROPEAN NEIGHBOURHOOD POLICY', 'EUROPEAN SOUTHERN OBSERVATORY', 'EUROPEAN STATISTICAL CLASSIFICATION OF ECONOMIC ACTIVITIES', 'EUROPEAN STATISTICAL SYSTEM', 'EUROPEAN STATISTICS', 'EUROPEAN SYNCHROTRON RADIATION FACILITY', 'EUROPEAN UNION', "EUROPEAN UNION 'S", 'EUROPEAN UNION (MAASTRICHT TREATY', 'EUROSTAT', 'EUROSTAT STS', 'EVERY EUROPEAN UNION', 'EW-MFA', 'EXCHANGE', 'EXCLUDES ENERGY', 'EXCLUDES HOLDINGS', 'EXCLUDES NURSERIES', 'EXECUTIVE', 'EXTRA-EU', 'F.1', 'F.3', 'F.5', 'FADN FADN', 'FAO', 'FARMERS', 'FATS', 'FDI', 'FERTILISERS', 'FIM', 'FISHER', 'FLAG', 'FOOD AND AGRICULTURE ORGANIZATION', 'FORTUNELLA', 'FOUNDATION', 'FRUIT', 'FSS', 'FTE', 'FVC', 'G20', 'GAE', 'GAEC', 'GALI', 'GATS', 'GBAORD', 'GBP', 'GE', 'GENDER', 'GENERAL ASSEMBLY', 'GENERAL GOVERNMENT', 'GEONOM', 'GFCF', 'G ...

# %%
len(org_all_freqs)
# Out:
# 855

# %%
print('\n100 most common:\n')
org_common_freqs = Counter(org_list).most_common(100)
org_common = sorted([x[0] for x in org_common_freqs])
print(org_common)
# Out:
# 100 most common:
#
# ['AEI', 'AGRICULTURAL', 'ALL EUROPEAN UNION', 'ASEAN', 'ASYLUM', 'BMI', 'CAP', 'CIS', 'CLASSIFICATION', 'COMMISSION', 'COMMISSION REGULATION', 'COUNCIL', 'COUNCIL REGULATION', 'CROPS', 'DE', 'DIGITAL', 'DK', 'DZ', 'EC', 'EDP', 'EEA', 'EFTA', 'EL', 'ES', 'ESA', 'ESS', 'EU', 'EUROPEAN BUSINESS STATISTICS REGULATION', 'EUROPEAN ENVIRONMENTAL ECONOMIC ACCOUNTS', 'EUROPEAN UNION', 'EUROSTAT', 'EXTRA-EU', 'FAO', 'FDI', 'FSS', 'GFCF', 'GNI', 'HICP', 'HOUSEHOLDS', 'HRST', 'ICT', 'IFS', 'INCOME AND LIVING CONDITIONS', 'INTEGRATED FARM STATISTICS', 'IPC', 'ISIC', 'KAU', 'LFS', 'LPG', 'LSU', 'LUCAS', 'METADATA EXCHANGE', 'NACE', 'NACE REV.2', 'NATIONAL STATISTICAL INSTITUTES', 'NL', 'NPISH', 'NUAA', 'NUTS', 'OECD', 'PACKAGING DIRECTIVE', 'PECR', 'PPS', 'R & D', 'R & D.', 'S&T', 'S.', 'SAPM', 'SBS', 'SDR', 'SES', 'SNA', 'STABILITY', 'STATE', 'STATISTICAL', 'STATISTICAL DATA', 'STS', 'THE COUNCIL OF EUROPE', 'THE COUNCIL OF THE EUROPEAN UNION', 'THE EUROPEAN CENTRAL BANK', 'THE EUROPEAN COMMISSION', 'THE EUROPEAN COMMUNITIES', 'THE EUROPEAN COMMUNITY', 'THE EUROPEAN COUNCIL', 'THE EUROPEAN ECONOMIC AREA', 'THE EUROPEAN FREE TRADE ASSOCIATION', 'THE EUROPEAN HEALTH INTERVIEW SURVEY', 'THE EUROPEAN PARLIAMENT', 'THE EUROPEAN PATENT OFFICE', 'THE EUROPEAN STATISTICAL SYSTEM', 'THE EUROPEAN UNION', 'THE INTERNATIONAL LABOUR ORGANIZATION (ILO', 'THE INTERNATIONAL MONETARY FUND', 'THE ORGANISATION FOR ECONOMIC CO-OPERATION AND', 'THE UNITED NATIONS', 'TPP', 'UAA', 'UN', 'UNITED NATIONS', 'WHO']

# %% [markdown]
# # Step 6. Storing information on these most common entities per article: example with ORG entities
#
# This is one way of storing the information on both all entities and counts and on the most common ones in a Pandas dataframe.

# %%
Gloss_concepts['ORG_COMMON_100'] = Gloss_concepts['ORG'].apply(lambda x: {y:x[y] for y in x.keys() if y in org_common})
Gloss_concepts
# Out:
#         id                                              title  \
# 0        1  Arrival of tourist at a tourist accommodation ...
# 1        3                                    Nights spent
# 2        4                  Supply side tourism statistics
# 3        5                                         Tourist
# 4        7                         Asia-Europe Meeting (ASEM)
# ...    ...                                                ...
# 1279  2879                              Statistical territory
# 1280  2881                              Statistical indicator
# 1281  2885                                 Tourism industries
# 1282  2891                                           Sawnwood
# 1283  2896                                       LeaMickatest
#
#                                              definition  \
# 0     See arrival disambiguation page for other mean...
# 1     A night spent or tourism night (overnight stay...
# 2     Regulation (EU) No 692. of 6 July. establishes...
# 3     For tourism statistics, a traveller is someone...
# 4     The Asia-Europe Meeting, abbreviated as ASEM, ...
# ...                                                 ...
# 1279  The statistical territory of the European Unio...
# 1280  A statistical indicator is the representation ...
# 1281  For the article Tourism industries - economic ...
# 1282  Sawnwood is wood that has been produced either...
# 1283                                               test
#
#                                         definition_init  \
# 0        See      arrival disambiguation page     fo...
# 1       A     night spent    or     tourism night   ...
# 2       Regulation (EU) No 692/2011 of 6 July 2011 e...
# 3       For     tourism    statistics, a     travell...
# 4       The     Asia-Europe Meeting    , abbreviated...
# ...                                                 ...
# 1279    The     statistical territory    of the     ...
# 1280    A     statistical indicator    is the repres...
# 1281    For the article     Tourism industries - eco...
# 1282     Sawnwood    is wood that has been produced ...
# 1283                                               test
#
#                                                     ORG  \
# 0     {'EUROPEAN UNION': [[(14, 16)], 1], 'EU': [[(1...
# 1                                                    {}
# 2     {'EU': [[(2, 3)], 1], 'ACCOMMODATION': [[(47, ...
# 3                                                    {}
# 4     {'ASEM': [[(8, 9)], 1], 'THE EUROPEAN UNION': ...
# ...                                                 ...
# 1279  {'THE EUROPEAN UNION': [[(4, 7)], 1], 'EU': [[...
# 1280  {'EUROPEAN UNION': [[(82, 84)], 1], 'EU': [[(8...
# 1281  {'UNWTO': [[(21, 22)], 1], 'SBS': [[(134, 135)...
# 1282                        {'SAWNWOOD': [[(0, 1)], 1]}
# 1283                                                 {}
#
#                                                     GPE  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'OCEANIA': [[(29, 30)], 1], 'NORWAY': [[(57, ...
# ...                                                 ...
# 1279  {'STATES': [[(31, 32)], 1], 'GERMANY': [[(40, ...
# 1280                                                 {}
# 1281                                                 {}
# 1282                                                 {}
# 1283                                                 {}
#
#                                NORP LOCATION  \
# 0                                {}       {}
# 1                                {}       {}
# 2     {'EUROPEAN': [[(24, 25)], 1]}       {}
# 3                                {}       {}
# 4                                {}       {}
# ...                             ...      ...
# 1279    {'FRENCH': [[(62, 63)], 1]}       {}
# 1280                             {}       {}
# 1281  {'EUROPEAN': [[(29, 30)], 1]}       {}
# 1282                             {}       {}
# 1283                             {}       {}
#
#                                          ORG_COMMON_100
# 0     {'EUROPEAN UNION': [[(14, 16)], 1], 'EU': [[(1...
# 1                                                    {}
# 2                                 {'EU': [[(2, 3)], 1]}
# 3                                                    {}
# 4     {'THE EUROPEAN UNION': [[(41, 44)], 1], 'EU': ...
# ...                                                 ...
# 1279  {'THE EUROPEAN UNION': [[(4, 7)], 1], 'EU': [[...
# 1280  {'EUROPEAN UNION': [[(82, 84)], 1], 'EU': [[(8...
# 1281  {'SBS': [[(134, 135), (229, 230)], 2], 'STS': ...
# 1282                                                 {}
# 1283                                                 {}
#
# [1284 rows x 9 columns]

# %% [markdown]
# # Step 7. Exporting the dataframe to Excel
#
# This is useful for the manual inspection and the design of rules for the fine-tuning of the NER engine. This output can then directly be imported in the database.

# %%
Gloss_concepts.to_excel('Gloss_concepts.xlsx')
