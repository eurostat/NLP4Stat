# %% [markdown]
# # Produce inputs for Power BI
# ***
#
# ### Revised (January 2022) to read all data from the database
#
# * Produces the following inputs to Power BI:
#     * **SE_df_for_PowerBI.xlsx**.
#     * **OECD_content_for_PowerBI.xlsx**.

# %%
import pandas as pd
import numpy as np

import pyodbc

import gensim

# %% [markdown]
# ### The data cleansing function

# %%
import re
import unicodedata as ud

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) ## NEW
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) ## NEW

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x

# %% [markdown]
# ### Import Statistics Explained data from the database
#
# * Id, context and last update from table dat_article.
# * Title and url from table dat_link_info, on matching id and resource_information_id=1 (i.e. Eurostat).
# * Abstract from field content in table dat_article_paragraph, on matching article_id and abstract=1 ("yes").
# * Apply data cleansing.

# %%
c = pyodbc.connect('DSN=Virtuoso All;DBA=ESTAT;UID=xxxxx;PWD=xxxxx')
cursor = c.cursor()

SQLCommand = """SELECT T1.id, T1.context, T1.last_update, T2.title, T2.url, T3.content 
                FROM ESTAT.V1.dat_article as T1 
                INNER JOIN ESTAT.V1.dat_link_info as T2  
                  ON T1.id=T2.id  
                INNER JOIN ESTAT.V1.dat_article_paragraph as T3  
                  ON T2.id=T3.article_id  
                WHERE T2.resource_information_id=1 AND T3.abstract=1"""

SE_df = pd.read_sql(SQLCommand,c)
SE_df.rename(columns={'content':'abstract'},inplace=True)
SE_df = SE_df[['id','context','title','abstract','url','last_update']]

SE_df['context'] = SE_df['context'].apply(clean)
SE_df['title'] = SE_df['title'].apply(clean)
SE_df['abstract'] = SE_df['abstract'].apply(clean)

SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00

# %% [markdown]
# ### Paragraph titles and contents
#
# * From the dat_article_paragraph table with abstract=0 and matching article_id.
# * Apply data cleansing.

# %%
SQLCommand = """SELECT article_id, title, content 
                FROM ESTAT.V1.dat_article_paragraph
                WHERE abstract=0 AND article_id IN (SELECT id FROM ESTAT.V1.dat_article) """

add_content = pd.read_sql(SQLCommand,c)
add_content.sort_values(by=['article_id'],inplace=True)
add_content['title'] = add_content['title'].apply(clean)
add_content['content'] = add_content['content'].apply(clean)
add_content.head(5)
# Out:
#     article_id                         title  \
# 9            7           Number of accidents
# 10           7               Incidence rates
# 11           7  Standardised incidence rates
# 12           7          Analysis by activity
# 13           7    Analysis by type of injury
#
#                                               content
# 9   In 2018, there were 3.1 million non-fatal acci...
# 10  An alternative way to analyse the information ...
# 11  When comparing data between countries, inciden...
# 12  As noted above, one of the main reasons why th...
# 13  Figure 6 presents an analysis of data accordin...

# %% [markdown]
# ### Aggregate the above paragraph titles and contents
#
# * Create a column _raw content_ which gathers all paragraph titles and contents in one text per article.

# %%
add_content_grouped = add_content.groupby(['article_id'])[['title','content']].aggregate(lambda x: list(x))
add_content_grouped.reset_index(drop=False, inplace=True)
for i in range(len(add_content_grouped)):
    add_content_grouped.loc[i,'raw content'] = ''
    for (a,b) in zip(add_content_grouped.loc[i,'title'],add_content_grouped.loc[i,'content']):
        add_content_grouped.loc[i,'raw content'] += ' '+a + ' ' + b
add_content_grouped = add_content_grouped[['article_id','raw content']]    

add_content_grouped.head(5)
# Out:
#    article_id                                        raw content
# 0           7   Number of accidents In 2018, there were 3.1 m...
# 1          13   Household consumption Consumption expenditure...
# 2          16   Suicides on railways Suicides occurring on th...
# 3          17   Geographical location plays a key role in the...
# 4          18   Number of passengers transported by rail incr...

# %% [markdown]
# ### Merge the raw content of the SE articles with the main file

# %%
SE_df = pd.merge(SE_df,add_content_grouped,left_on='id',right_on='article_id',how='inner')
SE_df.drop(['article_id'],axis=1,inplace=True)

SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...

# %% [markdown]
# ### Related links
#
# * From the dat_article_shared_link table with article_division=2 ("Other articles", see mod_article_division table).
# * link_id points to id in dat_link_info (where we select resource_information_id=1).
# * Apply data cleansing (with an additional step to replace question marks from the related titles).

# %%
SQLCommand = """SELECT T1.article_id, T1.link_id, T2.title, T2.url 
                FROM dat_article_shared_link as T1 
                INNER JOIN ESTAT.V1.dat_link_info as T2  
                  ON T1.link_id=T2.id  
                WHERE T1.article_division_id=2 AND T2.resource_information_id=1
                ORDER BY T1.article_id, T1.link_id """

add_related_links = pd.read_sql(SQLCommand,c)
add_related_links['title'] = add_related_links['title'] .apply(clean)
add_related_links['title'] = add_related_links['title'] .apply(lambda x: re.sub(r'\?','-',x))
add_related_links.head(5)
# Out:
#    article_id  link_id                                              title  \
# 0           7      229   Health in the European Union a facts and figures
# 1           7     1157                       Health statistics introduced
# 2           7     2914                  Accidents and injuries statistics
# 3           7     2946  Accidents at work - statistics by economic act...
# 4           7     2947  Accidents at work - statistics on causes and c...
#
#                                                  url
# 0  https://ec.europa.eu/eurostat/statistics-expla...
# 1  https://ec.europa.eu/eurostat/statistics-expla...
# 2  https://ec.europa.eu/eurostat/statistics-expla...
# 3  https://ec.europa.eu/eurostat/statistics-expla...
# 4  https://ec.europa.eu/eurostat/statistics-expla...

# %% [markdown]
# ### Aggregate above by article id
#
# * Aggregate related titles and URLs in one string.

# %%
add_related_grouped = pd.DataFrame(add_related_links.groupby(['article_id'])[['title','url']].aggregate(lambda x: list(x)))
add_related_grouped.reset_index(drop=False, inplace=True)
add_related_grouped.rename(columns={'title':'related_titles','url':'related_urls'},inplace=True)
add_related_grouped.head(5)
# Out:
#    article_id                                     related_titles  \
# 0           7  [Health in the European Union a facts and figu...
# 1          13  [Sector accounts, European system of national ...
# 2          16  [Railway freight transport statistics, Railway...
# 3          17  [Transport statistics at regional level, All a...
# 4          18  [Railway freight transport statistics, Freight...
#
#                                         related_urls
# 0  [https://ec.europa.eu/eurostat/statistics-expl...
# 1  [https://ec.europa.eu/eurostat/statistics-expl...
# 2  [https://ec.europa.eu/eurostat/statistics-expl...
# 3  [https://ec.europa.eu/eurostat/statistics-expl...
# 4  [https://ec.europa.eu/eurostat/statistics-expl...

# %% [markdown]
# ### Merge above with the main file

# %%
SE_df = pd.merge(SE_df,add_related_grouped,left_on='id',right_on='article_id',how='inner')
SE_df.drop(['article_id'],axis=1,inplace=True)


SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content  \
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...
#
#                                       related_titles  \
# 0  [Health in the European Union a facts and figu...
# 1  [Sector accounts, European system of national ...
# 2  [Railway freight transport statistics, Railway...
# 3  [Transport statistics at regional level, All a...
# 4  [Railway freight transport statistics, Freight...
#
#                                         related_urls
# 0  [https://ec.europa.eu/eurostat/statistics-expl...
# 1  [https://ec.europa.eu/eurostat/statistics-expl...
# 2  [https://ec.europa.eu/eurostat/statistics-expl...
# 3  [https://ec.europa.eu/eurostat/statistics-expl...
# 4  [https://ec.europa.eu/eurostat/statistics-expl...

# %% [markdown]
# ### Read categories from the database

# %%
import ast

SQLCommand = """SELECT article_id, categories 
                FROM ESTAT.V1.SE_articles_categories 
             """

categories = pd.read_sql(SQLCommand,c)
categories['categories']=categories['categories'].apply(ast.literal_eval)
categories
# Out:
#      article_id                                         categories
# 0             7  [Accidents at work, Health, Health and safety,...
# 1            13  [National accounts (incl. GDP), Statistical ar...
# 2            16  [Rail, Statistical article, Transport, Transpo...
# 3            17    [Freight, Rail, Statistical article, Transport]
# 4            18  [Passengers, Rail, Statistical article, Transp...
# ..          ...                                                ...
# 600        9472  [International trade, Trade in goods, Trade in...
# 601        9477              [Trade in goods, Statistical article]
# 602        9479  [Trade in goods, Statistical article, Internat...
# 603        9492  [Household composition and family situation, L...
# 604        9911    [Employment, Labour market, Background article]
#
# [605 rows x 2 columns]

# %% [markdown]
# ### Merge with the main file

# %%
SE_df = pd.merge(SE_df,categories,left_on='id',right_on='article_id')
SE_df.drop(columns=['article_id'],inplace=True)

SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content  \
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...
#
#                                       related_titles  \
# 0  [Health in the European Union a facts and figu...
# 1  [Sector accounts, European system of national ...
# 2  [Railway freight transport statistics, Railway...
# 3  [Transport statistics at regional level, All a...
# 4  [Railway freight transport statistics, Freight...
#
#                                         related_urls  \
# 0  [https://ec.europa.eu/eurostat/statistics-expl...
# 1  [https://ec.europa.eu/eurostat/statistics-expl...
# 2  [https://ec.europa.eu/eurostat/statistics-expl...
# 3  [https://ec.europa.eu/eurostat/statistics-expl...
# 4  [https://ec.europa.eu/eurostat/statistics-expl...
#
#                                           categories
# 0  [Accidents at work, Health, Health and safety,...
# 1  [National accounts (incl. GDP), Statistical ar...
# 2  [Rail, Statistical article, Transport, Transpo...
# 3    [Freight, Rail, Statistical article, Transport]
# 4  [Passengers, Rail, Statistical article, Transp...

# %% [markdown]
# ### Exract last update year
#
# * And check missing values.

# %%
SE_df['new_date'] = [d.date() for d in SE_df['last_update']]  
SE_df['year'] = SE_df['last_update'].dt.year
SE_df['year'] =SE_df["year"].astype(str)

SE_df.replace('', np.nan, inplace=True)

SE_df['year'].fillna(value="Not found", inplace=True)

print(SE_df.isnull().sum(),'\n')

SE_df.reset_index(drop=True,inplace=True)
SE_df.head(5)
# Out:
# id                 0
# context           59
# title              0
# abstract           9
# url                0
# last_update        0
# raw content        0
# related_titles     0
# related_urls       0
# categories         0
# new_date           0
# year               0
# dtype: int64
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content  \
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...
#
#                                       related_titles  \
# 0  [Health in the European Union a facts and figu...
# 1  [Sector accounts, European system of national ...
# 2  [Railway freight transport statistics, Railway...
# 3  [Transport statistics at regional level, All a...
# 4  [Railway freight transport statistics, Freight...
#
#                                         related_urls  \
# 0  [https://ec.europa.eu/eurostat/statistics-expl...
# 1  [https://ec.europa.eu/eurostat/statistics-expl...
# 2  [https://ec.europa.eu/eurostat/statistics-expl...
# 3  [https://ec.europa.eu/eurostat/statistics-expl...
# 4  [https://ec.europa.eu/eurostat/statistics-expl...
#
#                                           categories    new_date  year
# 0  [Accidents at work, Health, Health and safety,...  2020-11-26  2020
# 1  [National accounts (incl. GDP), Statistical ar...  2021-06-28  2021
# 2  [Rail, Statistical article, Transport, Transpo...  2021-06-25  2021
# 3    [Freight, Rail, Statistical article, Transport]  2020-11-27  2020
# 4  [Passengers, Rail, Statistical article, Transp...  2021-07-07  2021

# %% [markdown]
# ### Add themes / sub-themes information in the articles
#
# * We create dictionary _themes_ manually.
# * Include some artificial ones (theme: 'Other') to match some OECD's Glossary themes.
# * Each article will have a list of themes and corresponding sub-themes, potentially empty. If an article has a category which is a key of _themes_ the theme is added to the first list. If it has a category which is in one of the values of _themes_ i.e. it is a sub-theme, the corresponding key (theme) is added to the first list and the sub-theme is added to the second list.
# * There are relatively few articles without such information, see below.

# %%
import ast

themes = {'General and regional statistics/EU policies':
          ['Non-EU countries','Regions and cities','Sustainable development goals',
          'Policy indicators'],
          'Economy and finance': 
          ['Balance of payments','Comparative price levels (PPPs)','Consumer prices',
           'Exchange rates and interest rates','Government finance','National accounts (incl. GDP)'],
          'Population and social conditions':
          ['Asylum and migration','Crime','Culture','Education and training','Health',
           'Labour market','Living conditions','Population','Social protection','Sport','Youth'],
          'Industry and services': ['Short-term business statistics','Structural business statistics',
                                    'Business registers','Globalisation in businesses','Production statistics',
                                    'Tourism'],
          'Agriculture, forestry and fisheries':['Agriculture','Fisheries','Forestry'],
          'International trade':['Goods','Services'],
          'Transport':[],
          'Environment and energy':['Energy','Environment'],
          'Science, technology and digital society':['Digital economy and society','Science and technology'],
          'Other':['Methodology','Other']}

SE_df['themes'] = pd.Series([set() for i in range(len(SE_df))])
SE_df['sub_themes'] = pd.Series([set() for i in range(len(SE_df))])
for i in range(len(SE_df)):
    
    cats=SE_df.loc[i,'categories']
    cats = [cat.strip() for cat in cats]

    for cat in cats:
        if cat in themes.keys():
            SE_df.loc[i,'themes'].add(cat)
        else:
            for theme in themes.keys():
                if cat in themes[theme]:
                    SE_df.loc[i,'themes'].add(theme)
                    SE_df.loc[i,'sub_themes'].add(cat)
    
SE_df['themes'] = SE_df['themes'].apply(lambda x: ';'.join(x))    
SE_df['sub_themes'] = SE_df['sub_themes'].apply(lambda x: ';'.join(x))    

#SE_df['categories']= SE_df['categories'].apply(lambda x: ';'.join(x))  ## de-comment to produce the input file for R Shiny, 
## i.e. categories not in list but separated by semicolon    

print(SE_df.isnull().sum(),'\n')

print('No info in themes: ',sum(SE_df['themes']==''))
print('No info in sub_themes: ',sum(SE_df['sub_themes']==''))


SE_df.head(5)
# Out:
# id                 0
# context           59
# title              0
# abstract           9
# url                0
# last_update        0
# raw content        0
# related_titles     0
# related_urls       0
# categories         0
# new_date           0
# year               0
# themes             0
# sub_themes         0
# dtype: int64
#
# No info in themes:  48
# No info in sub_themes:  83
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content  \
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...
#
#                                       related_titles  \
# 0  [Health in the European Union a facts and figu...
# 1  [Sector accounts, European system of national ...
# 2  [Railway freight transport statistics, Railway...
# 3  [Transport statistics at regional level, All a...
# 4  [Railway freight transport statistics, Freight...
#
#                                         related_urls  \
# 0  [https://ec.europa.eu/eurostat/statistics-expl...
# 1  [https://ec.europa.eu/eurostat/statistics-expl...
# 2  [https://ec.europa.eu/eurostat/statistics-expl...
# 3  [https://ec.europa.eu/eurostat/statistics-expl...
# 4  [https://ec.europa.eu/eurostat/statistics-expl...
#
#                                           categories    new_date  year  \
# 0  [Accidents at work, Health, Health and safety,...  2020-11-26  2020
# 1  [National accounts (incl. GDP), Statistical ar...  2021-06-28  2021
# 2  [Rail, Statistical article, Transport, Transpo...  2021-06-25  2021
# 3    [Freight, Rail, Statistical article, Transport]  2020-11-27  2020
# 4  [Passengers, Rail, Statistical article, Transp...  2021-07-07  2021
#
#                              themes                     sub_themes
# 0  Population and social conditions           Health;Labour market
# 1               Economy and finance  National accounts (incl. GDP)
# 2                         Transport
# 3                         Transport
# 4                         Transport

# %% [markdown]
# ### Tokenize and stem the articles titles, contexts, abstracts and contents and produce first file
#
# * Also remove stop-words.
# * Create columns _title tokens_, _context tokens_, _abstract tokens_, _raw content tokens_.

# %%
#Stemming.

from gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import stem_text
from gensim.parsing.porter import PorterStemmer

p = PorterStemmer()

def text_to_words(text):
    words = str(gensim.utils.simple_preprocess(text, deacc=True))
    words = remove_stopwords(words) 
    words = gensim.utils.tokenize(words)
        
    words = [p.stem(token) for token in words]  
    return ' '.join(words)        

for i in range(len(SE_df)):
    SE_df.loc[i,'title tokens']=text_to_words(SE_df.loc[i,'title'])
    if not pd.isnull(SE_df.loc[i,'context']):
        SE_df.loc[i,'context tokens']=text_to_words(SE_df.loc[i,'context'])
    else:
        SE_df.loc[i,'context tokens']=''
    if not pd.isnull(SE_df.loc[i,'abstract']):        
        SE_df.loc[i,'abstract tokens']=text_to_words(SE_df.loc[i,'abstract'])
    else:
        SE_df.loc[i,'abstract tokens']=''
    SE_df.loc[i,'raw content tokens']=text_to_words(SE_df.loc[i,'raw content'])

SE_df.rename(columns={'id':'article_id'},inplace=True)


## Produce first file
SE_df.to_excel('SE_df_for_PowerBI.xlsx')
SE_df.head(5)
# Out:
#    article_id                                            context  \
# 0           7  A safe, healthy working environment is a cruci...
# 1          13  European institutions, governments, central ba...
# 2          16  National rail networks have different technica...
# 3          17  The content of this statistical article is bas...
# 4          18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content  \
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...
#
#                                       related_titles  \
# 0  [Health in the European Union a facts and figu...
# 1  [Sector accounts, European system of national ...
# 2  [Railway freight transport statistics, Railway...
# 3  [Transport statistics at regional level, All a...
# 4  [Railway freight transport statistics, Freight...
#
#                                         related_urls  \
# 0  [https://ec.europa.eu/eurostat/statistics-expl...
# 1  [https://ec.europa.eu/eurostat/statistics-expl...
# 2  [https://ec.europa.eu/eurostat/statistics-expl...
# 3  [https://ec.europa.eu/eurostat/statistics-expl...
# 4  [https://ec.europa.eu/eurostat/statistics-expl...
#
#                                           categories    new_date  year  \
# 0  [Accidents at work, Health, Health and safety,...  2020-11-26  2020
# 1  [National accounts (incl. GDP), Statistical ar...  2021-06-28  2021
# 2  [Rail, Statistical article, Transport, Transpo...  2021-06-25  2021
# 3    [Freight, Rail, Statistical article, Transport]  2020-11-27  2020
# 4  [Passengers, Rail, Statistical article, Transp...  2021-07-07  2021
#
#                              themes                     sub_themes  \
# 0  Population and social conditions           Health;Labour market
# 1               Economy and finance  National accounts (incl. GDP)
# 2                         Transport
# 3                         Transport
# 4                         Transport
#
#                                         title tokens  \
# 0                              accid at work statist
# 1                             nation account and gdp
# 2                   railwai safeti statist in the eu
# 3                  railwai freight transport statist
# 4  railwai passeng transport statist quarterli an...
#
#                                       context tokens  \
# 0  safe healthi work environ is crucial factor in...
# 1  european institut govern central bank as well ...
# 2  nation rail network have differ technic specif...
# 3  the content of thi statist articl is base on d...
# 4  the content of thi statist articl is base on d...
#
#                                      abstract tokens  \
# 0  thi articl present set of main statist find in...
# 1  nation account ar the sourc for multitud of we...
# 2  in signific railwai accid were report in the e...
# 3  thi articl focus on recent rail freight transp...
# 4  thi articl take look at recent annual and quar...
#
#                                   raw content tokens
# 0  number of accid in there were million non fata...
# 1  household consumpt consumpt expenditur of hous...
# 2  suicid on railwai suicid occur on the railwai ...
# 3  geograph locat plai kei role in the share of i...
# 4  number of passeng transport by rail increas in...

# %% [markdown]
# ### Read the file with OECD's terms and definitions
# * Column 'related' has the cross-references separated by semicolons and also with some invalid ones (not valid URL in 'related_URL') removed.

# %%
SQLCommand = """SELECT article_id,term,url,definition,context,theme,related,related_url,last_update,source_publ
                FROM ESTAT.V1.OECD_Glossary """

OECD_df = pd.read_sql(SQLCommand,c)
OECD_df.rename(columns={'article_id':'ID','url':'URL','related_url':'related_URL','source_publ':'Source Publication:'},inplace=True)
OECD_df
# Out:
#         ID                                               term  \
# 0        1                                          Abatement
# 1        2                   Absence from work due to illness
# 2        3             Activity restriction - free expectancy
# 3        4                                         Acute care
# 4        5                                    Acute care beds
# ...    ...                                                ...
# 6931  7352  European Agricultural Fund for Rural Developme...
# 6932  7354                                      Carbon market
# 6933  7355                           Classification structure
# 6934  7356  United Nation Framework Convention on Climate ...
# 6935  7357                   Carbon Capture and Storage (CCS)
#
#                                                     URL  \
# 0       https://stats.oecd.org/glossary/detail.asp?ID=1
# 1       https://stats.oecd.org/glossary/detail.asp?ID=2
# 2       https://stats.oecd.org/glossary/detail.asp?ID=3
# 3       https://stats.oecd.org/glossary/detail.asp?ID=4
# 4       https://stats.oecd.org/glossary/detail.asp?ID=5
# ...                                                 ...
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6933  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6934  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6935  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6931  The Common Agricultural Policy (CAP) is financ...
# 6932  A popular (but misleading) term for a trading ...
# 6933  Refers to how the categories of a classificati...
# 6934  The United Nations Framework Convention on Cli...
# 6935  Carbon Capture and Storage (CCS) is a process ...
#
#                                                 context  \
# 0
# 1
# 2
# 3
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6931
# 6932
# 6933
# 6934  The other ?Rio Conventions?, also negotiated a...
# 6935
#
#                          theme  \
# 0     Environmental statistics
# 1            Health statistics
# 2            Health statistics
# 3            Health statistics
# 4            Health statistics
# ...                        ...
# 6931
# 6932
# 6933
# 6934
# 6935
#
#                                                 related  \
# 0                                   Pollution abatement
# 1
# 2
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6931  Common Agricultural Policy (CAP);European Agri...
# 6932                                   Greenhouse gases
# 6933                                     Classification
# 6934  United Nations Conference on Environment and D...
# 6935                               Carbon sequestration
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1
# 2
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6933  https://stats.oecd.org/glossary/detail.asp?ID=350
# 6934  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6935  https://stats.oecd.org/glossary/detail.asp?ID=286
#
#                       last_update  \
# 0        Thursday, March 14, 2002
# 1     Thursday, November 22, 2001
# 2     Wednesday, October 31, 2001
# 3        Thursday, April 25, 2013
# 4        Thursday, April 25, 2013
# ...                           ...
# 6931     Wednesday, April 3, 2013
# 6932      Thursday, April 4, 2013
# 6933       Tuesday, April 9, 2013
# 6934       Friday, April 26, 2013
# 6935       Monday, April 15, 2013
#
#                                     Source Publication:
# 0
# 1     OECD Health Data 2001: A Comparative Analysis ...
# 2     OECD Health Data 2001: A Comparative Analysis ...
# 3     OECD Health Data 2001: A Comparative Analysis ...
# 4     2001 Data Collection on Education Systems: Def...
# ...                                                 ...
# 6931  European Commission, Agriculture and Rural Dev...
# 6932  United Nations Framework Convention on Climate...
# 6933  United Nations Statistics Division, n.d. UN Gl...
# 6934  United Nations Framework Convention on Climate...
# 6935  IPCC, 2007. Climate Change 2007 - Mitigation o...
#
# [6936 rows x 10 columns]

# %% [markdown]
# * Drop records with missing values and apply data cleansing.

# %%
OECD_df.replace('',np.nan,inplace=True)
print(OECD_df.isnull().sum())
OECD_df.dropna(subset=['term','definition'],inplace=True)
OECD_df.reset_index(drop=True, inplace=True)
print(OECD_df.isnull().sum())

OECD_df['term'] = OECD_df['term'].apply(clean)
OECD_df['definition'] = OECD_df['definition'].apply(clean)
OECD_df['context'] = OECD_df['context'].apply(clean)
OECD_df
# Out:
# ID                        0
# term                      3
# URL                       0
# definition                0
# context                5538
# theme                    35
# related                4373
# related_URL            4373
# last_update            1763
# Source Publication:     866
# dtype: int64
# ID                        0
# term                      0
# URL                       0
# definition                0
# context                5536
# theme                    35
# related                4371
# related_URL            4371
# last_update            1761
# Source Publication:     866
# dtype: int64
#         ID                                               term  \
# 0        1                                          Abatement
# 1        2                   Absence from work due to illness
# 2        3             Activity restriction - free expectancy
# 3        4                                         Acute care
# 4        5                                    Acute care beds
# ...    ...                                                ...
# 6928  7352  European Agricultural Fund for Rural Developme...
# 6929  7354                                      Carbon market
# 6930  7355                           Classification structure
# 6931  7356  United Nation Framework Convention on Climate ...
# 6932  7357                   Carbon Capture and Storage (CCS)
#
#                                                     URL  \
# 0       https://stats.oecd.org/glossary/detail.asp?ID=1
# 1       https://stats.oecd.org/glossary/detail.asp?ID=2
# 2       https://stats.oecd.org/glossary/detail.asp?ID=3
# 3       https://stats.oecd.org/glossary/detail.asp?ID=4
# 4       https://stats.oecd.org/glossary/detail.asp?ID=5
# ...                                                 ...
# 6928  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6929  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6930  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6928  The Common Agricultural Policy (CAP) is financ...
# 6929  A popular (but misleading) term for a trading ...
# 6930  Refers to how the categories of a classificati...
# 6931  The United Nations Framework Convention on Cli...
# 6932  Carbon Capture and Storage (CCS) is a process ...
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN
# 6931  The other ?Rio Conventions?, also negotiated a...
# 6932                                                NaN
#
#                          theme  \
# 0     Environmental statistics
# 1            Health statistics
# 2            Health statistics
# 3            Health statistics
# 4            Health statistics
# ...                        ...
# 6928                       NaN
# 6929                       NaN
# 6930                       NaN
# 6931                       NaN
# 6932                       NaN
#
#                                                 related  \
# 0                                   Pollution abatement
# 1                                                   NaN
# 2                                                   NaN
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6928  Common Agricultural Policy (CAP);European Agri...
# 6929                                   Greenhouse gases
# 6930                                     Classification
# 6931  United Nations Conference on Environment and D...
# 6932                               Carbon sequestration
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6928  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6929  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6930  https://stats.oecd.org/glossary/detail.asp?ID=350
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=286
#
#                       last_update  \
# 0        Thursday, March 14, 2002
# 1     Thursday, November 22, 2001
# 2     Wednesday, October 31, 2001
# 3        Thursday, April 25, 2013
# 4        Thursday, April 25, 2013
# ...                           ...
# 6928     Wednesday, April 3, 2013
# 6929      Thursday, April 4, 2013
# 6930       Tuesday, April 9, 2013
# 6931       Friday, April 26, 2013
# 6932       Monday, April 15, 2013
#
#                                     Source Publication:
# 0                                                   NaN
# 1     OECD Health Data 2001: A Comparative Analysis ...
# 2     OECD Health Data 2001: A Comparative Analysis ...
# 3     OECD Health Data 2001: A Comparative Analysis ...
# 4     2001 Data Collection on Education Systems: Def...
# ...                                                 ...
# 6928  European Commission, Agriculture and Rural Dev...
# 6929  United Nations Framework Convention on Climate...
# 6930  United Nations Statistics Division, n.d. UN Gl...
# 6931  United Nations Framework Convention on Climate...
# 6932  IPCC, 2007. Climate Change 2007 - Mitigation o...
#
# [6933 rows x 10 columns]

# %% [markdown]
# ### Tokenize and stem the articles terms, definitions and contexts
#
# * Also remove stop-words.
# * Create columns _term tokens_, _definition tokens_, _context tokens_.

# %%
texts=list()

for i in range(len(OECD_df)):
    OECD_df.loc[i,'term tokens']=text_to_words(OECD_df.loc[i,'term'])
    OECD_df.loc[i,'definition tokens']=text_to_words(OECD_df.loc[i,'definition'])
    if not pd.isnull(OECD_df.loc[i,'context']):        
        OECD_df.loc[i,'context tokens']=text_to_words(OECD_df.loc[i,'context'])
    else:
        OECD_df.loc[i,'context tokens']=''

OECD_df
# Out:
#         ID                                               term  \
# 0        1                                          Abatement
# 1        2                   Absence from work due to illness
# 2        3             Activity restriction - free expectancy
# 3        4                                         Acute care
# 4        5                                    Acute care beds
# ...    ...                                                ...
# 6928  7352  European Agricultural Fund for Rural Developme...
# 6929  7354                                      Carbon market
# 6930  7355                           Classification structure
# 6931  7356  United Nation Framework Convention on Climate ...
# 6932  7357                   Carbon Capture and Storage (CCS)
#
#                                                     URL  \
# 0       https://stats.oecd.org/glossary/detail.asp?ID=1
# 1       https://stats.oecd.org/glossary/detail.asp?ID=2
# 2       https://stats.oecd.org/glossary/detail.asp?ID=3
# 3       https://stats.oecd.org/glossary/detail.asp?ID=4
# 4       https://stats.oecd.org/glossary/detail.asp?ID=5
# ...                                                 ...
# 6928  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6929  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6930  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6928  The Common Agricultural Policy (CAP) is financ...
# 6929  A popular (but misleading) term for a trading ...
# 6930  Refers to how the categories of a classificati...
# 6931  The United Nations Framework Convention on Cli...
# 6932  Carbon Capture and Storage (CCS) is a process ...
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN
# 6931  The other ?Rio Conventions?, also negotiated a...
# 6932                                                NaN
#
#                          theme  \
# 0     Environmental statistics
# 1            Health statistics
# 2            Health statistics
# 3            Health statistics
# 4            Health statistics
# ...                        ...
# 6928                       NaN
# 6929                       NaN
# 6930                       NaN
# 6931                       NaN
# 6932                       NaN
#
#                                                 related  \
# 0                                   Pollution abatement
# 1                                                   NaN
# 2                                                   NaN
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6928  Common Agricultural Policy (CAP);European Agri...
# 6929                                   Greenhouse gases
# 6930                                     Classification
# 6931  United Nations Conference on Environment and D...
# 6932                               Carbon sequestration
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6928  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6929  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6930  https://stats.oecd.org/glossary/detail.asp?ID=350
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=286
#
#                       last_update  \
# 0        Thursday, March 14, 2002
# 1     Thursday, November 22, 2001
# 2     Wednesday, October 31, 2001
# 3        Thursday, April 25, 2013
# 4        Thursday, April 25, 2013
# ...                           ...
# 6928     Wednesday, April 3, 2013
# 6929      Thursday, April 4, 2013
# 6930       Tuesday, April 9, 2013
# 6931       Friday, April 26, 2013
# 6932       Monday, April 15, 2013
#
#                                     Source Publication:  \
# 0                                                   NaN
# 1     OECD Health Data 2001: A Comparative Analysis ...
# 2     OECD Health Data 2001: A Comparative Analysis ...
# 3     OECD Health Data 2001: A Comparative Analysis ...
# 4     2001 Data Collection on Education Systems: Def...
# ...                                                 ...
# 6928  European Commission, Agriculture and Rural Dev...
# 6929  United Nations Framework Convention on Climate...
# 6930  United Nations Statistics Division, n.d. UN Gl...
# 6931  United Nations Framework Convention on Climate...
# 6932  IPCC, 2007. Climate Change 2007 - Mitigation o...
#
#                                             term tokens  \
# 0                                                  abat
# 1                           absenc from work due to ill
# 2                            activ restrict free expect
# 3                                             acut care
# 4                                         acut care bed
# ...                                                 ...
# 6928   european agricultur fund for rural develop eafrd
# 6929                                      carbon market
# 6930                                   classif structur
# 6931  unit nation framework convent on climat chang ...
# 6932                        carbon captur and storag cc
#
#                                       definition tokens  \
# 0                                       see pollut abat
# 1     absenc from work due to ill refer to the numbe...
# 2     function limit free life expect is the averag ...
# 3     acut care is on in which the princip intent is...
# 4     acut care bed ar bed accommod patient where th...
# ...                                                 ...
# 6928  the common agricultur polici cap is financ by ...
# 6929  popular but mislead term for trade system thro...
# 6930  refer to how the categori of classif ar arrang...
# 6931  the unit nation framework convent on climat ch...
# 6932  carbon captur and storag cc is process consist...
#
#                                          context tokens
# 0
# 1
# 2
# 3
# 4     acut care bed have altern been defin as bed ac...
# ...                                                 ...
# 6928
# 6929
# 6930
# 6931  the other rio convent also negoti at the unit ...
# 6932
#
# [6933 rows x 13 columns]

# %% [markdown]
# ### Read the table with the correspondence between a) Eurostat's themes and sub-themes b) OECD's Glossary themes
#
# * There may be more than one OECD's themes corresponding to a Eurostat's theme and sub-theme combination.

# %%
SQLCommand = """SELECT ESTAT_theme, ESTAT_sub_theme, OECD_themes
                FROM ESTAT.V1.Eurostat_OECD_themes """

corresp_df = pd.read_sql(SQLCommand,c)
corresp_df.replace(np.nan,value='',inplace=True)
corresp_df['OECD_themes'] = corresp_df['OECD_themes'].apply(lambda x: x.split(';'))
corresp_df.rename(columns={'OECD_themes':'OECD_theme'},inplace=True)
print(corresp_df.isnull().sum())
corresp_df
# Out:
# ESTAT_theme        0
# ESTAT_sub_theme    0
# OECD_theme         0
# dtype: int64
#                                     ESTAT_theme  \
# 0   General and regional statistics/EU policies
# 1   General and regional statistics/EU policies
# 2   General and regional statistics/EU policies
# 3   General and regional statistics/EU policies
# 4                           Economy and finance
# 5                           Economy and finance
# 6                           Economy and finance
# 7                           Economy and finance
# 8                           Economy and finance
# 9                           Economy and finance
# 10             Population and social conditions
# 11             Population and social conditions
# 12             Population and social conditions
# 13             Population and social conditions
# 14             Population and social conditions
# 15             Population and social conditions
# 16             Population and social conditions
# 17             Population and social conditions
# 18             Population and social conditions
# 19             Population and social conditions
# 20             Population and social conditions
# 21                        Industry and services
# 22                        Industry and services
# 23                        Industry and services
# 24                        Industry and services
# 25                        Industry and services
# 26                        Industry and services
# 27          Agriculture, forestry and fisheries
# 28          Agriculture, forestry and fisheries
# 29          Agriculture, forestry and fisheries
# 30                          International trade
# 31                          International trade
# 32                                    Transport
# 33                       Environment and energy
# 34                       Environment and energy
# 35      Science, technology and digital society
# 36      Science, technology and digital society
# 37                                        Other
# 38                                        Other
# 39                                        Other
# 40                                        Other
#
#                       ESTAT_sub_theme  \
# 0                    Non-EU countries
# 1                  Regions and cities
# 2       Sustainable development goals
# 3                   Policy indicators
# 4                 Balance of payments
# 5     Comparative price levels (PPPs)
# 6                     Consumer prices
# 7   Exchange rates and interest rates
# 8                  Government finance
# 9       National accounts (incl. GDP)
# 10               Asylum and migration
# 11                              Crime
# 12                            Culture
# 13             Education and training
# 14                             Health
# 15                      Labour market
# 16                  Living conditions
# 17                         Population
# 18                  Social protection
# 19                              Sport
# 20                              Youth
# 21     Short-term business statistics
# 22     Structural business statistics
# 23                 Business registers
# 24        Globalisation in businesses
# 25              Production statistics
# 26                            Tourism
# 27                        Agriculture
# 28                          Fisheries
# 29                           Forestry
# 30                              Goods
# 31                           Services
# 32
# 33                             Energy
# 34                        Environment
# 35        Digital economy and society
# 36             Science and technology
# 37                        Methodology
# 38                              Other
# 39                              Other
# 40                              Other
#
#                                            OECD_theme
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4        [Financial statistics - Balance of payments]
# 5   [Prices and purchasing power parities - Price ...
# 6   [Prices and purchasing power parities - Price ...
# 7             [Financial statistics - Exchange rates]
# 8   [Financial statistics - Government finance and...
# 9   [National accounts - Input-output tables, Nati...
# 10  [Demographic and population statistics - Migra...
# 11                    [Social and welfare statistics]
# 12                    [Social and welfare statistics]
# 13  [Education and training statistics, Education ...
# 14                                [Health statistics]
# 15  [Labour statistics, Labour statistics - Labour...
# 16                    [Social and welfare statistics]
# 17  [Demographic and population statistics - Popul...
# 18  [Social and welfare statistics - Social protec...
# 19                    [Social and welfare statistics]
# 20  [Demographic and population statistics, Social...
# 21  [Industry and services statistics, Industry an...
# 22  [Industry and services statistics, Industry an...
# 23  [Industry and services statistics, Industry an...
# 24  [Industry and services statistics, Industry an...
# 25  [Industry and services statistics, Industry an...
# 26  [Industry and services statistics, Industry an...
# 27  [Agriculture and fisheries statistics, Agricul...
# 28             [Agriculture and fisheries statistics]
# 29                                                 []
# 30                   [International trade statistics]
# 31  [International trade statistics - Internationa...
# 32                             [Transport statistics]
# 33      [Environmental statistics, Energy statistics]
# 34  [Environmental statistics, Environmental stati...
# 35         [Information and communication technology]
# 36                [Science and technology statistics]
# 37  [Methodological information (metadata), Method...
# 38                                          [Acronym]
# 39  [Non-member economies, Non-member economies - ...
# 40                                [Public management]

# %% [markdown]
# ### Insert Eurostat's themes - sub-themes information into OECD Glossary articles dataframe

# %%
OECD_df['ESTAT_theme']=pd.Series(list() for i in range(len(OECD_df)))
OECD_df['ESTAT_sub_theme']=pd.Series(list() for i in range(len(OECD_df)))
for i in range(len(OECD_df)):
    theme = OECD_df.loc[i,'theme']
    #print(theme)
    for j in range(len(corresp_df)):
        if theme in corresp_df.loc[j,'OECD_theme']:
            if corresp_df.loc[j,'ESTAT_theme'] not in OECD_df.loc[i,'ESTAT_theme']: ## avoid duplicates
                OECD_df.loc[i,'ESTAT_theme'].append(corresp_df.loc[j,'ESTAT_theme'])
            if corresp_df.loc[j,'ESTAT_sub_theme'] not in OECD_df.loc[i,'ESTAT_sub_theme']: ## avoid duplicates               
                OECD_df.loc[i,'ESTAT_sub_theme'].append(corresp_df.loc[j,'ESTAT_sub_theme'])
            

idx=OECD_df[OECD_df['ESTAT_theme'].apply(len)==0].index
OECD_df.drop(index=idx,inplace=True)
OECD_df.reset_index()
OECD_df
# Out:
#         ID                                    term  \
# 0        1                               Abatement
# 1        2        Absence from work due to illness
# 2        3  Activity restriction - free expectancy
# 3        4                              Acute care
# 4        5                         Acute care beds
# ...    ...                                     ...
# 6919  7343                    Statistical products
# 6920  7344               Statistical press release
# 6921  7345                           Press release
# 6922  7346         APW - Average Production Worker
# 6923  7347                     AW - Average Worker
#
#                                                     URL  \
# 0       https://stats.oecd.org/glossary/detail.asp?ID=1
# 1       https://stats.oecd.org/glossary/detail.asp?ID=2
# 2       https://stats.oecd.org/glossary/detail.asp?ID=3
# 3       https://stats.oecd.org/glossary/detail.asp?ID=4
# 4       https://stats.oecd.org/glossary/detail.asp?ID=5
# ...                                                 ...
# 6919  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6920  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6921  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6922  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6923  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6919  Statistical products are, generally, informati...
# 6920  Is an announcement to media of statistical pro...
# 6921                     See Statistical press release.
# 6922  An adult full-time worker directly engaged in ...
# 6923  An adult full-time worker in the private secto...
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6919  Statistical products include general-purpose t...
# 6920                                                NaN
# 6921                                                NaN
# 6922  This definition was last used in tax calculati...
# 6923                                                NaN
#
#                                       theme  \
# 0                  Environmental statistics
# 1                         Health statistics
# 2                         Health statistics
# 3                         Health statistics
# 4                         Health statistics
# ...                                     ...
# 6919  Methodological information (metadata)
# 6920  Methodological information (metadata)
# 6921  Methodological information (metadata)
# 6922   Tax policy & analysis - Taxing Wages
# 6923   Tax policy & analysis - Taxing Wages
#
#                                                 related  \
# 0                                   Pollution abatement
# 1                                                   NaN
# 2                                                   NaN
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6919                                   Statistical data
# 6920                               Statistical products
# 6921                          Statistical press release
# 6922                                                NaN
# 6923                                                NaN
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6919  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6920  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6921  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6922                                                NaN
# 6923                                                NaN
#
#                       last_update  \
# 0        Thursday, March 14, 2002
# 1     Thursday, November 22, 2001
# 2     Wednesday, October 31, 2001
# 3        Thursday, April 25, 2013
# 4        Thursday, April 25, 2013
# ...                           ...
# 6919      Monday, October 1, 2007
# 6920      Monday, October 1, 2007
# 6921                          NaN
# 6922   Thursday, January 13, 2011
# 6923   Thursday, January 13, 2011
#
#                                     Source Publication:  \
# 0                                                   NaN
# 1     OECD Health Data 2001: A Comparative Analysis ...
# 2     OECD Health Data 2001: A Comparative Analysis ...
# 3     OECD Health Data 2001: A Comparative Analysis ...
# 4     2001 Data Collection on Education Systems: Def...
# ...                                                 ...
# 6919  United States Office of Management and Budget,...
# 6920  United States Office of Management and Budget,...
# 6921                                                NaN
# 6922  OECD: The Tax/Benefits Position of Production ...
# 6923  OECD: Taxing Wages (2005-2009).OCDE: Les impôt...
#
#                       term tokens  \
# 0                            abat
# 1     absenc from work due to ill
# 2      activ restrict free expect
# 3                       acut care
# 4                   acut care bed
# ...                           ...
# 6919              statist product
# 6920         statist press releas
# 6921                 press releas
# 6922    apw averag product worker
# 6923             aw averag worker
#
#                                       definition tokens  \
# 0                                       see pollut abat
# 1     absenc from work due to ill refer to the numbe...
# 2     function limit free life expect is the averag ...
# 3     acut care is on in which the princip intent is...
# 4     acut care bed ar bed accommod patient where th...
# ...                                                 ...
# 6919  statist product ar gener inform dissemin produ...
# 6920  is an announc to media of statist product rele...
# 6921                           see statist press releas
# 6922  an adult full time worker directli engag in pr...
# 6923  an adult full time worker in the privat sector...
#
#                                          context tokens  \
# 0
# 1
# 2
# 3
# 4     acut care bed have altern been defin as bed ac...
# ...                                                 ...
# 6919  statist product includ gener purpos tabul anal...
# 6920
# 6921
# 6922  thi definit wa last us in tax calcul within th...
# 6923
#
#                              ESTAT_theme        ESTAT_sub_theme
# 0               [Environment and energy]  [Energy, Environment]
# 1     [Population and social conditions]               [Health]
# 2     [Population and social conditions]               [Health]
# 3     [Population and social conditions]               [Health]
# 4     [Population and social conditions]               [Health]
# ...                                  ...                    ...
# 6919                             [Other]          [Methodology]
# 6920                             [Other]          [Methodology]
# 6921                             [Other]          [Methodology]
# 6922               [Economy and finance]   [Government finance]
# 6923               [Economy and finance]   [Government finance]
#
# [5672 rows x 15 columns]

# %% [markdown]
# * Extract last update year and produce the second file

# %%
def my_split(x):
    if pd.isna(x):
        return []
    else:
        return x.split(';')

OECD_df['related'] = OECD_df['related'].apply(my_split)
OECD_df[["day", "month", "year"]] =OECD_df["last_update"].str.split(",", expand = True)
OECD_df['year'] =OECD_df["year"].astype(str)

OECD_df.loc[OECD_df['year'] == 'nan', 'year'] = np.nan 
OECD_df['year'].fillna(value="Not found", inplace=True)
OECD_df.reset_index(drop=True,inplace=True)
OECD_df
# Out:
#         ID                                    term  \
# 0        1                               Abatement
# 1        2        Absence from work due to illness
# 2        3  Activity restriction - free expectancy
# 3        4                              Acute care
# 4        5                         Acute care beds
# ...    ...                                     ...
# 5667  7343                    Statistical products
# 5668  7344               Statistical press release
# 5669  7345                           Press release
# 5670  7346         APW - Average Production Worker
# 5671  7347                     AW - Average Worker
#
#                                                     URL  \
# 0       https://stats.oecd.org/glossary/detail.asp?ID=1
# 1       https://stats.oecd.org/glossary/detail.asp?ID=2
# 2       https://stats.oecd.org/glossary/detail.asp?ID=3
# 3       https://stats.oecd.org/glossary/detail.asp?ID=4
# 4       https://stats.oecd.org/glossary/detail.asp?ID=5
# ...                                                 ...
# 5667  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5668  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5669  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5670  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5671  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 5667  Statistical products are, generally, informati...
# 5668  Is an announcement to media of statistical pro...
# 5669                     See Statistical press release.
# 5670  An adult full-time worker directly engaged in ...
# 5671  An adult full-time worker in the private secto...
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 5667  Statistical products include general-purpose t...
# 5668                                                NaN
# 5669                                                NaN
# 5670  This definition was last used in tax calculati...
# 5671                                                NaN
#
#                                       theme  \
# 0                  Environmental statistics
# 1                         Health statistics
# 2                         Health statistics
# 3                         Health statistics
# 4                         Health statistics
# ...                                     ...
# 5667  Methodological information (metadata)
# 5668  Methodological information (metadata)
# 5669  Methodological information (metadata)
# 5670   Tax policy & analysis - Taxing Wages
# 5671   Tax policy & analysis - Taxing Wages
#
#                                                 related  \
# 0                                 [Pollution abatement]
# 1                                                    []
# 2                                                    []
# 3     [Acute care beds, Acute care hospital staff ra...
# 4        [Acute care, Long-term care beds in hospitals]
# ...                                                 ...
# 5667                                 [Statistical data]
# 5668                             [Statistical products]
# 5669                        [Statistical press release]
# 5670                                                 []
# 5671                                                 []
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 5667  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5668  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5669  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5670                                                NaN
# 5671                                                NaN
#
#                       last_update  \
# 0        Thursday, March 14, 2002
# 1     Thursday, November 22, 2001
# 2     Wednesday, October 31, 2001
# 3        Thursday, April 25, 2013
# 4        Thursday, April 25, 2013
# ...                           ...
# 5667      Monday, October 1, 2007
# 5668      Monday, October 1, 2007
# 5669                          NaN
# 5670   Thursday, January 13, 2011
# 5671   Thursday, January 13, 2011
#
#                                     Source Publication:  \
# 0                                                   NaN
# 1     OECD Health Data 2001: A Comparative Analysis ...
# 2     OECD Health Data 2001: A Comparative Analysis ...
# 3     OECD Health Data 2001: A Comparative Analysis ...
# 4     2001 Data Collection on Education Systems: Def...
# ...                                                 ...
# 5667  United States Office of Management and Budget,...
# 5668  United States Office of Management and Budget,...
# 5669                                                NaN
# 5670  OECD: The Tax/Benefits Position of Production ...
# 5671  OECD: Taxing Wages (2005-2009).OCDE: Les impôt...
#
#                       term tokens  \
# 0                            abat
# 1     absenc from work due to ill
# 2      activ restrict free expect
# 3                       acut care
# 4                   acut care bed
# ...                           ...
# 5667              statist product
# 5668         statist press releas
# 5669                 press releas
# 5670    apw averag product worker
# 5671             aw averag worker
#
#                                       definition tokens  \
# 0                                       see pollut abat
# 1     absenc from work due to ill refer to the numbe...
# 2     function limit free life expect is the averag ...
# 3     acut care is on in which the princip intent is...
# 4     acut care bed ar bed accommod patient where th...
# ...                                                 ...
# 5667  statist product ar gener inform dissemin produ...
# 5668  is an announc to media of statist product rele...
# 5669                           see statist press releas
# 5670  an adult full time worker directli engag in pr...
# 5671  an adult full time worker in the privat sector...
#
#                                          context tokens  \
# 0
# 1
# 2
# 3
# 4     acut care bed have altern been defin as bed ac...
# ...                                                 ...
# 5667  statist product includ gener purpos tabul anal...
# 5668
# 5669
# 5670  thi definit wa last us in tax calcul within th...
# 5671
#
#                              ESTAT_theme        ESTAT_sub_theme        day  \
# 0               [Environment and energy]  [Energy, Environment]   Thursday
# 1     [Population and social conditions]               [Health]   Thursday
# 2     [Population and social conditions]               [Health]  Wednesday
# 3     [Population and social conditions]               [Health]   Thursday
# 4     [Population and social conditions]               [Health]   Thursday
# ...                                  ...                    ...        ...
# 5667                             [Other]          [Methodology]     Monday
# 5668                             [Other]          [Methodology]     Monday
# 5669                             [Other]          [Methodology]        NaN
# 5670               [Economy and finance]   [Government finance]   Thursday
# 5671               [Economy and finance]   [Government finance]   Thursday
#
#              month       year
# 0         March 14       2002
# 1      November 22       2001
# 2       October 31       2001
# 3         April 25       2013
# 4         April 25       2013
# ...            ...        ...
# 5667     October 1       2007
# 5668     October 1       2007
# 5669           NaN  Not found
# 5670    January 13       2011
# 5671    January 13       2011
#
# [5672 rows x 18 columns]

# %%
## Produce the second file



OECD_df['ESTAT_theme'] = OECD_df['ESTAT_theme'].apply(lambda x: ';'.join(x))
OECD_df['ESTAT_sub_theme'] = OECD_df['ESTAT_sub_theme'].apply(lambda x: ';'.join(x))

OECD_df['related'] = OECD_df['related'].apply(lambda x: ';'.join(x))

OECD_df.to_excel('OECD_content_for_PowerBI.xlsx')
