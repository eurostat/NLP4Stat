# %% [markdown]
# # Use Case B - Faceted search
# ***
# ## Using Eurostat themes and sub-themes to search articles from the OECD's Glossary of Statistical Terms: https://stats.oecd.org/glossary/

# %%
import pandas as pd
import numpy as np

import ipywidgets as widgets

import gensim

# %%
import datetime

def file_name(pre,ext):
    current_time = datetime.datetime.now() 
    return pre + '_'+ str(current_time.month)+ '_' + str(current_time.day) + \
                 '_' + str(current_time.hour)+ '_' + str(current_time.minute)  +'.'+ext

# %% [markdown]
# ### The data cleansing function

# %%
import re
import unicodedata as ud

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) ## NEW
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) ## NEW

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x

# %% [markdown]
# ### Create a dictionary with Eurostat's themes and sub-themes
#
# * Include some artificial ones (theme: 'Other') to match some OECD's Glossary themes.

# %%
themes = {'General and regional statistics/EU policies':
          ['Non-EU countries','Regions and cities','Sustainable development goals',
          'Policy indicators'],
          'Economy and finance': 
          ['Balance of payments','Comparative price levels (PPPs)','Consumer prices',
           'Exchange rates and interest rates','Government finance','National accounts (incl. GDP)'],
          'Population and social conditions':
          ['Asylum and migration','Crime','Culture','Education and training','Health',
           'Labour market','Living conditions','Population','Social protection','Sport','Youth'],
          'Industry and services': ['Short-term business statistics','Structural business statistics',
                                    'Business registers','Globalisation in businesses','Production statistics',
                                    'Tourism'],
          'Agriculture, forestry and fisheries':['Agriculture','Fisheries','Forestry'],
          'International trade':['Goods','Services'],
          'Transport':[],
          'Environment and energy':['Energy','Environment'],
          'Science, technology and digital society':['Digital economy and society','Science and technology'],
          'Other':['Methodology','Other']}

# %% [markdown]
# ### Read the file with OECD's terms and definitions
# * Column 'related' has the cross-references separated by semicolons and also with some invalid ones (not valid URL in 'related_URL' removed).

# %%
OECD_df = pd.read_excel('OECD_final_results_2.xlsx')
OECD_df.drop(columns=['Unnamed: 0','Cross References:','French Equivalent:','French Definition:',
                     'Glossary Output Segments:','Classification Indicator:','Version Indicator:',
                     'Created on','Source Publication:','Hyperlink:'],inplace=True)
OECD_df.rename(columns={'Term':'term','Definition:':'definition',
                        'Statistical Theme:':'theme','Cross_References_2':'related','Context:':'context',
                       'URL:Cross References':'related_URL','Last updated on':'last_update'},inplace=True)
OECD_df
# Out:
#         ID                                                URL  \
# 0        1    https://stats.oecd.org/glossary/detail.asp?ID=1
# 1        2    https://stats.oecd.org/glossary/detail.asp?ID=2
# 2        3    https://stats.oecd.org/glossary/detail.asp?ID=3
# 3        4    https://stats.oecd.org/glossary/detail.asp?ID=4
# 4        5    https://stats.oecd.org/glossary/detail.asp?ID=5
# ...    ...                                                ...
# 6934  7353  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6935  7354  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6936  7355  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6937  7356  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6938  7357  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                                    term  \
# 0                                             Abatement
# 1                      Absence from work due to illness
# 2                Activity restriction - free expectancy
# 3                                            Acute care
# 4                                       Acute care beds
# ...                                                 ...
# 6934                                                CO2
# 6935                                      Carbon market
# 6936                           Classification structure
# 6937  United Nation Framework Convention on Climate ...
# 6938                   Carbon Capture and Storage (CCS)
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6934  https://stats.oecd.org/glossary/detail.asp?ID=284
# 6935  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6936  https://stats.oecd.org/glossary/detail.asp?ID=350
# 6937  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6938  https://stats.oecd.org/glossary/detail.asp?ID=286
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6934                                                NaN
# 6935  A popular (but misleading) term for a trading ...
# 6936  Refers to how the categories of a classificati...
# 6937  The United Nations Framework Convention on Cli...
# 6938  Carbon Capture and Storage (CCS) is a process ...
#
#                          theme                  last_update  \
# 0     Environmental statistics     Thursday, March 14, 2002
# 1            Health statistics  Thursday, November 22, 2001
# 2            Health statistics  Wednesday, October 31, 2001
# 3            Health statistics     Thursday, April 25, 2013
# 4            Health statistics     Thursday, April 25, 2013
# ...                        ...                          ...
# 6934                       NaN      Thursday, April 4, 2013
# 6935                       NaN      Thursday, April 4, 2013
# 6936                       NaN       Tuesday, April 9, 2013
# 6937                       NaN       Friday, April 26, 2013
# 6938                       NaN       Monday, April 15, 2013
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6934                                                NaN
# 6935                                                NaN
# 6936                                                NaN
# 6937  The other “Rio Conventions”, also negotiated a...
# 6938                                                NaN
#
#                                                 related
# 0                                   Pollution abatement
# 1                                                   NaN
# 2                                                   NaN
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6934                               Carbon dioxide (CO2)
# 6935                                   Greenhouse gases
# 6936                                     Classification
# 6937  United Nations Conference on Environment and D...
# 6938                               Carbon sequestration
#
# [6939 rows x 9 columns]

# %% [markdown]
# * Drop records with missing values and apply data cleansing.

# %%
print(OECD_df.isnull().sum())
OECD_df.dropna(subset=['term','definition'],inplace=True)
OECD_df.reset_index(drop=True, inplace=True)
print(OECD_df.isnull().sum())

OECD_df['term'] = OECD_df['term'].apply(clean)
OECD_df['definition'] = OECD_df['definition'].apply(clean)
OECD_df['context'] = OECD_df['context'].apply(clean)
OECD_df.head(5)
# Out:
# ID                0
# URL               0
# term              4
# related_URL    4374
# definition        3
# theme            37
# last_update    1764
# context        5541
# related        4374
# dtype: int64
# ID                0
# URL               0
# term              0
# related_URL    4371
# definition        0
# theme            35
# last_update    1761
# context        5536
# related        4371
# dtype: int64
#    ID                                              URL  \
# 0   1  https://stats.oecd.org/glossary/detail.asp?ID=1
# 1   2  https://stats.oecd.org/glossary/detail.asp?ID=2
# 2   3  https://stats.oecd.org/glossary/detail.asp?ID=3
# 3   4  https://stats.oecd.org/glossary/detail.asp?ID=4
# 4   5  https://stats.oecd.org/glossary/detail.asp?ID=5
#
#                                      term  \
# 0                               Abatement
# 1        Absence from work due to illness
# 2  Activity restriction - free expectancy
# 3                              Acute care
# 4                         Acute care beds
#
#                                          related_URL  \
# 0  https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                NaN
# 2                                                NaN
# 3  https://stats.oecd.org/glossary/detail.asp?ID=...
# 4  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                           definition  \
# 0                           See Pollution abatement.
# 1  Absence from work due to illness refers to the...
# 2  Functional limitation-free life expectancy is ...
# 3  Acute care is one in which the principal inten...
# 4  Acute care beds are beds accommodating patient...
#
#                       theme                  last_update  \
# 0  Environmental statistics     Thursday, March 14, 2002
# 1         Health statistics  Thursday, November 22, 2001
# 2         Health statistics  Wednesday, October 31, 2001
# 3         Health statistics     Thursday, April 25, 2013
# 4         Health statistics     Thursday, April 25, 2013
#
#                                              context  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Acute care beds have alternatively been define...
#
#                                              related
# 0                                Pollution abatement
# 1                                                NaN
# 2                                                NaN
# 3  Acute care beds;Acute care hospital staff rati...
# 4        Acute care;Long-term care beds in hospitals

# %% [markdown]
# ### Tokenize and stem the articles terms, definitions and contexts
#
# * Also remove stop-words.
# * Create columns _term tokens_, _definition tokens_, _context tokens_.

# %%
from gensim.parsing.preprocessing import stem_text
from gensim.parsing.porter import PorterStemmer
from gensim.parsing.preprocessing import STOPWORDS
all_stopwords_gensim = STOPWORDS

p = PorterStemmer()

def text_to_words(text):
    words = str(gensim.utils.simple_preprocess(text, deacc=True))
    words = gensim.utils.tokenize(words)
    words = [word for word in words if not word in all_stopwords_gensim]
        
    words = [p.stem(token) for token in words]  
    return ' '.join(words)        

texts=list()

for i in range(len(OECD_df)):
    OECD_df.loc[i,'term tokens']=text_to_words(OECD_df.loc[i,'term'])
    OECD_df.loc[i,'definition tokens']=text_to_words(OECD_df.loc[i,'definition'])
    if not pd.isnull(OECD_df.loc[i,'context']):        
        OECD_df.loc[i,'context tokens']=text_to_words(OECD_df.loc[i,'context'])
    else:
        OECD_df.loc[i,'context tokens']=''

OECD_df
# Out:
#         ID                                                URL  \
# 0        1    https://stats.oecd.org/glossary/detail.asp?ID=1
# 1        2    https://stats.oecd.org/glossary/detail.asp?ID=2
# 2        3    https://stats.oecd.org/glossary/detail.asp?ID=3
# 3        4    https://stats.oecd.org/glossary/detail.asp?ID=4
# 4        5    https://stats.oecd.org/glossary/detail.asp?ID=5
# ...    ...                                                ...
# 6928  7352  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6929  7354  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6930  7355  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6931  7356  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  7357  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                                    term  \
# 0                                             Abatement
# 1                      Absence from work due to illness
# 2                Activity restriction - free expectancy
# 3                                            Acute care
# 4                                       Acute care beds
# ...                                                 ...
# 6928  European Agricultural Fund for Rural Developme...
# 6929                                      Carbon market
# 6930                           Classification structure
# 6931  United Nation Framework Convention on Climate ...
# 6932                   Carbon Capture and Storage (CCS)
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6928  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6929  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6930  https://stats.oecd.org/glossary/detail.asp?ID=350
# 6931  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6932  https://stats.oecd.org/glossary/detail.asp?ID=286
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6928  The Common Agricultural Policy (CAP) is financ...
# 6929  A popular (but misleading) term for a trading ...
# 6930  Refers to how the categories of a classificati...
# 6931  The United Nations Framework Convention on Cli...
# 6932  Carbon Capture and Storage (CCS) is a process ...
#
#                          theme                  last_update  \
# 0     Environmental statistics     Thursday, March 14, 2002
# 1            Health statistics  Thursday, November 22, 2001
# 2            Health statistics  Wednesday, October 31, 2001
# 3            Health statistics     Thursday, April 25, 2013
# 4            Health statistics     Thursday, April 25, 2013
# ...                        ...                          ...
# 6928                       NaN     Wednesday, April 3, 2013
# 6929                       NaN      Thursday, April 4, 2013
# 6930                       NaN       Tuesday, April 9, 2013
# 6931                       NaN       Friday, April 26, 2013
# 6932                       NaN       Monday, April 15, 2013
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN
# 6931  The other Rio Conventions, also negotiated at ...
# 6932                                                NaN
#
#                                                 related  \
# 0                                   Pollution abatement
# 1                                                   NaN
# 2                                                   NaN
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6928  Common Agricultural Policy (CAP);European Agri...
# 6929                                   Greenhouse gases
# 6930                                     Classification
# 6931  United Nations Conference on Environment and D...
# 6932                               Carbon sequestration
#
#                                             term tokens  \
# 0                                                  abat
# 1                                       absenc work ill
# 2                            activ restrict free expect
# 3                                             acut care
# 4                                         acut care bed
# ...                                                 ...
# 6928       european agricultur fund rural develop eafrd
# 6929                                      carbon market
# 6930                                   classif structur
# 6931  unit nation framework convent climat chang unfccc
# 6932                            carbon captur storag cc
#
#                                       definition tokens  \
# 0                                           pollut abat
# 1     absenc work ill refer number work dai lost yea...
# 2     function limit free life expect averag number ...
# 3     acut care princip intent follow manag labour o...
# 4     acut care bed bed accommod patient princip cli...
# ...                                                 ...
# 6928  common agricultur polici cap financ fund europ...
# 6929  popular mislead term trade countri bui sell un...
# 6930  refer categori classif arrang group sub divid ...
# 6931  unit nation framework convent climat chang unf...
# 6932  carbon captur storag cc process consist separ ...
#
#                                          context tokens
# 0
# 1
# 2
# 3
# 4     acut care bed altern defin bed accommod patien...
# ...                                                 ...
# 6928
# 6929
# 6930
# 6931  rio convent negoti unit nation confer environ ...
# 6932
#
# [6933 rows x 12 columns]

# %% [markdown]
# ### Read the file with the correspondence between a) Eurostat's themes and sub-themes b) OECD's Glossary themes
#
# * There may be more than one OECD's themes corresponding to a Eurostat's theme and sub-theme combination.

# %%
corresp_df =  pd.read_excel('themes_eurostat_oecd_v2.xlsx')
corresp_df.drop(columns=['Unnamed: 0','id'],inplace=True)
corresp_df.rename(columns={'Eurostat_Themes':'ESTAT_theme','Subthemes':'ESTAT_sub_theme','OECD_Themes':'OECD_theme'},inplace=True)
corresp_df.replace(np.nan,value='',inplace=True)
corresp_df['OECD_theme'] = corresp_df['OECD_theme'].apply(lambda x: x.split(';'))
print(corresp_df.isnull().sum())
corresp_df
# Out:
# ESTAT_theme        0
# ESTAT_sub_theme    0
# OECD_theme         0
# dtype: int64
#                                     ESTAT_theme  \
# 0   General and regional statistics/EU policies
# 1   General and regional statistics/EU policies
# 2   General and regional statistics/EU policies
# 3   General and regional statistics/EU policies
# 4                           Economy and finance
# 5                           Economy and finance
# 6                           Economy and finance
# 7                           Economy and finance
# 8                           Economy and finance
# 9                           Economy and finance
# 10             Population and social conditions
# 11             Population and social conditions
# 12             Population and social conditions
# 13             Population and social conditions
# 14             Population and social conditions
# 15             Population and social conditions
# 16             Population and social conditions
# 17             Population and social conditions
# 18             Population and social conditions
# 19             Population and social conditions
# 20             Population and social conditions
# 21                        Industry and services
# 22                        Industry and services
# 23                        Industry and services
# 24                        Industry and services
# 25                        Industry and services
# 26                        Industry and services
# 27          Agriculture, forestry and fisheries
# 28          Agriculture, forestry and fisheries
# 29          Agriculture, forestry and fisheries
# 30                          International trade
# 31                          International trade
# 32                                    Transport
# 33                       Environment and energy
# 34                       Environment and energy
# 35      Science, technology and digital society
# 36      Science, technology and digital society
# 37                                        Other
# 38                                        Other
# 39                                        Other
# 40                                        Other
#
#                       ESTAT_sub_theme  \
# 0                    Non-EU countries
# 1                  Regions and cities
# 2       Sustainable development goals
# 3                   Policy indicators
# 4                 Balance of payments
# 5     Comparative price levels (PPPs)
# 6                     Consumer prices
# 7   Exchange rates and interest rates
# 8                  Government finance
# 9       National accounts (incl. GDP)
# 10               Asylum and migration
# 11                              Crime
# 12                            Culture
# 13             Education and training
# 14                             Health
# 15                      Labour market
# 16                  Living conditions
# 17                         Population
# 18                  Social protection
# 19                              Sport
# 20                              Youth
# 21     Short-term business statistics
# 22     Structural business statistics
# 23                 Business registers
# 24        Globalisation in businesses
# 25              Production statistics
# 26                            Tourism
# 27                        Agriculture
# 28                          Fisheries
# 29                           Forestry
# 30                              Goods
# 31                           Services
# 32
# 33                             Energy
# 34                        Environment
# 35        Digital economy and society
# 36             Science and technology
# 37                        Methodology
# 38                              Other
# 39                              Other
# 40                              Other
#
#                                            OECD_theme
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4        [Financial statistics - Balance of payments]
# 5   [Prices and purchasing power parities - Price ...
# 6   [Prices and purchasing power parities - Price ...
# 7             [Financial statistics - Exchange rates]
# 8   [Financial statistics - Government finance and...
# 9   [National accounts - Input-output tables, Nati...
# 10  [Demographic and population statistics - Migra...
# 11                    [Social and welfare statistics]
# 12                    [Social and welfare statistics]
# 13  [Education and training statistics, Education ...
# 14                                [Health statistics]
# 15  [Labour statistics, Labour statistics - Labour...
# 16                    [Social and welfare statistics]
# 17  [Demographic and population statistics - Popul...
# 18  [Social and welfare statistics - Social protec...
# 19                    [Social and welfare statistics]
# 20  [Demographic and population statistics, Social...
# 21  [Industry and services statistics, Industry an...
# 22  [Industry and services statistics, Industry an...
# 23  [Industry and services statistics, Industry an...
# 24  [Industry and services statistics, Industry an...
# 25  [Industry and services statistics, Industry an...
# 26  [Industry and services statistics, Industry an...
# 27  [Agriculture and fisheries statistics, Agricul...
# 28             [Agriculture and fisheries statistics]
# 29                                                 []
# 30                   [International trade statistics]
# 31  [International trade statistics - Internationa...
# 32                             [Transport statistics]
# 33      [Environmental statistics, Energy statistics]
# 34  [Environmental statistics, Environmental stati...
# 35         [Information and communication technology]
# 36                [Science and technology statistics]
# 37  [Methodological information (metadata), Method...
# 38                                          [Acronym]
# 39  [Non-member economies, Non-member economies - ...
# 40                                [Public management]

# %% [markdown]
# ### Insert Eurostat's themes - sub-themes information into OECD Glossary articles dataframe

# %%
OECD_df['ESTAT_theme']=pd.Series(list() for i in range(len(OECD_df)))
OECD_df['ESTAT_sub_theme']=pd.Series(list() for i in range(len(OECD_df)))
for i in range(len(OECD_df)):
    theme = OECD_df.loc[i,'theme']
    #print(theme)
    for j in range(len(corresp_df)):
        if theme in corresp_df.loc[j,'OECD_theme']:
            if corresp_df.loc[j,'ESTAT_theme'] not in OECD_df.loc[i,'ESTAT_theme']: ## avoid duplicates
                OECD_df.loc[i,'ESTAT_theme'].append(corresp_df.loc[j,'ESTAT_theme'])
            if corresp_df.loc[j,'ESTAT_sub_theme'] not in OECD_df.loc[i,'ESTAT_sub_theme']: ## avoid duplicates               
                OECD_df.loc[i,'ESTAT_sub_theme'].append(corresp_df.loc[j,'ESTAT_sub_theme'])
            

idx=OECD_df[OECD_df['ESTAT_theme'].apply(len)==0].index
OECD_df.drop(index=idx,inplace=True)
OECD_df.reset_index()
OECD_df
# Out:
#         ID                                                URL  \
# 0        1    https://stats.oecd.org/glossary/detail.asp?ID=1
# 1        2    https://stats.oecd.org/glossary/detail.asp?ID=2
# 2        3    https://stats.oecd.org/glossary/detail.asp?ID=3
# 3        4    https://stats.oecd.org/glossary/detail.asp?ID=4
# 4        5    https://stats.oecd.org/glossary/detail.asp?ID=5
# ...    ...                                                ...
# 6919  7343  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6920  7344  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6921  7345  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6922  7346  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6923  7347  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                         term  \
# 0                                  Abatement
# 1           Absence from work due to illness
# 2     Activity restriction - free expectancy
# 3                                 Acute care
# 4                            Acute care beds
# ...                                      ...
# 6919                    Statistical products
# 6920               Statistical press release
# 6921                           Press release
# 6922         APW - Average Production Worker
# 6923                     AW - Average Worker
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 6919  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6920  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6921  https://stats.oecd.org/glossary/detail.asp?ID=...
# 6922                                                NaN
# 6923                                                NaN
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 6919  Statistical products are, generally, informati...
# 6920  Is an announcement to media of statistical pro...
# 6921                     See Statistical press release.
# 6922  An adult full-time worker directly engaged in ...
# 6923  An adult full-time worker in the private secto...
#
#                                       theme                  last_update  \
# 0                  Environmental statistics     Thursday, March 14, 2002
# 1                         Health statistics  Thursday, November 22, 2001
# 2                         Health statistics  Wednesday, October 31, 2001
# 3                         Health statistics     Thursday, April 25, 2013
# 4                         Health statistics     Thursday, April 25, 2013
# ...                                     ...                          ...
# 6919  Methodological information (metadata)      Monday, October 1, 2007
# 6920  Methodological information (metadata)      Monday, October 1, 2007
# 6921  Methodological information (metadata)                          NaN
# 6922   Tax policy & analysis - Taxing Wages   Thursday, January 13, 2011
# 6923   Tax policy & analysis - Taxing Wages   Thursday, January 13, 2011
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 6919  Statistical products include general-purpose t...
# 6920                                                NaN
# 6921                                                NaN
# 6922  This definition was last used in tax calculati...
# 6923                                                NaN
#
#                                                 related  \
# 0                                   Pollution abatement
# 1                                                   NaN
# 2                                                   NaN
# 3     Acute care beds;Acute care hospital staff rati...
# 4           Acute care;Long-term care beds in hospitals
# ...                                                 ...
# 6919                                   Statistical data
# 6920                               Statistical products
# 6921                          Statistical press release
# 6922                                                NaN
# 6923                                                NaN
#
#                      term tokens  \
# 0                           abat
# 1                absenc work ill
# 2     activ restrict free expect
# 3                      acut care
# 4                  acut care bed
# ...                          ...
# 6919             statist product
# 6920        statist press releas
# 6921                press releas
# 6922   apw averag product worker
# 6923            aw averag worker
#
#                                       definition tokens  \
# 0                                           pollut abat
# 1     absenc work ill refer number work dai lost yea...
# 2     function limit free life expect averag number ...
# 3     acut care princip intent follow manag labour o...
# 4     acut care bed bed accommod patient princip cli...
# ...                                                 ...
# 6919  statist product gener inform dissemin product ...
# 6920  announc media statist product releas contain t...
# 6921                               statist press releas
# 6922  adult time worker directli engag product activ...
# 6923  adult time worker privat sector wage earn equa...
#
#                                          context tokens  \
# 0
# 1
# 2
# 3
# 4     acut care bed altern defin bed accommod patien...
# ...                                                 ...
# 6919  statist product includ gener purpos tabul anal...
# 6920
# 6921
# 6922  definit tax calcul tax wage public averag work...
# 6923
#
#                              ESTAT_theme        ESTAT_sub_theme
# 0               [Environment and energy]  [Energy, Environment]
# 1     [Population and social conditions]               [Health]
# 2     [Population and social conditions]               [Health]
# 3     [Population and social conditions]               [Health]
# 4     [Population and social conditions]               [Health]
# ...                                  ...                    ...
# 6919                             [Other]          [Methodology]
# 6920                             [Other]          [Methodology]
# 6921                             [Other]          [Methodology]
# 6922               [Economy and finance]   [Government finance]
# 6923               [Economy and finance]   [Government finance]
#
# [5672 rows x 14 columns]

# %%
def my_split(x):
    if pd.isna(x):
        return []
    else:
        return x.split(';')

OECD_df['related'] = OECD_df['related'].apply(my_split)
OECD_df[["day", "month", "year"]] =OECD_df["last_update"].str.split(",", expand = True)
OECD_df['year'] =OECD_df["year"].astype(str)

OECD_df.loc[OECD_df['year'] == 'nan', 'year'] = np.nan 

OECD_df['year'].fillna(value="Not found", inplace=True)
OECD_df.reset_index(drop=True,inplace=True)
OECD_df
# Out:
#         ID                                                URL  \
# 0        1    https://stats.oecd.org/glossary/detail.asp?ID=1
# 1        2    https://stats.oecd.org/glossary/detail.asp?ID=2
# 2        3    https://stats.oecd.org/glossary/detail.asp?ID=3
# 3        4    https://stats.oecd.org/glossary/detail.asp?ID=4
# 4        5    https://stats.oecd.org/glossary/detail.asp?ID=5
# ...    ...                                                ...
# 5667  7343  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5668  7344  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5669  7345  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5670  7346  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5671  7347  https://stats.oecd.org/glossary/detail.asp?ID=...
#
#                                         term  \
# 0                                  Abatement
# 1           Absence from work due to illness
# 2     Activity restriction - free expectancy
# 3                                 Acute care
# 4                            Acute care beds
# ...                                      ...
# 5667                    Statistical products
# 5668               Statistical press release
# 5669                           Press release
# 5670         APW - Average Production Worker
# 5671                     AW - Average Worker
#
#                                             related_URL  \
# 0     https://stats.oecd.org/glossary/detail.asp?ID=...
# 1                                                   NaN
# 2                                                   NaN
# 3     https://stats.oecd.org/glossary/detail.asp?ID=...
# 4     https://stats.oecd.org/glossary/detail.asp?ID=...
# ...                                                 ...
# 5667  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5668  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5669  https://stats.oecd.org/glossary/detail.asp?ID=...
# 5670                                                NaN
# 5671                                                NaN
#
#                                              definition  \
# 0                              See Pollution abatement.
# 1     Absence from work due to illness refers to the...
# 2     Functional limitation-free life expectancy is ...
# 3     Acute care is one in which the principal inten...
# 4     Acute care beds are beds accommodating patient...
# ...                                                 ...
# 5667  Statistical products are, generally, informati...
# 5668  Is an announcement to media of statistical pro...
# 5669                     See Statistical press release.
# 5670  An adult full-time worker directly engaged in ...
# 5671  An adult full-time worker in the private secto...
#
#                                       theme                  last_update  \
# 0                  Environmental statistics     Thursday, March 14, 2002
# 1                         Health statistics  Thursday, November 22, 2001
# 2                         Health statistics  Wednesday, October 31, 2001
# 3                         Health statistics     Thursday, April 25, 2013
# 4                         Health statistics     Thursday, April 25, 2013
# ...                                     ...                          ...
# 5667  Methodological information (metadata)      Monday, October 1, 2007
# 5668  Methodological information (metadata)      Monday, October 1, 2007
# 5669  Methodological information (metadata)                          NaN
# 5670   Tax policy & analysis - Taxing Wages   Thursday, January 13, 2011
# 5671   Tax policy & analysis - Taxing Wages   Thursday, January 13, 2011
#
#                                                 context  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Acute care beds have alternatively been define...
# ...                                                 ...
# 5667  Statistical products include general-purpose t...
# 5668                                                NaN
# 5669                                                NaN
# 5670  This definition was last used in tax calculati...
# 5671                                                NaN
#
#                                                 related  \
# 0                                 [Pollution abatement]
# 1                                                    []
# 2                                                    []
# 3     [Acute care beds, Acute care hospital staff ra...
# 4        [Acute care, Long-term care beds in hospitals]
# ...                                                 ...
# 5667                                 [Statistical data]
# 5668                             [Statistical products]
# 5669                        [Statistical press release]
# 5670                                                 []
# 5671                                                 []
#
#                      term tokens  \
# 0                           abat
# 1                absenc work ill
# 2     activ restrict free expect
# 3                      acut care
# 4                  acut care bed
# ...                          ...
# 5667             statist product
# 5668        statist press releas
# 5669                press releas
# 5670   apw averag product worker
# 5671            aw averag worker
#
#                                       definition tokens  \
# 0                                           pollut abat
# 1     absenc work ill refer number work dai lost yea...
# 2     function limit free life expect averag number ...
# 3     acut care princip intent follow manag labour o...
# 4     acut care bed bed accommod patient princip cli...
# ...                                                 ...
# 5667  statist product gener inform dissemin product ...
# 5668  announc media statist product releas contain t...
# 5669                               statist press releas
# 5670  adult time worker directli engag product activ...
# 5671  adult time worker privat sector wage earn equa...
#
#                                          context tokens  \
# 0
# 1
# 2
# 3
# 4     acut care bed altern defin bed accommod patien...
# ...                                                 ...
# 5667  statist product includ gener purpos tabul anal...
# 5668
# 5669
# 5670  definit tax calcul tax wage public averag work...
# 5671
#
#                              ESTAT_theme        ESTAT_sub_theme        day  \
# 0               [Environment and energy]  [Energy, Environment]   Thursday
# 1     [Population and social conditions]               [Health]   Thursday
# 2     [Population and social conditions]               [Health]  Wednesday
# 3     [Population and social conditions]               [Health]   Thursday
# 4     [Population and social conditions]               [Health]   Thursday
# ...                                  ...                    ...        ...
# 5667                             [Other]          [Methodology]     Monday
# 5668                             [Other]          [Methodology]     Monday
# 5669                             [Other]          [Methodology]        NaN
# 5670               [Economy and finance]   [Government finance]   Thursday
# 5671               [Economy and finance]   [Government finance]   Thursday
#
#              month       year
# 0         March 14       2002
# 1      November 22       2001
# 2       October 31       2001
# 3         April 25       2013
# 4         April 25       2013
# ...            ...        ...
# 5667     October 1       2007
# 5668     October 1       2007
# 5669           NaN  Not found
# 5670    January 13       2011
# 5671    January 13       2011
#
# [5672 rows x 17 columns]

# %% [markdown]
# ### Produce also file for input to Power BI

# %%
OECD_content = OECD_df.copy()
OECD_content['ESTAT_theme'] = OECD_content['ESTAT_theme'].apply(lambda x: ';'.join(x))
OECD_content['ESTAT_sub_theme'] = OECD_content['ESTAT_sub_theme'].apply(lambda x: ';'.join(x))
OECD_content
OECD_content.to_excel('OECD_content.xlsx')

# %% [markdown]
# ## Facets
# ***
# ### The function filtering the results.

# %%
df1 = None

def articles(Top_articles, Keywords, themes_dd, sub_themes_dd,year,related): 

    global df1
    
    Keywords = text_to_words(Keywords) 
    df1=OECD_df[OECD_df['term tokens'].str.contains(Keywords,regex=False) | OECD_df['definition tokens'].str.contains(Keywords,regex=False) | OECD_df['context tokens'].str.contains(Keywords,regex=False)]

    if year != "All years":    
        df1 = df1[df1['year'].str.contains(year)]    
        
        
    if themes_dd != "All themes":
        #df1 = df1[df1['ESTAT_theme'].str.contains(themes_dd,regex=False)]
        df1=df1[df1['ESTAT_theme'].apply(lambda x: themes_dd in x)]
        

    if sub_themes_dd is not None:
        if sub_themes_dd != "All sub-themes" and sub_themes_dd != "":    
            #df1 = df1[df1['ESTAT_sub_theme'].str.contains(sub_themes_dd,regex=False)]
            df1=df1[df1['ESTAT_sub_theme'].apply(lambda x: sub_themes_dd in x)]

    if len(df1) == 0:
        print("No matches found")
    else:
        df1.reset_index(inplace=True)
        print(df1.term.count()," articles found")
        h = ''
        for i in range(min(Top_articles,len(df1))):
            l,n = df1.loc[i,["URL","term"]].values
            h += '<br/><u><a href="' + l + '" target="_blank">'+ n + '</a></u>'
            if related:
                h += '<blockquote>Related links:'
                if len(df1.loc[i,"related"]) > 0:
                    # print(df1.loc[i,"related"])
                    #print(len(df1.loc[i,"related"]))
                    #if not np.isnan(df1.loc[i,"related"]):
                    for k in range(len(df1.loc[i,"related"])):
                        #print(df1.loc[i,"related"])
                        title = df1.loc[i,"related"][k]
                        url = df1.loc[i,"related_URL"][k]
                        h += '<br><a href="' + url + '" target="_blank">'+ title + '</a>'
                else:
                    h += ' None'
                h += '</blockquote>'
        display(HTML( h))

# %% [markdown]
# ### The widgets.

# %%
from IPython.display import display
from ipywidgets import HTML
layout = widgets.Layout(width='500px', height='30px')

# %%
def query_build2(themes):
    style = {'description_width': 'initial'}
      
    
    
    themes_dd = widgets.Dropdown(
        description='Select theme:',
        options=['All themes']+sorted([k for k in themes.keys()]),
        style=style
    )    
    

    def on_change_theme(change):
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'All themes':
                sub_themes_dd.options = []
            else:    
                sub_themes_dd.options = ['All sub-themes']+themes[themes_dd.value]
                
                

    themes_dd.observe(on_change_theme)
    
    sub_themes_dd = widgets.Dropdown(
        description='Select sub-theme:',
        options= [''],
        style=style
    )    
    

 
   

    Top_articles = widgets.IntSlider(
        description='Display',
        tooltip='maximum:',
        value=50,
        min=1, 
        max = 200,
        style={'description_width': 'initial'}
    )


    Keywords = widgets.Text(
        value='',
        placeholder='Type something',
        description='Keywords:',
        disabled=False
    )
    

    year = widgets.Dropdown(
        options=['All years','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','Not found'],
        value='All years',
        description='Year:',
        disabled=False)


    
    related = widgets.Checkbox(
        value=False,
        description='Show related links',
        disabled=False,
        indent=True
     )    
    
    out = widgets.interactive_output(articles, {'Top_articles': Top_articles, 'Keywords': Keywords,'themes_dd':themes_dd,'sub_themes_dd':sub_themes_dd,'year':year,'related':related})


    left_box = widgets.VBox([themes_dd, sub_themes_dd])
    right_box = widgets.VBox([Keywords,related])
    box = widgets.HBox([left_box, right_box])
    display(box)
    
    display(year,Top_articles,out)
    
        

query_build2(themes)
# Out:
# HBox(children=(VBox(children=(Dropdown(description='Select theme:', options=('All themes', 'Agriculture, fores…
# Dropdown(description='Year:', options=('All years', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2…
# IntSlider(value=50, description='Display', max=200, min=1, style=SliderStyle(description_width='initial'))
# Output()
