# %% [markdown]
# # Use Case A - Faceted search
# ***
# ### In the Statistics Explained articles using also themes, sub-themes and categories
#
# ### Adjusted (May 2022) to read all related resources from the Knowledge Database (and not only related SE articles)
#
# ### Installation instructions
#
# * This is a Google Colab notebook. You must have a Google account. Please allow access to your Google Drive.
# * Launch the notebook and put your own credentials in the chunk with title "Connect to the Virtuoso database".

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyodbc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyodbc in /usr/local/lib/python3.7/dist-packages (4.0.32)

# %%
# !pip install SPARQLWrapper
# !pip install sparql_dataframe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper) (6.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (4.11.3)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper) (4.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib>=6.1.1->SPARQLWrapper) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sparql_dataframe in /usr/local/lib/python3.7/dist-packages (0.4)
# Requirement already satisfied: SPARQLWrapper>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from sparql_dataframe) (2.0.0)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from sparql_dataframe) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->sparql_dataframe) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.22.0->sparql_dataframe) (1.15.0)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.7/dist-packages (from SPARQLWrapper>=1.8.1->sparql_dataframe) (6.1.1)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (0.6.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (4.11.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (3.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=6.1.1->SPARQLWrapper>=1.8.1->sparql_dataframe) (3.8.0)

# %%
# !apt-get install virtuoso-opensource
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# virtuoso-opensource is already the newest version (6.1.6+repack-0ubuntu9).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
import pandas as pd
import numpy as np

import ipywidgets as widgets

import pyodbc
import gensim

import os 
import re
import logging
import sys
import hashlib
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, POST, DIGEST, GET
from SPARQLWrapper import JSON, INSERT, DELETE
import sparql_dataframe

# %% [markdown]
# ### The data cleansing function

# %%
import re
import unicodedata as ud

def clean(x, quotes=True):
    if pd.isnull(x): return x  
    x = x.strip()
    
    ## make letter-question mark-letter -> letter-quote-space-letter !!! but NOT in the lists of URLs!!!
    if quotes:
        x = re.sub(r'([A-Za-z])\?([A-Za-z])','\\1\' \\2',x) ## NEW
    
    ## make letter-question mark-space lower case letter letter-quote-space letter
    x = re.sub(r'([A-Za-z])\? ([a-z])','\\1\' \\2',x) ## NEW

    ## delete ,000 commas in numbers    
    x = re.sub(r'\b(\d+),(\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## delete  000 spaces in numbers
    x = re.sub(r'\b(\d+) (\d+)\b','\\1\\2',x) ## CORRECTED
    
    ## remove more than one spaces
    x = re.sub(r' +', ' ',x)
    
    ## remove start and end spaces
    x = re.sub(r'^ +| +$', '',x,flags=re.MULTILINE) 
    
    ## space-comma -> comma
    x = re.sub(r' \,',',',x)
    
    ## space-dot -> dot
    x = re.sub(r' \.','.',x)
    
    #x = x.encode('latin1').decode('utf-8') ## â\x80\x99
    x = ud.normalize('NFKD',x).encode('ascii', 'ignore').decode()
    
    return x

# %% [markdown]
# ###Connect to the Virtuoso database

# %%
user = 'xxxxx'
passw = 'xxxxx'

# %%
c = pyodbc.connect('DRIVER=/usr/lib/odbc/virtodbc.so;HOST=lod.csd.auth.gr:1111;UID='+user+';PWD='+passw+';DATABASE=ESTAT')

# %%
#set encoding
c.setdecoding(pyodbc.SQL_CHAR, encoding='latin-1')
c.setencoding(encoding="latin-1")
cursor = c.cursor()

# %%
def load_table(cursor,query):
  cursor.execute(query)
  t1 = cursor.fetchall()
  df = pd.DataFrame.from_records(t1, columns=[x[0] for x in cursor.description])
  return df

# %%
def connect_virtuoso(DSN, UID, PWD):

    sparql = SPARQLWrapper(DSN)
    sparql.setHTTPAuth(DIGEST)
    sparql.setCredentials(UID, PWD)
    sparql.setMethod(GET)

    return sparql

# Connection to the KDB 
endpoint = "http://lod.csd.auth.gr:8890/sparql/"
sparql = connect_virtuoso(endpoint,user,passw)

# %% [markdown]
# ## A. Import Statistics Explained data from the database
# ***
#
# * Id, context and last update from table dat_article.
# * Title and url from table dat_link_info, on matching id and resource_information_id=1 (i.e. Eurostat).
# * Abstract from field content in table dat_article_paragraph, on matching article_id and abstract=1 ("yes").
# * Apply data cleansing.

# %%
query =      """SELECT T1.id, T1.context, T1.last_update, T2.title, T2.url, T3.content 
                FROM ESTAT.V1.dat_article as T1 
                INNER JOIN ESTAT.V1.dat_link_info as T2  
                  ON T1.id=T2.id  
                INNER JOIN ESTAT.V1.dat_article_paragraph as T3  
                  ON T2.id=T3.article_id  
                WHERE T2.resource_information_id=1 AND T3.abstract=1"""

SE_df = load_table(cursor,query)
SE_df.rename(columns={'content':'abstract'},inplace=True)
SE_df = SE_df[['id','context','title','abstract','url','last_update']]

SE_df['context'] = SE_df['context'].apply(clean)
SE_df['title'] = SE_df['title'].apply(clean)
SE_df['title'] = SE_df['title'].apply(lambda x: re.sub(r'\?','-',x)) ## also replace question marks by dashes in titles
SE_df['abstract'] = SE_df['abstract'].apply(clean)

SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00

# %% [markdown]
# ### Paragraph titles and contents
#
# * From the dat_article_paragraph table with abstract=0 and matching article_id.
# * Apply data cleansing.

# %%
query =      """SELECT article_id, title, content 
                FROM ESTAT.V1.dat_article_paragraph
                WHERE abstract=0 AND article_id IN (SELECT id FROM ESTAT.V1.dat_article) """

add_content = load_table(cursor,query)
add_content.sort_values(by=['article_id'],inplace=True)
add_content['title'] = add_content['title'].apply(clean)
add_content['content'] = add_content['content'].apply(clean)
add_content.head(5)
# Out:
#     article_id                         title  \
# 9            7           Number of accidents
# 10           7               Incidence rates
# 11           7  Standardised incidence rates
# 12           7          Analysis by activity
# 13           7    Analysis by type of injury
#
#                                               content
# 9   In 2018, there were 3.1 million non-fatal acci...
# 10  An alternative way to analyse the information ...
# 11  When comparing data between countries, inciden...
# 12  As noted above, one of the main reasons why th...
# 13  Figure 6 presents an analysis of data accordin...

# %% [markdown]
# ### Aggregate the above paragraph titles and contents
#
# * Create a column _raw content_ which gathers all paragraph titles and contents in one text per article.

# %%
add_content_grouped = add_content.groupby(['article_id'])[['title','content']].aggregate(lambda x: list(x))
add_content_grouped.reset_index(drop=False, inplace=True)
for i in range(len(add_content_grouped)):
    add_content_grouped.loc[i,'raw content'] = ''
    for (a,b) in zip(add_content_grouped.loc[i,'title'],add_content_grouped.loc[i,'content']):
        add_content_grouped.loc[i,'raw content'] += ' '+a + ' ' + b
add_content_grouped = add_content_grouped[['article_id','raw content']]    

add_content_grouped.head(5)
# Out:
#    article_id                                        raw content
# 0           7   Number of accidents In 2018, there were 3.1 m...
# 1          13   Household consumption Consumption expenditure...
# 2          16   Suicides on railways Suicides occurring on th...
# 3          17   Geographical location plays a key role in the...
# 4          18   Number of passengers transported by rail incr...

# %% [markdown]
# ### Merge the raw content of the SE articles with the main file

# %%
SE_df = pd.merge(SE_df,add_content_grouped,left_on='id',right_on='article_id',how='inner')
SE_df.drop(['article_id'],axis=1,inplace=True)

SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url         last_update  \
# 0  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3  https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
#
#                                          raw content
# 0   Number of accidents In 2018, there were 3.1 m...
# 1   Household consumption Consumption expenditure...
# 2   Suicides on railways Suicides occurring on th...
# 3   Geographical location plays a key role in the...
# 4   Number of passengers transported by rail incr...

# %%
del(add_content_grouped)

# %% [markdown]
# ## B. Read categories from the database
# ***

# %%
import ast

query =      """SELECT article_id, categories 
                FROM ESTAT.V1.SE_articles_categories """

categories = load_table(cursor,query)
categories['categories']=categories['categories'].apply(ast.literal_eval)
categories
# Out:
#      article_id                                         categories
# 0             7  [Accidents at work, Health, Health and safety,...
# 1            13  [National accounts (incl. GDP), Statistical ar...
# 2            16  [Rail, Statistical article, Transport, Transpo...
# 3            17    [Freight, Rail, Statistical article, Transport]
# 4            18  [Passengers, Rail, Statistical article, Transp...
# ..          ...                                                ...
# 600        9472  [International trade, Trade in goods, Trade in...
# 601        9477              [Trade in goods, Statistical article]
# 602        9479  [Trade in goods, Statistical article, Internat...
# 603        9492  [Household composition and family situation, L...
# 604        9911    [Employment, Labour market, Background article]
#
# [605 rows x 2 columns]

# %% [markdown]
# ### Merge with the main file

# %%
SE_df = pd.merge(SE_df,categories,left_on='id',right_on='article_id',how='inner')
SE_df
# Out:
#        id                                            context  \
# 0       7  A safe, healthy working environment is a cruci...
# 1      13  European institutions, governments, central ba...
# 2      16  National rail networks have different technica...
# 3      17  The content of this statistical article is bas...
# 4      18  The content of this statistical article is bas...
# ..    ...                                                ...
# 600  9472  Trade is an important indicator of Europeas pr...
# 601  9477  Trade is an important indicator of Europeas pr...
# 602  9479  Trade is an important indicator of Europeas pr...
# 603  9492  In addition to the Labour Force Survey (LFS), ...
# 604  9911  The COVID-19 health crisis hit Europe in Janua...
#
#                                                  title  \
# 0                         Accidents at work statistics
# 1                            National accounts and GDP
# 2                  Railway safety statistics in the EU
# 3                 Railway freight transport statistics
# 4    Railway passenger transport statistics - quart...
# ..                                                 ...
# 600              EU trade in COVID-19 related products
# 601  EU international trade in goods - latest devel...
# 602                          EU and main world traders
# 603  Age of young people leaving their parental hou...
# 604  Sample size and non-response - quarterly stati...
#
#                                               abstract  \
# 0    This article presents a set of main statistica...
# 1    National accounts are the source for a multitu...
# 2    In 2019, 1516 significant railway accidents we...
# 3    This article focuses on recent rail freight tr...
# 4    This article takes a look at recent annual and...
# ..                                                 ...
# 600  To help prevent the spread of the COVID-19 pan...
# 601  This article provides a picture of the interna...
# 602  International trade a especially the size and ...
# 603  Leaving the parental home is considered as a m...
# 604  The global spread of Sars-CoV-2 at the beginni...
#
#                                                    url         last_update  \
# 0    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-26 16:06:00
# 1    https://ec.europa.eu/eurostat/statistics-expla... 2021-06-28 16:29:00
# 2    https://ec.europa.eu/eurostat/statistics-expla... 2021-06-25 18:31:00
# 3    https://ec.europa.eu/eurostat/statistics-expla... 2020-11-27 18:19:00
# 4    https://ec.europa.eu/eurostat/statistics-expla... 2021-07-07 10:30:00
# ..                                                 ...                 ...
# 600  https://ec.europa.eu/eurostat/statistics-expla... 2021-03-31 13:04:00
# 601  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-02 16:55:00
# 602  https://ec.europa.eu/eurostat/statistics-expla... 2020-10-07 15:19:00
# 603  https://ec.europa.eu/eurostat/statistics-expla... 2021-06-30 14:54:00
# 604  https://ec.europa.eu/eurostat/statistics-expla... 2021-07-02 11:24:00
#
#                                            raw content  article_id  \
# 0     Number of accidents In 2018, there were 3.1 m...           7
# 1     Household consumption Consumption expenditure...          13
# 2     Suicides on railways Suicides occurring on th...          16
# 3     Geographical location plays a key role in the...          17
# 4     Number of passengers transported by rail incr...          18
# ..                                                 ...         ...
# 600   Sharp increase in COVID-19 related imports in...        9472
# 601   Extra-EU trade by product: Strongest fluctuat...        9477
# 602   Main world traders: EU, USA and China In 2019...        9479
# 603   Geographical differences Map 1 indicates that...        9492
# 604   In the third quarter of 2020, the unit non-re...        9911
#
#                                             categories
# 0    [Accidents at work, Health, Health and safety,...
# 1    [National accounts (incl. GDP), Statistical ar...
# 2    [Rail, Statistical article, Transport, Transpo...
# 3      [Freight, Rail, Statistical article, Transport]
# 4    [Passengers, Rail, Statistical article, Transp...
# ..                                                 ...
# 600  [International trade, Trade in goods, Trade in...
# 601              [Trade in goods, Statistical article]
# 602  [Trade in goods, Statistical article, Internat...
# 603  [Household composition and family situation, L...
# 604    [Employment, Labour market, Background article]
#
# [605 rows x 9 columns]

# %%
del(categories)

# %% [markdown]
# ### Exract last update year
#
# * And check missing values.

# %%
SE_df['new_date'] = [d.date() for d in SE_df['last_update']]  
SE_df['year'] = SE_df['last_update'].dt.year
SE_df['year'] =SE_df["year"].astype(str)

SE_df.replace('', np.nan, inplace=True)

SE_df['year'].fillna(value="Not found", inplace=True)

print(SE_df.isnull().sum(),'\n')

SE_df.reset_index(drop=True,inplace=True)
SE_df.drop(columns=['last_update','new_date'],inplace=True)
SE_df.head(5)
# Out:
# id              0
# context        64
# title           0
# abstract        9
# url             0
# last_update     0
# raw content     0
# article_id      0
# categories      0
# new_date        0
# year            0
# dtype: int64
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url  \
# 0  https://ec.europa.eu/eurostat/statistics-expla...
# 1  https://ec.europa.eu/eurostat/statistics-expla...
# 2  https://ec.europa.eu/eurostat/statistics-expla...
# 3  https://ec.europa.eu/eurostat/statistics-expla...
# 4  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                          raw content  article_id  \
# 0   Number of accidents In 2018, there were 3.1 m...           7
# 1   Household consumption Consumption expenditure...          13
# 2   Suicides on railways Suicides occurring on th...          16
# 3   Geographical location plays a key role in the...          17
# 4   Number of passengers transported by rail incr...          18
#
#                                           categories  year
# 0  [Accidents at work, Health, Health and safety,...  2020
# 1  [National accounts (incl. GDP), Statistical ar...  2021
# 2  [Rail, Statistical article, Transport, Transpo...  2021
# 3    [Freight, Rail, Statistical article, Transport]  2020
# 4  [Passengers, Rail, Statistical article, Transp...  2021

# %% [markdown]
# ## C. Add themes / sub-themes information in the articles
# ***
#
# * We create dictionary _themes_ manually.
# * Dictionary _dict_categories_ is used for debugging. The keys are the categories found in the SE articles and the values are the corresponding article ids.
# * Each article will have a list of themes and corresponding sub-themes, potentially empty. If an article has a category which is a key of _themes_ the theme is added to the first list. If it has a category which is in one of the values of _themes_ i.e. it is a sub-theme, the corresponding key (theme) is added to the first list and the sub-theme is added to the second list.
# * There are relatively few articles without such information, see below.

# %%
import ast

themes = {'General and regional statistics/EU policies':
          ['Non-EU countries','Regions and cities','Sustainable development goals',
          'Policy indicators'],
          'Economy and finance': 
          ['Balance of payments','Comparative price levels (PPPs)','Consumer prices',
           'Exchange rates and interest rates','Government finance','National accounts (incl. GDP)'],
          'Population and social conditions':
          ['Asylum and migration','Crime','Culture','Education and training','Health',
           'Labour market','Living conditions','Population','Social protection','Sport','Youth'],
          'Industry and services': ['Short-term business statistics','Structural business statistics',
                                    'Business registers','Globalisation in businesses','Production statistics',
                                    'Tourism'],
          'Agriculture, forestry and fisheries':['Agriculture','Fisheries','Forestry'],
          'International trade':['Goods','Services'],
          'Transport':[],
          'Environment and energy':['Energy','Environment'],
          'Science, technology and digital society':['Digital economy and society','Science and technology']}

dict_categories=dict()

for i in range(len(SE_df)):
    
    cats=SE_df.loc[i,'categories']
    cats = [cat.strip() for cat in cats]
        
    for cat in cats:
        if cat in dict_categories.keys():
            dict_categories[cat].append(SE_df.loc[i,'id'])
        else:
            dict_categories[cat] = [SE_df.loc[i,'id']]



SE_df['themes'] = pd.Series([set() for i in range(len(SE_df))])
SE_df['sub_themes'] = pd.Series([set() for i in range(len(SE_df))])
for i in range(len(SE_df)):
    
    cats=SE_df.loc[i,'categories']
    cats = [cat.strip() for cat in cats]

    for cat in cats:
        if cat in themes.keys():
            SE_df.loc[i,'themes'].add(cat)
        else:
            for theme in themes.keys():
                if cat in themes[theme]:
                    SE_df.loc[i,'themes'].add(theme)
                    SE_df.loc[i,'sub_themes'].add(cat)
    
SE_df['themes'] = SE_df['themes'].apply(lambda x: ';'.join(x))    
SE_df['sub_themes'] = SE_df['sub_themes'].apply(lambda x: ';'.join(x))    

#SE_df['categories']= SE_df['categories'].apply(lambda x: ';'.join(x))  ## de-comment to produce the input file for R Shiny, 
## i.e. categories not in list but separated by semicolon    

print(SE_df.isnull().sum(),'\n')

print('No info in themes: ',sum(SE_df['themes']==''))
print('No info in sub_themes: ',sum(SE_df['sub_themes']==''))

#SE_df.sort_values(by=['title'],inplace=True)

SE_df.head(5)
# Out:
# id              0
# context        64
# title           0
# abstract        9
# url             0
# raw content     0
# article_id      0
# categories      0
# year            0
# themes          0
# sub_themes      0
# dtype: int64
#
# No info in themes:  49
# No info in sub_themes:  85
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url  \
# 0  https://ec.europa.eu/eurostat/statistics-expla...
# 1  https://ec.europa.eu/eurostat/statistics-expla...
# 2  https://ec.europa.eu/eurostat/statistics-expla...
# 3  https://ec.europa.eu/eurostat/statistics-expla...
# 4  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                          raw content  article_id  \
# 0   Number of accidents In 2018, there were 3.1 m...           7
# 1   Household consumption Consumption expenditure...          13
# 2   Suicides on railways Suicides occurring on th...          16
# 3   Geographical location plays a key role in the...          17
# 4   Number of passengers transported by rail incr...          18
#
#                                           categories  year  \
# 0  [Accidents at work, Health, Health and safety,...  2020
# 1  [National accounts (incl. GDP), Statistical ar...  2021
# 2  [Rail, Statistical article, Transport, Transpo...  2021
# 3    [Freight, Rail, Statistical article, Transport]  2020
# 4  [Passengers, Rail, Statistical article, Transp...  2021
#
#                              themes                     sub_themes
# 0  Population and social conditions           Health;Labour market
# 1               Economy and finance  National accounts (incl. GDP)
# 2                         Transport
# 3                         Transport
# 4                         Transport

# %% [markdown]
# ## D. Tokenize and stem the articles titles, contexts, abstracts and contents
# ***
#
# * Also remove stop-words.
# * Create columns _title tokens_, _context tokens_, _abstract tokens_, _raw content tokens_.

# %%
#Stemming.

from gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import stem_text
from gensim.parsing.porter import PorterStemmer

p = PorterStemmer()

def text_to_words(text):
    words = str(gensim.utils.simple_preprocess(text, deacc=True))
    words = remove_stopwords(words) 
    words = gensim.utils.tokenize(words)
        
    words = [p.stem(token) for token in words] 
    
    return ' '.join(words)        

for i in range(len(SE_df)):
    SE_df.loc[i,'title tokens']=text_to_words(SE_df.loc[i,'title'])
    if not pd.isnull(SE_df.loc[i,'context']):
        SE_df.loc[i,'context tokens']=text_to_words(SE_df.loc[i,'context'])
    else:
        SE_df.loc[i,'context tokens']=''
    if not pd.isnull(SE_df.loc[i,'abstract']):        
        SE_df.loc[i,'abstract tokens']=text_to_words(SE_df.loc[i,'abstract'])
    else:
        SE_df.loc[i,'abstract tokens']=''
    SE_df.loc[i,'raw content tokens']=text_to_words(SE_df.loc[i,'raw content'])


SE_df.head(5)
# Out:
#    id                                            context  \
# 0   7  A safe, healthy working environment is a cruci...
# 1  13  European institutions, governments, central ba...
# 2  16  National rail networks have different technica...
# 3  17  The content of this statistical article is bas...
# 4  18  The content of this statistical article is bas...
#
#                                                title  \
# 0                       Accidents at work statistics
# 1                          National accounts and GDP
# 2                Railway safety statistics in the EU
# 3               Railway freight transport statistics
# 4  Railway passenger transport statistics - quart...
#
#                                             abstract  \
# 0  This article presents a set of main statistica...
# 1  National accounts are the source for a multitu...
# 2  In 2019, 1516 significant railway accidents we...
# 3  This article focuses on recent rail freight tr...
# 4  This article takes a look at recent annual and...
#
#                                                  url  \
# 0  https://ec.europa.eu/eurostat/statistics-expla...
# 1  https://ec.europa.eu/eurostat/statistics-expla...
# 2  https://ec.europa.eu/eurostat/statistics-expla...
# 3  https://ec.europa.eu/eurostat/statistics-expla...
# 4  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                          raw content  article_id  \
# 0   Number of accidents In 2018, there were 3.1 m...           7
# 1   Household consumption Consumption expenditure...          13
# 2   Suicides on railways Suicides occurring on th...          16
# 3   Geographical location plays a key role in the...          17
# 4   Number of passengers transported by rail incr...          18
#
#                                           categories  year  \
# 0  [Accidents at work, Health, Health and safety,...  2020
# 1  [National accounts (incl. GDP), Statistical ar...  2021
# 2  [Rail, Statistical article, Transport, Transpo...  2021
# 3    [Freight, Rail, Statistical article, Transport]  2020
# 4  [Passengers, Rail, Statistical article, Transp...  2021
#
#                              themes                     sub_themes  \
# 0  Population and social conditions           Health;Labour market
# 1               Economy and finance  National accounts (incl. GDP)
# 2                         Transport
# 3                         Transport
# 4                         Transport
#
#                                         title tokens  \
# 0                              accid at work statist
# 1                             nation account and gdp
# 2                   railwai safeti statist in the eu
# 3                  railwai freight transport statist
# 4  railwai passeng transport statist quarterli an...
#
#                                       context tokens  \
# 0  safe healthi work environ is crucial factor in...
# 1  european institut govern central bank as well ...
# 2  nation rail network have differ technic specif...
# 3  the content of thi statist articl is base on d...
# 4  the content of thi statist articl is base on d...
#
#                                      abstract tokens  \
# 0  thi articl present set of main statist find in...
# 1  nation account ar the sourc for multitud of we...
# 2  in signific railwai accid were report in the e...
# 3  thi articl focus on recent rail freight transp...
# 4  thi articl take look at recent annual and quar...
#
#                                   raw content tokens
# 0  number of accid in there were million non fata...
# 1  household consumpt consumpt expenditur of hous...
# 2  suicid on railwai suicid occur on the railwai ...
# 3  geograph locat plai kei role in the share of i...
# 4  number of passeng transport by rail increas in...

# %% [markdown]
# ## E. All related resources from the Knowledge Database
# ***
# * Drop duplicates due to reference type.
# * Group by unique URI and put related titles and related URLs in columns with lists.

# %%
## DEFINE input:inference <https://ec.europa.eu/eurostat/NLP4StatRef/knowledge/>
RelationsStatements = """
PREFIX estat: <https://ec.europa.eu/eurostat/NLP4StatRef/ontology/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
select ?a ?t ?url ?ref ?ref_type ?ref_t ?ref_uri ?ref_url where { 
    # ?a rdf:type/rdfs:subClassOf* estat:StatisticsExplainedArticle .
    # ?a estat:title ?t .
    # ?a estat:hasURL ?url .
    # ?a estat:hasReference ?ref .
    # ?ref a ?ref_type .
    # ?ref estat:title ?ref_t .
    OPTIONAL {?ref estat:hasURI ?ref_uri} .
    # ?ref estat:hasURL ?ref_url .
} 
"""
## estat:GlossaryArticle OR StatisticsExplainedArticle
  
sparql.setQuery(RelationsStatements)
sparql.method = "POST"
sparql.setReturnFormat(JSON)
results = sparql.query().convert()['results']['bindings']
results = pd.json_normalize(results)
print(len(results))
print(results.columns)
#display(results)

results.drop_duplicates(subset=['a.value','t.value','url.value','ref_t.value','ref_url.value'],inplace=True)
print(len(results))
#results.to_excel('results.xlsx')
results2 = results.groupby(['a.value']).agg({'t.value': lambda x: x.iloc[0],'url.value': lambda x: x.iloc[0], \
                                             'ref_t.value':lambda x: list(x), 'ref_url.value':lambda x: list(x)}).reset_index()

print(len(results2))       
results2.to_excel('/content/drive/MyDrive/results2.xlsx')  
                                                                               
display(results2)
# Out:
# 13802
# Index(['a.type', 'a.value', 't.type', 't.value', 'url.type', 'url.datatype',
#        'url.value', 'ref.type', 'ref.value', 'ref_type.type', 'ref_type.value',
#        'ref_t.type', 'ref_t.value', 'ref_uri.type', 'ref_uri.value',
#        'ref_url.type', 'ref_url.datatype', 'ref_url.value'],
#       dtype='object')
# 13684
# 848
#                                                a.value  \
# 0    https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 1    https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 2    https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 3    https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 4    https://ec.europa.eu/eurostat/NLP4StatRef/know...
# ..                                                 ...
# 843  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 844  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 845  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 846  https://ec.europa.eu/eurostat/NLP4StatRef/know...
# 847  https://ec.europa.eu/eurostat/NLP4StatRef/know...
#
#                                                t.value  \
# 0    Merging statistics and geospatial information ...
# 1    Statistics in development cooperation coordina...
# 2    Statistics in development cooperation data ava...
# 3    Statistics in development cooperation interven...
# 4    Statistics in development cooperation national...
# ..                                                 ...
# 843   Short term business statistics observation units
# 844   Short term business statistics quality and scope
# 845           Short term business statistics revisions
# 846  Short term business statistics seasonal adjust...
# 847  Short term business statistics and annual chai...
#
#                                              url.value  \
# 0    https://ec.europa.eu/eurostat/statistics-expla...
# 1    https://ec.europa.eu/eurostat/statistics-expla...
# 2    https://ec.europa.eu/eurostat/statistics-expla...
# 3    https://ec.europa.eu/eurostat/statistics-expla...
# 4    https://ec.europa.eu/eurostat/statistics-expla...
# ..                                                 ...
# 843  https://ec.europa.eu/eurostat/statistics-expla...
# 844  https://ec.europa.eu/eurostat/statistics-expla...
# 845  https://ec.europa.eu/eurostat/statistics-expla...
# 846  https://ec.europa.eu/eurostat/statistics-expla...
# 847  https://ec.europa.eu/eurostat/statistics-expla...
#
#                                            ref_t.value  \
# 0                                       [Final report]
# 1    [Statistical cooperation, Statistics in develo...
# 2    [Statistical cooperation, Statistics in develo...
# 3    [Statistical cooperation, Statistics in develo...
# 4    [Statistical cooperation, Statistics in develo...
# ..                                                 ...
# 843  [All articles on short term business statistic...
# 844  [All articles on short term business statistic...
# 845  [All articles on short term business statistic...
# 846  [All articles on short term business statistic...
# 847  [All articles on short term business statistic...
#
#                                          ref_url.value
# 0    [https://circabc.europa.eu/sd/a/acd1a0f9-72c6-...
# 1    [https://ec.europa.eu/eurostat/statistics-expl...
# 2    [https://ec.europa.eu/eurostat/statistics-expl...
# 3    [https://ec.europa.eu/eurostat/statistics-expl...
# 4    [https://ec.europa.eu/eurostat/statistics-expl...
# ..                                                 ...
# 843  [https://ec.europa.eu/eurostat/statistics-expl...
# 844  [https://ec.europa.eu/eurostat/statistics-expl...
# 845  [https://ec.europa.eu/eurostat/statistics-expl...
# 846  [https://ec.europa.eu/eurostat/statistics-expl...
# 847  [https://ec.europa.eu/eurostat/statistics-expl...
#
# [848 rows x 5 columns]

# %%
del(results)

# %% [markdown]
# ### Merge with main file

# %%
print(SE_df.columns)
print(results2.columns)
SE_df2 = pd.merge(SE_df,results2,how='left',left_on='url',right_on='url.value')
print(SE_df2.columns)
#SE_df2.drop(columns=['a.value','related_titles','related_urls','t.value','url.value'],inplace=True)
SE_df2.drop(columns=['a.value','t.value','url.value'],inplace=True)
SE_df2.rename(columns={'ref_t.value':'related_titles','ref_url.value':'related_urls'},inplace=True)

SE_df2.sort_values(by=['title'],inplace=True)
display(SE_df2)
SE_df2.to_excel('SE_df2.xlsx')
# Out:
# Index(['id', 'context', 'title', 'abstract', 'url', 'raw content',
#        'article_id', 'categories', 'year', 'themes', 'sub_themes',
#        'title tokens', 'context tokens', 'abstract tokens',
#        'raw content tokens'],
#       dtype='object')
# Index(['a.value', 't.value', 'url.value', 'ref_t.value', 'ref_url.value'], dtype='object')
# Index(['id', 'context', 'title', 'abstract', 'url', 'raw content',
#        'article_id', 'categories', 'year', 'themes', 'sub_themes',
#        'title tokens', 'context tokens', 'abstract tokens',
#        'raw content tokens', 'a.value', 't.value', 'url.value', 'ref_t.value',
#        'ref_url.value'],
#       dtype='object')
#        id                                            context  \
# 589  9295  Trade is an important indicator of Europeas pr...
# 180  2905  The COVID-19 pandemic hit Europe in January an...
# 181  2914  The importance of action to prevent accidents ...
# 184  2946  A safe, healthy working environment is a cruci...
# 185  2947  A safe, healthy working environment is a cruci...
# ..    ...                                                ...
# 451  6945                                                NaN
# 454  6981  Housing conditions are a fundamental aspect of...
# 453  6967  Social exclusion at an early age has the poten...
# 452  6947  The European Commission's EU2020 Strategy has ...
# 85    748  Young people are a priority for the European U...
#
#                                                  title  \
# 589  ASEAN-EU - international trade in goods statis...
# 180          Absences from work - quarterly statistics
# 181                  Accidents and injuries statistics
# 184  Accidents at work - statistics by economic act...
# 185  Accidents at work - statistics on causes and c...
# ..                                                 ...
# 451                            World trade in services
# 454                  Young people - housing conditions
# 453                    Young people - social inclusion
# 452     Young people on the labour market - statistics
# 85                                  Youth unemployment
#
#                                               abstract  \
# 589  This article provides a picture of the interna...
# 180  Absences from work can be classified into two ...
# 181  This article presents an overview of European ...
# 184  This article presents a set of main statistica...
# 185  This article presents a set of main statistica...
# ..                                                 ...
# 451  Globalisation patterns in EU trade and investm...
# 454  This article analyses the housing conditions o...
# 453  This article presents statistics on the social...
# 452  This article presents some findings from a sur...
# 85   This article explains how youth unemployment i...
#
#                                                    url  \
# 589  https://ec.europa.eu/eurostat/statistics-expla...
# 180  https://ec.europa.eu/eurostat/statistics-expla...
# 181  https://ec.europa.eu/eurostat/statistics-expla...
# 184  https://ec.europa.eu/eurostat/statistics-expla...
# 185  https://ec.europa.eu/eurostat/statistics-expla...
# ..                                                 ...
# 451  https://ec.europa.eu/eurostat/statistics-expla...
# 454  https://ec.europa.eu/eurostat/statistics-expla...
# 453  https://ec.europa.eu/eurostat/statistics-expla...
# 452  https://ec.europa.eu/eurostat/statistics-expla...
# 85   https://ec.europa.eu/eurostat/statistics-expla...
#
#                                            raw content  article_id  \
# 589   ASEAN countries trade in goods with main part...        9295
# 180   Absences from work sharply increase in first ...        2905
# 181   Deaths from accidents, injuries and assault I...        2914
# 184   Analysis of non-fatal accidents by sex and ag...        2946
# 185   When combining several classifications fatal ...        2947
# ..                                                 ...         ...
# 451   International trade in services a overview St...        6945
# 454   Housing cost overburden rate In 2019, 10.6 % ...        6981
# 453   Living in households with very low work inten...        6967
# 452   Few move house or commute to find or to have ...        6947
# 85    Definition of unemployment and youth unemploy...         748
#
#                                             categories  year  \
# 589  [Non-EU countries, Trade in goods, Statistical...  2021
# 180   [Employment, Labour market, Statistical article]  2021
# 181       [Health, Health status, Statistical article]  2020
# 184  [Accidents at work, Health, Health and safety,...  2020
# 185  [Accidents at work, Health, Health and safety,...  2020
# ..                                                 ...   ...
# 451  [Statistical article, Globalisation, Internati...  2019
# 454  [Population, Statistical article, Youth, Livin...  2021
# 453  [Population, Statistical article, Youth, Livin...  2021
# 452  [Employment, Labour market - young people, Liv...  2021
# 85   [Labour market, Labour market background artic...  2021
#
#                                                 themes  \
# 589  International trade;General and regional stati...
# 180                   Population and social conditions
# 181                   Population and social conditions
# 184                   Population and social conditions
# 185                   Population and social conditions
# ..                                                 ...
# 451
# 454                   Population and social conditions
# 453                   Population and social conditions
# 452                   Population and social conditions
# 85                    Population and social conditions
#
#                              sub_themes  \
# 589                    Non-EU countries
# 180                       Labour market
# 181                              Health
# 184                Health;Labour market
# 185                Health;Labour market
# ..                                  ...
# 451
# 454  Living conditions;Youth;Population
# 453  Living conditions;Youth;Population
# 452  Living conditions;Youth;Population
# 85                  Youth;Labour market
#
#                                    title tokens  \
# 589       asean eu intern trade in good statist
# 180          absenc from work quarterli statist
# 181                    accid and injuri statist
# 184       accid at work statist by econom activ
# 185  accid at work statist on caus and circumst
# ..                                          ...
# 451                       world trade in servic
# 454                     young peopl hous condit
# 453                   young peopl social inclus
# 452    young peopl on the labour market statist
# 85                               youth unemploy
#
#                                         context tokens  \
# 589  trade is an import indic of europea prosper an...
# 180  the covid pandem hit europ in januari and febr...
# 181  the import of action to prevent accid and inju...
# 184  safe healthi work environ is crucial factor in...
# 185  safe healthi work environ is crucial factor in...
# ..                                                 ...
# 451
# 454  hous condit ar fundament aspect of live standa...
# 453  social exclus at an earli ag ha the potenti to...
# 452  the european commiss eu strategi ha sever goal...
# 85   young peopl ar prioriti for the european union...
#
#                                        abstract tokens  \
# 589  thi articl provid pictur of the intern trade i...
# 180  absenc from work can be classifi into two grou...
# 181  thi articl present an overview of european uni...
# 184  thi articl present set of main statist find in...
# 185  thi articl present set of main statist find in...
# ..                                                 ...
# 451  globalis pattern in eu trade and invest is an ...
# 454  thi articl analys the hous condit of young peo...
# 453  thi articl present statist on the social inclu...
# 452  thi articl present some find from survei on th...
# 85   thi articl explain how youth unemploy in the e...
#
#                                     raw content tokens  \
# 589  asean countri trade in good with main partner ...
# 180  absenc from work sharpli increas in first half...
# 181  death from accid injuri and assault in there w...
# 184  analysi of non fatal accid by sex and ag accid...
# 185  when combin sever classif fatal accid at work ...
# ..                                                 ...
# 451  intern trade in servic overview statist on int...
# 454  hous cost overburden rate in of the young popu...
# 453  live in household with veri low work intens th...
# 452  few move hous or commut to find or to have job...
# 85   definit of unemploy and youth unemploy indic p...
#
#                                         related_titles  \
# 589  [International trade in goods, Extra EU trade ...
# 180  [Tables and Figures update April 2021 xlsx, La...
# 181  [Causes of death statistics, Causes of death s...
# 184  [Accidents and injuries statistics, Accidents ...
# 185  [Accidents and injuries statistics, Accidents ...
# ..                                                 ...
# 451  [Globalisation patterns in EU trade and invest...
# 454  [Children at risk of poverty or social exclusi...
# 453  [Children at risk of poverty or social exclusi...
# 452  [EU Labour Force Survey, Employment and unempl...
# 85   [Education and training statistics introduced,...
#
#                                           related_urls
# 589  [https://ec.europa.eu/eurostat/statistics-expl...
# 180  [https://ec.europa.eu/eurostat/statistics-expl...
# 181  [https://ec.europa.eu/eurostat/statistics-expl...
# 184  [https://ec.europa.eu/eurostat/statistics-expl...
# 185  [https://ec.europa.eu/eurostat/statistics-expl...
# ..                                                 ...
# 451  [https://ec.europa.eu/eurostat/statistics-expl...
# 454  [https://ec.europa.eu/eurostat/statistics-expl...
# 453  [https://ec.europa.eu/eurostat/statistics-expl...
# 452  [https://ec.europa.eu/eurostat/statistics-expl...
# 85   [https://ec.europa.eu/eurostat/statistics-expl...
#
# [605 rows x 17 columns]

# %%
del(SE_df,results2)

# %% [markdown]
# ### Create a column *related_types* from the pattern in column *related_urls*

# %%
def recode_list(llist):
  new_list=[]
  for el in llist:
    ## print(el)
    if 'Glossary' in el:
      new_list.append('SE GL articles')
    elif 'statistics-explained/index.php' in el:  
      new_list.append('SE articles')
    elif 'eurostat/product' in el:        
      new_list.append('Publications')
    elif 'eur-lex.europa.eu' in el:        
      new_list.append('Legislation')
    else:
      new_list.append('Other')
  return new_list    

SE_df2['related_types'] = SE_df2['related_urls'].apply(lambda x: recode_list(x))
display(SE_df2)
# Out:
#        id                                            context  \
# 589  9295  Trade is an important indicator of Europeas pr...
# 180  2905  The COVID-19 pandemic hit Europe in January an...
# 181  2914  The importance of action to prevent accidents ...
# 184  2946  A safe, healthy working environment is a cruci...
# 185  2947  A safe, healthy working environment is a cruci...
# ..    ...                                                ...
# 451  6945                                                NaN
# 454  6981  Housing conditions are a fundamental aspect of...
# 453  6967  Social exclusion at an early age has the poten...
# 452  6947  The European Commission's EU2020 Strategy has ...
# 85    748  Young people are a priority for the European U...
#
#                                                  title  \
# 589  ASEAN-EU - international trade in goods statis...
# 180          Absences from work - quarterly statistics
# 181                  Accidents and injuries statistics
# 184  Accidents at work - statistics by economic act...
# 185  Accidents at work - statistics on causes and c...
# ..                                                 ...
# 451                            World trade in services
# 454                  Young people - housing conditions
# 453                    Young people - social inclusion
# 452     Young people on the labour market - statistics
# 85                                  Youth unemployment
#
#                                               abstract  \
# 589  This article provides a picture of the interna...
# 180  Absences from work can be classified into two ...
# 181  This article presents an overview of European ...
# 184  This article presents a set of main statistica...
# 185  This article presents a set of main statistica...
# ..                                                 ...
# 451  Globalisation patterns in EU trade and investm...
# 454  This article analyses the housing conditions o...
# 453  This article presents statistics on the social...
# 452  This article presents some findings from a sur...
# 85   This article explains how youth unemployment i...
#
#                                                    url  \
# 589  https://ec.europa.eu/eurostat/statistics-expla...
# 180  https://ec.europa.eu/eurostat/statistics-expla...
# 181  https://ec.europa.eu/eurostat/statistics-expla...
# 184  https://ec.europa.eu/eurostat/statistics-expla...
# 185  https://ec.europa.eu/eurostat/statistics-expla...
# ..                                                 ...
# 451  https://ec.europa.eu/eurostat/statistics-expla...
# 454  https://ec.europa.eu/eurostat/statistics-expla...
# 453  https://ec.europa.eu/eurostat/statistics-expla...
# 452  https://ec.europa.eu/eurostat/statistics-expla...
# 85   https://ec.europa.eu/eurostat/statistics-expla...
#
#                                            raw content  article_id  \
# 589   ASEAN countries trade in goods with main part...        9295
# 180   Absences from work sharply increase in first ...        2905
# 181   Deaths from accidents, injuries and assault I...        2914
# 184   Analysis of non-fatal accidents by sex and ag...        2946
# 185   When combining several classifications fatal ...        2947
# ..                                                 ...         ...
# 451   International trade in services a overview St...        6945
# 454   Housing cost overburden rate In 2019, 10.6 % ...        6981
# 453   Living in households with very low work inten...        6967
# 452   Few move house or commute to find or to have ...        6947
# 85    Definition of unemployment and youth unemploy...         748
#
#                                             categories  year  \
# 589  [Non-EU countries, Trade in goods, Statistical...  2021
# 180   [Employment, Labour market, Statistical article]  2021
# 181       [Health, Health status, Statistical article]  2020
# 184  [Accidents at work, Health, Health and safety,...  2020
# 185  [Accidents at work, Health, Health and safety,...  2020
# ..                                                 ...   ...
# 451  [Statistical article, Globalisation, Internati...  2019
# 454  [Population, Statistical article, Youth, Livin...  2021
# 453  [Population, Statistical article, Youth, Livin...  2021
# 452  [Employment, Labour market - young people, Liv...  2021
# 85   [Labour market, Labour market background artic...  2021
#
#                                                 themes  \
# 589  International trade;General and regional stati...
# 180                   Population and social conditions
# 181                   Population and social conditions
# 184                   Population and social conditions
# 185                   Population and social conditions
# ..                                                 ...
# 451
# 454                   Population and social conditions
# 453                   Population and social conditions
# 452                   Population and social conditions
# 85                    Population and social conditions
#
#                              sub_themes  \
# 589                    Non-EU countries
# 180                       Labour market
# 181                              Health
# 184                Health;Labour market
# 185                Health;Labour market
# ..                                  ...
# 451
# 454  Living conditions;Youth;Population
# 453  Living conditions;Youth;Population
# 452  Living conditions;Youth;Population
# 85                  Youth;Labour market
#
#                                    title tokens  \
# 589       asean eu intern trade in good statist
# 180          absenc from work quarterli statist
# 181                    accid and injuri statist
# 184       accid at work statist by econom activ
# 185  accid at work statist on caus and circumst
# ..                                          ...
# 451                       world trade in servic
# 454                     young peopl hous condit
# 453                   young peopl social inclus
# 452    young peopl on the labour market statist
# 85                               youth unemploy
#
#                                         context tokens  \
# 589  trade is an import indic of europea prosper an...
# 180  the covid pandem hit europ in januari and febr...
# 181  the import of action to prevent accid and inju...
# 184  safe healthi work environ is crucial factor in...
# 185  safe healthi work environ is crucial factor in...
# ..                                                 ...
# 451
# 454  hous condit ar fundament aspect of live standa...
# 453  social exclus at an earli ag ha the potenti to...
# 452  the european commiss eu strategi ha sever goal...
# 85   young peopl ar prioriti for the european union...
#
#                                        abstract tokens  \
# 589  thi articl provid pictur of the intern trade i...
# 180  absenc from work can be classifi into two grou...
# 181  thi articl present an overview of european uni...
# 184  thi articl present set of main statist find in...
# 185  thi articl present set of main statist find in...
# ..                                                 ...
# 451  globalis pattern in eu trade and invest is an ...
# 454  thi articl analys the hous condit of young peo...
# 453  thi articl present statist on the social inclu...
# 452  thi articl present some find from survei on th...
# 85   thi articl explain how youth unemploy in the e...
#
#                                     raw content tokens  \
# 589  asean countri trade in good with main partner ...
# 180  absenc from work sharpli increas in first half...
# 181  death from accid injuri and assault in there w...
# 184  analysi of non fatal accid by sex and ag accid...
# 185  when combin sever classif fatal accid at work ...
# ..                                                 ...
# 451  intern trade in servic overview statist on int...
# 454  hous cost overburden rate in of the young popu...
# 453  live in household with veri low work intens th...
# 452  few move hous or commut to find or to have job...
# 85   definit of unemploy and youth unemploy indic p...
#
#                                         related_titles  \
# 589  [International trade in goods, Extra EU trade ...
# 180  [Tables and Figures update April 2021 xlsx, La...
# 181  [Causes of death statistics, Causes of death s...
# 184  [Accidents and injuries statistics, Accidents ...
# 185  [Accidents and injuries statistics, Accidents ...
# ..                                                 ...
# 451  [Globalisation patterns in EU trade and invest...
# 454  [Children at risk of poverty or social exclusi...
# 453  [Children at risk of poverty or social exclusi...
# 452  [EU Labour Force Survey, Employment and unempl...
# 85   [Education and training statistics introduced,...
#
#                                           related_urls  \
# 589  [https://ec.europa.eu/eurostat/statistics-expl...
# 180  [https://ec.europa.eu/eurostat/statistics-expl...
# 181  [https://ec.europa.eu/eurostat/statistics-expl...
# 184  [https://ec.europa.eu/eurostat/statistics-expl...
# 185  [https://ec.europa.eu/eurostat/statistics-expl...
# ..                                                 ...
# 451  [https://ec.europa.eu/eurostat/statistics-expl...
# 454  [https://ec.europa.eu/eurostat/statistics-expl...
# 453  [https://ec.europa.eu/eurostat/statistics-expl...
# 452  [https://ec.europa.eu/eurostat/statistics-expl...
# 85   [https://ec.europa.eu/eurostat/statistics-expl...
#
#                                          related_types
# 589  [SE articles, SE articles, SE articles, Other,...
# 180  [Other, SE articles, SE articles, Other, Other...
# 181  [SE articles, SE articles, SE articles, SE art...
# 184  [SE articles, SE articles, SE articles, SE art...
# 185  [SE articles, SE articles, SE articles, SE art...
# ..                                                 ...
# 451  [SE articles, Other, Other, Other, Other, Othe...
# 454  [SE articles, SE articles, SE articles, SE art...
# 453  [SE articles, SE articles, SE articles, SE art...
# 452  [SE articles, Other, Other, Other, Other, Othe...
# 85   [SE articles, SE articles, SE articles, SE art...
#
# [605 rows x 18 columns]

# %% [markdown]
# ## F. Facets
# ***
# ### The function filtering the results.

# %%
# from ipywidgets.widgets.widget_string import Password
df1 = None

def articles(Top_articles, Keywords, Categories, themes_dd, sub_themes_dd,year,related): 

    global df1
    Keywords = text_to_words(Keywords) 

    df1 = SE_df2[SE_df2['title tokens'].str.contains(Keywords,regex=False) | SE_df2['raw content tokens'].str.contains(Keywords,regex=False)]
    df1 = df1[df1['context tokens'].str.contains(Keywords,regex=False) | df1['abstract tokens'].str.contains(Keywords,regex=False)]
    
    if year != "All years":    
        df1 = df1[df1['year'].str.contains(year)]    
        
        
    if themes_dd != "All themes":
        df1 = df1[df1['themes'].str.contains(themes_dd,regex=False)]
        

    if sub_themes_dd is not None:
        if sub_themes_dd != "All sub-themes" and sub_themes_dd != "":    
            df1 = df1[df1['sub_themes'].str.contains(sub_themes_dd,regex=False)]
    
    if Categories is not None:
        if Categories != "All categories":
            
            df1 = df1[df1['categories'].apply(lambda x: Categories in x)]
 
          
    if len(df1) == 0:
        print("No matches found")
    else:
        df1.reset_index(inplace=True)
        print(df1.title.count()," articles found")
        h = ''
        for i in range(min(Top_articles,len(df1))):
            l,n = df1.loc[i,["url","title"]].values
            h += '<br><br/><u><b><a href="' + l + '" target="_blank">'+ n + '</a></b></u>'
            if related:
                h += '<blockquote>Related links:'
                for type_group in ['SE articles','SE GL articles','Publications','Legislation','Other']:
                    found = False
                    for k in range(len(df1.loc[i,"related_titles"])):  
                        type_k = df1.loc[i,"related_types"][k]
                        if type_k == type_group:
                            if not found: ## exists, first line
                                h += '<blockquote>'+type_k+'</blockquote>'
                                found = True
                            ## exists, first or next lines   
                            title = df1.loc[i,"related_titles"][k]
                            url = df1.loc[i,"related_urls"][k]
                            h += '<blockquote><blockquote><a href="' + url + '" target="_blank">'+ title + '</a></blockquote></blockquote>'
                h += '</blockquote>'
        display(HTML( h))

# %% [markdown]
# ### The widgets.

# %%
from IPython.display import display
from ipywidgets import HTML
layout = widgets.Layout(width='500px', height='500px')

# %%
def new_categories():
    if len(df1) > 0:
        res=set()
        for i in range(len(df1)):
            res.update(df1.loc[i,'categories'])
        return sorted(list(res))
    else:
        return []
    
    

def query_build2(themes):
    style = {'description_width': 'initial'}

    Categories = widgets.Dropdown(
        description='Select category:',
        options=['All categories'] + sorted(list(dict_categories.keys())),
        style=style
    )
    
    
    themes_dd = widgets.Dropdown(
        description='Select theme:',
        options=['All themes']+sorted([k for k in themes.keys()]),
        style=style
    )    
    

    def on_change_theme(change):
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'All themes':
                sub_themes_dd.options = []
                Categories.options = ['All categories']+sorted(list(dict_categories.keys()))
            else:    
                sub_themes_dd.options = ['All sub-themes']+themes[themes_dd.value]
                
                

    themes_dd.observe(on_change_theme)
    
    sub_themes_dd = widgets.Dropdown(
        description='Select sub-theme:',
        options= [''],
        style=style
    )    
    
    def on_change_subtheme(change):
        if change['type'] == 'change' and change['name'] == 'value':
            Categories.options= []
            Categories.options = ['All categories']+new_categories()

    sub_themes_dd.observe(on_change_subtheme)
 
    Top_articles = widgets.IntSlider(
        description='Display',
        tooltip='maximum:',
        value=20,
        min=1, 
        max = 30,
        style={'description_width': 'initial'}
    )


    Keywords = widgets.Text(
        value='',
        placeholder='Type something',
        description='Keywords:',
        disabled=False
    )
    

    year = widgets.Dropdown(
        options=['All years','2021','2020','2019','2018','Not found'],
        value='All years',
        description='Year:',
        disabled=False)


    
    related = widgets.Checkbox(
        value=False,
        description='Show related links',
        disabled=False,
        indent=True
     )    
    
    out = widgets.interactive_output(articles, {'Top_articles': Top_articles, 'Keywords': Keywords, 'Categories':Categories,
                                              'themes_dd':themes_dd,'sub_themes_dd':sub_themes_dd,'year':year,'related':related})

    print(Top_articles)


    left_box = widgets.VBox([themes_dd, sub_themes_dd])
    right_box = widgets.VBox([Keywords,Categories,related])
    box = widgets.HBox([left_box, right_box])
    display(box)
    
    display(year,Top_articles,out)
    
        
query_build2(themes)
# Out:
# IntSlider(value=20, description='Display', max=30, min=1, style=SliderStyle(description_width='initial'))
# HBox(children=(VBox(children=(Dropdown(description='Select theme:', options=('All themes', 'Agriculture, fores…
# Dropdown(description='Year:', options=('All years', '2021', '2020', '2019', '2018', 'Not found'), value='All y…
# IntSlider(value=20, description='Display', max=30, min=1, style=SliderStyle(description_width='initial'))
# Output()
